# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import shutil
import keras
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
from glob import glob
trn='D:/D-Video/PennA/Penn_Action/*/'
tr= glob(trn)
len(tr)
# Out:
# 15

# %%
train = []
val = []
test = []
train_y = []
val_y = []
test_y = []

y = 0
for i in tr:
    
    #print(i)
    x = glob(i+'/*/')
    
    #shuffle(x)
    t,tt = train_test_split( x , test_size=0.1, random_state=42)
    t, vv = train_test_split( t , test_size=0.1, random_state=42)
    
    for j in t:
        
        mm = len(glob(j+'/*'))
        
        if(mm<10):
            continue
        
        train.append(j)
        train_y.append(y)
    
    for j in vv:
        
        mm = len(glob(j+'/*'))
        
        if(mm<10):
            continue
            
        val.append(j)
        val_y.append(y)
        
    for j in tt:
        
        mm = len(glob(j+'/*'))
        
        if(mm<10):
            continue
            
        test.append(j)
        test_y.append(y)
        
    y = y+1

from tensorflow.keras.utils import to_categorical
tra_y =  np.array(to_categorical(train_y))
va_y  =  np.array(to_categorical(val_y))
te_y  =  np.array(to_categorical(test_y))

(train, tra_y) = shuffle(train, tra_y)
(val, va_y) = shuffle(val, va_y)
(test, te_y) = shuffle(test, te_y)

# %%
len(test)
# Out:
# 239

# %%
def get_te(k , a) :
    x = glob(k+'/*')
    imgdata=[]
    for i in range(0,15):
        
        a = Image.open(x[i])
        b = a.resize((48, 48))
        c = np.array(b)
        imgdata.append(c.reshape(48, 48,3))
        
    idata = np.array(imgdata)
    X_train = idata
    X_train = X_train.astype('float32') / 255.
    #print(np.shape(X_train))
    return X_train

def get_cat(k) :
    return np.array(k)

# %%
class My_Custom_Generator(keras.utils.Sequence) :
  
  def __init__(self, filename , labels, batch_size) :
    self.filename = filename
    self.labels = labels
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.filename) / float(self.batch_size))).astype(int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.filename[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
    y_train = get_cat(batch_y)
    i=0
    return np.array([get_te(i,self.filename)for i in batch_x]), np.array( y_train )

# %%
class My_Test_Generator(keras.utils.Sequence) :
  
  def __init__(self, filename , batch_size) :
    self.filename = filename
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.filename) / float(self.batch_size))).astype(int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.filename[idx * self.batch_size : (idx+1) * self.batch_size]
    i=0
    return np.array([get_te(i,self.filename)for i in batch_x])

# %%
batch_size = 16

my_training_batch_generator = My_Custom_Generator(train, tra_y, batch_size)
my_validation_batch_generator = My_Custom_Generator(val, va_y, batch_size)

# %%
arr = np.array(My_Test_Generator(test, batch_size).__getitem__(1))
for i in range(2,len(x)):
    x = My_Test_Generator(test, batch_size).__getitem__(i)
    arr = np.concatenate((arr,x),axis=0)

# %%
np.shape(arr)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed, Conv2D, MaxPooling2D, Flatten, LSTM, Dense

num_frames = 15
frame_height = 48
frame_width = 48
num_channels = 3
num_classes = 15  # Change this to the number of classes in your dataset

model = Sequential()

# CNN
model.add(TimeDistributed(Conv2D(64, (3, 3), activation='relu'), input_shape=(num_frames, frame_height, frame_width, num_channels)))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(TimeDistributed(Conv2D(32, (3, 3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(TimeDistributed(Conv2D(16, (3, 3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(TimeDistributed(Conv2D(8, (3, 3), activation='relu')))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(TimeDistributed(Flatten()))

# LSTM
model.add(LSTM(50))

# Fully connected layer
model.add(Dense(num_classes, activation='softmax'))

model.summary()

# %%
model.compile(optimizer="Adam", loss='categorical_crossentropy', metrics='accuracy')
model.fit_generator(generator=my_training_batch_generator, epochs = 50,validation_data = my_validation_batch_generator)
# Out:
# C:\Users\shaif\AppData\Local\Temp\ipykernel_14828\1958852391.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator=my_training_batch_generator, epochs = 50,validation_data = my_validation_batch_generator)
# Epoch 1/50
# 118/118 [==============================] - 240s 2s/step - loss: 2.6741 - accuracy: 0.0880 - val_loss: 2.6539 - val_accuracy: 0.1315
# Epoch 2/50
# 118/118 [==============================] - 71s 602ms/step - loss: 2.6494 - accuracy: 0.1099 - val_loss: 2.6174 - val_accuracy: 0.1174
# Epoch 3/50
# 118/118 [==============================] - 66s 562ms/step - loss: 2.5701 - accuracy: 0.1377 - val_loss: 2.4762 - val_accuracy: 0.1878
# Epoch 4/50
# 118/118 [==============================] - 68s 577ms/step - loss: 2.4450 - accuracy: 0.1633 - val_loss: 2.2975 - val_accuracy: 0.1972
# Epoch 5/50
# 118/118 [==============================] - 232s 2s/step - loss: 2.3405 - accuracy: 0.2022 - val_loss: 2.2329 - val_accuracy: 0.1925
# Epoch 6/50
# 118/118 [==============================] - 264s 2s/step - loss: 2.2517 - accuracy: 0.2401 - val_loss: 2.1993 - val_accuracy: 0.2441
# Epoch 7/50
# 118/118 [==============================] - 69s 583ms/step - loss: 2.1753 - accuracy: 0.2556 - val_loss: 2.1486 - val_accuracy: 0.2488
# Epoch 8/50
# 118/118 [==============================] - 67s 564ms/step - loss: 2.1257 - accuracy: 0.2791 - val_loss: 2.1408 - val_accuracy: 0.2488
# Epoch 9/50
# 118/118 [==============================] - 68s 571ms/step - loss: 2.0515 - accuracy: 0.3036 - val_loss: 2.1658 - val_accuracy: 0.2488
# Epoch 10/50
# 118/118 [==============================] - 75s 640ms/step - loss: 2.0274 - accuracy: 0.3036 - val_loss: 2.1185 - val_accuracy: 0.2535
# Epoch 11/50
# 118/118 [==============================] - 68s 577ms/step - loss: 1.9539 - accuracy: 0.3319 - val_loss: 2.0736 - val_accuracy: 0.3146
# Epoch 12/50
# 118/118 [==============================] - 70s 593ms/step - loss: 1.9266 - accuracy: 0.3319 - val_loss: 2.0643 - val_accuracy: 0.2629
# Epoch 13/50
# 118/118 [==============================] - 76s 640ms/step - loss: 1.8765 - accuracy: 0.3639 - val_loss: 2.0524 - val_accuracy: 0.2676
# Epoch 14/50
# 118/118 [==============================] - 67s 563ms/step - loss: 1.8360 - accuracy: 0.3634 - val_loss: 2.0286 - val_accuracy: 0.2723
# Epoch 15/50
# 118/118 [==============================] - 69s 582ms/step - loss: 1.7636 - accuracy: 0.3986 - val_loss: 2.0961 - val_accuracy: 0.2864
# Epoch 16/50
# 118/118 [==============================] - 75s 635ms/step - loss: 1.7450 - accuracy: 0.3954 - val_loss: 2.1208 - val_accuracy: 0.2911
# Epoch 17/50
# 118/118 [==============================] - 72s 606ms/step - loss: 1.7181 - accuracy: 0.4109 - val_loss: 2.0477 - val_accuracy: 0.2911
# Epoch 18/50
# 118/118 [==============================] - 68s 579ms/step - loss: 1.6379 - accuracy: 0.4381 - val_loss: 1.9894 - val_accuracy: 0.3192
# Epoch 19/50
# 118/118 [==============================] - 69s 587ms/step - loss: 1.6196 - accuracy: 0.4296 - val_loss: 2.0506 - val_accuracy: 0.3099
# Epoch 20/50
# 118/118 [==============================] - 79s 670ms/step - loss: 1.5537 - accuracy: 0.4573 - val_loss: 2.0278 - val_accuracy: 0.3239
# Epoch 21/50
# 118/118 [==============================] - 64s 539ms/step - loss: 1.5369 - accuracy: 0.4621 - val_loss: 2.0071 - val_accuracy: 0.3192
# Epoch 22/50
# 118/118 [==============================] - 66s 557ms/step - loss: 1.5344 - accuracy: 0.4642 - val_loss: 1.9852 - val_accuracy: 0.3333
# Epoch 23/50
# 118/118 [==============================] - 76s 644ms/step - loss: 1.4567 - accuracy: 0.4936 - val_loss: 2.0754 - val_accuracy: 0.2817
# Epoch 24/50
# 118/118 [==============================] - 64s 540ms/step - loss: 1.4400 - accuracy: 0.4947 - val_loss: 2.0296 - val_accuracy: 0.3333
# Epoch 25/50
# 118/118 [==============================] - 74s 629ms/step - loss: 1.4010 - accuracy: 0.5187 - val_loss: 2.0928 - val_accuracy: 0.3474
# Epoch 26/50
# 118/118 [==============================] - 74s 621ms/step - loss: 1.3769 - accuracy: 0.5256 - val_loss: 2.0773 - val_accuracy: 0.3521
# Epoch 27/50
# 118/118 [==============================] - 72s 607ms/step - loss: 1.3340 - accuracy: 0.5464 - val_loss: 2.0607 - val_accuracy: 0.3192
# Epoch 28/50
# 118/118 [==============================] - 72s 606ms/step - loss: 1.3307 - accuracy: 0.5240 - val_loss: 2.0955 - val_accuracy: 0.3380
# Epoch 29/50
# 118/118 [==============================] - 74s 622ms/step - loss: 1.2875 - accuracy: 0.5496 - val_loss: 2.0618 - val_accuracy: 0.3474
# Epoch 30/50
# 118/118 [==============================] - 81s 683ms/step - loss: 1.2194 - accuracy: 0.5763 - val_loss: 2.0845 - val_accuracy: 0.3615
# Epoch 31/50
# 118/118 [==============================] - 70s 594ms/step - loss: 1.1703 - accuracy: 0.5977 - val_loss: 2.1270 - val_accuracy: 0.3146
# Epoch 32/50
# 118/118 [==============================] - 68s 572ms/step - loss: 1.1680 - accuracy: 0.5971 - val_loss: 2.2078 - val_accuracy: 0.3052
# Epoch 33/50
# 118/118 [==============================] - 79s 669ms/step - loss: 1.1312 - accuracy: 0.6062 - val_loss: 2.1727 - val_accuracy: 0.3474
# Epoch 34/50
# 118/118 [==============================] - 66s 561ms/step - loss: 1.1073 - accuracy: 0.6195 - val_loss: 2.1677 - val_accuracy: 0.3474
# Epoch 35/50
# 118/118 [==============================] - 68s 575ms/step - loss: 1.1150 - accuracy: 0.6179 - val_loss: 2.1886 - val_accuracy: 0.3615
# Epoch 36/50
# 118/118 [==============================] - 75s 631ms/step - loss: 1.0586 - accuracy: 0.6323 - val_loss: 2.1758 - val_accuracy: 0.3615
# Epoch 37/50
# 118/118 [==============================] - 74s 625ms/step - loss: 1.0462 - accuracy: 0.6254 - val_loss: 2.1995 - val_accuracy: 0.3521
# Epoch 38/50
# 118/118 [==============================] - 76s 643ms/step - loss: 0.9580 - accuracy: 0.6601 - val_loss: 2.3274 - val_accuracy: 0.3146
# Epoch 39/50
# 118/118 [==============================] - 84s 715ms/step - loss: 1.0122 - accuracy: 0.6467 - val_loss: 2.2571 - val_accuracy: 0.3474
# Epoch 40/50
# 118/118 [==============================] - 81s 683ms/step - loss: 0.9564 - accuracy: 0.6702 - val_loss: 2.2436 - val_accuracy: 0.3615
# Epoch 41/50
# 118/118 [==============================] - 73s 617ms/step - loss: 0.9003 - accuracy: 0.6793 - val_loss: 2.2836 - val_accuracy: 0.3568
# Epoch 42/50
# 118/118 [==============================] - 84s 716ms/step - loss: 0.9036 - accuracy: 0.6798 - val_loss: 2.2962 - val_accuracy: 0.3192
# Epoch 43/50
# 118/118 [==============================] - 78s 659ms/step - loss: 0.8639 - accuracy: 0.7145 - val_loss: 2.2869 - val_accuracy: 0.3850
# Epoch 44/50
# 118/118 [==============================] - 72s 607ms/step - loss: 0.9144 - accuracy: 0.6798 - val_loss: 2.2841 - val_accuracy: 0.3662
# Epoch 45/50
# 118/118 [==============================] - 85s 720ms/step - loss: 0.8413 - accuracy: 0.7044 - val_loss: 2.3037 - val_accuracy: 0.3897
# Epoch 46/50
# 118/118 [==============================] - 73s 615ms/step - loss: 0.8279 - accuracy: 0.7231 - val_loss: 2.3640 - val_accuracy: 0.3286
# Epoch 47/50
# 118/118 [==============================] - 72s 609ms/step - loss: 0.8323 - accuracy: 0.7145 - val_loss: 2.3220 - val_accuracy: 0.3521
# Epoch 48/50
# 118/118 [==============================] - 78s 663ms/step - loss: 0.7107 - accuracy: 0.7641 - val_loss: 2.4364 - val_accuracy: 0.3662
# Epoch 49/50
# 118/118 [==============================] - 69s 585ms/step - loss: 0.7200 - accuracy: 0.7572 - val_loss: 2.4622 - val_accuracy: 0.3474
# Epoch 50/50
# 118/118 [==============================] - 69s 585ms/step - loss: 0.7213 - accuracy: 0.7625 - val_loss: 2.4778 - val_accuracy: 0.3756
