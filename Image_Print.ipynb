# %%
import pickle

# File path
file_path = r"F:\combo_lists\limuc_combo_list.pickle"

# Load the list from the pickle file
with open(file_path, 'rb') as file:
    combo_list = pickle.load(file)

# Print the top 10 elements
print("Top 10 elements:")
for element in combo_list[:10]:
    print(element)
# Out:
# Top 10 elements:
# F:/imagenet21k_resized/imagenet21k_train\n00007846\
# F:/imagenet21k_resized/imagenet21k_train\n00007846\
# F:/imagenet21k_resized/imagenet21k_train\n00440941\
# F:/imagenet21k_resized/imagenet21k_train\n00007846\
# F:/imagenet21k_resized/imagenet21k_train\n00021265\
# F:/imagenet21k_resized/imagenet21k_train\n00440941\
# F:/imagenet21k_resized/imagenet21k_train\n00445802\
# F:/imagenet21k_resized/imagenet21k_train\n00446311\
# F:/imagenet21k_resized/imagenet21k_train\n00446493\
# F:/imagenet21k_resized/imagenet21k_train\n00446804\

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import pickle

# Load the combo list
file_path = r"F:\combo_lists\ofx_combo_list.pickle"
with open(file_path, 'rb') as file:
    combo_list = pickle.load(file)

# Function to load and display images
def load_and_display_images(directories, num_images=5, size=64):
    plt.figure(figsize=(10, 10))
    for i, directory in enumerate(directories, 1):
        image_files = os.listdir(directory)
        num_images = min(num_images, len(image_files))
        for j in range(num_images):
            image_path = os.path.join(directory, image_files[j])
            image = Image.open(image_path)
            image = image.resize((size, size), Image.ANTIALIAS)
            plt.subplot(len(directories), num_images, (i-1)*num_images + j + 1)
            plt.imshow(image)
            plt.axis('off')
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()

# Directories to display images from
directories = combo_list[140:150]

# Display all images together
load_and_display_images(directories, size=64)
# Out:
# C:\Users\shaif\AppData\Local\Temp\ipykernel_208\2218950386.py:20: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   image = image.resize((size, size), Image.ANTIALIAS)
