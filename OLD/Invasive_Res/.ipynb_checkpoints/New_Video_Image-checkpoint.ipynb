# %%
import glob
invasive_dirs = [
    r'D:\VeligerData\Baylor 2022-03-21_2\Veligers',
    r'D:\VeligerData\invasive',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1 To Baylor\Preserved Zebra Ped 1 To Baylor\Sorted Images\Pedi-Zebra Veligers',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1a To Baylor\Preserved Zebra Ped 1a To Baylor\Sorted Images\Preserved Zebra Ped 1a',
    
    ]

# Non-Invasive category
non_invasive_dirs = [
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Not',
    r'D:\VeligerData\Baylor 2022-03-21_2\NonVeligers\Images_001',
    r'D:\VeligerData\noninvasive',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1 To Baylor\Preserved Ostracods 1 To Baylor\Sorted Images\Not',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1a To Baylor\Preserved Ostracods 1a To Baylor\Sorted Images\Not',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1 To Baylor\Preserved Zebra Ped 1 To Baylor\Sorted Images\Not',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Not',
    ]

# Ostracod category
ostracod_dirs = [
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1 To Baylor\Preserved Ostracods 1 To Baylor\Sorted Images\Preserve Ostracods',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1a To Baylor\Preserved Ostracods 1a To Baylor\Sorted Images\Preserved Ostracods 1a',
    r'D:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Ostracod Image1\Ostracods1',
    r'D:\VeligerData\Ostracods Day 2 Image1 To Baylor\Ostracods',
   ]


# List to store subdirectories
invasive_subdirs = []
non_invasive_subdirs = []
ostracod_subdirs = []

# Collect subdirectories in the invasive category
for invasive_dir in invasive_dirs:
    invasive_subdirs.extend(glob.glob(invasive_dir))

# Collect subdirectories in the non-invasive category
for non_invasive_dir in non_invasive_dirs:
    non_invasive_subdirs.extend(glob.glob(non_invasive_dir))
    
for ostracod_dir in ostracod_dirs:
    ostracod_subdirs.extend(glob.glob(ostracod_dir))

# %%
import glob
from PIL import Image
import os

# List of directories in x
x = non_invasive_subdirs

# List to store subdirectories
y1 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y1.extend(subdirectories)

import glob

# List of directories in x
x = invasive_subdirs

# List to store subdirectories
y2 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y2.extend(subdirectories)

    
import glob

# List of directories in x
x = ostracod_subdirs

# List to store subdirectories
y3 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y3.extend(subdirectories)

import os
import numpy as np
from PIL import Image

def preprocess_images(y1, label_num, target_size=(28, 28)):
    # List to store preprocessed images
    images = []

    # List to store labels for each directory
    labels = []

    # Loop through each directory in y1
    for directory in y1:
        # Count the number of images processed for this directory
        images_processed = 0

        # List to store images for this directory
        directory_images = []

        # Loop through the files in the directory
        for root, dirs, files in os.walk(directory):
            for file in files:
                # Check if the file has an image extension
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    try:
                        # Read the image using PIL
                        image = Image.open(os.path.join(root, file))
                        # Resize the image using PIL's resize function
                        image = image.resize(target_size)
                        # Convert to numpy array and normalize
                        image = np.array(image) / 255.0
                        # Add the image to the directory_images list
                        directory_images.append(image)

                        # Increment the count of processed images for this directory
                        images_processed += 1

                        # If we've processed 5 images for this directory, break out of the loop
                        if images_processed >= 5:
                            break

                    except Exception as e:
                        print(f"Error processing image: {os.path.join(root, file)}. Skipping...")

            # If we've processed 5 images for this directory, break out of the loop
            if images_processed >= 5:
                break

        # Stack the images for this directory and append to the images list
        if directory_images:
            directory_images = np.array(directory_images)
            images.append(directory_images)
            labels.append(label_num)

    # Stack the images for all directories
    images = np.array(images)

    # Convert labels to numpy array
    labels = np.array(labels)

    return images, labels

  

X0,Y0 = preprocess_images(y1, label_num = 0)
X1,Y1 = preprocess_images(y2, label_num = 1)
X2,Y2 = preprocess_images(y3, label_num = 2)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Concatenate the image arrays
train_images = np.concatenate((X0, X1, X2), axis=0)

# Combine the label arrays
train_labels = np.concatenate((Y0, Y1, Y2), axis=0)

# Convert the labels to categorical
train_labels_categorical = to_categorical(train_labels)

# Set the dtype of train_images to float32
train_images = train_images.astype('float32')

# Split the data into train and test sets
from sklearn.utils import shuffle


train_images, train_labels_categorical = shuffle(train_images, train_labels_categorical)

# Now the shuffled data is assigned to the same variable names

X_train, X_test, Y_train, Y_test = train_test_split(train_images, train_labels_categorical, test_size=0.05, random_state=42)

# %%
np.shape(Y_train)
# Out:
# (13, 3)

# %%
DATASET_NAME = "organmnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = ( 5, 28, 28, 3 )
NUM_CLASSES = 2

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 60

# TUBELET EMBEDDING
PATCH_SIZE = (4, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 32
NUM_HEADS = 2
NUM_LAYERS = 2

#Patch Encoder with Conv2D ,  LSTM , Pos_Emd
from tensorflow.keras import layers
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim, **kwargs):
        super(PatchEncoder, self).__init__(**kwargs)
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.projection =keras.Sequential(
            [
                (layers.Conv2D(2, (3, 3), strides=(1,1),activation='relu')),
                TimeDistributed(MaxPooling2D(2,2)),
                TimeDistributed(Flatten()),
                layers.Dense(projection_dim)
            ]) 
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        
    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "projection_dim": self.projection_dim,
        })
        return config

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded 
    
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
import keras

inputs = layers.Input(shape= (5,28,28,3) )

encoded_patches = (PatchEncoder(5, 32 )) (inputs)

for _ in range(6):
    
    x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)

    attention_output= layers.MultiHeadAttention (  num_heads=6, key_dim=32, dropout=0.1 )  (x1, x1)
    
    lstm_output =  LSTM(32,return_sequences=True,dropout=0.1)(x1)

    x2 = layers.Add()([attention_output, encoded_patches,lstm_output])

        # Layer Normalization and MLP
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)


    x3 = keras.Sequential(layers.Dense(units=32, activation=tf.nn.gelu) )(x3)

        # Skip connection
    encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)

representation = layers.GlobalAvgPool1D()(representation)

#representation = LSTM(100,return_sequences=False,dropout=0.1)(representation)

outputs = layers.Dense(units=3, activation="softmax") ( representation)

model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 5, 28, 28,   0           []
#                                 3)]
#
#  patch_encoder_2 (PatchEncoder)  (None, 5, 32)       11064       ['input_3[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 5, 32)       64          ['patch_encoder_2[0][0]']
#  ormalization)
#
#  multi_head_attention_6 (MultiH  (None, 5, 32)       25184       ['layer_normalization_13[0][0]',
#  eadAttention)                                                    'layer_normalization_13[0][0]']
#
#  lstm_6 (LSTM)                  (None, 5, 32)        8320        ['layer_normalization_13[0][0]']
#
#  add_12 (Add)                   (None, 5, 32)        0           ['multi_head_attention_6[0][0]',
#                                                                   'patch_encoder_2[0][0]',
#                                                                   'lstm_6[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 5, 32)       64          ['add_12[0][0]']
#  ormalization)
#
#  sequential_8 (Sequential)      (None, 5, 32)        1056        ['layer_normalization_14[0][0]']
#
#  add_13 (Add)                   (None, 5, 32)        0           ['sequential_8[0][0]',
#                                                                   'add_12[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 5, 32)       64          ['add_13[0][0]']
#  ormalization)
#
#  multi_head_attention_7 (MultiH  (None, 5, 32)       25184       ['layer_normalization_15[0][0]',
#  eadAttention)                                                    'layer_normalization_15[0][0]']
#
#  lstm_7 (LSTM)                  (None, 5, 32)        8320        ['layer_normalization_15[0][0]']
#
#  add_14 (Add)                   (None, 5, 32)        0           ['multi_head_attention_7[0][0]',
#                                                                   'add_13[0][0]',
#                                                                   'lstm_7[0][0]']
#
#  layer_normalization_16 (LayerN  (None, 5, 32)       64          ['add_14[0][0]']
#  ormalization)
#
#  sequential_9 (Sequential)      (None, 5, 32)        1056        ['layer_normalization_16[0][0]']
#
#  add_15 (Add)                   (None, 5, 32)        0           ['sequential_9[0][0]',
#                                                                   'add_14[0][0]']
#
#  layer_normalization_17 (LayerN  (None, 5, 32)       64          ['add_15[0][0]']
#  ormalization)
#
#  multi_head_attention_8 (MultiH  (None, 5, 32)       25184       ['layer_normalization_17[0][0]',
#  eadAttention)                                                    'layer_normalization_17[0][0]']
#
#  lstm_8 (LSTM)                  (None, 5, 32)        8320        ['layer_normalization_17[0][0]']
#
#  add_16 (Add)                   (None, 5, 32)        0           ['multi_head_attention_8[0][0]',
#                                                                   'add_15[0][0]',
#                                                                   'lstm_8[0][0]']
#
#  layer_normalization_18 (LayerN  (None, 5, 32)       64          ['add_16[0][0]']
#  ormalization)
#
#  sequential_10 (Sequential)     (None, 5, 32)        1056        ['layer_normalization_18[0][0]']
#
#  add_17 (Add)                   (None, 5, 32)        0           ['sequential_10[0][0]',
#                                                                   'add_16[0][0]']
#
#  layer_normalization_19 (LayerN  (None, 5, 32)       64          ['add_17[0][0]']
#  ormalization)
#
#  multi_head_attention_9 (MultiH  (None, 5, 32)       25184       ['layer_normalization_19[0][0]',
#  eadAttention)                                                    'layer_normalization_19[0][0]']
#
#  lstm_9 (LSTM)                  (None, 5, 32)        8320        ['layer_normalization_19[0][0]']
#
#  add_18 (Add)                   (None, 5, 32)        0           ['multi_head_attention_9[0][0]',
#                                                                   'add_17[0][0]',
#                                                                   'lstm_9[0][0]']
#
#  layer_normalization_20 (LayerN  (None, 5, 32)       64          ['add_18[0][0]']
#  ormalization)
#
#  sequential_11 (Sequential)     (None, 5, 32)        1056        ['layer_normalization_20[0][0]']
#
#  add_19 (Add)                   (None, 5, 32)        0           ['sequential_11[0][0]',
#                                                                   'add_18[0][0]']
#
#  layer_normalization_21 (LayerN  (None, 5, 32)       64          ['add_19[0][0]']
#  ormalization)
#
#  multi_head_attention_10 (Multi  (None, 5, 32)       25184       ['layer_normalization_21[0][0]',
#  HeadAttention)                                                   'layer_normalization_21[0][0]']
#
#  lstm_10 (LSTM)                 (None, 5, 32)        8320        ['layer_normalization_21[0][0]']
#
#  add_20 (Add)                   (None, 5, 32)        0           ['multi_head_attention_10[0][0]',
#                                                                   'add_19[0][0]',
#                                                                   'lstm_10[0][0]']
#
#  layer_normalization_22 (LayerN  (None, 5, 32)       64          ['add_20[0][0]']
#  ormalization)
#
#  sequential_12 (Sequential)     (None, 5, 32)        1056        ['layer_normalization_22[0][0]']
#
#  add_21 (Add)                   (None, 5, 32)        0           ['sequential_12[0][0]',
#                                                                   'add_20[0][0]']
#
#  layer_normalization_23 (LayerN  (None, 5, 32)       64          ['add_21[0][0]']
#  ormalization)
#
#  multi_head_attention_11 (Multi  (None, 5, 32)       25184       ['layer_normalization_23[0][0]',
#  HeadAttention)                                                   'layer_normalization_23[0][0]']
#
#  lstm_11 (LSTM)                 (None, 5, 32)        8320        ['layer_normalization_23[0][0]']
#
#  add_22 (Add)                   (None, 5, 32)        0           ['multi_head_attention_11[0][0]',
#                                                                   'add_21[0][0]',
#                                                                   'lstm_11[0][0]']
#
#  layer_normalization_24 (LayerN  (None, 5, 32)       64          ['add_22[0][0]']
#  ormalization)
#
#  sequential_13 (Sequential)     (None, 5, 32)        1056        ['layer_normalization_24[0][0]']
#
#  add_23 (Add)                   (None, 5, 32)        0           ['sequential_13[0][0]',
#                                                                   'add_22[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 5, 32)       64          ['add_23[0][0]']
#  ormalization)
#
#  global_average_pooling1d_1 (Gl  (None, 32)          0           ['layer_normalization_25[0][0]']
#  obalAveragePooling1D)
#
#  dense_15 (Dense)               (None, 3)            99          ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 219,355
# Trainable params: 219,355
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class_weights = np.zeros(3)

unique_labels, counts = np.unique(train_labels, return_counts=True)

total_samples = np.sum(counts)

for i, label in enumerate(unique_labels):
    class_weights[label] = total_samples / (len(unique_labels) * counts[i])

print("Class weights:", class_weights)

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics='accuracy')
class_weights = [1,1,1]
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 16s 16s/step - loss: 1.2560 - accuracy: 0.6364 - val_loss: 0.3242 - val_accuracy: 1.0000
# Epoch 2/10
# 1/1 [==============================] - 0s 298ms/step - loss: 1.3997 - accuracy: 0.2727 - val_loss: 0.7297 - val_accuracy: 1.0000
# Epoch 3/10
# 1/1 [==============================] - 0s 216ms/step - loss: 0.9624 - accuracy: 0.2727 - val_loss: 1.4022 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 0s 474ms/step - loss: 0.7822 - accuracy: 0.6364 - val_loss: 2.0401 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 0s 126ms/step - loss: 0.8074 - accuracy: 0.6364 - val_loss: 2.2958 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 96ms/step - loss: 0.8503 - accuracy: 0.6364 - val_loss: 2.2085 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 0s 92ms/step - loss: 0.7888 - accuracy: 0.6364 - val_loss: 1.9304 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 0s 92ms/step - loss: 0.6985 - accuracy: 0.6364 - val_loss: 1.5911 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6124 - accuracy: 0.6364 - val_loss: 1.2937 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6122 - accuracy: 0.7273 - val_loss: 1.1744 - val_accuracy: 0.0000e+00

# %%
invasive_dirs = [
    r'D:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Zebra Pediveliger Image1a\Zebra Pediveligers',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Umbonal',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Umbonal',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Zebra D-Hinge',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Umbonal'
]

# Non-Invasive category
non_invasive_dirs = [
     r'D:\VeligerData\Ostracods Day 2 Image1 To Baylor\Not',
    r'D:\VeligerData\Ostracods Day 2 Image2 To Baylor\Not',
    r'D:\VeligerData\Ostracods Day 2 Image12 To Baylor_3\Ostracods Day 2 Image12 To Baylor\Sorted Images\Not',
    r'D:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Not Veligers\O1',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Not',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Not'
]

# Ostracod category
ostracod_dirs = [
     r'D:\VeligerData\Ostracods Day 2 Image3 To Baylor_2\Ostracods Day 2 Image3 To Baylor\Sorted Images\Ostracods',
    r'D:\VeligerData\Ostracods Day 2 Image12 To Baylor_3\Ostracods Day 2 Image12 To Baylor\Sorted Images\Ostracods',
    r'D:\VeligerData\Ostracods Day 2 Image2 To Baylor\Ostracods',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Ostracod'
  ]


# List to store subdirectories
invasive_subdirs = []
non_invasive_subdirs = []
ostracod_subdirs = []

# Collect subdirectories in the invasive category
for invasive_dir in invasive_dirs:
    invasive_subdirs.extend(glob.glob(invasive_dir))

# Collect subdirectories in the non-invasive category
for non_invasive_dir in non_invasive_dirs:
    non_invasive_subdirs.extend(glob.glob(non_invasive_dir))
    
for ostracod_dir in ostracod_dirs:
    ostracod_subdirs.extend(glob.glob(ostracod_dir))

# %%
import glob
from PIL import Image

# List of directories in x
x = non_invasive_subdirs

# List to store subdirectories
y1 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y1.extend(subdirectories)

import glob

# List of directories in x
x = invasive_subdirs

# List to store subdirectories
y2 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y2.extend(subdirectories)

    
import glob

# List of directories in x
x = ostracod_subdirs

# List to store subdirectories
y3 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y3.extend(subdirectories)



X0,Y0 = preprocess_images(y1, label_num = 0)
X1,Y1 = preprocess_images(y2, label_num = 1)
X2,Y2 = preprocess_images(y3, label_num = 2)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Concatenate the image arrays
train_images = np.concatenate((X0, X1, X2), axis=0)

# Combine the label arrays
train_labels = np.concatenate((Y0, Y1, Y2), axis=0)

# Convert the labels to categorical
train_labels_categorical = to_categorical(train_labels)

# Set the dtype of train_images to float32
train_images = train_images.astype('float32')


# Split the data into train and test sets
from sklearn.utils import shuffle

# Assuming you have the original train_images and train_labels_categorical

# Shuffle the data
train_images, train_labels_categorical = shuffle(train_images, train_labels_categorical)

# Now the shuffled data is assigned to the same variable names

X_train, X_test1, Y_train, Y_test1 = train_test_split(train_images, train_labels_categorical, test_size=0.01, random_state=42)

# %%
np.shape(X_train)
# Out:
# (8, 5, 28, 28, 3)

# %%
class_weights = np.zeros(3)

unique_labels, counts = np.unique(train_labels, return_counts=True)

total_samples = np.sum(counts)

for i, label in enumerate(unique_labels):
    class_weights[label] = total_samples / (len(unique_labels) * counts[i])

print("Class weights:", class_weights)

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics='accuracy')
class_weights = [1,1,1]
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 18s 18s/step - loss: 0.5228 - accuracy: 0.8571 - val_loss: 2.7268 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 0s 101ms/step - loss: 0.4292 - accuracy: 0.8571 - val_loss: 2.0292 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 1/1 [==============================] - 0s 112ms/step - loss: 0.3715 - accuracy: 0.8571 - val_loss: 1.3798 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 1/1 [==============================] - 0s 111ms/step - loss: 0.3550 - accuracy: 0.8571 - val_loss: 1.6782 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2780 - accuracy: 0.8571 - val_loss: 2.1758 - val_accuracy: 0.0000e+00

# %%
pred = model.predict(X_test)
p = np.argmax(pred, axis=1)
res = p
        
test = []
for i in Y_test:
    if(i[0]==1):
        test.append(0)
    elif(i[1]==1):
        test.append(1)
    else:
        test.append(2)
        
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(test,np.argmax(Y_test, axis=1))
print("Accuracy:", accuracy)

# %%
from tensorflow.keras.models import load_model
# Assuming you have a Keras model named "model"
model.save("five_frame_model.h5")
