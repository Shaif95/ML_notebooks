# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json

import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd

#import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import shutil
import keras
from PIL import Image
#import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import Lambda, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras import Input
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE
from sklearn.metrics import confusion_matrix
import random

AUTO = tf.data.AUTOTUNE
BATCH_SIZE = 32
EPOCHS = 50
CROP_TO = 32
SEED = 26

PROJECT_DIM = 128
LATENT_DIM = 512
WEIGHT_DECAY = 0.0005
learning_rate = 0.0001
batch_size = 128
hidden_units = 512
projection_units = 256
num_epochs = 2
dropout_rate = 0.5

temperature = 0.05
# Out:
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')
train_images = train_images / 255
test_images = test_images / 255

X_train, x_unlab, Y_train, y_unlab = train_test_split( train_images, train_labels , test_size=0.6, random_state=42 )
X_test = test_images
Y_test = test_labels

# %%
np.shape(x_train)
# Out:
# (18000, 32, 32, 3)

# %%
len(X_test)
# Out:
# 5000

# %%
len(Y_all)
# Out:
# 45000

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["accuracy"]
    val_accuracy = val_accuracy + history.history["val_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE

num_classes = 10
input_shape = (32, 32, 3)

def create_model():
    
    base_model = tf.keras.applications.ResNet50V2(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

    # Add custom top layers
    x = base_model.output
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(10, activation='softmax')(x)

    # Compile the model
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

# %%
def test(model, X_test, Y_test):
    print("-" * 100)
    print("Test set evaluation: ", model.evaluate( X_test, Y_test , verbose=0, return_dict=True), )
    print("-" * 100)

# %%
def train(model,X_train, Y_train, epoch):
    
    print(f"Starting to train with {len(Y_train)} samples")

    history = model.fit(X_train, Y_train, batch_size = 64, epochs=epoch,validation_split=.20)

    return model

# %%
from sklearn.metrics import confusion_matrix
import random

def train_active_learning_models(
    model,
    X_train,
    Y_train,
    x_unlab,
    y_unlab,
    X_test,
    Y_test,
    num_iterations=2
):
    test(model, X_test, Y_test)
    
    d = 100/num_iterations
    l = len(y_unlab)
    x = 600
    
    for iteration in range(num_iterations):

        model = tf.keras.models.load_model('saved_model/my_model')
        
        l = len(y_unlab)
        
        print("\n\n")
        
        print("Iteration : ")
        
        print(iteration)
        
        print("\n\n")
         
        #generate random number and substract from all numbers
        rnd = random.sample(range(1, l), x)
        all = list(range(1, l))
        main_list = list(set(all) - set(rnd))
        
        #add those index to from unlablled set to training set
        new_lab = x_unlab[rnd]
        arr = np.concatenate((X_train, new_lab))
        X_train = arr

        #predict on the set and add to training data
        new_y = y_unlab[rnd]
        arr = np.concatenate((Y_train, new_y))
        Y_train = arr
        
        
        #create the new unlabelled set
        x_unlab = x_unlab[main_list]

        #create the new unlabelled label set
        y_unlab = y_unlab[main_list]
        
        
        #train on data
        model = train(model,X_train, Y_train,15)
        
        #test for final time
        test(model, X_test, Y_test)

        model.save('saved_model/my_model')

        del model
    
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

def resize_images(images, target_shape=(32, 32)):
    resized_images = np.zeros((images.shape[0], *target_shape))
    for i, img in enumerate(images):
        resized_images[i] = resize(img, target_shape, anti_aliasing=True)
    return resized_images

# Preprocess the data
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Resize images to 32x32
x_train = resize_images(x_train)
x_test = resize_images(x_test)

# Reshape to have an additional channel dimension and repeat the channel 3 times
x_train = np.stack((x_train,)*3, axis=-1)
x_test = np.stack((x_test,)*3, axis=-1)

X_test = x_test
Y_test = to_categorical(y_test)
y_train = to_categorical(y_train)

X_train, x_unlab, Y_train, y_unlab = train_test_split( x_train,y_train, test_size=0.95, random_state=42 )


model = create_model()
    
model.compile(
        loss="categorical_crossentropy",
        optimizer="Adam",
        metrics='accuracy',
    )
    
model = train(model,X_train, Y_train,50)

model.save('saved_model/my_model')

active_learning_model = train_active_learning_models(model,X_train,Y_train,x_unlab,y_unlab,X_test,Y_test,num_iterations=10)
# Out:
# Starting to train with 3000 samples
# Epoch 1/50
# 38/38 [==============================] - 43s 494ms/step - loss: 1.2217 - accuracy: 0.5788 - val_loss: 2.3087 - val_accuracy: 0.0833
# Epoch 2/50
# 38/38 [==============================] - 13s 354ms/step - loss: 0.6322 - accuracy: 0.7696 - val_loss: 2.3297 - val_accuracy: 0.1050
# Epoch 3/50
# 38/38 [==============================] - 12s 328ms/step - loss: 0.4716 - accuracy: 0.8263 - val_loss: 2.4666 - val_accuracy: 0.1383
# Epoch 4/50
# 38/38 [==============================] - 13s 330ms/step - loss: 0.3860 - accuracy: 0.8625 - val_loss: 2.1429 - val_accuracy: 0.2767
# Epoch 5/50
# 38/38 [==============================] - 12s 316ms/step - loss: 0.4006 - accuracy: 0.8521 - val_loss: 1.7500 - val_accuracy: 0.3133
# Epoch 6/50
# 38/38 [==============================] - 12s 323ms/step - loss: 0.0654 - accuracy: 0.9767 - val_loss: 0.9104 - val_accuracy: 0.7933
# Epoch 26/50
# 38/38 [==============================] - 12s 324ms/step - loss: 0.0698 - accuracy: 0.9737 - val_loss: 0.7944 - val_accuracy: 0.8083
# Epoch 27/50
# 38/38 [==============================] - 12s 327ms/step - loss: 0.1045 - accuracy: 0.9688 - val_loss: 0.9840 - val_accuracy: 0.7933
# Epoch 28/50
# 38/38 [==============================] - 12s 327ms/step - loss: 0.1182 - accuracy: 0.9592 - val_loss: 0.6368 - val_accuracy: 0.8550
# Epoch 29/50
# 38/38 [==============================] - 13s 335ms/step - loss: 0.0720 - accuracy: 0.9779 - val_loss: 1.0693 - val_accuracy: 0.7850
# Epoch 30/50
# 38/38 [==============================] - 12s 330ms/step - loss: 0.0815 - accuracy: 0.9754 - val_loss: 0.7232 - val_accuracy: 0.8133
# Epoch 31/50
# 38/38 [==============================] - 12s 326ms/step - loss: 0.1171 - accuracy: 0.9692 - val_loss: 0.8838 - val_accuracy: 0.7783
# Epoch 32/50
# 38/38 [==============================] - 12s 325ms/step - loss: 0.0982 - accuracy: 0.9629 - val_loss: 0.6364 - val_accuracy: 0.8250
# Epoch 33/50
# 38/38 [==============================] - 12s 324ms/step - loss: 0.1716 - accuracy: 0.9567 - val_loss: 1.7579 - val_accuracy: 0.5633
# Epoch 34/50
# 38/38 [==============================] - 13s 338ms/step - loss: 0.4316 - accuracy: 0.8658 - val_loss: 13.2183 - val_accuracy: 0.3417
# Epoch 35/50
# 38/38 [==============================] - 12s 325ms/step - loss: 0.2198 - accuracy: 0.9287 - val_loss: 1.5995 - val_accuracy: 0.7067
# Epoch 36/50
# 38/38 [==============================] - 12s 319ms/step - loss: 0.1436 - accuracy: 0.9504 - val_loss: 1.8710 - val_accuracy: 0.7250
# Epoch 37/50
# 38/38 [==============================] - 12s 322ms/step - loss: 0.1266 - accuracy: 0.9617 - val_loss: 0.8188 - val_accuracy: 0.8117
# Epoch 38/50
# 38/38 [==============================] - 12s 315ms/step - loss: 0.1281 - accuracy: 0.9571 - val_loss: 0.8010 - val_accuracy: 0.8283
# Epoch 39/50
# 38/38 [==============================] - 14s 360ms/step - loss: 0.0550 - accuracy: 0.9821 - val_loss: 0.8026 - val_accuracy: 0.8367
# Epoch 40/50
# 38/38 [==============================] - 14s 363ms/step - loss: 0.0949 - accuracy: 0.9663 - val_loss: 0.6562 - val_accuracy: 0.8433
# Epoch 41/50
# 38/38 [==============================] - 13s 338ms/step - loss: 0.0710 - accuracy: 0.9771 - val_loss: 0.6855 - val_accuracy: 0.8367
# Epoch 42/50
# 38/38 [==============================] - 12s 307ms/step - loss: 0.1379 - accuracy: 0.9608 - val_loss: 1.0641 - val_accuracy: 0.8100
# Epoch 43/50
# 38/38 [==============================] - 12s 316ms/step - loss: 0.1015 - accuracy: 0.9679 - val_loss: 1.0381 - val_accuracy: 0.8183
# Epoch 44/50
# 38/38 [==============================] - 12s 314ms/step - loss: 0.0733 - accuracy: 0.9758 - val_loss: 0.6983 - val_accuracy: 0.8300
# Epoch 45/50
# 38/38 [==============================] - 12s 308ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.8671 - val_accuracy: 0.8133
# Epoch 46/50
# 38/38 [==============================] - 12s 329ms/step - loss: 0.0388 - accuracy: 0.9879 - val_loss: 0.5311 - val_accuracy: 0.8550
# Epoch 47/50
# 38/38 [==============================] - 12s 320ms/step - loss: 0.0340 - accuracy: 0.9887 - val_loss: 0.6843 - val_accuracy: 0.8533
# Epoch 48/50
# 38/38 [==============================] - 13s 333ms/step - loss: 0.0302 - accuracy: 0.9900 - val_loss: 0.7099 - val_accuracy: 0.8550
# Epoch 49/50
# 38/38 [==============================] - 12s 312ms/step - loss: 0.0168 - accuracy: 0.9929 - val_loss: 0.7358 - val_accuracy: 0.8367
# Epoch 50/50
# 38/38 [==============================] - 12s 308ms/step - loss: 0.0825 - accuracy: 0.9721 - val_loss: 1.1089 - val_accuracy: 0.8200
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 1.1395020484924316, 'accuracy': 0.8066999912261963}
# ----------------------------------------------------------------------------------------------------
#
#
#
# Iteration :
# 0
#
#
#
# Starting to train with 3600 samples
# Epoch 1/15
# 45/45 [==============================] - 47s 592ms/step - loss: 0.3305 - accuracy: 0.9028 - val_loss: 159.3241 - val_accuracy: 0.2375
# Epoch 2/15
# 45/45 [==============================] - 22s 494ms/step - loss: 0.2594 - accuracy: 0.9170 - val_loss: 19.3561 - val_accuracy: 0.4375
# Epoch 3/15
# 45/45 [==============================] - 26s 588ms/step - loss: 0.1864 - accuracy: 0.9424 - val_loss: 2.9903 - val_accuracy: 0.7000
# Epoch 4/15
# 45/45 [==============================] - 23s 503ms/step - loss: 0.1835 - accuracy: 0.9424 - val_loss: 0.6805 - val_accuracy: 0.8222
# Epoch 5/15
# 45/45 [==============================] - 20s 449ms/step - loss: 0.1797 - accuracy: 0.9427 - val_loss: 0.6864 - val_accuracy: 0.8069
# Epoch 6/15
# 45/45 [==============================] - 18s 396ms/step - loss: 0.1513 - accuracy: 0.9503 - val_loss: 0.8627 - val_accuracy: 0.7917
# Epoch 7/15
# 45/45 [==============================] - 17s 376ms/step - loss: 0.1297 - accuracy: 0.9611 - val_loss: 0.7521 - val_accuracy: 0.8333
# Epoch 8/15
# 45/45 [==============================] - 17s 373ms/step - loss: 0.1336 - accuracy: 0.9576 - val_loss: 0.7267 - val_accuracy: 0.8319
# Epoch 9/15
# 45/45 [==============================] - 17s 378ms/step - loss: 0.1141 - accuracy: 0.9632 - val_loss: 0.6673 - val_accuracy: 0.8500
# Epoch 10/15
# 45/45 [==============================] - 17s 377ms/step - loss: 0.0790 - accuracy: 0.9760 - val_loss: 0.6139 - val_accuracy: 0.8583
# Epoch 11/15
# 45/45 [==============================] - 18s 408ms/step - loss: 0.0976 - accuracy: 0.9684 - val_loss: 0.6817 - val_accuracy: 0.8292
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.7540059685707092, 'accuracy': 0.8431000113487244}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# Iteration :
# 2
#
#
#
# Starting to train with 4800 samples
# Epoch 1/15
# 60/60 [==============================] - 56s 518ms/step - loss: 0.2006 - accuracy: 0.9362 - val_loss: 0.9081 - val_accuracy: 0.8146
# Epoch 2/15
# 60/60 [==============================] - 28s 464ms/step - loss: 0.1547 - accuracy: 0.9518 - val_loss: 0.6699 - val_accuracy: 0.8542
# Epoch 3/15
# 60/60 [==============================] - 26s 437ms/step - loss: 0.1223 - accuracy: 0.9604 - val_loss: 0.7185 - val_accuracy: 0.8469
# Epoch 4/15
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0869 - accuracy: 0.9742 - val_loss: 0.6156 - val_accuracy: 0.8500
# Epoch 5/15
# 60/60 [==============================] - 28s 475ms/step - loss: 0.0999 - accuracy: 0.9669 - val_loss: 0.5891 - val_accuracy: 0.8479
# Epoch 6/15
# 60/60 [==============================] - 29s 490ms/step - loss: 0.0856 - accuracy: 0.9727 - val_loss: 0.5992 - val_accuracy: 0.8500
# Epoch 7/15
# 60/60 [==============================] - 27s 451ms/step - loss: 0.1007 - accuracy: 0.9664 - val_loss: 0.9768 - val_accuracy: 0.7906
# Epoch 8/15
# 60/60 [==============================] - 27s 444ms/step - loss: 0.0758 - accuracy: 0.9758 - val_loss: 0.6688 - val_accuracy: 0.8365
# Epoch 9/15
# 60/60 [==============================] - 26s 441ms/step - loss: 0.1143 - accuracy: 0.9599 - val_loss: 0.7802 - val_accuracy: 0.8281
# Epoch 10/15
# 60/60 [==============================] - 27s 446ms/step - loss: 0.0888 - accuracy: 0.9716 - val_loss: 0.8200 - val_accuracy: 0.8219
# Epoch 11/15
# 60/60 [==============================] - 26s 426ms/step - loss: 0.0725 - accuracy: 0.9792 - val_loss: 0.8060 - val_accuracy: 0.8333
# Epoch 12/15
# 60/60 [==============================] - 27s 450ms/step - loss: 0.0414 - accuracy: 0.9883 - val_loss: 0.8173 - val_accuracy: 0.8427
# Epoch 13/15
# 60/60 [==============================] - 29s 481ms/step - loss: 0.0587 - accuracy: 0.9820 - val_loss: 0.6163 - val_accuracy: 0.8542
# Epoch 14/15
# 60/60 [==============================] - 28s 465ms/step - loss: 0.0458 - accuracy: 0.9862 - val_loss: 0.6648 - val_accuracy: 0.8552
# Epoch 15/15
# 60/60 [==============================] - 29s 489ms/step - loss: 0.0624 - accuracy: 0.9805 - val_loss: 0.6857 - val_accuracy: 0.8458
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.83424973487854, 'accuracy': 0.8281999826431274}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# Iteration :
# 4
#
#
#
# Starting to train with 6000 samples
# Epoch 1/15
# 75/75 [==============================] - 59s 527ms/step - loss: 0.1513 - accuracy: 0.9550 - val_loss: 0.6806 - val_accuracy: 0.8267
# Epoch 2/15
# 75/75 [==============================] - 47s 631ms/step - loss: 0.0960 - accuracy: 0.9685 - val_loss: 0.7224 - val_accuracy: 0.8233
# Epoch 3/15
# 75/75 [==============================] - 44s 586ms/step - loss: 0.2546 - accuracy: 0.9560 - val_loss: 2.6443 - val_accuracy: 0.6725
# Epoch 4/15
# 75/75 [==============================] - 42s 561ms/step - loss: 0.2910 - accuracy: 0.9050 - val_loss: 0.5229 - val_accuracy: 0.8333
# Epoch 5/15
# 75/75 [==============================] - 36s 475ms/step - loss: 0.1136 - accuracy: 0.9613 - val_loss: 0.5462 - val_accuracy: 0.8492
# Epoch 6/15
# 75/75 [==============================] - 51s 681ms/step - loss: 0.1066 - accuracy: 0.9758 - val_loss: 0.6295 - val_accuracy: 0.8392
# Epoch 7/15
# 75/75 [==============================] - 46s 615ms/step - loss: 0.1295 - accuracy: 0.9598 - val_loss: 0.6733 - val_accuracy: 0.8475
# Epoch 8/15
# 75/75 [==============================] - 54s 713ms/step - loss: 0.0610 - accuracy: 0.9808 - val_loss: 0.6262 - val_accuracy: 0.8550
# Epoch 9/15
# 75/75 [==============================] - 42s 556ms/step - loss: 0.0270 - accuracy: 0.9921 - val_loss: 0.7382 - val_accuracy: 0.8575
# Epoch 10/15
# 75/75 [==============================] - 40s 530ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.8149 - val_accuracy: 0.8458
# Epoch 11/15
# 75/75 [==============================] - 39s 525ms/step - loss: 0.0341 - accuracy: 0.9892 - val_loss: 0.7338 - val_accuracy: 0.8417
# Epoch 12/15
# 75/75 [==============================] - 40s 540ms/step - loss: 0.2692 - accuracy: 0.9367 - val_loss: 4.9016 - val_accuracy: 0.7175
# Epoch 13/15
# 75/75 [==============================] - 46s 609ms/step - loss: 0.1846 - accuracy: 0.9379 - val_loss: 0.6325 - val_accuracy: 0.8308
# Epoch 14/15
# 75/75 [==============================] - 43s 575ms/step - loss: 0.0780 - accuracy: 0.9744 - val_loss: 0.6080 - val_accuracy: 0.8533
# Epoch 15/15
# 75/75 [==============================] - 44s 581ms/step - loss: 0.0446 - accuracy: 0.9858 - val_loss: 0.7703 - val_accuracy: 0.8483
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.7894163727760315, 'accuracy': 0.8461999893188477}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# Iteration :
# 5
#
#
#
# Starting to train with 6600 samples
# Epoch 1/15
# 83/83 [==============================] - 69s 573ms/step - loss: 0.1676 - accuracy: 0.9536 - val_loss: 0.6167 - val_accuracy: 0.8530
# Epoch 2/15
# 83/83 [==============================] - 38s 464ms/step - loss: 0.1170 - accuracy: 0.9617 - val_loss: 0.5839 - val_accuracy: 0.8606
# Epoch 3/15
# 83/83 [==============================] - 38s 462ms/step - loss: 0.0885 - accuracy: 0.9727 - val_loss: 0.5332 - val_accuracy: 0.8765
# Epoch 4/15
# 83/83 [==============================] - 39s 466ms/step - loss: 0.2230 - accuracy: 0.9487 - val_loss: 0.6256 - val_accuracy: 0.8492
# Epoch 5/15
# 83/83 [==============================] - 38s 460ms/step - loss: 0.1244 - accuracy: 0.9591 - val_loss: 0.4720 - val_accuracy: 0.8636
# Epoch 6/15
# 83/83 [==============================] - 38s 455ms/step - loss: 0.0491 - accuracy: 0.9850 - val_loss: 0.5854 - val_accuracy: 0.8697
# Epoch 7/15
# 83/83 [==============================] - 39s 466ms/step - loss: 0.0264 - accuracy: 0.9919 - val_loss: 0.6701 - val_accuracy: 0.8727
# Epoch 8/15
# 83/83 [==============================] - 38s 463ms/step - loss: 0.0509 - accuracy: 0.9848 - val_loss: 0.8147 - val_accuracy: 0.8523
# Epoch 9/15
# 83/83 [==============================] - 40s 485ms/step - loss: 0.0560 - accuracy: 0.9818 - val_loss: 0.6325 - val_accuracy: 0.8705
# Epoch 10/15
# 83/83 [==============================] - 38s 464ms/step - loss: 0.0419 - accuracy: 0.9856 - val_loss: 0.7388 - val_accuracy: 0.8636
# Epoch 11/15
# 83/83 [==============================] - 38s 462ms/step - loss: 0.0401 - accuracy: 0.9873 - val_loss: 0.6274 - val_accuracy: 0.8644
# Epoch 12/15
# 83/83 [==============================] - 38s 458ms/step - loss: 0.0630 - accuracy: 0.9797 - val_loss: 0.5948 - val_accuracy: 0.8720
# Epoch 13/15
# 83/83 [==============================] - 37s 452ms/step - loss: 0.0327 - accuracy: 0.9900 - val_loss: 0.6836 - val_accuracy: 0.8682
# Epoch 14/15
# 83/83 [==============================] - 38s 453ms/step - loss: 0.0211 - accuracy: 0.9945 - val_loss: 0.6529 - val_accuracy: 0.8742
# Epoch 15/15
# 83/83 [==============================] - 38s 464ms/step - loss: 0.0797 - accuracy: 0.9780 - val_loss: 0.6642 - val_accuracy: 0.8576
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.7940022349357605, 'accuracy': 0.8450000286102295}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# Iteration :
# 6
#
#
#
# Starting to train with 7200 samples
# Epoch 1/15
# 90/90 [==============================] - 61s 435ms/step - loss: 0.1089 - accuracy: 0.9700 - val_loss: 0.6338 - val_accuracy: 0.8611
# Epoch 2/15
# 90/90 [==============================] - 36s 396ms/step - loss: 0.0609 - accuracy: 0.9814 - val_loss: 0.6238 - val_accuracy: 0.8583
# Epoch 3/15
# 90/90 [==============================] - 36s 398ms/step - loss: 0.0495 - accuracy: 0.9854 - val_loss: 0.6838 - val_accuracy: 0.8340
# Epoch 4/15
# 90/90 [==============================] - 36s 399ms/step - loss: 0.1198 - accuracy: 0.9644 - val_loss: 0.8617 - val_accuracy: 0.8562
# Epoch 5/15
# 90/90 [==============================] - 36s 397ms/step - loss: 0.0563 - accuracy: 0.9809 - val_loss: 0.6673 - val_accuracy: 0.8604
# Epoch 6/15
# 90/90 [==============================] - 36s 402ms/step - loss: 0.0355 - accuracy: 0.9887 - val_loss: 0.7618 - val_accuracy: 0.8514
# Epoch 7/15
# 90/90 [==============================] - 36s 402ms/step - loss: 0.0377 - accuracy: 0.9882 - val_loss: 0.7422 - val_accuracy: 0.8556
# Epoch 8/15
# 90/90 [==============================] - 42s 470ms/step - loss: 0.0437 - accuracy: 0.9868 - val_loss: 0.7618 - val_accuracy: 0.8451
# Epoch 9/15
# 90/90 [==============================] - 38s 421ms/step - loss: 0.0527 - accuracy: 0.9826 - val_loss: 0.6018 - val_accuracy: 0.8542
# Epoch 10/15
# 90/90 [==============================] - 38s 418ms/step - loss: 0.0434 - accuracy: 0.9868 - val_loss: 0.6915 - val_accuracy: 0.8618
# Epoch 11/15
# 90/90 [==============================] - 42s 466ms/step - loss: 0.0506 - accuracy: 0.9849 - val_loss: 0.7437 - val_accuracy: 0.8535
# Epoch 12/15
# 90/90 [==============================] - 41s 459ms/step - loss: 0.1736 - accuracy: 0.9766 - val_loss: 0.6884 - val_accuracy: 0.8319
# Epoch 13/15
# 90/90 [==============================] - 82s 910ms/step - loss: 0.1686 - accuracy: 0.9648 - val_loss: 1.1472 - val_accuracy: 0.8313
# Epoch 14/15
# 90/90 [==============================] - 48s 537ms/step - loss: 0.2738 - accuracy: 0.9675 - val_loss: 1.5174 - val_accuracy: 0.8090
# Epoch 15/15
# 90/90 [==============================] - 39s 434ms/step - loss: 0.0739 - accuracy: 0.9812 - val_loss: 0.7941 - val_accuracy: 0.8236
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.8536689281463623, 'accuracy': 0.8216000199317932}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# Iteration :
# 7
#
#
#
# Starting to train with 7800 samples
# Epoch 1/15
# 98/98 [==============================] - 87s 594ms/step - loss: 0.1214 - accuracy: 0.9696 - val_loss: 0.5197 - val_accuracy: 0.8718
# Epoch 2/15
# 98/98 [==============================] - 58s 584ms/step - loss: 0.1061 - accuracy: 0.9796 - val_loss: 0.5315 - val_accuracy: 0.8647
# Epoch 3/15
# 98/98 [==============================] - 45s 461ms/step - loss: 0.0473 - accuracy: 0.9853 - val_loss: 0.5981 - val_accuracy: 0.8667
# Epoch 4/15
# 98/98 [==============================] - 50s 510ms/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 0.6126 - val_accuracy: 0.8744
# Epoch 5/15
# 98/98 [==============================] - 48s 492ms/step - loss: 0.0253 - accuracy: 0.9925 - val_loss: 0.7166 - val_accuracy: 0.8513
# Epoch 6/15
# 98/98 [==============================] - 49s 499ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.6338 - val_accuracy: 0.8788
# Epoch 7/15
# 98/98 [==============================] - 48s 486ms/step - loss: 0.0794 - accuracy: 0.9889 - val_loss: 0.9579 - val_accuracy: 0.8365
# Epoch 8/15
# 98/98 [==============================] - 56s 571ms/step - loss: 0.1450 - accuracy: 0.9510 - val_loss: 0.5634 - val_accuracy: 0.8654
# Epoch 9/15
# 98/98 [==============================] - 48s 493ms/step - loss: 0.0452 - accuracy: 0.9857 - val_loss: 0.6616 - val_accuracy: 0.8654
# Epoch 10/15
# 98/98 [==============================] - 48s 493ms/step - loss: 0.0284 - accuracy: 0.9913 - val_loss: 0.6735 - val_accuracy: 0.8718
# Epoch 11/15
# 98/98 [==============================] - 48s 488ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.7859 - val_accuracy: 0.8673
# Epoch 12/15
# 98/98 [==============================] - 45s 462ms/step - loss: 0.0235 - accuracy: 0.9925 - val_loss: 0.7216 - val_accuracy: 0.8660
# Epoch 13/15
# 98/98 [==============================] - 48s 487ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0.6751 - val_accuracy: 0.8744
# Epoch 14/15
# 98/98 [==============================] - 55s 562ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.7350 - val_accuracy: 0.8660
# Epoch 15/15
# 98/98 [==============================] - 48s 491ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.8002 - val_accuracy: 0.8647
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.8511563539505005, 'accuracy': 0.8592000007629395}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# Iteration :
# 8
#
#
#
# Starting to train with 8400 samples
# Epoch 1/15
# 105/105 [==============================] - 79s 562ms/step - loss: 0.0869 - accuracy: 0.9771 - val_loss: 0.5086 - val_accuracy: 0.8798
# Epoch 2/15
# 105/105 [==============================] - 54s 510ms/step - loss: 0.0494 - accuracy: 0.9868 - val_loss: 0.5531 - val_accuracy: 0.8720
# Epoch 3/15
# 105/105 [==============================] - 60s 571ms/step - loss: 0.0371 - accuracy: 0.9884 - val_loss: 0.6398 - val_accuracy: 0.8714
# Epoch 4/15
# 105/105 [==============================] - 57s 542ms/step - loss: 0.1026 - accuracy: 0.9732 - val_loss: 0.5654 - val_accuracy: 0.8655
# Epoch 5/15
# 105/105 [==============================] - 54s 512ms/step - loss: 0.1695 - accuracy: 0.9753 - val_loss: 0.6082 - val_accuracy: 0.8387
# Epoch 6/15
# 105/105 [==============================] - 52s 498ms/step - loss: 0.0673 - accuracy: 0.9802 - val_loss: 0.6114 - val_accuracy: 0.8595
# Epoch 7/15
# 105/105 [==============================] - 56s 531ms/step - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.6308 - val_accuracy: 0.8810
# Epoch 8/15
# 105/105 [==============================] - 57s 546ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 0.6761 - val_accuracy: 0.8649
# Epoch 9/15
# 105/105 [==============================] - 63s 604ms/step - loss: 0.0320 - accuracy: 0.9888 - val_loss: 0.6147 - val_accuracy: 0.8679
# Epoch 10/15
# 105/105 [==============================] - 52s 491ms/step - loss: 0.0264 - accuracy: 0.9917 - val_loss: 0.7048 - val_accuracy: 0.8720
# Epoch 11/15
# 105/105 [==============================] - 53s 506ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.6806 - val_accuracy: 0.8774
# Epoch 12/15
# 105/105 [==============================] - 53s 504ms/step - loss: 0.0163 - accuracy: 0.9963 - val_loss: 0.7710 - val_accuracy: 0.8720
# Epoch 13/15
# 105/105 [==============================] - 55s 524ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.7302 - val_accuracy: 0.8720
# Epoch 14/15
# 105/105 [==============================] - 55s 527ms/step - loss: 0.0207 - accuracy: 0.9942 - val_loss: 0.6821 - val_accuracy: 0.8673
# Epoch 15/15
# 105/105 [==============================] - 62s 594ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.8434 - val_accuracy: 0.8696
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.8860633969306946, 'accuracy': 0.8723000288009644}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
# Iteration :
# 9
#
#
#
# Starting to train with 9000 samples
# Epoch 1/15
# 113/113 [==============================] - 85s 569ms/step - loss: 0.0763 - accuracy: 0.9793 - val_loss: 0.6157 - val_accuracy: 0.8672
# Epoch 2/15
# 113/113 [==============================] - 56s 500ms/step - loss: 0.0530 - accuracy: 0.9856 - val_loss: 0.6971 - val_accuracy: 0.8783
# Epoch 3/15
# 113/113 [==============================] - 58s 515ms/step - loss: 0.0272 - accuracy: 0.9915 - val_loss: 0.6564 - val_accuracy: 0.8750
# Epoch 4/15
# 113/113 [==============================] - 61s 543ms/step - loss: 0.0213 - accuracy: 0.9939 - val_loss: 0.6649 - val_accuracy: 0.8772
# Epoch 5/15
# 113/113 [==============================] - 61s 537ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.7305 - val_accuracy: 0.8728
# Epoch 6/15
# 113/113 [==============================] - 58s 512ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 0.9169 - val_accuracy: 0.8628
# Epoch 7/15
# 113/113 [==============================] - 57s 507ms/step - loss: 0.0516 - accuracy: 0.9839 - val_loss: 0.6295 - val_accuracy: 0.8761
# Epoch 8/15
# 113/113 [==============================] - 58s 512ms/step - loss: 0.0265 - accuracy: 0.9925 - val_loss: 0.7335 - val_accuracy: 0.8700
# Epoch 9/15
# 113/113 [==============================] - 58s 517ms/step - loss: 0.0249 - accuracy: 0.9925 - val_loss: 0.6930 - val_accuracy: 0.8656
# Epoch 10/15
# 113/113 [==============================] - 58s 512ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.6759 - val_accuracy: 0.8728
# Epoch 11/15
# 113/113 [==============================] - 57s 506ms/step - loss: 0.0545 - accuracy: 0.9833 - val_loss: 0.6076 - val_accuracy: 0.8756
# Epoch 12/15
# 113/113 [==============================] - 57s 508ms/step - loss: 0.0246 - accuracy: 0.9935 - val_loss: 0.6287 - val_accuracy: 0.8789
# Epoch 13/15
# 113/113 [==============================] - 57s 503ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.6572 - val_accuracy: 0.8800
# Epoch 14/15
# 113/113 [==============================] - 58s 511ms/step - loss: 0.0248 - accuracy: 0.9933 - val_loss: 0.6475 - val_accuracy: 0.8783
# Epoch 15/15
# 113/113 [==============================] - 57s 506ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.7194 - val_accuracy: 0.8833
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.8331876993179321, 'accuracy': 0.8716999888420105}
# ----------------------------------------------------------------------------------------------------
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\chowd\AppData\Roaming\Python\Python39\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
