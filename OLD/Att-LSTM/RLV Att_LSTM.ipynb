# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns
import shutil
import keras
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
from glob import glob
trn='D:/RLV_data/*/'
tr= glob(trn)

len(tr)
# Out:
# 2

# %%
from glob import glob
trn='E:/HMDB20/*/'
tr= glob(trn)

len(tr)
# Out:
# 51

# %%
x = glob(tr[1]+'/*/')
x
# Out:
# ['D:/RLV_data\\Violence\\V_1\\',
#  'D:/RLV_data\\Violence\\V_10\\',
#  'D:/RLV_data\\Violence\\V_100\\',
#  'D:/RLV_data\\Violence\\V_1000\\',
#  'D:/RLV_data\\Violence\\V_101\\',
#  'D:/RLV_data\\Violence\\V_102\\',
#  'D:/RLV_data\\Violence\\V_103\\',
#  'D:/RLV_data\\Violence\\V_104\\',
#  'D:/RLV_data\\Violence\\V_105\\',
#  'D:/RLV_data\\Violence\\V_106\\',
#  'D:/RLV_data\\Violence\\V_107\\',
#  'D:/RLV_data\\Violence\\V_108\\',
#  'D:/RLV_data\\Violence\\V_109\\',
#  'D:/RLV_data\\Violence\\V_11\\',
#  'D:/RLV_data\\Violence\\V_110\\',
#  'D:/RLV_data\\Violence\\V_111\\',
#  'D:/RLV_data\\Violence\\V_112\\',
#  'D:/RLV_data\\Violence\\V_113\\',
#  'D:/RLV_data\\Violence\\V_114\\',
#  'D:/RLV_data\\Violence\\V_115\\',
#  'D:/RLV_data\\Violence\\V_116\\',
#  'D:/RLV_data\\Violence\\V_117\\',
#  'D:/RLV_data\\Violence\\V_118\\',
#  'D:/RLV_data\\Violence\\V_119\\',
#  'D:/RLV_data\\Violence\\V_12\\',
#  'D:/RLV_data\\Violence\\V_120\\',
#  'D:/RLV_data\\Violence\\V_121\\',
#  'D:/RLV_data\\Violence\\V_122\\',
#  'D:/RLV_data\\Violence\\V_123\\',
#  'D:/RLV_data\\Violence\\V_124\\',
#  'D:/RLV_data\\Violence\\V_125\\',
#  'D:/RLV_data\\Violence\\V_126\\',
#  'D:/RLV_data\\Violence\\V_127\\',
#  'D:/RLV_data\\Violence\\V_128\\',
#  'D:/RLV_data\\Violence\\V_129\\',
#  'D:/RLV_data\\Violence\\V_13\\',
#  'D:/RLV_data\\Violence\\V_130\\',
#  'D:/RLV_data\\Violence\\V_131\\',
#  'D:/RLV_data\\Violence\\V_132\\',
#  'D:/RLV_data\\Violence\\V_957\\',
#  'D:/RLV_data\\Violence\\V_958\\',
#  'D:/RLV_data\\Violence\\V_959\\',
#  'D:/RLV_data\\Violence\\V_96\\',
#  'D:/RLV_data\\Violence\\V_960\\',
#  'D:/RLV_data\\Violence\\V_961\\',
#  'D:/RLV_data\\Violence\\V_962\\',
#  'D:/RLV_data\\Violence\\V_963\\',
#  'D:/RLV_data\\Violence\\V_964\\',
#  'D:/RLV_data\\Violence\\V_965\\',
#  'D:/RLV_data\\Violence\\V_966\\',
#  'D:/RLV_data\\Violence\\V_967\\',
#  'D:/RLV_data\\Violence\\V_968\\',
#  'D:/RLV_data\\Violence\\V_969\\',
#  'D:/RLV_data\\Violence\\V_97\\',
#  'D:/RLV_data\\Violence\\V_970\\',
#  'D:/RLV_data\\Violence\\V_971\\',
#  'D:/RLV_data\\Violence\\V_972\\',
#  'D:/RLV_data\\Violence\\V_973\\',
#  'D:/RLV_data\\Violence\\V_974\\',
#  'D:/RLV_data\\Violence\\V_975\\',
#  'D:/RLV_data\\Violence\\V_976\\',
#  'D:/RLV_data\\Violence\\V_977\\',
#  'D:/RLV_data\\Violence\\V_978\\',
#  'D:/RLV_data\\Violence\\V_979\\',
#  'D:/RLV_data\\Violence\\V_98\\',
#  'D:/RLV_data\\Violence\\V_980\\',
#  'D:/RLV_data\\Violence\\V_981\\',
#  'D:/RLV_data\\Violence\\V_982\\',
#  'D:/RLV_data\\Violence\\V_983\\',
#  'D:/RLV_data\\Violence\\V_984\\',
#  'D:/RLV_data\\Violence\\V_985\\',
#  'D:/RLV_data\\Violence\\V_986\\',
#  'D:/RLV_data\\Violence\\V_987\\',
#  'D:/RLV_data\\Violence\\V_988\\',
#  'D:/RLV_data\\Violence\\V_989\\',
#  'D:/RLV_data\\Violence\\V_99\\',
#  'D:/RLV_data\\Violence\\V_990\\',
#  'D:/RLV_data\\Violence\\V_991\\',
#  'D:/RLV_data\\Violence\\V_992\\',
#  'D:/RLV_data\\Violence\\V_993\\',
#  'D:/RLV_data\\Violence\\V_994\\',
#  'D:/RLV_data\\Violence\\V_995\\',
#  'D:/RLV_data\\Violence\\V_996\\',
#  'D:/RLV_data\\Violence\\V_997\\',
#  'D:/RLV_data\\Violence\\V_998\\',
#  'D:/RLV_data\\Violence\\V_999\\']

# %%
train = []
val = []
test = []
train_y = []
val_y = []
test_y = []

y = 0
for i in tr:
    
    #print(i)
    x = glob(i+'/*/')
    
    #shuffle(x)
    t,tt = train_test_split( x , test_size=0.1, random_state=42)
    t, vv = train_test_split( t , test_size=0.1, random_state=42)
    
    for j in t:
        
        mm = len(glob(j+'/*'))
        
        if(mm<10):
            continue
        
        train.append(j)
        train_y.append(y)
    
    for j in vv:
        
        mm = len(glob(j+'/*'))
        
        if(mm<10):
            continue
            
        val.append(j)
        val_y.append(y)
        
    for j in tt:
        
        mm = len(glob(j+'/*'))
        
        if(mm<10):
            continue
            
        test.append(j)
        test_y.append(y)
        
    y = y+1

from tensorflow.keras.utils import to_categorical
tra_y =  np.array(to_categorical(train_y))
va_y  =  np.array(to_categorical(val_y))
te_y  =  np.array(to_categorical(test_y))

(train, tra_y) = shuffle(train, tra_y)
(val, va_y) = shuffle(val, va_y)
(test, te_y) = shuffle(test, te_y)

# %%
def get_te(k , a) :
    x = glob(k+'/*')
    imgdata=[]
    for i in range(0,20):
        
        a = Image.open(x[i])
        b = a.resize((32, 32))
        c = np.array(b)
        imgdata.append(c.reshape(32,32,3))
        
    idata = np.array(imgdata)
    X_train = idata
    X_train = X_train.astype('float32') / 255.
    #print(np.shape(X_train))
    return X_train

def get_cat(k) :
    return np.array(k)

# %%
class My_Custom_Generator(keras.utils.Sequence) :
  
  def __init__(self, filename , labels, batch_size) :
    self.filename = filename
    self.labels = labels
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.filename) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.filename[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
    y_train = get_cat(batch_y)
    i=0
    return np.array([get_te(i,self.filename)for i in batch_x]), np.array( y_train )

# %%
class My_Test_Generator(keras.utils.Sequence) :
  
  def __init__(self, filename , batch_size) :
    self.filename = filename
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.filename) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.filename[idx * self.batch_size : (idx+1) * self.batch_size]
    i=0
    return np.array([get_te(i,self.filename)for i in batch_x])

# %%
batch_size = 32

my_training_batch_generator = My_Custom_Generator(train, tra_y, batch_size)
my_validation_batch_generator = My_Custom_Generator(val, va_y, batch_size)

# %%
arr = np.array(My_Test_Generator(test, batch_size).__getitem__(1))
for i in range(2,len(x)):
    x = My_Test_Generator(test, batch_size).__getitem__(i)
    arr = np.concatenate((arr,x),axis=0)

# %%
np.shape(arr)
# Out:
# (32, 20, 40, 40, 3)

# %%
arr = np.array(My_Test_Generator(test, batch_size))
# Out:
# C:\Users\chowd\AppData\Local\Temp\ipykernel_13936\1543328956.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.filename) / float(self.batch_size))).astype(np.int)
# C:\Users\chowd\AppData\Local\Temp\ipykernel_13936\701633684.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.array(My_Test_Generator(test, batch_size))

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE

def create_model():
    
    
    model = tf.keras.applications.MobileNetV3Small(
    input_shape=(32,32,3),
    alpha=1.0,
    minimalistic=True,
    include_top=False,
    weights=None,
    input_tensor=None,
    pooling=None,
    dropout_rate=0.2,
    include_preprocessing=True,
)
    

    model.summary()
    return model

model = create_model()
model.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  rescaling_1 (Rescaling)        (None, 32, 32, 3)    0           ['input_2[0][0]']
#
#  Conv (Conv2D)                  (None, 16, 16, 16)   432         ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 16, 16, 16)  64          ['Conv[0][0]']
#  tion)
#
#  re_lu_24 (ReLU)                (None, 16, 16, 16)   0           ['Conv/BatchNorm[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 17, 17, 16)  0           ['re_lu_24[0][0]']
#  eroPadding2D)
#
#  expanded_conv/depthwise (Depth  (None, 8, 8, 16)    144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 8, 8, 16)    64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_25 (ReLU)                (None, 8, 8, 16)     0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 8, 8, 16)    256         ['re_lu_25[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 8, 8, 16)    64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 8, 8, 72)    1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 8, 8, 72)    288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_26 (ReLU)                (None, 8, 8, 72)     0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 9, 9, 72)    0           ['re_lu_26[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 4, 4, 72)    648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 4, 4, 72)    288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_27 (ReLU)                (None, 4, 4, 72)     0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 4, 4, 24)    1728        ['re_lu_27[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 4, 4, 24)    96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 4, 4, 88)    2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 4, 4, 88)    352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_28 (ReLU)                (None, 4, 4, 88)     0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 4, 4, 88)    792         ['re_lu_28[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 4, 4, 88)    352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_29 (ReLU)                (None, 4, 4, 88)     0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 4, 4, 24)    2112        ['re_lu_29[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 4, 4, 24)    96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 4, 4, 24)     0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 4, 4, 96)    2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 4, 4, 96)    384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_30 (ReLU)                (None, 4, 4, 96)     0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 5, 5, 96)    0           ['re_lu_30[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 2, 2, 96)    864         ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 2, 2, 96)    384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_31 (ReLU)                (None, 2, 2, 96)     0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 2, 2, 40)    3840        ['re_lu_31[0][0]']
#  D)
#
#  expanded_conv_3/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 2, 2, 240)   9600        ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 2, 2, 240)   960         ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_32 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 2, 2, 240)   2160        ['re_lu_32[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 2, 2, 240)   960         ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_33 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 2, 2, 40)    9600        ['re_lu_33[0][0]']
#  D)
#
#  expanded_conv_4/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 2, 2, 40)     0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 2, 2, 240)   9600        ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 2, 2, 240)   960         ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_34 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 2, 2, 240)   2160        ['re_lu_34[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 2, 2, 240)   960         ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_35 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 2, 2, 40)    9600        ['re_lu_35[0][0]']
#  D)
#
#  expanded_conv_5/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 2, 2, 40)     0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 2, 2, 120)   4800        ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 2, 2, 120)   480         ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_36 (ReLU)                (None, 2, 2, 120)    0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 2, 2, 120)   1080        ['re_lu_36[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 2, 2, 120)   480         ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_37 (ReLU)                (None, 2, 2, 120)    0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 2, 2, 48)    5760        ['re_lu_37[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 2, 2, 48)    192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 2, 2, 144)   6912        ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 2, 2, 144)   576         ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_38 (ReLU)                (None, 2, 2, 144)    0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 2, 2, 144)   1296        ['re_lu_38[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 2, 2, 144)   576         ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_39 (ReLU)                (None, 2, 2, 144)    0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 2, 2, 48)    6912        ['re_lu_39[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 2, 2, 48)    192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 2, 2, 48)     0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 2, 2, 288)   13824       ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 2, 2, 288)   1152        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_40 (ReLU)                (None, 2, 2, 288)    0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_8/depthwise/pad   (None, 3, 3, 288)   0           ['re_lu_40[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_8/depthwise (Dep  (None, 1, 1, 288)   2592        ['expanded_conv_8/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_8/depthwise/Batc  (None, 1, 1, 288)   1152        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_41 (ReLU)                (None, 1, 1, 288)    0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 1, 1, 96)    27648       ['re_lu_41[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 1, 1, 96)    384         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/expand (Conv2D  (None, 1, 1, 576)   55296       ['expanded_conv_8/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_9/expand/BatchNo  (None, 1, 1, 576)   2304        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_42 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 1, 1, 576)   5184        ['re_lu_42[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 1, 1, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_43 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 1, 1, 96)    55296       ['re_lu_43[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 1, 1, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 1, 1, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 1, 1, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 1, 1, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_44 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 1, 1, 576)   5184        ['re_lu_44[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 1, 1, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  re_lu_45 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 1, 1, 96)    55296       ['re_lu_45[0][0]']
#  2D)
#
#  expanded_conv_10/project/Batch  (None, 1, 1, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 1, 1, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 1, 1, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 1, 1, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  re_lu_46 (ReLU)                (None, 1, 1, 576)    0           ['Conv_1/BatchNorm[0][0]']
#
# ==================================================================================================
# Total params: 441,000
# Trainable params: 428,888
# Non-trainable params: 12,112
# __________________________________________________________________________________________________
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  rescaling_1 (Rescaling)        (None, 32, 32, 3)    0           ['input_2[0][0]']
#
#  Conv (Conv2D)                  (None, 16, 16, 16)   432         ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 16, 16, 16)  64          ['Conv[0][0]']
#  tion)
#
#  re_lu_24 (ReLU)                (None, 16, 16, 16)   0           ['Conv/BatchNorm[0][0]']
#  expanded_conv/depthwise/pad (Z  (None, 17, 17, 16)  0           ['re_lu_24[0][0]']
#  eroPadding2D)
#
#  expanded_conv/depthwise (Depth  (None, 8, 8, 16)    144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 8, 8, 16)    64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_25 (ReLU)                (None, 8, 8, 16)     0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 8, 8, 16)    256         ['re_lu_25[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 8, 8, 16)    64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 8, 8, 72)    1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 8, 8, 72)    288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_26 (ReLU)                (None, 8, 8, 72)     0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 9, 9, 72)    0           ['re_lu_26[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 4, 4, 72)    648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 4, 4, 72)    288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_27 (ReLU)                (None, 4, 4, 72)     0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 4, 4, 24)    1728        ['re_lu_27[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 4, 4, 24)    96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 4, 4, 88)    2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 4, 4, 88)    352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_28 (ReLU)                (None, 4, 4, 88)     0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 4, 4, 88)    792         ['re_lu_28[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 4, 4, 88)    352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_29 (ReLU)                (None, 4, 4, 88)     0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 4, 4, 24)    2112        ['re_lu_29[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 4, 4, 24)    96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 4, 4, 24)     0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 4, 4, 96)    2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 4, 4, 96)    384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_30 (ReLU)                (None, 4, 4, 96)     0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 5, 5, 96)    0           ['re_lu_30[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 2, 2, 96)    864         ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 2, 2, 96)    384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_31 (ReLU)                (None, 2, 2, 96)     0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 2, 2, 40)    3840        ['re_lu_31[0][0]']
#  D)
#
#  expanded_conv_3/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 2, 2, 240)   9600        ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 2, 2, 240)   960         ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_32 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 2, 2, 240)   2160        ['re_lu_32[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 2, 2, 240)   960         ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_33 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 2, 2, 40)    9600        ['re_lu_33[0][0]']
#  D)
#
#  expanded_conv_4/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 2, 2, 40)     0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 2, 2, 240)   9600        ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 2, 2, 240)   960         ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_34 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 2, 2, 240)   2160        ['re_lu_34[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 2, 2, 240)   960         ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_35 (ReLU)                (None, 2, 2, 240)    0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 2, 2, 40)    9600        ['re_lu_35[0][0]']
#  D)
#
#  expanded_conv_5/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 2, 2, 40)     0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 2, 2, 120)   4800        ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 2, 2, 120)   480         ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_36 (ReLU)                (None, 2, 2, 120)    0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]']
#  expanded_conv_6/depthwise (Dep  (None, 2, 2, 120)   1080        ['re_lu_36[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 2, 2, 120)   480         ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_37 (ReLU)                (None, 2, 2, 120)    0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 2, 2, 48)    5760        ['re_lu_37[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 2, 2, 48)    192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 2, 2, 144)   6912        ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 2, 2, 144)   576         ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_38 (ReLU)                (None, 2, 2, 144)    0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 2, 2, 144)   1296        ['re_lu_38[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 2, 2, 144)   576         ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_39 (ReLU)                (None, 2, 2, 144)    0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 2, 2, 48)    6912        ['re_lu_39[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 2, 2, 48)    192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 2, 2, 48)     0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 2, 2, 288)   13824       ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 2, 2, 288)   1152        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_40 (ReLU)                (None, 2, 2, 288)    0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_8/depthwise/pad   (None, 3, 3, 288)   0           ['re_lu_40[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_8/depthwise (Dep  (None, 1, 1, 288)   2592        ['expanded_conv_8/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_8/depthwise/Batc  (None, 1, 1, 288)   1152        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_41 (ReLU)                (None, 1, 1, 288)    0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 1, 1, 96)    27648       ['re_lu_41[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 1, 1, 96)    384         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/expand (Conv2D  (None, 1, 1, 576)   55296       ['expanded_conv_8/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_9/expand/BatchNo  (None, 1, 1, 576)   2304        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_42 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 1, 1, 576)   5184        ['re_lu_42[0][0]']
#  thwiseConv2D)
#  expanded_conv_9/depthwise/Batc  (None, 1, 1, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_43 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 1, 1, 96)    55296       ['re_lu_43[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 1, 1, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 1, 1, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 1, 1, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 1, 1, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_44 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 1, 1, 576)   5184        ['re_lu_44[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 1, 1, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  re_lu_45 (ReLU)                (None, 1, 1, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 1, 1, 96)    55296       ['re_lu_45[0][0]']
#  2D)
#
#  expanded_conv_10/project/Batch  (None, 1, 1, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 1, 1, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 1, 1, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 1, 1, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  re_lu_46 (ReLU)                (None, 1, 1, 576)    0           ['Conv_1/BatchNorm[0][0]']
#
# ==================================================================================================
# Total params: 441,000
# Trainable params: 428,888
# Non-trainable params: 12,112
# __________________________________________________________________________________________________

# %%
DATASET_NAME = "organmnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = ( 6, 28, 28, 3 )
NUM_CLASSES = 2

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 60

# TUBELET EMBEDDING
PATCH_SIZE = (4, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 2
NUM_LAYERS = 2

# %%
#Patch Encoder with Conv2D ,  LSTM , Pos_Emd

class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        model = create_model()
        self.projection =keras.Sequential(
            [
               TimeDistributed ( tf.keras.applications.MobileNetV3Small(
    input_shape=(32,32,3),
    alpha=1.0,
    minimalistic=True,
    include_top=False,
    weights=None,
    input_tensor=None,
    pooling=None,
    dropout_rate=0.2,
    include_preprocessing=True,
) ) ,
                TimeDistributed(Flatten()),
                layers.Dense(projection_dim)
            ]) 
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
#Patch Encoder with Conv2D ,  LSTM , Pos_Emd

class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection =keras.Sequential(
            [
                (layers.Conv2D(4, (3, 3), strides=(1,1),activation='relu')),
                TimeDistributed(MaxPooling2D(2,2)),
                (layers.Conv2D(8, (3, 3), strides=(1,1),activation='relu')),
                TimeDistributed(MaxPooling2D(2,2)),
                (layers.Conv2D(16, (3, 3), strides=(1,1),activation='relu')),
                TimeDistributed(MaxPooling2D(2,2)),
                TimeDistributed(Flatten()),
                layers.Dense(projection_dim)
            ]) 
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models

inputs = layers.Input(shape= (20,32,32,3) )

encoded_patches = (PatchEncoder(20, 32 )) (inputs)

for _ in range(6):
    
    x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)

    attention_output = layers.MultiHeadAttention (  num_heads=6, key_dim=32, dropout=0.1 )  (x1, x1)
    
    lstm_output =  LSTM(32,return_sequences=True,dropout=0.3)(x1)

    x2 = layers.Add()([attention_output, encoded_patches,lstm_output])

        # Layer Normalization and MLP
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)


    x3 = keras.Sequential(layers.Dense(units=32, activation=tf.nn.gelu) )(x3)

        # Skip connection
    encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)

representation = layers.GlobalAvgPool1D()(representation)

outputs = layers.Dense(units=2, activation="softmax") ( representation)

model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  rescaling_9 (Rescaling)        (None, 32, 32, 3)    0           ['input_16[0][0]']
#
#  Conv (Conv2D)                  (None, 16, 16, 16)   432         ['rescaling_9[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 16, 16, 16)  64          ['Conv[0][0]']
#  tion)
#
#  re_lu_208 (ReLU)               (None, 16, 16, 16)   0           ['Conv/BatchNorm[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 17, 17, 16)  0           ['re_lu_208[0][0]']
#  eroPadding2D)
#
#  expanded_conv/depthwise (Depth  (None, 8, 8, 16)    144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 8, 8, 16)    64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_209 (ReLU)               (None, 8, 8, 16)     0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 8, 8, 16)    256         ['re_lu_209[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 8, 8, 16)    64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 8, 8, 72)    1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 8, 8, 72)    288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_210 (ReLU)               (None, 8, 8, 72)     0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 9, 9, 72)    0           ['re_lu_210[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 4, 4, 72)    648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 4, 4, 72)    288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_211 (ReLU)               (None, 4, 4, 72)     0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 4, 4, 24)    1728        ['re_lu_211[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 4, 4, 24)    96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 4, 4, 88)    2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 4, 4, 88)    352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_212 (ReLU)               (None, 4, 4, 88)     0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 4, 4, 88)    792         ['re_lu_212[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 4, 4, 88)    352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_213 (ReLU)               (None, 4, 4, 88)     0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 4, 4, 24)    2112        ['re_lu_213[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 4, 4, 24)    96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 4, 4, 24)     0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 4, 4, 96)    2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 4, 4, 96)    384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_214 (ReLU)               (None, 4, 4, 96)     0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 5, 5, 96)    0           ['re_lu_214[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 2, 2, 96)    864         ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 2, 2, 96)    384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_215 (ReLU)               (None, 2, 2, 96)     0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 2, 2, 40)    3840        ['re_lu_215[0][0]']
#  D)
#
#  expanded_conv_3/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 2, 2, 240)   9600        ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 2, 2, 240)   960         ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_216 (ReLU)               (None, 2, 2, 240)    0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 2, 2, 240)   2160        ['re_lu_216[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 2, 2, 240)   960         ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_217 (ReLU)               (None, 2, 2, 240)    0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 2, 2, 40)    9600        ['re_lu_217[0][0]']
#  D)
#
#  expanded_conv_4/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 2, 2, 40)     0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 2, 2, 240)   9600        ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 2, 2, 240)   960         ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_218 (ReLU)               (None, 2, 2, 240)    0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 2, 2, 240)   2160        ['re_lu_218[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 2, 2, 240)   960         ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_219 (ReLU)               (None, 2, 2, 240)    0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 2, 2, 40)    9600        ['re_lu_219[0][0]']
#  D)
#
#  expanded_conv_5/project/BatchN  (None, 2, 2, 40)    160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 2, 2, 40)     0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 2, 2, 120)   4800        ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 2, 2, 120)   480         ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_220 (ReLU)               (None, 2, 2, 120)    0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 2, 2, 120)   1080        ['re_lu_220[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 2, 2, 120)   480         ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_221 (ReLU)               (None, 2, 2, 120)    0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 2, 2, 48)    5760        ['re_lu_221[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 2, 2, 48)    192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 2, 2, 144)   6912        ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 2, 2, 144)   576         ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_222 (ReLU)               (None, 2, 2, 144)    0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 2, 2, 144)   1296        ['re_lu_222[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 2, 2, 144)   576         ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_223 (ReLU)               (None, 2, 2, 144)    0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 2, 2, 48)    6912        ['re_lu_223[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 2, 2, 48)    192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 2, 2, 48)     0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 2, 2, 288)   13824       ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 2, 2, 288)   1152        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_224 (ReLU)               (None, 2, 2, 288)    0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_8/depthwise/pad   (None, 3, 3, 288)   0           ['re_lu_224[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_8/depthwise (Dep  (None, 1, 1, 288)   2592        ['expanded_conv_8/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_8/depthwise/Batc  (None, 1, 1, 288)   1152        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_225 (ReLU)               (None, 1, 1, 288)    0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 1, 1, 96)    27648       ['re_lu_225[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 1, 1, 96)    384         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/expand (Conv2D  (None, 1, 1, 576)   55296       ['expanded_conv_8/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_9/expand/BatchNo  (None, 1, 1, 576)   2304        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_226 (ReLU)               (None, 1, 1, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 1, 1, 576)   5184        ['re_lu_226[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 1, 1, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_227 (ReLU)               (None, 1, 1, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 1, 1, 96)    55296       ['re_lu_227[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 1, 1, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 1, 1, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 1, 1, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 1, 1, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_228 (ReLU)               (None, 1, 1, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 1, 1, 576)   5184        ['re_lu_228[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 1, 1, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  re_lu_229 (ReLU)               (None, 1, 1, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 1, 1, 96)    55296       ['re_lu_229[0][0]']
#  2D)
#
#  expanded_conv_10/project/Batch  (None, 1, 1, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 1, 1, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 1, 1, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 1, 1, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  re_lu_230 (ReLU)               (None, 1, 1, 576)    0           ['Conv_1/BatchNorm[0][0]']
#
# ==================================================================================================
# Total params: 441,000
# Trainable params: 428,888
# Non-trainable params: 12,112
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 20, 32, 32,  0           []
#                                  3)]
#
#  patch_encoder_5 (PatchEncoder)  (None, 20, 32)      460104      ['input_15[0][0]']
#
#  layer_normalization (LayerNorm  (None, 20, 32)      64          ['patch_encoder_5[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 20, 32)      25184       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#  lstm (LSTM)                    (None, 20, 32)       8320        ['layer_normalization[0][0]']
#
#  add (Add)                      (None, 20, 32)       0           ['multi_head_attention[0][0]',
#                                                                   'patch_encoder_5[0][0]',
#                                                                   'lstm[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 20, 32)      64          ['add[0][0]']
#  rmalization)
#
#  sequential_3 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_1[0][0]']
#
#  add_1 (Add)                    (None, 20, 32)       0           ['sequential_3[0][0]',
#                                                                   'add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 20, 32)      64          ['add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 20, 32)      25184       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_2[0][0]']
#
#  add_2 (Add)                    (None, 20, 32)       0           ['multi_head_attention_1[0][0]',
#                                                                   'add_1[0][0]',
#                                                                   'lstm_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 20, 32)      64          ['add_2[0][0]']
#  rmalization)
#
#  sequential_4 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_3[0][0]']
#
#  add_3 (Add)                    (None, 20, 32)       0           ['sequential_4[0][0]',
#                                                                   'add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 20, 32)      64          ['add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 20, 32)      25184       ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  lstm_2 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 20, 32)       0           ['multi_head_attention_2[0][0]',
#                                                                   'add_3[0][0]',
#                                                                   'lstm_2[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 20, 32)      64          ['add_4[0][0]']
#  rmalization)
#
#  sequential_5 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_5[0][0]']
#
#  add_5 (Add)                    (None, 20, 32)       0           ['sequential_5[0][0]',
#                                                                   'add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 20, 32)      64          ['add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 20, 32)      25184       ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  lstm_3 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_6[0][0]']
#
#  add_6 (Add)                    (None, 20, 32)       0           ['multi_head_attention_3[0][0]',
#                                                                   'add_5[0][0]',
#                                                                   'lstm_3[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 20, 32)      64          ['add_6[0][0]']
#  rmalization)
#
#  sequential_6 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_7[0][0]']
#
#  add_7 (Add)                    (None, 20, 32)       0           ['sequential_6[0][0]',
#                                                                   'add_6[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 20, 32)      64          ['add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 20, 32)      25184       ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  lstm_4 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_8[0][0]']
#
#  add_8 (Add)                    (None, 20, 32)       0           ['multi_head_attention_4[0][0]',
#                                                                   'add_7[0][0]',
#                                                                   'lstm_4[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 20, 32)      64          ['add_8[0][0]']
#  rmalization)
#
#  sequential_7 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_9[0][0]']
#
#  add_9 (Add)                    (None, 20, 32)       0           ['sequential_7[0][0]',
#                                                                   'add_8[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 20, 32)      64          ['add_9[0][0]']
#  ormalization)
#
#  multi_head_attention_5 (MultiH  (None, 20, 32)      25184       ['layer_normalization_10[0][0]',
#  eadAttention)                                                    'layer_normalization_10[0][0]']
#
#  lstm_5 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_10[0][0]']
#
#  add_10 (Add)                   (None, 20, 32)       0           ['multi_head_attention_5[0][0]',
#                                                                   'add_9[0][0]',
#                                                                   'lstm_5[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 20, 32)      64          ['add_10[0][0]']
#  ormalization)
#
#  sequential_8 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_11[0][0]']
#
#  add_11 (Add)                   (None, 20, 32)       0           ['sequential_8[0][0]',
#                                                                   'add_10[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 20, 32)      64          ['add_11[0][0]']
#  ormalization)
#
#  global_average_pooling1d (Glob  (None, 32)          0           ['layer_normalization_12[0][0]']
#  alAveragePooling1D)
#
#  dense_9 (Dense)                (None, 2)            66          ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 668,362
# Trainable params: 656,250
# Non-trainable params: 12,112
# __________________________________________________________________________________________________

# %%
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)
optimizer = keras.optimizers.Adam(lr_schedule)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='accuracy')
model.fit_generator(generator=my_training_batch_generator, epochs = 50,validation_data = my_validation_batch_generator)
# Out:
# C:\Users\chowd\AppData\Local\Temp\ipykernel_17876\2654258549.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator=my_training_batch_generator, epochs = 50,validation_data = my_validation_batch_generator)
# C:\Users\chowd\AppData\Local\Temp\ipykernel_17876\2168406815.py:10: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.filename) / float(self.batch_size))).astype(np.int)
# Epoch 1/50
# 51/51 [==============================] - 392s 7s/step - loss: 0.7207 - accuracy: 0.5716 - val_loss: 0.7250 - val_accuracy: 0.5000
# Epoch 2/50
# 51/51 [==============================] - 284s 6s/step - loss: 0.6469 - accuracy: 0.6327 - val_loss: 0.7085 - val_accuracy: 0.5000
# Epoch 3/50
# 51/51 [==============================] - 231s 5s/step - loss: 0.6129 - accuracy: 0.6636 - val_loss: 0.9687 - val_accuracy: 0.5000
# Epoch 4/50
# 51/51 [==============================] - 266s 5s/step - loss: 0.5914 - accuracy: 0.6858 - val_loss: 1.0681 - val_accuracy: 0.5000
# Epoch 5/50
# 51/51 [==============================] - 222s 4s/step - loss: 0.5568 - accuracy: 0.7086 - val_loss: 1.0653 - val_accuracy: 0.5000
# Epoch 6/50
# 51/51 [==============================] - 263s 5s/step - loss: 0.5113 - accuracy: 0.7562 - val_loss: 1.3690 - val_accuracy: 0.5000
# Epoch 7/50
# 51/51 [==============================] - 216s 4s/step - loss: 0.4896 - accuracy: 0.7698 - val_loss: 1.3957 - val_accuracy: 0.5000
# Epoch 8/50
# 51/51 [==============================] - 214s 4s/step - loss: 0.4508 - accuracy: 0.7951 - val_loss: 1.8155 - val_accuracy: 0.5000
# Epoch 9/50
# 51/51 [==============================] - 208s 4s/step - loss: 0.4165 - accuracy: 0.8062 - val_loss: 1.9829 - val_accuracy: 0.5000
# Epoch 10/50
# 51/51 [==============================] - 208s 4s/step - loss: 0.3755 - accuracy: 0.8414 - val_loss: 2.0173 - val_accuracy: 0.5000
# Epoch 11/50
# 51/51 [==============================] - 211s 4s/step - loss: 0.3586 - accuracy: 0.8370 - val_loss: 1.8979 - val_accuracy: 0.5000
# Epoch 12/50
# 51/51 [==============================] - 197s 4s/step - loss: 0.3325 - accuracy: 0.8512 - val_loss: 2.5614 - val_accuracy: 0.5000
# Epoch 13/50
# 51/51 [==============================] - 183s 4s/step - loss: 0.2889 - accuracy: 0.8772 - val_loss: 2.7145 - val_accuracy: 0.5000
# Epoch 14/50
# 51/51 [==============================] - 178s 4s/step - loss: 0.3022 - accuracy: 0.8716 - val_loss: 2.2878 - val_accuracy: 0.5000
# Epoch 15/50
# 51/51 [==============================] - 180s 4s/step - loss: 0.2443 - accuracy: 0.9068 - val_loss: 2.8582 - val_accuracy: 0.5000
# Epoch 16/50
# 51/51 [==============================] - 175s 3s/step - loss: 0.2394 - accuracy: 0.9049 - val_loss: 2.5172 - val_accuracy: 0.5000
# 51/51 [==============================] - 180s 4s/step - loss: 0.0768 - accuracy: 0.9667 - val_loss: 4.5601 - val_accuracy: 0.5000
# Epoch 37/50
# 51/51 [==============================] - 186s 4s/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 4.5659 - val_accuracy: 0.5000
# Epoch 38/50
# 51/51 [==============================] - 188s 4s/step - loss: 0.0597 - accuracy: 0.9772 - val_loss: 4.0359 - val_accuracy: 0.5000
# Epoch 39/50
# 51/51 [==============================] - 188s 4s/step - loss: 0.0982 - accuracy: 0.9623 - val_loss: 3.8717 - val_accuracy: 0.5000
# Epoch 40/50
# 51/51 [==============================] - 175s 3s/step - loss: 0.0604 - accuracy: 0.9759 - val_loss: 4.5775 - val_accuracy: 0.5000
# Epoch 41/50
# 51/51 [==============================] - 175s 3s/step - loss: 0.0425 - accuracy: 0.9858 - val_loss: 2.8350 - val_accuracy: 0.5000
# Epoch 42/50
# 51/51 [==============================] - 176s 3s/step - loss: 0.0501 - accuracy: 0.9827 - val_loss: 5.2599 - val_accuracy: 0.5000
# Epoch 43/50
# 51/51 [==============================] - 187s 4s/step - loss: 0.0632 - accuracy: 0.9747 - val_loss: 4.6046 - val_accuracy: 0.5000
# Epoch 44/50
# 51/51 [==============================] - 176s 3s/step - loss: 0.0541 - accuracy: 0.9790 - val_loss: 1.1598 - val_accuracy: 0.5000
# Epoch 45/50
# 51/51 [==============================] - 175s 3s/step - loss: 0.0253 - accuracy: 0.9907 - val_loss: 5.2167 - val_accuracy: 0.5000
# Epoch 46/50
# 51/51 [==============================] - 180s 4s/step - loss: 0.0278 - accuracy: 0.9907 - val_loss: 3.4682 - val_accuracy: 0.5000
# Epoch 47/50
# 51/51 [==============================] - 174s 3s/step - loss: 0.1360 - accuracy: 0.9451 - val_loss: 1.6319 - val_accuracy: 0.5000
# Epoch 48/50
# 51/51 [==============================] - 179s 4s/step - loss: 0.0826 - accuracy: 0.9654 - val_loss: 1.4409 - val_accuracy: 0.5000
# Epoch 49/50
# 51/51 [==============================] - 186s 4s/step - loss: 0.0793 - accuracy: 0.9716 - val_loss: 2.0753 - val_accuracy: 0.5333
# Epoch 50/50
# 51/51 [==============================] - 182s 4s/step - loss: 0.0601 - accuracy: 0.9796 - val_loss: 5.0891 - val_accuracy: 0.5000

# %%
model2 = Model(model.input, model.layers[-2].output)
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 20, 40, 40,  0           []
#                                  3)]
#
#  patch_encoder (PatchEncoder)   (None, 20, 32)       6856        ['input_1[0][0]']
#
#  layer_normalization (LayerNorm  (None, 20, 32)      64          ['patch_encoder[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 20, 32)      25184       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  lstm (LSTM)                    (None, 20, 32)       8320        ['layer_normalization[0][0]']
#
#  add (Add)                      (None, 20, 32)       0           ['multi_head_attention[0][0]',
#                                                                   'patch_encoder[0][0]',
#                                                                   'lstm[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 20, 32)      64          ['add[0][0]']
#  rmalization)
#
#  sequential_1 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_1[0][0]']
#
#  add_1 (Add)                    (None, 20, 32)       0           ['sequential_1[0][0]',
#                                                                   'add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 20, 32)      64          ['add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 20, 32)      25184       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_2[0][0]']
#
#  add_2 (Add)                    (None, 20, 32)       0           ['multi_head_attention_1[0][0]',
#                                                                   'add_1[0][0]',
#                                                                   'lstm_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 20, 32)      64          ['add_2[0][0]']
#  rmalization)
#
#  sequential_2 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_3[0][0]']
#
#  add_3 (Add)                    (None, 20, 32)       0           ['sequential_2[0][0]',
#                                                                   'add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 20, 32)      64          ['add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 20, 32)      25184       ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  lstm_2 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 20, 32)       0           ['multi_head_attention_2[0][0]',
#                                                                   'add_3[0][0]',
#                                                                   'lstm_2[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 20, 32)      64          ['add_4[0][0]']
#  rmalization)
#
#  sequential_3 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_5[0][0]']
#
#  add_5 (Add)                    (None, 20, 32)       0           ['sequential_3[0][0]',
#                                                                   'add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 20, 32)      64          ['add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 20, 32)      25184       ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  lstm_3 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_6[0][0]']
#
#  add_6 (Add)                    (None, 20, 32)       0           ['multi_head_attention_3[0][0]',
#                                                                   'add_5[0][0]',
#                                                                   'lstm_3[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 20, 32)      64          ['add_6[0][0]']
#  rmalization)
#  sequential_4 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_7[0][0]']
#
#  add_7 (Add)                    (None, 20, 32)       0           ['sequential_4[0][0]',
#                                                                   'add_6[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 20, 32)      64          ['add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 20, 32)      25184       ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  lstm_4 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_8[0][0]']
#
#  add_8 (Add)                    (None, 20, 32)       0           ['multi_head_attention_4[0][0]',
#                                                                   'add_7[0][0]',
#                                                                   'lstm_4[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 20, 32)      64          ['add_8[0][0]']
#  rmalization)
#
#  sequential_5 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_9[0][0]']
#
#  add_9 (Add)                    (None, 20, 32)       0           ['sequential_5[0][0]',
#                                                                   'add_8[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 20, 32)      64          ['add_9[0][0]']
#  ormalization)
#
#  multi_head_attention_5 (MultiH  (None, 20, 32)      25184       ['layer_normalization_10[0][0]',
#  eadAttention)                                                    'layer_normalization_10[0][0]']
#
#  lstm_5 (LSTM)                  (None, 20, 32)       8320        ['layer_normalization_10[0][0]']
#
#  add_10 (Add)                   (None, 20, 32)       0           ['multi_head_attention_5[0][0]',
#                                                                   'add_9[0][0]',
#                                                                   'lstm_5[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 20, 32)      64          ['add_10[0][0]']
#  ormalization)
#
#  sequential_6 (Sequential)      (None, 20, 32)       1056        ['layer_normalization_11[0][0]']
#
#  add_11 (Add)                   (None, 20, 32)       0           ['sequential_6[0][0]',
#                                                                   'add_10[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 20, 32)      64          ['add_11[0][0]']
#  ormalization)
#
#  global_average_pooling1d (Glob  (None, 32)          0           ['layer_normalization_12[0][0]']
#  alAveragePooling1D)
#
# ==================================================================================================
# Total params: 215,048
# Trainable params: 215,048
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
#, training=False

inputs = layers.Input(shape= (20,40,40,3) )

representation = model2 (inputs)

outputs = layers.Dense(units=2, activation="softmax") ( representation)

model3 = keras.Model(inputs=inputs, outputs=outputs)
model3.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 20, 40, 40, 3)]   0
#
#  model_1 (Functional)        (None, 32)                215048
#
#  dense_8 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 215,114
# Trainable params: 215,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
initial_learning_rate = 0.0001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)
optimizer = keras.optimizers.Adam(lr_schedule)

model3.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='accuracy')
model3.fit_generator(generator=my_training_batch_generator, epochs = 30,validation_data = my_validation_batch_generator)
# Out:
# C:\Users\chowd\AppData\Local\Temp\ipykernel_6088\1489281914.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model3.fit_generator(generator=my_training_batch_generator, epochs = 30,validation_data = my_validation_batch_generator)
# C:\Users\chowd\AppData\Local\Temp\ipykernel_6088\2168406815.py:10: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.filename) / float(self.batch_size))).astype(np.int)
# Epoch 1/30
# 51/51 [==============================] - 448s 9s/step - loss: 0.9787 - accuracy: 0.6290 - val_loss: 0.6912 - val_accuracy: 0.7333
# Epoch 2/30
# 51/51 [==============================] - 299s 6s/step - loss: 0.7690 - accuracy: 0.6840 - val_loss: 0.6488 - val_accuracy: 0.7333
# Epoch 3/30
# 51/51 [==============================] - 283s 6s/step - loss: 0.6372 - accuracy: 0.7204 - val_loss: 0.6090 - val_accuracy: 0.7667
# Epoch 4/30
# 51/51 [==============================] - 280s 6s/step - loss: 0.5812 - accuracy: 0.7333 - val_loss: 0.5722 - val_accuracy: 0.7778
# Epoch 5/30
# 51/51 [==============================] - 289s 6s/step - loss: 0.5299 - accuracy: 0.7611 - val_loss: 0.5715 - val_accuracy: 0.7778
# Epoch 6/30
# 51/51 [==============================] - 324s 6s/step - loss: 0.4802 - accuracy: 0.7691 - val_loss: 0.5629 - val_accuracy: 0.7833
# Epoch 7/30
# 51/51 [==============================] - 287s 6s/step - loss: 0.4482 - accuracy: 0.7907 - val_loss: 0.5379 - val_accuracy: 0.7944
# Epoch 8/30
# 51/51 [==============================] - 291s 6s/step - loss: 0.4196 - accuracy: 0.8074 - val_loss: 0.5388 - val_accuracy: 0.7889
# Epoch 9/30
# 51/51 [==============================] - 351s 7s/step - loss: 0.3896 - accuracy: 0.8284 - val_loss: 0.5376 - val_accuracy: 0.7833
# Epoch 10/30
# 51/51 [==============================] - 263s 5s/step - loss: 0.3732 - accuracy: 0.8401 - val_loss: 0.5392 - val_accuracy: 0.7778
# Epoch 11/30
