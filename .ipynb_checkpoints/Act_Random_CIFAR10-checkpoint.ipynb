# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd
#import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns
import shutil
import keras
from PIL import Image
#import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()
from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_labels = to_categorical(train_labels)
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')
train_images = train_images / 255
test_images = test_images / 255

# %%
np.shape(x_train)
# Out:
# (18000, 32, 32, 3)

# %%
x_train, x_unlab, y_train, y_unlab = train_test_split( train_images, train_labels , test_size=0.8, random_state=42 )

# %%
X_train, X_test, Y_train, Y_test = train_test_split( x_train,y_train , test_size=0.5, random_state=40 )

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["accuracy"]
    val_accuracy = val_accuracy + history.history["val_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'num_patches': self.num_patches,
            'projection': self.projection,
            'position_embedding': self.position_embedding
        })
        return config

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection =keras.Sequential(
            [
                (layers.Conv2D(4, (3, 3), strides=(2,2),activation='relu')),
                TimeDistributed(Flatten()),
                layers.LSTM(projection_dim,return_sequences=True,dropout=0.1),
            ]) 
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE

def create_model():
    
    
    model = models.Sequential()
    model.add(layers.Conv2D(2, (3, 3), input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(4, (3, 3), activation="relu"))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(4, (3, 3),))
    model.add(layers.Conv2D(8, (3, 3),))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(8, (3, 3),))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten()) 
    model.add(layers.Dense(32))
    model.add(layers.Dense(10, activation="softmax"))

    model.summary()
    return model

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE

def create_model():
    
    
    model = tf.keras.applications.MobileNetV3Large(
    input_shape=(32,32,3),
    alpha=1.0,
    minimalistic=False,
    include_top=True,
    weights=None,
    input_tensor=None,
    classes=10,
    pooling=None,
    dropout_rate=0.2,
    classifier_activation="softmax",
    include_preprocessing=True,
)

    model.summary()
    return model

# %%
# callbacks=[keras.callbacks.EarlyStopping(patience=4, verbose=1), ],

def train_full_model(X_train, X_test, Y_train, Y_test):
    model = create_model()
    model.compile( loss="categorical_crossentropy",  optimizer="Adam",  metrics='accuracy' )

    history = model.fit( X_train, Y_train, batch_size = 256, epochs=30,
                        validation_split=.30,callbacks=[ keras.callbacks.ModelCheckpoint( "FullModelCheckpoint.h5",
                        verbose=1, save_best_only=True ), ], )

    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["accuracy"],
        history.history["val_accuracy"],
    )


    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate( X_test, Y_test , verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


full_dataset_model = train_full_model(X_train, X_test, Y_train, Y_test)
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 32, 32, 3)    0           ['input_1[0][0]']
#
#  Conv (Conv2D)                  (None, 16, 16, 16)   432         ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 16, 16, 16)  64          ['Conv[0][0]']
#  tion)
#
#  tf.__operators__.add (TFOpLamb  (None, 16, 16, 16)  0           ['Conv/BatchNorm[0][0]']
#  da)
#
#  re_lu (ReLU)                   (None, 16, 16, 16)   0           ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 16, 16, 16)   0           ['re_lu[0][0]']
#
#  multiply (Multiply)            (None, 16, 16, 16)   0           ['Conv/BatchNorm[0][0]',
#                                                                   'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 16, 16, 16)  144         ['multiply[0][0]']
#  wiseConv2D)
#
#  expanded_conv/depthwise/BatchN  (None, 16, 16, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_1 (ReLU)                 (None, 16, 16, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 16, 16, 16)  256         ['re_lu_1[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 16, 16, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv/Add (Add)        (None, 16, 16, 16)   0           ['multiply[0][0]',
#                                                                   'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 16, 16, 64)  1024        ['expanded_conv/Add[0][0]']
#  )
#
#  expanded_conv_1/expand/BatchNo  (None, 16, 16, 64)  256         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_2 (ReLU)                 (None, 16, 16, 64)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 17, 17, 64)  0           ['re_lu_2[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 8, 8, 64)    576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 8, 8, 64)    256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_3 (ReLU)                 (None, 8, 8, 64)     0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 8, 8, 24)    1536        ['re_lu_3[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 8, 8, 24)    96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 8, 8, 72)    1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 8, 8, 72)    288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_4 (ReLU)                 (None, 8, 8, 72)     0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 8, 8, 72)    648         ['re_lu_4[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 8, 8, 72)    288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_5 (ReLU)                 (None, 8, 8, 72)     0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 8, 8, 24)    1728        ['re_lu_5[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 8, 8, 24)    96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 8, 8, 24)     0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 8, 8, 72)    1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 8, 8, 72)    288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_6 (ReLU)                 (None, 8, 8, 72)     0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 11, 11, 72)  0           ['re_lu_6[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 4, 4, 72)    1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 4, 4, 72)    288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_7 (ReLU)                 (None, 4, 4, 72)     0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_7[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 1, 1, 72)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 72)    0           ['re_lu_8[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, 4, 4, 72)    0           ['re_lu_7[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 4, 4, 40)    2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 4, 4, 40)    160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 4, 4, 120)   4800        ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 4, 4, 120)   480         ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_9 (ReLU)                 (None, 4, 4, 120)    0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 4, 4, 120)   3000        ['re_lu_9[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 4, 4, 120)   480         ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_10 (ReLU)                (None, 4, 4, 120)    0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_11 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_11[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, 4, 4, 120)   0           ['re_lu_10[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 4, 4, 40)    4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 4, 4, 40)    160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 4, 4, 40)     0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 4, 4, 120)   4800        ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 4, 4, 120)   480         ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_12 (ReLU)                (None, 4, 4, 120)    0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 4, 4, 120)   3000        ['re_lu_12[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 4, 4, 120)   480         ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_13 (ReLU)                (None, 4, 4, 120)    0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_13[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_14 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_14[0][0]']
#  )
#
#  expanded_conv_5/squeeze_excite  (None, 4, 4, 120)   0           ['re_lu_13[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 4, 4, 40)    4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 4, 4, 40)    160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 4, 4, 40)     0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 4, 4, 240)   9600        ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 4, 4, 240)   960         ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 4, 4, 240)   0           ['expanded_conv_6/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_15 (ReLU)                (None, 4, 4, 240)    0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 4, 4, 240)   0           ['re_lu_15[0][0]']
#  )
#
#  multiply_1 (Multiply)          (None, 4, 4, 240)    0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 5, 5, 240)   0           ['multiply_1[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 2, 2, 240)   2160        ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 2, 2, 240)   960         ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 2, 2, 240)   0           ['expanded_conv_6/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_16 (ReLU)                (None, 2, 2, 240)    0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 2, 2, 240)   0           ['re_lu_16[0][0]']
#  )
#
#  multiply_2 (Multiply)          (None, 2, 2, 240)    0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 2, 2, 80)    19200       ['multiply_2[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 2, 2, 80)    320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 2, 2, 200)   16000       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 2, 2, 200)   800         ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 2, 2, 200)   0           ['expanded_conv_7/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_17 (ReLU)                (None, 2, 2, 200)    0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 2, 2, 200)   0           ['re_lu_17[0][0]']
#  )
#
#  multiply_3 (Multiply)          (None, 2, 2, 200)    0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 2, 2, 200)   1800        ['multiply_3[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 2, 2, 200)   800         ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 2, 2, 200)   0           ['expanded_conv_7/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_18 (ReLU)                (None, 2, 2, 200)    0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 2, 2, 200)   0           ['re_lu_18[0][0]']
#  )
#
#  multiply_4 (Multiply)          (None, 2, 2, 200)    0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 2, 2, 80)    16000       ['multiply_4[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 2, 2, 80)    320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 2, 2, 80)     0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 2, 2, 184)   14720       ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 2, 2, 184)   736         ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 2, 2, 184)   0           ['expanded_conv_8/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_19 (ReLU)                (None, 2, 2, 184)    0           ['tf.__operators__.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 2, 2, 184)   0           ['re_lu_19[0][0]']
#  )
#
#  multiply_5 (Multiply)          (None, 2, 2, 184)    0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 2, 2, 184)   1656        ['multiply_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 2, 2, 184)   736         ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 2, 2, 184)   0           ['expanded_conv_8/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, 2, 2, 184)    0           ['tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 2, 2, 184)   0           ['re_lu_20[0][0]']
#  )
#
#  multiply_6 (Multiply)          (None, 2, 2, 184)    0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 2, 2, 80)    14720       ['multiply_6[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 2, 2, 80)    320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 2, 2, 80)     0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 2, 2, 184)   14720       ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 2, 2, 184)   736         ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 2, 2, 184)   0           ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_21 (ReLU)                (None, 2, 2, 184)    0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 2, 2, 184)   0           ['re_lu_21[0][0]']
#  a)
#
#  multiply_7 (Multiply)          (None, 2, 2, 184)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 2, 2, 184)   1656        ['multiply_7[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 2, 2, 184)   736         ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_11 (TFOpL  (None, 2, 2, 184)   0           ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_22 (ReLU)                (None, 2, 2, 184)    0           ['tf.__operators__.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 2, 2, 184)   0           ['re_lu_22[0][0]']
#  a)
#
#  multiply_8 (Multiply)          (None, 2, 2, 184)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 2, 2, 80)    14720       ['multiply_8[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 2, 2, 80)    320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 2, 2, 80)     0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 2, 2, 480)   38400       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 2, 2, 480)   1920        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 2, 2, 480)   0           ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_23 (ReLU)                (None, 2, 2, 480)    0           ['tf.__operators__.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 2, 2, 480)   0           ['re_lu_23[0][0]']
#  a)
#
#  multiply_9 (Multiply)          (None, 2, 2, 480)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 2, 2, 480)   4320        ['multiply_9[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 2, 2, 480)   1920        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 2, 2, 480)   0           ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_24 (ReLU)                (None, 2, 2, 480)    0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 2, 2, 480)   0           ['re_lu_24[0][0]']
#  a)
#
#  multiply_10 (Multiply)         (None, 2, 2, 480)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_13[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_10[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   58080       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
# ...
#  tf.__operators__.add_22 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_13/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_33 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_33[0][0]']
#  a)
#
#  multiply_16 (Multiply)         (None, 1, 1, 960)    0           ['expanded_conv_13/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_22[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_16[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_13/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_34[0][0]']
#  a)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_16[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_23[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 1, 1, 160)   153600      ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 1, 1, 160)   640         ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 1, 1, 160)    0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 1, 1, 960)   153600      ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 1, 1, 960)   3840        ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_24 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_35 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_35[0][0]']
#  a)
#
#  multiply_17 (Multiply)         (None, 1, 1, 960)    0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_24[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 1, 1, 960)   24000       ['multiply_17[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 1, 1, 960)   3840        ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_36 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_36[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 1, 1, 960)    0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_25[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_18[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_37 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_37[0][0]']
#  a)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_18[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_26[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 1, 1, 160)   153600      ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 1, 1, 160)   640         ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 1, 1, 160)    0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 1, 1, 960)    153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 1, 1, 960)   3840        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_27 (TFOpL  (None, 1, 1, 960)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_38 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_38[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 1, 1, 960)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1, 1, 960)   0           ['multiply_19[0][0]']
#  alAveragePooling2D)
#
#  Conv_2 (Conv2D)                (None, 1, 1, 1280)   1230080     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  tf.__operators__.add_28 (TFOpL  (None, 1, 1, 1280)  0           ['Conv_2[0][0]']
#  ambda)
#
#  re_lu_39 (ReLU)                (None, 1, 1, 1280)   0           ['tf.__operators__.add_28[0][0]']
#
#  tf.math.multiply_28 (TFOpLambd  (None, 1, 1, 1280)  0           ['re_lu_39[0][0]']
#  a)
#
#  multiply_20 (Multiply)         (None, 1, 1, 1280)   0           ['Conv_2[0][0]',
#                                                                   'tf.math.multiply_28[0][0]']
#
#  dropout (Dropout)              (None, 1, 1, 1280)   0           ['multiply_20[0][0]']
#
#  Logits (Conv2D)                (None, 1, 1, 10)     12810       ['dropout[0][0]']
#
#  flatten (Flatten)              (None, 10)           0           ['Logits[0][0]']
#
#  Predictions (Activation)       (None, 10)           0           ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 4,239,242
# Trainable params: 4,214,842
# Non-trainable params: 24,400
# __________________________________________________________________________________________________
# Epoch 1/30

# %%
def train(model,X_train, Y_train):
    
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    
    early_stopping = keras.callbacks.EarlyStopping(patience=8, verbose=1)

    print(f"Starting to train with {len(Y_train)} samples")

    history = model.fit(X_train, Y_train, batch_size = 256, epochs=30,validation_split=.20,
                        callbacks=[checkpoint],
    )
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["accuracy"],
        history.history["val_accuracy"],
    )

    return model

# %%
from sklearn.metrics import confusion_matrix
import random

def train_active_learning_models(
    X_train,
    Y_train,
    x_unlab,
    y_unlab,
    X_test,
    Y_test,
    num_iterations=5
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="categorical_crossentropy",
        optimizer="Adam",
        metrics='accuracy',
    )
    
    model = train(model,X_train, Y_train)
    
    l = len(y_unlab)
    x = int(np.round( l/20 ))
    
    for iteration in range(num_iterations-1):
        
        print("\n\n")
        
        print("Iteration : ")
        
        print(iteration)
        
        print("\n\n")
         
        
        rnd = random.sample(range(1, l), x)
        all = list(range(1, l))
        main_list = list(set(all) - set(rnd))
        
        new_lab = x_unlab[rnd]
        arr = np.concatenate((X_train, new_lab))
        X_train = arr

        new_y = np.round(model.predict(new_lab))
        arr = np.concatenate((Y_train, new_y))
        Y_train = arr
        
        
        new_lab = x_unlab[main_list]
        arr = np.concatenate((x_unlab, new_lab))
        x_unlab = arr

        new_y = y_unlab[main_list]
        arr = np.concatenate((y_unlab, new_y))
        y_unlab = arr
        
        test(model, X_test, Y_test)
        
        model = train(model,X_train, Y_train)
        
    
    arr = np.concatenate((X_train, x_unlab))
    X_train = arr

    new_y = np.round(model.predict(x_unlab))
    arr = np.concatenate((Y_train, new_y))
    Y_train = arr
    
    model = train(model,X_train, Y_train)
    
    test(model, X_test, Y_test)
    
    return model

active_learning_model = train_active_learning_models(X_train,Y_train,x_unlab,y_unlab,X_test,Y_test,num_iterations=5)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 30, 30, 2)         56
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 4)         76
#
#  max_pooling2d_18 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 12, 12, 4)         148
#
#  conv2d_33 (Conv2D)          (None, 10, 10, 8)         296
#
#  max_pooling2d_19 (MaxPoolin  (None, 5, 5, 8)          0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 3, 3, 8)           584
#
#  max_pooling2d_20 (MaxPoolin  (None, 1, 1, 8)          0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 8)                 0
#
#  dense_12 (Dense)            (None, 32)                288
#
#  dense_13 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 1,778
# Trainable params: 1,778
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 5000 samples
# Epoch 1/20
# 16/16 [==============================] - ETA: 0s - loss: 2.3047 - accuracy: 0.1058
# Epoch 1: val_loss improved from inf to 2.29957, saving model to AL_Model.h5
# 16/16 [==============================] - 3s 106ms/step - loss: 2.3047 - accuracy: 0.1058 - val_loss: 2.2996 - val_accuracy: 0.1040
# Epoch 2/20
# 16/16 [==============================] - ETA: 0s - loss: 2.2893 - accuracy: 0.1318
# Epoch 2: val_loss improved from 2.29957 to 2.28377, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 89ms/step - loss: 2.2893 - accuracy: 0.1318 - val_loss: 2.2838 - val_accuracy: 0.1510
# Epoch 3/20
# 16/16 [==============================] - ETA: 0s - loss: 2.2742 - accuracy: 0.1552
# Epoch 3: val_loss improved from 2.28377 to 2.26468, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 88ms/step - loss: 2.2742 - accuracy: 0.1552 - val_loss: 2.2647 - val_accuracy: 0.1700
# Epoch 4/20
# 16/16 [==============================] - ETA: 0s - loss: 2.2488 - accuracy: 0.1663
# Epoch 4: val_loss improved from 2.26468 to 2.23132, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 87ms/step - loss: 2.2488 - accuracy: 0.1663 - val_loss: 2.2313 - val_accuracy: 0.1850
# Epoch 5/20
# 16/16 [==============================] - ETA: 0s - loss: 2.2114 - accuracy: 0.1778
# Epoch 5: val_loss improved from 2.23132 to 2.19306, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 88ms/step - loss: 2.2114 - accuracy: 0.1778 - val_loss: 2.1931 - val_accuracy: 0.2060
# Epoch 6/20
# 16/16 [==============================] - ETA: 0s - loss: 2.1616 - accuracy: 0.1957
# Epoch 6: val_loss improved from 2.19306 to 2.15571, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 90ms/step - loss: 2.1616 - accuracy: 0.1957 - val_loss: 2.1557 - val_accuracy: 0.2040
# Epoch 7/20
# 16/16 [==============================] - ETA: 0s - loss: 2.1059 - accuracy: 0.2113
# Epoch 7: val_loss improved from 2.15571 to 2.07836, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 91ms/step - loss: 2.1059 - accuracy: 0.2113 - val_loss: 2.0784 - val_accuracy: 0.2270
# Epoch 8/20
# 16/16 [==============================] - ETA: 0s - loss: 2.0486 - accuracy: 0.2315
# Epoch 8: val_loss improved from 2.07836 to 2.03648, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 89ms/step - loss: 2.0486 - accuracy: 0.2315 - val_loss: 2.0365 - val_accuracy: 0.2440
# Epoch 9/20
# 16/16 [==============================] - ETA: 0s - loss: 2.0215 - accuracy: 0.2465
# Epoch 9: val_loss improved from 2.03648 to 2.01778, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 85ms/step - loss: 2.0215 - accuracy: 0.2465 - val_loss: 2.0178 - val_accuracy: 0.2480
# Epoch 10/20
# 15/16 [===========================>..] - ETA: 0s - loss: 2.0042 - accuracy: 0.2544
# Epoch 10: val_loss improved from 2.01778 to 1.99073, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 88ms/step - loss: 2.0028 - accuracy: 0.2553 - val_loss: 1.9907 - val_accuracy: 0.2640
# Epoch 11/20
# 16/16 [==============================] - ETA: 0s - loss: 1.9877 - accuracy: 0.2688
# Epoch 11: val_loss improved from 1.99073 to 1.97358, saving model to AL_Model.h5
# 16/16 [==============================] - 2s 96ms/step - loss: 1.9877 - accuracy: 0.2688 - val_loss: 1.9736 - val_accuracy: 0.2650
# Epoch 12/20
# 16/16 [==============================] - ETA: 0s - loss: 1.9708 - accuracy: 0.2702
# Epoch 12: val_loss improved from 1.97358 to 1.95550, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 86ms/step - loss: 1.9708 - accuracy: 0.2702 - val_loss: 1.9555 - val_accuracy: 0.2610
# Epoch 13/20
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9613 - accuracy: 0.2768
# Epoch 13: val_loss improved from 1.95550 to 1.93938, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 93ms/step - loss: 1.9609 - accuracy: 0.2765 - val_loss: 1.9394 - val_accuracy: 0.2720
# Epoch 14/20
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9419 - accuracy: 0.2870
# Epoch 14: val_loss improved from 1.93938 to 1.92924, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 85ms/step - loss: 1.9419 - accuracy: 0.2873 - val_loss: 1.9292 - val_accuracy: 0.2760
# Epoch 15/20
# 16/16 [==============================] - ETA: 0s - loss: 1.9339 - accuracy: 0.2903
# Epoch 15: val_loss improved from 1.92924 to 1.92644, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 86ms/step - loss: 1.9339 - accuracy: 0.2903 - val_loss: 1.9264 - val_accuracy: 0.2770
# Epoch 16/20
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9296 - accuracy: 0.2995
# Epoch 16: val_loss improved from 1.92644 to 1.90379, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 83ms/step - loss: 1.9263 - accuracy: 0.3013 - val_loss: 1.9038 - val_accuracy: 0.2880
# Epoch 17/20
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9092 - accuracy: 0.3013
# Epoch 17: val_loss improved from 1.90379 to 1.88812, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 87ms/step - loss: 1.9096 - accuracy: 0.3005 - val_loss: 1.8881 - val_accuracy: 0.2810
# Epoch 18/20
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8997 - accuracy: 0.3003
# Epoch 18: val_loss improved from 1.88812 to 1.87128, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 88ms/step - loss: 1.8974 - accuracy: 0.3020 - val_loss: 1.8713 - val_accuracy: 0.2950
# Epoch 19/20
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8881 - accuracy: 0.3018
# Epoch 19: val_loss improved from 1.87128 to 1.86265, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 84ms/step - loss: 1.8870 - accuracy: 0.3018 - val_loss: 1.8626 - val_accuracy: 0.3080
# Epoch 20/20
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8757 - accuracy: 0.3122
# Epoch 20: val_loss improved from 1.86265 to 1.85680, saving model to AL_Model.h5
# 16/16 [==============================] - 1s 86ms/step - loss: 1.8767 - accuracy: 0.3133 - val_loss: 1.8568 - val_accuracy: 0.2980
# Iteration :
# 0
#
#
#
# 63/63 [==============================] - 1s 7ms/step
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5968\3389723838.py in <module>
#      79     return model
#      80
# ---> 81 active_learning_model = train_active_learning_models(X_train,Y_train,x_unlab,y_unlab,X_test,Y_test,num_iterations=5)
#
# ~\AppData\Local\Temp\ipykernel_5968\3389723838.py in train_active_learning_models(X_train, Y_train, x_unlab, y_unlab, X_test, Y_test, num_iterations)
#      53
#      54
# ---> 55         new_lab = x_unlab[main_list]
#      56         arr = np.concatenate((x_unlab, new_lab))
#      57         x_unlab = arr
#
# MemoryError: Unable to allocate 445. MiB for an array with shape (37999, 32, 32, 3) and data type float32
