# %%
import glob

# Invasive category
invasive_dirs = [
    r'D:\VeligerData\Baylor 2022-03-21_2\Veligers',
    r'D:\VeligerData\invasive',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1 To Baylor\Preserved Zebra Ped 1 To Baylor\Sorted Images\Pedi-Zebra Veligers',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1a To Baylor\Preserved Zebra Ped 1a To Baylor\Sorted Images\Preserved Zebra Ped 1a',
    r'D:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Zebra Pediveliger Image1a\Zebra Pediveligers',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Umbonal',
    ]

# Non-Invasive category
non_invasive_dirs = [
    r'D:\VeligerData\noninvasive',
    r'D:\VeligerData\Ostracods Day 2 Image1 To Baylor\Not',
    ]

# Ostracod category
ostracod_dirs = [
    r'D:\VeligerData\Ostracod Day 2 Image12 Short To Baylor\Ostracod Day 2 Image12 To Baylor\Sorted Images\Ostracods',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1 To Baylor\Preserved Ostracods 1 To Baylor\Sorted Images\Preserve Ostracods',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1a To Baylor\Preserved Ostracods 1a To Baylor\Sorted Images\Preserved Ostracods 1a',
    r'D:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Ostracod Image1\Ostracods1',
    r'D:\VeligerData\Ostracods Day 2 Image1 To Baylor\Ostracods',
    r'D:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Ostracod Image1\Ostracods1',
    r'D:\VeligerData\Ostracods Day 2 Image1 To Baylor\Ostracods',
    ]

# List to store subdirectories
invasive_subdirs = []
non_invasive_subdirs = []
ostracod_subdirs = []

# Collect subdirectories in the invasive category
for invasive_dir in invasive_dirs:
    invasive_subdirs.extend(glob.glob(invasive_dir))

# Collect subdirectories in the non-invasive category
for non_invasive_dir in non_invasive_dirs:
    non_invasive_subdirs.extend(glob.glob(non_invasive_dir))
    
for ostracod_dir in ostracod_dirs:
    ostracod_subdirs.extend(glob.glob(ostracod_dir))
    
import glob
from PIL import Image

# List of directories in x
x = non_invasive_subdirs

# List to store subdirectories
y1 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y1.extend(subdirectories)

import glob

# List of directories in x
x = invasive_subdirs

# List to store subdirectories
y2 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y2.extend(subdirectories)

    
import glob

# List of directories in x
x = ostracod_subdirs

# List to store subdirectories
y3 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y3.extend(subdirectories)

# %%
y1
# Out:
# ['D:\\VeligerData\\noninvasive\\Object_003',
#  'D:\\VeligerData\\noninvasive\\Object_006',
#  'D:\\VeligerData\\noninvasive\\Object_007',
#  'D:\\VeligerData\\noninvasive\\Object_008',
#  'D:\\VeligerData\\noninvasive\\Object_011',
#  'D:\\VeligerData\\noninvasive\\Object_012',
#  'D:\\VeligerData\\noninvasive\\Object_013',
#  'D:\\VeligerData\\noninvasive\\Object_015',
#  'D:\\VeligerData\\noninvasive\\Object_017',
#  'D:\\VeligerData\\noninvasive\\Object_018',
#  'D:\\VeligerData\\noninvasive\\Object_020',
#  'D:\\VeligerData\\noninvasive\\Object_021',
#  'D:\\VeligerData\\noninvasive\\Object_022',
#  'D:\\VeligerData\\noninvasive\\Object_024',
#  'D:\\VeligerData\\noninvasive\\Object_025',
#  'D:\\VeligerData\\noninvasive\\Object_026',
#  'D:\\VeligerData\\noninvasive\\Object_027',
#  'D:\\VeligerData\\noninvasive\\Object_028',
#  'D:\\VeligerData\\noninvasive\\Object_029',
#  'D:\\VeligerData\\noninvasive\\Object_030',
#  'D:\\VeligerData\\noninvasive\\Object_031',
#  'D:\\VeligerData\\noninvasive\\Object_032',
#  'D:\\VeligerData\\noninvasive\\Object_034',
#  'D:\\VeligerData\\noninvasive\\Object_035',
#  'D:\\VeligerData\\noninvasive\\Object_036',
#  'D:\\VeligerData\\noninvasive\\Object_037',
#  'D:\\VeligerData\\noninvasive\\Object_039',
#  'D:\\VeligerData\\noninvasive\\Object_040',
#  'D:\\VeligerData\\noninvasive\\Object_041',
#  'D:\\VeligerData\\noninvasive\\Object_042',
#  'D:\\VeligerData\\noninvasive\\Object_043',
#  'D:\\VeligerData\\noninvasive\\Object_044',
#  'D:\\VeligerData\\noninvasive\\Object_045',
#  'D:\\VeligerData\\noninvasive\\Object_046',
#  'D:\\VeligerData\\noninvasive\\Object_047',
#  'D:\\VeligerData\\noninvasive\\Object_048',
#  'D:\\VeligerData\\noninvasive\\Object_049',
#  'D:\\VeligerData\\noninvasive\\Object_050',
#  'D:\\VeligerData\\noninvasive\\Object_051',
#  'D:\\VeligerData\\noninvasive\\Object_054',
#  'D:\\VeligerData\\noninvasive\\Object_055',
#  'D:\\VeligerData\\noninvasive\\Object_056',
#  'D:\\VeligerData\\noninvasive\\Object_057',
#  'D:\\VeligerData\\noninvasive\\Object_058',
#  'D:\\VeligerData\\noninvasive\\Object_059',
#  'D:\\VeligerData\\noninvasive\\Object_060',
#  'D:\\VeligerData\\noninvasive\\Object_061',
#  'D:\\VeligerData\\noninvasive\\Object_062',
#  'D:\\VeligerData\\noninvasive\\Object_063',
#  'D:\\VeligerData\\noninvasive\\Object_064',
#  'D:\\VeligerData\\noninvasive\\Object_066',
#  'D:\\VeligerData\\noninvasive\\Object_067',
#  'D:\\VeligerData\\noninvasive\\Object_068',
#  'D:\\VeligerData\\noninvasive\\Object_069',
#  'D:\\VeligerData\\noninvasive\\Object_070',
#  'D:\\VeligerData\\noninvasive\\Object_2006',
#  'D:\\VeligerData\\noninvasive\\Object_2007',
#  'D:\\VeligerData\\noninvasive\\Object_2008',
#  'D:\\VeligerData\\noninvasive\\Object_2009',
#  'D:\\VeligerData\\noninvasive\\Object_201',
#  'D:\\VeligerData\\noninvasive\\Object_2012',
#  'D:\\VeligerData\\noninvasive\\Object_2013',
#  'D:\\VeligerData\\noninvasive\\Object_2014',
#  'D:\\VeligerData\\noninvasive\\Object_2015',
#  'D:\\VeligerData\\noninvasive\\Object_2016',
#  'D:\\VeligerData\\noninvasive\\Object_2017',
#  'D:\\VeligerData\\noninvasive\\Object_2019',
#  'D:\\VeligerData\\noninvasive\\Object_202',
#  'D:\\VeligerData\\noninvasive\\Object_2020',
#  'D:\\VeligerData\\noninvasive\\Object_2023',
#  'D:\\VeligerData\\noninvasive\\Object_2024',
#  'D:\\VeligerData\\noninvasive\\Object_2025',
#  'D:\\VeligerData\\noninvasive\\Object_2026',
#  'D:\\VeligerData\\noninvasive\\Object_2028',
#  'D:\\VeligerData\\noninvasive\\Object_2029',
#  'D:\\VeligerData\\noninvasive\\Object_203',
#  'D:\\VeligerData\\noninvasive\\Object_2030',
#  'D:\\VeligerData\\noninvasive\\Object_2031',
#  'D:\\VeligerData\\noninvasive\\Object_2032',
#  'D:\\VeligerData\\noninvasive\\Object_2033',
#  'D:\\VeligerData\\noninvasive\\Object_2034',
#  'D:\\VeligerData\\noninvasive\\Object_2036',
#  'D:\\VeligerData\\noninvasive\\Object_2037',
#  'D:\\VeligerData\\noninvasive\\Object_2038',
#  'D:\\VeligerData\\noninvasive\\Object_2039',
#  'D:\\VeligerData\\noninvasive\\Object_204',
#  'D:\\VeligerData\\noninvasive\\Object_2041',
#  'D:\\VeligerData\\noninvasive\\Object_2042',
#  'D:\\VeligerData\\noninvasive\\Object_2043',
#  'D:\\VeligerData\\noninvasive\\Object_2044',
#  'D:\\VeligerData\\noninvasive\\Object_2045',
#  'D:\\VeligerData\\noninvasive\\Object_2046',
#  'D:\\VeligerData\\noninvasive\\Object_2047',
#  'D:\\VeligerData\\noninvasive\\Object_2048',
#  'D:\\VeligerData\\noninvasive\\Object_205',
#  'D:\\VeligerData\\noninvasive\\Object_2050',
#  'D:\\VeligerData\\noninvasive\\Object_2051',
#  'D:\\VeligerData\\noninvasive\\Object_2052',
#  'D:\\VeligerData\\noninvasive\\Object_2053',
#  'D:\\VeligerData\\noninvasive\\Object_2054',
#  'D:\\VeligerData\\noninvasive\\Object_2056',
#  'D:\\VeligerData\\noninvasive\\Object_2057',
#  'D:\\VeligerData\\noninvasive\\Object_2059',
#  'D:\\VeligerData\\noninvasive\\Object_206',
#  'D:\\VeligerData\\noninvasive\\Object_2060',
#  'D:\\VeligerData\\noninvasive\\Object_2062',
#  'D:\\VeligerData\\noninvasive\\Object_2063',
#  'D:\\VeligerData\\noninvasive\\Object_2064',
#  'D:\\VeligerData\\noninvasive\\Object_2065',
#  'D:\\VeligerData\\noninvasive\\Object_2066',
#  'D:\\VeligerData\\noninvasive\\Object_2067',
#  'D:\\VeligerData\\noninvasive\\Object_2068',
#  'D:\\VeligerData\\noninvasive\\Object_207',
#  'D:\\VeligerData\\noninvasive\\Object_2070',
#  'D:\\VeligerData\\noninvasive\\Object_2072',
#  'D:\\VeligerData\\noninvasive\\Object_2073',
#  'D:\\VeligerData\\noninvasive\\Object_2074',
#  'D:\\VeligerData\\noninvasive\\Object_2075',
#  'D:\\VeligerData\\noninvasive\\Object_2076',
#  'D:\\VeligerData\\noninvasive\\Object_2077',
#  'D:\\VeligerData\\noninvasive\\Object_2078',
#  'D:\\VeligerData\\noninvasive\\Object_2079',
#  'D:\\VeligerData\\noninvasive\\Object_208',
#  ...]

# %%
    
import os
import numpy as np
import tensorflow as tf
from PIL import Image

def preprocess_images(y1, label_num, target_size=(40, 40)):
    # List to store image files
    image_files = []
    # List to store labels
    labels = []

    # Retrieve image files and create labels for each directory in y1
    for directory in y1:
        for root, dirs, files in os.walk(directory):
            for file in files:
                # Check if the file has an image extension
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    # Add the file path to the image_files list
                    image_files.append(os.path.join(root, file))
                    # Add the label to the labels list
                    

    # List to store preprocessed images
    images = []

    # Preprocess each image
    for file in image_files:
        try:
            # Read the image using PIL
            image = Image.open(file)
            # Resize the image using tf.image.resize_with_crop_or_pad()
            image = tf.image.resize_with_crop_or_pad(
                tf.keras.preprocessing.image.img_to_array(image),
                target_size[0],
                target_size[1]
            )
            # Normalize the image pixels for ML training
            image = image / 255.0
            # Add the preprocessed image to the images list
            images.append(image)
            labels.append(label_num)
        except Exception as e:
            print(f"Error processing image: {file}. Skipping...")
            continue

    # Convert the images and labels lists to numpy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels


X0,Y0 = preprocess_images(y1, label_num = 0)
X1,Y1 = preprocess_images(y2, label_num = 1)
X2,Y2 = preprocess_images(y3, label_num = 2)
# Out:
# Error processing image: D:\VeligerData\Ostracod Day 2 Image12 Short To Baylor\Ostracod Day 2 Image12 To Baylor\Sorted Images\Ostracods\Object_002\._Image_032.png. Skipping...
# Error processing image: D:\VeligerData\Ostracod Day 2 Image12 Short To Baylor\Ostracod Day 2 Image12 To Baylor\Sorted Images\Ostracods\Object_002\._Image_036.png. Skipping...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Concatenate the image arrays
train_images = np.concatenate((X0, X1, X2), axis=0)

# Combine the label arrays
train_labels = np.concatenate((Y0, Y1, Y2), axis=0)

# Convert the labels to categorical
train_labels_categorical = to_categorical(train_labels)

# Set the dtype of train_images to float32
train_images = train_images.astype('float32')

# Split the data into train and test sets
from sklearn.utils import shuffle

# Shuffle the data
train_images, train_labels_categorical = shuffle(train_images, train_labels_categorical)

# Now the shuffled data is assigned to the same variable names
X_train, X_test, Y_train, Y_test = train_test_split(train_images, train_labels_categorical, test_size=0.05, random_state=42)

# %%
np.shape(X_train)
# Out:
# (119004, 40, 40, 3)

# %%
import numpy as np
import pandas as pd
from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), input_shape=(40, 40, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation="relu"))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(16, (3, 3)))
model.add(layers.Flatten())
model.add(layers.Dense(64))
model.add(layers.Dense(10))
model.add(layers.Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 38, 38, 32)        896
#
#  max_pooling2d_4 (MaxPooling  (None, 19, 19, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 17, 17, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 16)          4624
#
#  flatten_2 (Flatten)         (None, 576)               0
#
#  dense_6 (Dense)             (None, 64)                36928
#
#  dense_7 (Dense)             (None, 10)                650
#
#  dense_8 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 52,379
# Trainable params: 52,379
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_weights = np.zeros(3)

unique_labels, counts = np.unique(train_labels, return_counts=True)

total_samples = np.sum(counts)

for i, label in enumerate(unique_labels):
    class_weights[label] = total_samples / (len(unique_labels) * counts[i])

print("Class weights:", class_weights)
# Out:
# Class weights: [ 0.42666183  1.74476939 12.03633444]

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics='accuracy')
class_weights = [1,1,1]
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/50
# 3347/3347 [==============================] - 24s 7ms/step - loss: 0.1067 - accuracy: 0.9660 - val_loss: 0.0784 - val_accuracy: 0.9751
# Epoch 2/50
# 3347/3347 [==============================] - 23s 7ms/step - loss: 0.0649 - accuracy: 0.9786 - val_loss: 0.0507 - val_accuracy: 0.9821
# Epoch 3/50
# 3347/3347 [==============================] - 84s 25ms/step - loss: 0.0535 - accuracy: 0.9828 - val_loss: 0.0552 - val_accuracy: 0.9829
# Epoch 4/50
# 3347/3347 [==============================] - 69s 21ms/step - loss: 0.0481 - accuracy: 0.9845 - val_loss: 0.0520 - val_accuracy: 0.9832
# Epoch 5/50
# 3347/3347 [==============================] - 23s 7ms/step - loss: 0.0424 - accuracy: 0.9864 - val_loss: 0.0453 - val_accuracy: 0.9853
# Epoch 6/50
# 1041/3347 [========>.....................] - ETA: 18s - loss: 0.0438 - accuracy: 0.9862

# %%
import glob

# Invasive category
invasive_dirs = [
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1a To Baylor\Preserved Ostracods 1a To Baylor\Sorted Images\Not',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1 To Baylor\Preserved Zebra Ped 1 To Baylor\Sorted Images\Not',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Not',
    r'D:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Not Veligers\O1',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Not',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Umbonal',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Zebra D-Hinge',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Umbonal'
]

# Non-Invasive category
non_invasive_dirs = [
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Not',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1 To Baylor\Preserved Ostracods 1 To Baylor\Sorted Images\Not',
    r'D:\VeligerData\Ostracods Day 2 Image2 To Baylor\Not',
    r'D:\VeligerData\Ostracods Day 2 Image12 To Baylor_3\Ostracods Day 2 Image12 To Baylor\Sorted Images\Not',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Not'
    r'D:\VeligerData\Baylor 2022-03-21_2\NonVeligers\Images_001',
    
]

# Ostracod category
ostracod_dirs = [
    r'D:\VeligerData\Ostracod Day 2 Image12 Short To Baylor\Ostracod Day 2 Image12 To Baylor\Sorted Images\Ostracods',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1 To Baylor\Preserved Ostracods 1 To Baylor\Sorted Images\Preserve Ostracods',
    r'D:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1a To Baylor\Preserved Ostracods 1a To Baylor\Sorted Images\Preserved Ostracods 1a',
    ]

# List to store subdirectories
invasive_subdirs = []
non_invasive_subdirs = []
ostracod_subdirs = []

# Collect subdirectories in the invasive category
for invasive_dir in invasive_dirs:
    invasive_subdirs.extend(glob.glob(invasive_dir))

# Collect subdirectories in the non-invasive category
for non_invasive_dir in non_invasive_dirs:
    non_invasive_subdirs.extend(glob.glob(non_invasive_dir))
    
for ostracod_dir in ostracod_dirs:
    ostracod_subdirs.extend(glob.glob(ostracod_dir))

# %%
import glob
from PIL import Image

# List of directories in x
x = non_invasive_subdirs

# List to store subdirectories
y1 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y1.extend(subdirectories)

import glob

# List of directories in x
x = invasive_subdirs

# List to store subdirectories
y2 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y2.extend(subdirectories)

    
import glob

# List of directories in x
x = ostracod_subdirs

# List to store subdirectories
y3 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y3.extend(subdirectories)

    

    
import os
import numpy as np
import tensorflow as tf
from PIL import Image

def preprocess_images(y1, label_num, target_size=(40, 40)):
    # List to store image files
    image_files = []
    # List to store labels
    labels = []

    # Retrieve image files and create labels for each directory in y1
    for directory in y1:
        for root, dirs, files in os.walk(directory):
            for file in files:
                # Check if the file has an image extension
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    # Add the file path to the image_files list
                    image_files.append(os.path.join(root, file))
                    # Add the label to the labels list
                    

    # List to store preprocessed images
    images = []

    # Preprocess each image
    for file in image_files:
        try:
            # Read the image using PIL
            image = Image.open(file)
            # Resize the image using tf.image.resize_with_crop_or_pad()
            image = tf.image.resize_with_crop_or_pad(
                tf.keras.preprocessing.image.img_to_array(image),
                target_size[0],
                target_size[1]
            )
            # Normalize the image pixels for ML training
            image = image / 255.0
            # Add the preprocessed image to the images list
            images.append(image)
            labels.append(label_num)
        except Exception as e:
            print(f"Error processing image: {file}. Skipping...")
            continue

    # Convert the images and labels lists to numpy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels


X0,Y0 = preprocess_images(y1, label_num = 0)
X1,Y1 = preprocess_images(y2, label_num = 1)
X2,Y2 = preprocess_images(y3, label_num = 2)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Concatenate the image arrays
train_images = np.concatenate((X0, X1, X2), axis=0)

# Combine the label arrays
train_labels = np.concatenate((Y0, Y1, Y2), axis=0)

# Convert the labels to categorical
train_labels_categorical = to_categorical(train_labels)

# Set the dtype of train_images to float32
train_images = train_images.astype('float32')


# Split the data into train and test sets
from sklearn.utils import shuffle

# Assuming you have the original train_images and train_labels_categorical

# Shuffle the data
train_images, train_labels_categorical = shuffle(train_images, train_labels_categorical)

# Now the shuffled data is assigned to the same variable names

X_train, X_test1, Y_train, Y_test1 = train_test_split(train_images, train_labels_categorical, test_size=0.01, random_state=42)

# %%
from tensorflow.keras.models import load_model
# Assuming you have a Keras model named "model"
model.save("premodel.h5")

# %%
np.shape(X_train)

# %%
class_weights = np.zeros(3)

unique_labels, counts = np.unique(train_labels, return_counts=True)

total_samples = np.sum(counts)

for i, label in enumerate(unique_labels):
    class_weights[label] = total_samples / (len(unique_labels) * counts[i])

print("Class weights:", class_weights)

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics='accuracy')
class_weights = [1,1,1]
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# %%
pred = model.predict(X_test)
p = np.argmax(pred, axis=1)
res = p
        
test = []
for i in Y_test:
    if(i[0]==1):
        test.append(0)
    elif(i[1]==1):
        test.append(1)
    else:
        test.append(2)
        
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(test,np.argmax(Y_test, axis=1))
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
# Define the image path
from PIL import Image
image_path = r"D:\VeligerData\Baylor 2022-03-21_2\Veligers\Object_031\Image_009.png"
# Read the image using PIL
image = Image.open(image_path)
# Define the target size for resizing
target_size = (40, 40)
# Resize the image using TensorFlow's resize_with_crop_or_pad function
resized_image = tf.image.resize_with_crop_or_pad( tf.keras.preprocessing.image.img_to_array(image), target_size[0],   target_size[1]
)
# Expand the dimensions to match the model's input shape
expanded_image = tf.expand_dims(resized_image, axis=0)
# Evaluate the TensorFlow tensor and obtain the NumPy array
resized_array = tf.keras.backend.eval(expanded_image)
normalized_image = resized_array / 255.0
x = model.predict(normalized_image)
x

# %%
from tensorflow.keras.models import load_model
# Assuming you have a Keras model named "model"
model.save("single_image_model.h5")
