# %%
import cv2
import os

# Load video
video_path = r"C:\Users\shaif\Downloads\Video\Cultivated Ostracods Day 2 Image12 Short.mp4"
cap = cv2.VideoCapture(video_path)

# Create a folder to save cropped elements
output_folder = r"C:\Users\shaif\Downloads\Video\Cropped_Elements"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

frame_number = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    # Convert the frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to get binary image
    _, thresh_frame = cv2.threshold(gray_frame, 50, 255, cv2.THRESH_BINARY)

    # Find contours in the thresholded frame
    contours, _ = cv2.findContours(thresh_frame, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Filter out large contours and keep only small ones
    max_contour_area = 500  # Maximum size of elements to keep (adjust based on needs)
    min_contour_area = 5    # Minimum size of elements to keep (adjust based on needs)
    filtered_contours = [cnt for cnt in contours if min_contour_area < cv2.contourArea(cnt) < max_contour_area]

    # Save smaller elements as images
    element_id = 0
    for cnt in filtered_contours:
        x, y, w, h = cv2.boundingRect(cnt)
        crop = frame[y:y+h, x:x+w]
        element_filename = os.path.join(output_folder, f"frame_{frame_number}_element_{element_id}.png")
        cv2.imwrite(element_filename, crop)
        element_id += 1

    frame_number += 1

# Release the video capture object
cap.release()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 40
#      38     crop = frame[y:y+h, x:x+w]
#      39     element_filename = os.path.join(output_folder, f"frame_{frame_number}_element_{element_id}.png")
# ---> 40     cv2.imwrite(element_filename, crop)
#      41     element_id += 1
#      43 frame_number += 1
#
# KeyboardInterrupt:

# %%
import cv2
import os

# Load video
video_path = r"C:\Users\shaif\Downloads\Video\Cultivated Ostracods Day 2 Image12 Short.mp4"
cap = cv2.VideoCapture(video_path)

# Create a folder to save cropped elements
output_folder = r"C:\Users\shaif\Downloads\Video\Cropped_Elements"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

frame_number = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    # Convert the frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to get binary image
    _, thresh_frame = cv2.threshold(gray_frame, 50, 255, cv2.THRESH_BINARY)

    # Find contours in the thresholded frame
    contours, _ = cv2.findContours(thresh_frame, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Filter out large contours and keep only small ones
    max_contour_area = 500  # Maximum size of elements to keep (adjust based on needs)
    min_contour_area = 25    # Minimum size of elements to keep (adjust based on needs)
    filtered_contours = [cnt for cnt in contours if min_contour_area < cv2.contourArea(cnt) < max_contour_area]

    # Save smaller elements as images in subfolders
    element_id = 0
    for cnt in filtered_contours:
        x, y, w, h = cv2.boundingRect(cnt)
        crop = frame[y:y+h, x:x+w]

        # Resize the crop to 32x32 with 3 color channels
        resized_crop = cv2.resize(crop, (32, 32))

        # Create a subfolder for each element ID
        element_folder = os.path.join(output_folder, f"element_{element_id}")
        if not os.path.exists(element_folder):
            os.makedirs(element_folder)

        # Save the resized crop in the corresponding subfolder
        element_filename = os.path.join(element_folder, f"frame_{frame_number}.png")
        cv2.imwrite(element_filename, resized_crop)
        element_id += 1

    frame_number += 1

# Release the video capture object
cap.release()
