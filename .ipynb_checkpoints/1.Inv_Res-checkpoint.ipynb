# %%
import os

def check_subfolders_in_images(directory_path):
    """
    Checks the number of subfolders inside 'Images_001' for each main folder.

    Args:
    - directory_path (str): The main directory containing subfolders.

    Prints:
    - Number of subfolders inside 'Images_001' for each folder.
    """
    if os.path.exists(directory_path) and os.path.isdir(directory_path):
        folders = [f for f in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, f))]
        
        for folder in folders:
            image_001_path = os.path.join(directory_path, folder, "Images_001")
            if os.path.exists(image_001_path) and os.path.isdir(image_001_path):
                subfolders = [sf for sf in os.listdir(image_001_path) if os.path.isdir(os.path.join(image_001_path, sf))]
                print(f"Subfolders inside '{image_001_path}': {len(subfolders)}")
            else:
                print(f"No 'Images_001' folder found inside '{folder}'.")
    else:
        print(f"Directory '{directory_path}' does not exist or is not a directory.")

# Your directory path
directory_path = r"E:\2 Below Lake Waco Deep 28_8 Concentrated"
check_subfolders_in_images(directory_path)
# Out:
# Subfolders inside 'E:\2 Below Lake Waco Deep 28_8 Concentrated\2_38 Below Lake Waco Deep 28_8 Gal 9-17-21 Image1a\Images_001': 671
# Subfolders inside 'E:\2 Below Lake Waco Deep 28_8 Concentrated\2_38 Below Lake Waco Deep 28_8 Gal 9-17-21 Image2a\Images_001': 387
# Subfolders inside 'E:\2 Below Lake Waco Deep 28_8 Concentrated\2_38 Below Lake Waco Deep 28_8 Gal 9-17-21 Image3a\Images_001': 352
# Subfolders inside 'E:\2 Below Lake Waco Deep 28_8 Concentrated\2_38 Below Lake Waco Deep 28_8 Gal 9-17-21 Image4a\Images_001': 277
# Subfolders inside 'E:\2 Below Lake Waco Deep 28_8 Concentrated\2_38 Below Lake Waco Deep 28_8 Gal 9-17-21 Image5a\Images_001': 22
# Subfolders inside 'E:\2 Below Lake Waco Deep 28_8 Concentrated\2_38 Below Lake Waco Deep 28_8 Gal 9-17-21 Image6a\Images_001': 789

# %%
import os
import numpy as np
from tqdm import tqdm

try:
    from tensorflow.keras.preprocessing.image import load_img, img_to_array
except ImportError:
    print("TensorFlow is not installed. You can install it by running: pip install tensorflow")
    raise

def load_images_from_subfolders(directory_path):
    """
    Loads the first five images from each subfolder inside 'Images_001' for each main folder.
    Resizes the images to (28, 28, 3) for deep learning models.
    Pads with the last image if fewer than 5 images are available.
    Stores all subfolders' images in a single array and prints its shape.

    Args:
    - directory_path (str): The main directory containing subfolders.

    Prints:
    - Shape of the array containing resized images for all subfolders.
    """
    if os.path.exists(directory_path) and os.path.isdir(directory_path):
        folders = [f for f in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, f))]
        
        for folder in tqdm(folders, desc="Processing main folders"):
            image_001_path = os.path.join(directory_path, folder, "Images_001")
            if os.path.exists(image_001_path) and os.path.isdir(image_001_path):
                subfolders = [sf for sf in os.listdir(image_001_path) if os.path.isdir(os.path.join(image_001_path, sf))]
                
                # Array to store all images for the current main folder
                all_images = []

                for subfolder in tqdm(subfolders, desc=f"Processing subfolders in '{folder}'", leave=False):
                    subfolder_path = os.path.join(image_001_path, subfolder)
                    image_files = [f for f in os.listdir(subfolder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
                    
                    images = []
                    for image_file in image_files[:5]:
                        image_path = os.path.join(subfolder_path, image_file)
                        img = load_img(image_path, target_size=(28, 28))
                        img_array = img_to_array(img) / 255.0  # Normalize pixel values
                        images.append(img_array)

                    # Pad with the last image if there are fewer than 5
                    while len(images) < 5:
                        images.append(images[-1])

                    all_images.append(np.array(images))  # Add (5, 28, 28, 3) to the batch array

                # Convert to a numpy array of shape (num_subfolders, 5, 28, 28, 3)
                all_images_array = np.array(all_images)
                print(f"\nSubfolders inside '{image_001_path}': shape of images: {all_images_array.shape}")
            else:
                print(f"\nNo 'Images_001' folder found inside '{folder}'.")
    else:
        print(f"\nDirectory '{directory_path}' does not exist or is not a directory.")

# Your directory path
directory_path = r"E:\2 Below Lake Waco Deep 28_8 Concentrated"
load_images_from_subfolders(directory_path)

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tqdm import tqdm

# Custom PatchEncoder layer
class PatchEncoder(tf.keras.layers.Layer):
    def __init__(self, num_patches, projection_dim, **kwargs):
        super(PatchEncoder, self).__init__(**kwargs)
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.projection = tf.keras.Sequential(
            [
                tf.keras.layers.Conv2D(2, (3, 3), strides=(1, 1), activation='relu'),
                tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPooling2D((2, 2))),
                tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten()),
                tf.keras.layers.Dense(projection_dim),
            ]
        )
        self.position_embedding = tf.keras.layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "projection_dim": self.projection_dim,
        })
        return config

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# Load model
model_path = r"E:\five_frame_model.h5"
custom_objects = {'PatchEncoder': PatchEncoder}

try:
    model = load_model(model_path, custom_objects=custom_objects)
    print("\nModel loaded successfully!")
except Exception as e:
    print(f"\nError loading model: {e}")
    raise

def load_images_from_subfolders(directory_path):
    """
    Loads the first five images from each subfolder inside 'Images_001' for each main folder.
    Resizes the images to (28, 28, 3) for deep learning models.
    Pads with the last image if fewer than 5 images are available.
    """
    if os.path.exists(directory_path) and os.path.isdir(directory_path):
        folders = [f for f in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, f))]
        
        for folder in tqdm(folders, desc="Processing main folders"):
            image_001_path = os.path.join(directory_path, folder, "Images_001")
            if os.path.exists(image_001_path) and os.path.isdir(image_001_path):
                subfolders = [sf for sf in os.listdir(image_001_path) if os.path.isdir(os.path.join(image_001_path, sf))]
                all_images = []

                for subfolder in tqdm(subfolders, desc=f"Processing subfolders in '{folder}'", leave=False):
                    subfolder_path = os.path.join(image_001_path, subfolder)
                    image_files = [f for f in os.listdir(subfolder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

                    images = []
                    for image_file in image_files[:5]:
                        image_path = os.path.join(subfolder_path, image_file)
                        img = load_img(image_path, target_size=(28, 28))
                        img_array = img_to_array(img) / 255.0  # Normalize pixel values
                        images.append(img_array)

                    # Pad with the last image if there are fewer than 5
                    while len(images) < 5:
                        images.append(images[-1])

                    all_images.append(np.array(images))  # Add (5, 28, 28, 3) to the batch array

                # Convert to a numpy array of shape (num_subfolders, 5, 28, 28, 3)
                all_images_array = np.array(all_images)
                print(f"\nSubfolders inside '{image_001_path}': shape of images: {all_images_array.shape}")

                # Make individual predictions for the current folder
                make_predictions(model, all_images_array, folder)
            else:
                print(f"\nNo 'Images_001' folder found inside '{folder}'.")
    else:
        print(f"\nDirectory '{directory_path}' does not exist or is not a directory.")

def make_predictions(model, data, folder_name):
    """
    Makes predictions on the given data and prints the count of each class for a specific folder.
    """
    print(f"\nMaking predictions for folder '{folder_name}'...")
    predictions = model.predict(data, batch_size=32, verbose=1)
    predicted_classes = np.argmax(predictions, axis=1)
    unique_classes, counts = np.unique(predicted_classes, return_counts=True)
    print(f"\nPredicted Class Distribution for '{folder_name}':")
    for cls, count in zip(unique_classes, counts):
        print(f"Class {cls}: {count}")

# Load images and make individual predictions
directory_path = r"E:\2 Below Lake Waco Deep 28_8 Concentrated"
#load_images_from_subfolders(directory_path)
# Out:
# Model loaded successfully!

# %%
# Load images and make individual predictions
directory_path = r"G:\datasets\2.Veliger_Data\May 27 2022  11-18\18 Below Tom Miller Dam"
load_images_from_subfolders(directory_path)
# Out:
# Processing main folders:   0%|                                                                   | 0/6 [00:00<?, ?it/s]
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   0%| | 0/1761 [00:00<?, ?it/
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   0%| | 1/1761 [00:00<03:17,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   0%| | 3/1761 [00:00<03:20,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   0%| | 4/1761 [00:00<03:24,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   0%| | 5/1761 [00:00<03:36,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   0%| | 7/1761 [00:00<02:59,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 9/1761 [00:00<02:44,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 11/1761 [00:01<03:14,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 12/1761 [00:01<03:27,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 14/1761 [00:01<03:09,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 16/1761 [00:01<02:39,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 18/1761 [00:01<02:40,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 20/1761 [00:02<02:47,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 22/1761 [00:02<02:50,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 24/1761 [00:02<02:33,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   1%| | 26/1761 [00:02<02:41,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 28/1761 [00:02<02:28,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 30/1761 [00:02<02:29,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 32/1761 [00:03<02:39,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 34/1761 [00:03<02:33,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 36/1761 [00:03<02:24,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 38/1761 [00:03<02:40,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 40/1761 [00:03<02:47,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   2%| | 43/1761 [00:04<02:23,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 45/1761 [00:04<02:39,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 47/1761 [00:04<02:45,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 49/1761 [00:04<02:31,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 51/1761 [00:04<02:38,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 53/1761 [00:04<02:18,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 55/1761 [00:05<02:28,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 57/1761 [00:05<02:37,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   3%| | 59/1761 [00:05<02:44,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 62/1761 [00:05<02:17,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 64/1761 [00:05<02:16,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 66/1761 [00:06<02:24,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 68/1761 [00:06<02:25,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 70/1761 [00:06<02:14,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 72/1761 [00:06<02:03,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 74/1761 [00:06<02:06,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 76/1761 [00:06<01:59,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   4%| | 78/1761 [00:06<01:52,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 80/1761 [00:07<01:46,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 82/1761 [00:07<01:53,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 84/1761 [00:07<02:03,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 86/1761 [00:07<01:56,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 88/1761 [00:07<02:02,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 90/1761 [00:07<01:58,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 92/1761 [00:07<01:50,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 94/1761 [00:08<01:59,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   5%| | 96/1761 [00:08<02:12,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 98/1761 [00:08<02:02,
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 100/1761 [00:08<02:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 102/1761 [00:08<02:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 104/1761 [00:08<02:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 106/1761 [00:09<02:10
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 108/1761 [00:09<02:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 110/1761 [00:09<02:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 112/1761 [00:09<02:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   6%| | 114/1761 [00:09<02:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 116/1761 [00:09<02:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 118/1761 [00:10<02:12
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 120/1761 [00:10<02:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 122/1761 [00:10<02:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 124/1761 [00:10<02:10
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 126/1761 [00:10<02:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 128/1761 [00:10<02:21
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 130/1761 [00:11<02:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   7%| | 132/1761 [00:11<02:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 134/1761 [00:11<02:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 136/1761 [00:11<01:58
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 138/1761 [00:11<02:05
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 140/1761 [00:11<02:10
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 142/1761 [00:12<02:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 144/1761 [00:12<02:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 146/1761 [00:12<02:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   8%| | 148/1761 [00:12<02:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 150/1761 [00:12<02:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 152/1761 [00:12<02:13
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 154/1761 [00:13<02:08
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 156/1761 [00:13<01:59
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 158/1761 [00:13<02:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 160/1761 [00:13<02:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 163/1761 [00:13<02:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 165/1761 [00:13<01:54
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':   9%| | 167/1761 [00:13<01:46
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 169/1761 [00:14<01:52
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 172/1761 [00:14<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 174/1761 [00:14<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 176/1761 [00:14<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 178/1761 [00:14<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 180/1761 [00:14<01:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 182/1761 [00:15<02:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  10%| | 184/1761 [00:15<02:10
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 186/1761 [00:15<02:28
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 188/1761 [00:15<02:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 190/1761 [00:15<02:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 192/1761 [00:16<02:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 194/1761 [00:16<02:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 196/1761 [00:16<02:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 198/1761 [00:16<02:54
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 199/1761 [00:16<03:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  11%| | 201/1761 [00:17<02:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 203/1761 [00:17<02:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 205/1761 [00:17<02:05
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 208/1761 [00:17<01:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 211/1761 [00:17<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 213/1761 [00:17<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 215/1761 [00:17<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 217/1761 [00:17<01:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  12%| | 220/1761 [00:18<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  13%|▏| 222/1761 [00:18<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  13%|▏| 224/1761 [00:18<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  13%|▏| 226/1761 [00:18<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  13%|▏| 228/1761 [00:18<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  13%|▏| 231/1761 [00:18<01:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  13%|▏| 233/1761 [00:18<01:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  13%|▏| 235/1761 [00:19<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 238/1761 [00:19<01:18
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 240/1761 [00:19<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 242/1761 [00:19<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 244/1761 [00:19<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 246/1761 [00:19<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 248/1761 [00:19<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 250/1761 [00:20<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 252/1761 [00:20<01:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  14%|▏| 254/1761 [00:20<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 257/1761 [00:20<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 259/1761 [00:20<01:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 261/1761 [00:20<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 263/1761 [00:20<01:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 265/1761 [00:21<01:52
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 267/1761 [00:21<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 269/1761 [00:21<02:00
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  15%|▏| 271/1761 [00:21<02:00
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 273/1761 [00:21<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 275/1761 [00:21<01:58
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 277/1761 [00:22<02:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 279/1761 [00:22<02:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 281/1761 [00:22<01:57
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 283/1761 [00:22<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 285/1761 [00:22<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 288/1761 [00:22<01:32
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  16%|▏| 290/1761 [00:22<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 292/1761 [00:23<01:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 294/1761 [00:23<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 296/1761 [00:23<01:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 298/1761 [00:23<02:03
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 300/1761 [00:23<02:12
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 302/1761 [00:23<02:02
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 304/1761 [00:24<01:59
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 306/1761 [00:24<02:00
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  17%|▏| 308/1761 [00:24<01:52
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 310/1761 [00:24<01:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 312/1761 [00:24<01:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 314/1761 [00:24<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 316/1761 [00:24<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 318/1761 [00:25<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 320/1761 [00:25<01:36
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 322/1761 [00:25<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  18%|▏| 324/1761 [00:25<01:50
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 326/1761 [00:25<01:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 328/1761 [00:25<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 330/1761 [00:25<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 332/1761 [00:26<01:46
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 334/1761 [00:26<01:50
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 336/1761 [00:26<01:50
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 338/1761 [00:26<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 340/1761 [00:26<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  19%|▏| 342/1761 [00:26<01:46
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 344/1761 [00:26<01:46
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 346/1761 [00:27<01:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 348/1761 [00:27<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 350/1761 [00:27<01:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 352/1761 [00:27<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 354/1761 [00:27<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 357/1761 [00:27<01:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  20%|▏| 359/1761 [00:27<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 362/1761 [00:28<01:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 364/1761 [00:28<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 366/1761 [00:28<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 368/1761 [00:28<01:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 370/1761 [00:28<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 372/1761 [00:28<01:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 375/1761 [00:28<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  21%|▏| 377/1761 [00:28<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 379/1761 [00:29<01:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 381/1761 [00:29<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 383/1761 [00:29<01:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 385/1761 [00:29<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 387/1761 [00:29<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 389/1761 [00:29<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 391/1761 [00:29<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 393/1761 [00:30<01:56
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  22%|▏| 396/1761 [00:30<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 398/1761 [00:30<01:53
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 400/1761 [00:30<01:56
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 402/1761 [00:30<01:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 404/1761 [00:31<01:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 406/1761 [00:31<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 408/1761 [00:31<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 410/1761 [00:31<01:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  23%|▏| 412/1761 [00:31<01:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 414/1761 [00:31<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 416/1761 [00:32<01:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 418/1761 [00:32<01:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 420/1761 [00:32<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 422/1761 [00:32<01:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 424/1761 [00:32<01:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 426/1761 [00:32<01:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 428/1761 [00:32<01:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  24%|▏| 430/1761 [00:33<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▏| 432/1761 [00:33<01:36
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▏| 434/1761 [00:33<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▏| 436/1761 [00:33<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▏| 438/1761 [00:33<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▎| 441/1761 [00:33<01:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▎| 443/1761 [00:33<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▎| 445/1761 [00:34<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  25%|▎| 447/1761 [00:34<01:32
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 450/1761 [00:34<01:18
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 453/1761 [00:34<01:12
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 455/1761 [00:34<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 457/1761 [00:34<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 459/1761 [00:35<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 461/1761 [00:35<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 463/1761 [00:35<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  26%|▎| 465/1761 [00:35<01:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 468/1761 [00:35<01:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 470/1761 [00:35<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 472/1761 [00:35<01:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 474/1761 [00:36<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 476/1761 [00:36<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 478/1761 [00:36<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 480/1761 [00:36<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 482/1761 [00:36<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  27%|▎| 484/1761 [00:36<01:46
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 486/1761 [00:37<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 488/1761 [00:37<01:36
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 490/1761 [00:37<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 492/1761 [00:37<01:21
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 494/1761 [00:37<01:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 496/1761 [00:37<01:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 498/1761 [00:37<01:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  28%|▎| 500/1761 [00:37<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 502/1761 [00:38<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 504/1761 [00:38<01:55
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 506/1761 [00:38<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 508/1761 [00:38<01:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 510/1761 [00:38<01:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 512/1761 [00:38<01:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 514/1761 [00:39<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 516/1761 [00:39<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  29%|▎| 518/1761 [00:39<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 520/1761 [00:39<01:32
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 523/1761 [00:39<01:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 525/1761 [00:39<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 527/1761 [00:40<01:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 529/1761 [00:40<01:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 531/1761 [00:40<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 533/1761 [00:40<01:32
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  30%|▎| 535/1761 [00:40<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 538/1761 [00:40<01:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 540/1761 [00:40<01:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 543/1761 [00:40<01:05
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 545/1761 [00:41<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 547/1761 [00:41<01:28
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 549/1761 [00:41<01:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 551/1761 [00:41<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  31%|▎| 553/1761 [00:41<01:52
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 555/1761 [00:42<01:50
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 557/1761 [00:42<01:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 559/1761 [00:42<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 561/1761 [00:42<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 563/1761 [00:42<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 565/1761 [00:42<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 568/1761 [00:43<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 570/1761 [00:43<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  32%|▎| 572/1761 [00:43<01:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 574/1761 [00:43<01:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 576/1761 [00:43<01:36
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 578/1761 [00:44<01:54
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 580/1761 [00:44<02:00
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 582/1761 [00:44<01:53
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 584/1761 [00:44<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 586/1761 [00:44<01:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  33%|▎| 588/1761 [00:44<01:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 590/1761 [00:45<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 592/1761 [00:45<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 594/1761 [00:45<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 596/1761 [00:45<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 598/1761 [00:45<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 600/1761 [00:45<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 602/1761 [00:46<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 604/1761 [00:46<01:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  34%|▎| 607/1761 [00:46<01:13
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 609/1761 [00:46<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 611/1761 [00:46<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 613/1761 [00:46<01:18
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 615/1761 [00:46<01:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 618/1761 [00:47<01:03
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 620/1761 [00:47<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 622/1761 [00:47<01:11
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  35%|▎| 624/1761 [00:47<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 627/1761 [00:47<01:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 630/1761 [00:47<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 632/1761 [00:47<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 634/1761 [00:48<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 636/1761 [00:48<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 638/1761 [00:48<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 640/1761 [00:48<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  36%|▎| 642/1761 [00:48<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 644/1761 [00:48<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 646/1761 [00:49<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 648/1761 [00:49<01:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 650/1761 [00:49<01:18
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 652/1761 [00:49<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 654/1761 [00:49<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 656/1761 [00:49<01:32
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 658/1761 [00:50<01:32
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  37%|▎| 660/1761 [00:50<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 662/1761 [00:50<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 664/1761 [00:50<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 666/1761 [00:50<01:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 668/1761 [00:50<01:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 670/1761 [00:51<01:28
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 672/1761 [00:51<01:36
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 674/1761 [00:51<01:36
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  38%|▍| 677/1761 [00:51<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 679/1761 [00:51<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 681/1761 [00:51<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 683/1761 [00:52<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 685/1761 [00:52<01:47
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 687/1761 [00:52<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 689/1761 [00:52<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 691/1761 [00:52<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 693/1761 [00:52<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  39%|▍| 695/1761 [00:53<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 697/1761 [00:53<01:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 699/1761 [00:53<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 701/1761 [00:53<01:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 703/1761 [00:53<01:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 705/1761 [00:54<01:36
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 707/1761 [00:54<01:35
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 709/1761 [00:54<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 711/1761 [00:54<01:56
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  40%|▍| 713/1761 [00:54<01:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 715/1761 [00:55<01:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 717/1761 [00:55<01:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 719/1761 [00:55<01:38
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 721/1761 [00:55<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 723/1761 [00:55<01:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 725/1761 [00:55<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 727/1761 [00:56<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  41%|▍| 729/1761 [00:56<01:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 731/1761 [00:56<01:27
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 733/1761 [00:56<01:39
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 735/1761 [00:56<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 737/1761 [00:56<01:30
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 739/1761 [00:57<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 741/1761 [00:57<01:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 743/1761 [00:57<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 745/1761 [00:57<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  42%|▍| 747/1761 [00:57<01:31
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 749/1761 [00:57<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 751/1761 [00:58<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 753/1761 [00:58<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 755/1761 [00:58<01:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 757/1761 [00:58<01:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 759/1761 [00:58<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 761/1761 [00:58<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 764/1761 [00:59<01:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  43%|▍| 766/1761 [00:59<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 769/1761 [00:59<01:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 771/1761 [00:59<01:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 773/1761 [00:59<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 775/1761 [00:59<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 777/1761 [01:00<01:18
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 779/1761 [01:00<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 781/1761 [01:00<01:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  44%|▍| 783/1761 [01:00<01:18
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 785/1761 [01:00<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 787/1761 [01:00<01:11
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 789/1761 [01:00<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 791/1761 [01:01<01:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 793/1761 [01:01<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 795/1761 [01:01<01:29
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 797/1761 [01:01<01:33
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 799/1761 [01:01<01:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  45%|▍| 801/1761 [01:02<01:21
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 803/1761 [01:02<01:13
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 805/1761 [01:02<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 807/1761 [01:02<01:14
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 809/1761 [01:02<01:22
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 811/1761 [01:02<01:18
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 813/1761 [01:03<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 815/1761 [01:03<01:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  46%|▍| 817/1761 [01:03<01:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  47%|▍| 819/1761 [01:03<01:19
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image1a':  47%|▍| 821/1761 [01:03<01:17
# ...
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  44%|▍| 638/1448 [00:57<01:21
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  44%|▍| 640/1448 [00:57<01:13
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  44%|▍| 642/1448 [00:57<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  44%|▍| 644/1448 [00:57<01:02
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  45%|▍| 646/1448 [00:57<01:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  45%|▍| 648/1448 [00:57<01:12
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  45%|▍| 650/1448 [00:57<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  45%|▍| 652/1448 [00:58<01:13
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  45%|▍| 654/1448 [00:58<01:08
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  45%|▍| 656/1448 [00:58<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  45%|▍| 658/1448 [00:58<01:11
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  46%|▍| 660/1448 [00:58<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  46%|▍| 662/1448 [00:59<01:08
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  46%|▍| 664/1448 [00:59<01:03
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  46%|▍| 666/1448 [00:59<01:05
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  46%|▍| 668/1448 [00:59<01:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  46%|▍| 670/1448 [00:59<01:03
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  46%|▍| 672/1448 [00:59<00:58
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  47%|▍| 674/1448 [00:59<00:59
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  47%|▍| 676/1448 [01:00<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  47%|▍| 678/1448 [01:00<01:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  47%|▍| 680/1448 [01:00<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  47%|▍| 682/1448 [01:00<00:56
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  47%|▍| 684/1448 [01:00<00:55
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  47%|▍| 686/1448 [01:00<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 688/1448 [01:01<01:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 690/1448 [01:01<01:14
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 692/1448 [01:01<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 694/1448 [01:01<01:02
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 696/1448 [01:01<01:05
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 698/1448 [01:02<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 700/1448 [01:02<01:11
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  48%|▍| 702/1448 [01:02<01:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  49%|▍| 704/1448 [01:02<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  49%|▍| 706/1448 [01:02<01:12
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  49%|▍| 708/1448 [01:03<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  49%|▍| 710/1448 [01:03<01:10
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  49%|▍| 713/1448 [01:03<00:56
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  49%|▍| 715/1448 [01:03<01:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▍| 717/1448 [01:03<00:57
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▍| 719/1448 [01:03<00:55
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▍| 721/1448 [01:04<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▍| 723/1448 [01:05<03:25
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 724/1448 [01:06<04:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 725/1448 [01:07<05:28
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 726/1448 [01:07<06:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 727/1448 [01:08<06:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 728/1448 [01:09<06:26
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 729/1448 [01:10<08:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 730/1448 [01:11<10:05
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  50%|▌| 731/1448 [01:12<11:15
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 732/1448 [01:13<11:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 734/1448 [01:14<06:59
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 736/1448 [01:14<04:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 737/1448 [01:14<03:55
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 739/1448 [01:14<02:40
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 741/1448 [01:14<01:56
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 743/1448 [01:14<01:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  51%|▌| 745/1448 [01:14<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  52%|▌| 747/1448 [01:15<01:16
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  52%|▌| 749/1448 [01:15<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  52%|▌| 751/1448 [01:15<01:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  52%|▌| 753/1448 [01:15<01:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  52%|▌| 755/1448 [01:15<01:03
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  52%|▌| 757/1448 [01:15<00:55
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  52%|▌| 759/1448 [01:16<00:57
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  53%|▌| 761/1448 [01:16<00:50
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  53%|▌| 763/1448 [01:16<00:55
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  53%|▌| 765/1448 [01:16<00:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  53%|▌| 767/1448 [01:16<00:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  53%|▌| 769/1448 [01:16<00:59
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  53%|▌| 771/1448 [01:16<00:59
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  53%|▌| 773/1448 [01:17<00:56
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 775/1448 [01:17<00:53
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 777/1448 [01:17<01:02
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 779/1448 [01:17<01:07
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 781/1448 [01:17<01:09
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 783/1448 [01:18<01:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 785/1448 [01:18<01:13
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 786/1448 [01:18<01:13
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 787/1448 [01:19<03:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 788/1448 [01:21<07:02
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  54%|▌| 789/1448 [01:21<05:37
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  55%|▌| 790/1448 [01:21<04:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  55%|▌| 792/1448 [01:21<03:00
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  55%|▌| 794/1448 [01:21<02:06
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  55%|▌| 796/1448 [01:22<01:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  55%|▌| 798/1448 [01:22<01:34
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  55%|▌| 800/1448 [01:22<01:23
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  55%|▌| 802/1448 [01:22<01:12
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 804/1448 [01:22<01:05
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 806/1448 [01:23<01:04
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 808/1448 [01:23<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 809/1448 [01:23<01:24
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 811/1448 [01:23<01:17
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 812/1448 [01:23<01:20
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 814/1448 [01:24<01:03
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  56%|▌| 817/1448 [01:24<00:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  57%|▌| 819/1448 [01:24<00:53
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  57%|▌| 821/1448 [01:24<00:49
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  57%|▌| 823/1448 [01:24<00:50
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  57%|▌| 825/1448 [01:24<00:54
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  57%|▌| 828/1448 [01:25<00:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  57%|▌| 830/1448 [01:25<00:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  57%|▌| 832/1448 [01:25<00:47
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  58%|▌| 834/1448 [01:25<00:43
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  58%|▌| 836/1448 [01:25<00:46
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  58%|▌| 838/1448 [01:25<00:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  58%|▌| 840/1448 [01:25<00:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  58%|▌| 842/1448 [01:26<00:41
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  58%|▌| 844/1448 [01:26<00:42
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  58%|▌| 846/1448 [01:26<00:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  59%|▌| 848/1448 [01:26<00:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  59%|▌| 850/1448 [01:26<00:45
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  59%|▌| 852/1448 [01:26<00:53
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  59%|▌| 854/1448 [01:27<00:50
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  59%|▌| 856/1448 [01:27<00:51
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  59%|▌| 858/1448 [01:27<00:53
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  59%|▌| 860/1448 [01:27<00:55
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  60%|▌| 862/1448 [01:27<01:01
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  60%|▌| 864/1448 [01:28<00:53
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  60%|▌| 866/1448 [01:28<00:48
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  60%|▌| 868/1448 [01:28<00:47
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  60%|▌| 870/1448 [01:28<00:44
# Processing subfolders in '18_25 Below Tom Miller Dam 10 Minutes 300 Gal 12-3-21 Image3a':  60%|▌| 872/1448 [01:29<01:17
# Processing main folders:  33%|███████████████████▎                                      | 2/6 [07:46<15:32, 233.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Load images and make individual predictions
#       2 directory_path = r"G:\datasets\2.Veliger_Data\May 27 2022  11-18\18 Below Tom Miller Dam"
# ----> 3 load_images_from_subfolders(directory_path)
#
# Cell In[1], line 67, in load_images_from_subfolders(directory_path)
#      65 for subfolder in tqdm(subfolders, desc=f"Processing subfolders in '{folder}'", leave=False):
#      66     subfolder_path = os.path.join(image_001_path, subfolder)
# ---> 67     image_files = [f for f in os.listdir(subfolder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
#      69     images = []
#      70     for image_file in image_files[:5]:
#
# KeyboardInterrupt:
