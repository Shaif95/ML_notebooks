# %%
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tqdm import tqdm

# Define the path to the directory
directory_path = r"D:\datasets\Underwater_Image\WHOI\archive\dataset_pm\training"

# Initialize empty lists for images and labels
X_train = []
Y_train = []
class_label = 0

# Loop through subdirectories (classes)
for class_folder in tqdm(sorted(os.listdir(directory_path))):
    class_path = os.path.join(directory_path, class_folder)
    
    for image_file in os.listdir(class_path):
        if image_file.endswith('.png'):
            image_path = os.path.join(class_path, image_file)
            
            # Load image, convert to RGB and resize
            img = Image.open(image_path).convert('RGB')
            img = img.resize((224, 224))
            img_array = np.array(img)
            
            # Append image and label to lists
            X_train.append(img_array)
            Y_train.append(class_label)
            
    class_label = class_label + 1

# Convert lists to numpy arrays
X_train = np.array(X_train)
Y_train = np.array(Y_train)

print(f'X_train shape: {X_train.shape}')
print(f'Y_train shape: {Y_train.shape}')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 19/19 [11:49<00:00, 37.36s/it]
# X_train shape: (2872, 224, 224, 3)
# Y_train shape: (2872,)

# %%
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tqdm import tqdm

# Define the path to the directory
directory_path = r"D:\datasets\Underwater_Image\WHOI\archive\dataset_pm\validation"

# Initialize empty lists for images and labels
X_val = []
Y_val = []
class_label = 0

# Loop through subdirectories (classes)
for class_folder in tqdm(sorted(os.listdir(directory_path))):
    class_path = os.path.join(directory_path, class_folder)
    
    for image_file in os.listdir(class_path):
        if image_file.endswith('.png'):
            image_path = os.path.join(class_path, image_file)
            
            # Load image, convert to RGB and resize
            img = Image.open(image_path).convert('RGB')
            img = img.resize((224, 224))
            img_array = np.array(img)
            
            # Append image and label to lists
            X_val.append(img_array)
            Y_val.append(class_label)
            
    class_label = class_label + 1

# Convert lists to numpy arrays
X_val = np.array(X_val)
Y_val = np.array(Y_val)

print(f'X_train shape: {X_val.shape}')
print(f'Y_train shape: {Y_val.shape}')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 19/19 [00:02<00:00,  7.75it/s]
# X_train shape: (93, 224, 224, 3)
# Y_train shape: (93,)

# %%
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tqdm import tqdm

# Define the path to the directory
directory_path = r"D:\datasets\Underwater_Image\WHOI\archive\dataset_pm\test"

# Initialize empty lists for images and labels
X_test = []
Y_test = []
class_label = 0

# Loop through subdirectories (classes)
for class_folder in tqdm(sorted(os.listdir(directory_path))):
    class_path = os.path.join(directory_path, class_folder)
    
    for image_file in os.listdir(class_path):
        if image_file.endswith('.png'):
            image_path = os.path.join(class_path, image_file)
            
            # Load image, convert to RGB and resize
            img = Image.open(image_path).convert('RGB')
            img = img.resize((224, 224))
            img_array = np.array(img)
            
            # Append image and label to lists
            X_test.append(img_array)
            Y_test.append(class_label)
            
    class_label = class_label + 1

# Convert lists to numpy arrays
X_test = np.array(X_test)
Y_test = np.array(Y_test)

print(f'X_train shape: {X_test.shape}')

print(f'Y_train shape: {Y_test.shape}')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 19/19 [00:15<00:00,  1.24it/s]
# X_train shape: (118, 224, 224, 3)
# Y_train shape: (118,)

# %%
import tensorflow as tf
tf.keras.backend.clear_session()
#YT = to_categorical(Y_train)
#VT = to_categorical(Y_val)

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
num_classes = 19
model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\mob_whoi_224_model.h5")

x = model.layers[-4].output  # Access the last 4th layer from the end
x = GlobalAveragePooling2D()(x)  # Explicitly specify keepdims
output = Dense(num_classes, activation='softmax')(x)
new_model = keras.models.Model(inputs=model.input, outputs=output) 
new_model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 50
new_model.fit(X_train,YT, epochs=epochs,batch_size=8, validation_data=(X_val,VT))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 8
#       6 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       7 num_classes = 19
# ----> 8 model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\mob_whoi_224_model.h5")
#      10 x = model.layers[-4].output  # Access the last 4th layer from the end
#      11 x = GlobalAveragePooling2D()(x)  # Explicitly specify keepdims
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\saving\save.py:201, in load_model(filepath, custom_objects, compile, options)
#     198 with load_context.load_context(options):
#     199   if (h5py is not None and
#     200       (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 201     return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#     202                                             compile)
#     204   filepath = path_to_string(filepath)
#     205   if isinstance(filepath, str):
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py:180, in load_model_from_hdf5(filepath, custom_objects, compile)
#     178   model_config = model_config.decode('utf-8')
#     179 model_config = json_utils.decode(model_config)
# --> 180 model = model_config_lib.model_from_config(model_config,
#     181                                            custom_objects=custom_objects)
#     183 # set weights
#     184 load_weights_from_hdf5_group(f['model_weights'], model.layers)
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\saving\model_config.py:52, in model_from_config(config, custom_objects)
#      48   raise TypeError('`model_from_config` expects a dictionary, not a list. '
#      49                   'Maybe you meant to use '
#      50                   '`Sequential.from_config(config)`?')
#      51 from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 52 return deserialize(config, custom_objects=custom_objects)
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\layers\serialization.py:159, in deserialize(config, custom_objects)
#     148 """Instantiates a layer from a config dictionary.
#     149
#     150 Args:
#    (...)
#     156     Layer instance (may be Model, Sequential, Network, Layer...)
#     157 """
#     158 populate_deserializable_objects()
# --> 159 return generic_utils.deserialize_keras_object(
#     160     config,
#     161     module_objects=LOCAL.ALL_OBJECTS,
#     162     custom_objects=custom_objects,
#     163     printable_module_name='layer')
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:668, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     665 custom_objects = custom_objects or {}
#     667 if 'custom_objects' in arg_spec.args:
# --> 668   deserialized_obj = cls.from_config(
#     669       cls_config,
#     670       custom_objects=dict(
#     671           list(_GLOBAL_CUSTOM_OBJECTS.items()) +
#     672           list(custom_objects.items())))
#     673 else:
#     674   with CustomObjectScope(custom_objects):
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\engine\functional.py:668, in Functional.from_config(cls, config, custom_objects)
#     653 """Instantiates a Model from its config (output of `get_config()`).
#     654
#     655 Args:
#    (...)
#     665     ValueError: In case of improperly formatted config dict.
#     666 """
#     667 with generic_utils.SharedObjectLoadingScope():
# --> 668   input_tensors, output_tensors, created_layers = reconstruct_from_config(
#     669       config, custom_objects)
#     670   model = cls(inputs=input_tensors, outputs=output_tensors,
#     671               name=config.get('name'))
#     672   connect_ancillary_layers(model, created_layers)
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\engine\functional.py:1279, in reconstruct_from_config(config, custom_objects, created_layers)
#    1277 # First, we create all layers and enqueue nodes to be processed
#    1278 for layer_data in config['layers']:
# -> 1279   process_layer(layer_data)
#    1280 # Then we process nodes in order of layer depth.
#    1281 # Nodes that cannot yet be processed (if the inbound node
#    1282 # does not yet exist) are re-enqueued, and the process
#    1283 # is repeated until all nodes are processed.
#    1284 while unprocessed_nodes:
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\engine\functional.py:1261, in reconstruct_from_config.<locals>.process_layer(layer_data)
#    1257 else:
#    1258   # Instantiate layer.
#    1259   from tensorflow.python.keras.layers import deserialize as deserialize_layer  # pylint: disable=g-import-not-at-top
# -> 1261   layer = deserialize_layer(layer_data, custom_objects=custom_objects)
#    1262   created_layers[layer_name] = layer
#    1264 node_count_by_layer[layer] = int(_should_skip_first_node(layer))
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\layers\serialization.py:159, in deserialize(config, custom_objects)
#     148 """Instantiates a layer from a config dictionary.
#     149
#     150 Args:
#    (...)
#     156     Layer instance (may be Model, Sequential, Network, Layer...)
#     157 """
#     158 populate_deserializable_objects()
# --> 159 return generic_utils.deserialize_keras_object(
#     160     config,
#     161     module_objects=LOCAL.ALL_OBJECTS,
#     162     custom_objects=custom_objects,
#     163     printable_module_name='layer')
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:675, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     673   else:
#     674     with CustomObjectScope(custom_objects):
# --> 675       deserialized_obj = cls.from_config(cls_config)
#     676 else:
#     677   # Then `cls` may be a function returning a class.
#     678   # in this case by convention `config` holds
#     679   # the kwargs of the function.
#     680   custom_objects = custom_objects or {}
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:740, in Layer.from_config(cls, config)
#     724 @classmethod
#     725 def from_config(cls, config):
#     726   """Creates a layer from its config.
#     727
#     728   This method is the reverse of `get_config`,
#    (...)
#     738       A layer instance.
#     739   """
# --> 740   return cls(**config)
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\layers\pooling.py:1023, in GlobalPooling2D.__init__(self, data_format, **kwargs)
#    1022 def __init__(self, data_format=None, **kwargs):
# -> 1023   super(GlobalPooling2D, self).__init__(**kwargs)
#    1024   self.data_format = conv_utils.normalize_data_format(data_format)
#    1025   self.input_spec = InputSpec(ndim=4)
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\training\tracking\base.py:522, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     520 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521 try:
# --> 522   result = method(self, *args, **kwargs)
#     523 finally:
#     524   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:347, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     336 allowed_kwargs = {
#     337     'input_dim',
#     338     'input_shape',
#    (...)
#     344     'implementation',
#     345 }
#     346 # Validate optional keyword arguments.
# --> 347 generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     349 # Mutable properties
#     350 # Indicates whether the layer's weights are updated during training
#     351 # and whether the layer's updates are run during training.
#     352 self._trainable = trainable
#
# File ~\anaconda3\envs\tens\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:1137, in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    1135 for kwarg in kwargs:
#    1136   if kwarg not in allowed_kwargs:
# -> 1137     raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'keepdims')

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = new_model.predict(X_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, predicted_labels)

# Calculate F1 score
f1 = f1_score(Y_test, predicted_labels, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 1.0
# F1 Score: 1.0

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
num_classes = 19
model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\conv_whoi_224_model.h5")

x = model.layers[-4].output  # Access the last 4th layer from the end
x = GlobalAveragePooling2D(keepdims=False)(x)  # Explicitly specify keepdims
output = Dense(num_classes, activation='softmax')(x)
new_model = keras.models.Model(inputs=model.input, outputs=output) 
new_model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 50
new_model.fit(X_train,YT, epochs=epochs,batch_size=8, validation_data=(X_val,VT))

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = new_model.predict(X_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, predicted_labels)

# Calculate F1 score
f1 = f1_score(Y_test, predicted_labels, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.46413649025069637
# F1 Score: 0.4518371904435395

# %%
import tensorflow as tf

# Disable GPU
tf.config.set_visible_devices([], 'GPU')

# Now TensorFlow will use only CPU

# %%
from keras import backend
from keras import layers
from keras import utils

class LayerScale(layers.Layer):
    """Layer scale module.

    References:
      - https://arxiv.org/abs/2103.17239

    Args:
      init_values (float): Initial value for layer scale. Should be within
        [0, 1].
      projection_dim (int): Projection dimensionality.

    Returns:
      Tensor multiplied to the scale.
    """

    def __init__(self, init_values, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.init_values = init_values
        self.projection_dim = projection_dim

    def build(self, input_shape):
        self.gamma = tf.Variable(
            self.init_values * tf.ones((self.projection_dim,))
        )

    def call(self, x):
        return x * self.gamma

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "init_values": self.init_values,
                "projection_dim": self.projection_dim,
            }
        )
        return config


import keras
import tensorflow.keras as keras
# Load the model
model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\conv_whoi_224_model.h5",custom_objects={ "LayerScale": LayerScale })

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# convnext_base_prestem_normaliza (None, 224, 224, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# convnext_base_stem (Sequential) (None, 56, 56, 128)  6528        convnext_base_prestem_normalizati
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_0_d (None, 56, 56, 128)  6400        convnext_base_stem[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_0_l (None, 56, 56, 128)  256         convnext_base_stage_0_block_0_dep
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_0_p (None, 56, 56, 512)  66048       convnext_base_stage_0_block_0_lay
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_0_g (None, 56, 56, 512)  0           convnext_base_stage_0_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_0_p (None, 56, 56, 128)  65664       convnext_base_stage_0_block_0_gel
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_0_l (None, 56, 56, 128)  128         convnext_base_stage_0_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_0_i (None, 56, 56, 128)  0           convnext_base_stage_0_block_0_lay
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 56, 56, 128)  0           convnext_base_stem[0][0]
#                                                                  convnext_base_stage_0_block_0_ide
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_1_d (None, 56, 56, 128)  6400        tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_1_l (None, 56, 56, 128)  256         convnext_base_stage_0_block_1_dep
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_1_p (None, 56, 56, 512)  66048       convnext_base_stage_0_block_1_lay
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_1_g (None, 56, 56, 512)  0           convnext_base_stage_0_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_1_p (None, 56, 56, 128)  65664       convnext_base_stage_0_block_1_gel
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_1_l (None, 56, 56, 128)  128         convnext_base_stage_0_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_1_i (None, 56, 56, 128)  0           convnext_base_stage_0_block_1_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 56, 56, 128)  0           tf.__operators__.add[0][0]
#                                                                  convnext_base_stage_0_block_1_ide
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_2_d (None, 56, 56, 128)  6400        tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_2_l (None, 56, 56, 128)  256         convnext_base_stage_0_block_2_dep
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_2_p (None, 56, 56, 512)  66048       convnext_base_stage_0_block_2_lay
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_2_g (None, 56, 56, 512)  0           convnext_base_stage_0_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_2_p (None, 56, 56, 128)  65664       convnext_base_stage_0_block_2_gel
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_2_l (None, 56, 56, 128)  128         convnext_base_stage_0_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_0_block_2_i (None, 56, 56, 128)  0           convnext_base_stage_0_block_2_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 56, 56, 128)  0           tf.__operators__.add_1[0][0]
#                                                                  convnext_base_stage_0_block_2_ide
# __________________________________________________________________________________________________
# convnext_base_downsampling_bloc (None, 28, 28, 256)  131584      tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_0_d (None, 28, 28, 256)  12800       convnext_base_downsampling_block_
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_0_l (None, 28, 28, 256)  512         convnext_base_stage_1_block_0_dep
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_0_p (None, 28, 28, 1024) 263168      convnext_base_stage_1_block_0_lay
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_0_g (None, 28, 28, 1024) 0           convnext_base_stage_1_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_0_p (None, 28, 28, 256)  262400      convnext_base_stage_1_block_0_gel
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_0_l (None, 28, 28, 256)  256         convnext_base_stage_1_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_0_i (None, 28, 28, 256)  0           convnext_base_stage_1_block_0_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 28, 28, 256)  0           convnext_base_downsampling_block_
#                                                                  convnext_base_stage_1_block_0_ide
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_1_d (None, 28, 28, 256)  12800       tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_1_l (None, 28, 28, 256)  512         convnext_base_stage_1_block_1_dep
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_1_p (None, 28, 28, 1024) 263168      convnext_base_stage_1_block_1_lay
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_1_g (None, 28, 28, 1024) 0           convnext_base_stage_1_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_1_p (None, 28, 28, 256)  262400      convnext_base_stage_1_block_1_gel
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_1_l (None, 28, 28, 256)  256         convnext_base_stage_1_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_1_i (None, 28, 28, 256)  0           convnext_base_stage_1_block_1_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 28, 28, 256)  0           tf.__operators__.add_3[0][0]
#                                                                  convnext_base_stage_1_block_1_ide
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_2_d (None, 28, 28, 256)  12800       tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_2_l (None, 28, 28, 256)  512         convnext_base_stage_1_block_2_dep
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_2_p (None, 28, 28, 1024) 263168      convnext_base_stage_1_block_2_lay
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_2_g (None, 28, 28, 1024) 0           convnext_base_stage_1_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_2_p (None, 28, 28, 256)  262400      convnext_base_stage_1_block_2_gel
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_2_l (None, 28, 28, 256)  256         convnext_base_stage_1_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_1_block_2_i (None, 28, 28, 256)  0           convnext_base_stage_1_block_2_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 28, 28, 256)  0           tf.__operators__.add_4[0][0]
#                                                                  convnext_base_stage_1_block_2_ide
# __________________________________________________________________________________________________
# convnext_base_downsampling_bloc (None, 14, 14, 512)  525312      tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_0_d (None, 14, 14, 512)  25600       convnext_base_downsampling_block_
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_0_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_0_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_0_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_0_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_0_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_0_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_0_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_0_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_0_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_0_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 14, 14, 512)  0           convnext_base_downsampling_block_
#                                                                  convnext_base_stage_2_block_0_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_1_d (None, 14, 14, 512)  25600       tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_1_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_1_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_1_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_1_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_1_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_1_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_1_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_1_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_1_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_1_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 14, 14, 512)  0           tf.__operators__.add_6[0][0]
#                                                                  convnext_base_stage_2_block_1_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_2_d (None, 14, 14, 512)  25600       tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_2_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_2_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_2_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_2_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_2_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_2_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_2_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_2_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_2_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_2_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 14, 14, 512)  0           tf.__operators__.add_7[0][0]
#                                                                  convnext_base_stage_2_block_2_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_3_d (None, 14, 14, 512)  25600       tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_3_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_3_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_3_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_3_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_3_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_3_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_3_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_3_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_3_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_3_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_3_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_3_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 14, 14, 512)  0           tf.__operators__.add_8[0][0]
#                                                                  convnext_base_stage_2_block_3_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_4_d (None, 14, 14, 512)  25600       tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_4_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_4_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_4_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_4_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_4_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_4_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_4_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_4_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_4_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_4_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_4_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_4_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_9[0][0]
#                                                                  convnext_base_stage_2_block_4_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_5_d (None, 14, 14, 512)  25600       tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_5_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_5_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_5_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_5_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_5_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_5_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_5_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_5_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_5_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_5_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_5_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_5_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_10[0][0]
#                                                                  convnext_base_stage_2_block_5_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_6_d (None, 14, 14, 512)  25600       tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_6_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_6_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_6_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_6_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_6_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_6_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_6_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_6_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_6_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_6_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_6_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_6_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_12 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_11[0][0]
#                                                                  convnext_base_stage_2_block_6_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_7_d (None, 14, 14, 512)  25600       tf.__operators__.add_12[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_7_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_7_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_7_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_7_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_7_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_7_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_7_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_7_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_7_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_7_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_7_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_7_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_13 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_12[0][0]
#                                                                  convnext_base_stage_2_block_7_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_8_d (None, 14, 14, 512)  25600       tf.__operators__.add_13[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_8_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_8_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_8_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_8_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_8_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_8_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_8_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_8_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_8_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_8_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_8_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_8_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_14 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_13[0][0]
#                                                                  convnext_base_stage_2_block_8_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_9_d (None, 14, 14, 512)  25600       tf.__operators__.add_14[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_9_l (None, 14, 14, 512)  1024        convnext_base_stage_2_block_9_dep
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_9_p (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_9_lay
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_9_g (None, 14, 14, 2048) 0           convnext_base_stage_2_block_9_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_9_p (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_9_gel
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_9_l (None, 14, 14, 512)  512         convnext_base_stage_2_block_9_poi
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_9_i (None, 14, 14, 512)  0           convnext_base_stage_2_block_9_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_15 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_14[0][0]
#                                                                  convnext_base_stage_2_block_9_ide
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_10_ (None, 14, 14, 512)  25600       tf.__operators__.add_15[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_10_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_10_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_10_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_10_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_10_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_10_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_10_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_10_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_10_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_10_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_10_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_10_la
# __________________________________________________________________________________________________
# tf.__operators__.add_16 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_15[0][0]
#                                                                  convnext_base_stage_2_block_10_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_11_ (None, 14, 14, 512)  25600       tf.__operators__.add_16[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_11_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_11_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_11_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_11_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_11_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_11_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_11_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_11_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_11_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_11_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_11_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_11_la
# __________________________________________________________________________________________________
# tf.__operators__.add_17 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_16[0][0]
#                                                                  convnext_base_stage_2_block_11_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_12_ (None, 14, 14, 512)  25600       tf.__operators__.add_17[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_12_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_12_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_12_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_12_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_12_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_12_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_12_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_12_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_12_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_12_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_12_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_12_la
# __________________________________________________________________________________________________
# tf.__operators__.add_18 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_17[0][0]
#                                                                  convnext_base_stage_2_block_12_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_13_ (None, 14, 14, 512)  25600       tf.__operators__.add_18[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_13_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_13_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_13_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_13_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_13_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_13_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_13_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_13_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_13_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_13_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_13_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_13_la
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_18[0][0]
#                                                                  convnext_base_stage_2_block_13_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_14_ (None, 14, 14, 512)  25600       tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_14_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_14_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_14_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_14_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_14_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_14_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_14_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_14_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_14_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_14_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_14_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_14_la
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_19[0][0]
#                                                                  convnext_base_stage_2_block_14_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_15_ (None, 14, 14, 512)  25600       tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_15_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_15_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_15_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_15_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_15_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_15_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_15_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_15_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_15_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_15_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_15_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_15_la
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_20[0][0]
#                                                                  convnext_base_stage_2_block_15_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_16_ (None, 14, 14, 512)  25600       tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_16_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_16_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_16_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_16_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_16_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_16_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_16_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_16_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_16_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_16_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_16_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_16_la
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_21[0][0]
#                                                                  convnext_base_stage_2_block_16_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_17_ (None, 14, 14, 512)  25600       tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_17_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_17_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_17_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_17_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_17_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_17_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_17_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_17_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_17_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_17_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_17_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_17_la
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_22[0][0]
#                                                                  convnext_base_stage_2_block_17_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_18_ (None, 14, 14, 512)  25600       tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_18_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_18_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_18_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_18_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_18_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_18_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_18_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_18_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_18_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_18_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_18_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_18_la
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_23[0][0]
#                                                                  convnext_base_stage_2_block_18_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_19_ (None, 14, 14, 512)  25600       tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_19_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_19_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_19_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_19_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_19_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_19_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_19_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_19_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_19_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_19_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_19_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_19_la
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_24[0][0]
#                                                                  convnext_base_stage_2_block_19_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_20_ (None, 14, 14, 512)  25600       tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_20_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_20_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_20_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_20_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_20_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_20_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_20_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_20_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_20_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_20_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_20_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_20_la
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_25[0][0]
#                                                                  convnext_base_stage_2_block_20_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_21_ (None, 14, 14, 512)  25600       tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_21_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_21_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_21_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_21_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_21_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_21_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_21_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_21_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_21_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_21_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_21_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_21_la
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_26[0][0]
#                                                                  convnext_base_stage_2_block_21_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_22_ (None, 14, 14, 512)  25600       tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_22_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_22_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_22_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_22_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_22_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_22_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_22_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_22_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_22_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_22_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_22_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_22_la
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_27[0][0]
#                                                                  convnext_base_stage_2_block_22_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_23_ (None, 14, 14, 512)  25600       tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_23_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_23_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_23_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_23_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_23_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_23_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_23_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_23_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_23_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_23_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_23_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_23_la
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_28[0][0]
#                                                                  convnext_base_stage_2_block_23_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_24_ (None, 14, 14, 512)  25600       tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_24_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_24_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_24_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_24_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_24_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_24_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_24_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_24_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_24_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_24_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_24_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_24_la
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_29[0][0]
#                                                                  convnext_base_stage_2_block_24_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_25_ (None, 14, 14, 512)  25600       tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_25_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_25_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_25_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_25_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_25_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_25_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_25_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_25_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_25_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_25_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_25_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_25_la
# __________________________________________________________________________________________________
# tf.__operators__.add_31 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_30[0][0]
#                                                                  convnext_base_stage_2_block_25_id
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_26_ (None, 14, 14, 512)  25600       tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_26_ (None, 14, 14, 512)  1024        convnext_base_stage_2_block_26_de
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_26_ (None, 14, 14, 2048) 1050624     convnext_base_stage_2_block_26_la
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_26_ (None, 14, 14, 2048) 0           convnext_base_stage_2_block_26_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_26_ (None, 14, 14, 512)  1049088     convnext_base_stage_2_block_26_ge
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_26_ (None, 14, 14, 512)  512         convnext_base_stage_2_block_26_po
# __________________________________________________________________________________________________
# convnext_base_stage_2_block_26_ (None, 14, 14, 512)  0           convnext_base_stage_2_block_26_la
# __________________________________________________________________________________________________
# tf.__operators__.add_32 (TFOpLa (None, 14, 14, 512)  0           tf.__operators__.add_31[0][0]
#                                                                  convnext_base_stage_2_block_26_id
# __________________________________________________________________________________________________
# convnext_base_downsampling_bloc (None, 7, 7, 1024)   2099200     tf.__operators__.add_32[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_0_d (None, 7, 7, 1024)   51200       convnext_base_downsampling_block_
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_0_l (None, 7, 7, 1024)   2048        convnext_base_stage_3_block_0_dep
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_0_p (None, 7, 7, 4096)   4198400     convnext_base_stage_3_block_0_lay
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_0_g (None, 7, 7, 4096)   0           convnext_base_stage_3_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_0_p (None, 7, 7, 1024)   4195328     convnext_base_stage_3_block_0_gel
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_0_l (None, 7, 7, 1024)   1024        convnext_base_stage_3_block_0_poi
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_0_i (None, 7, 7, 1024)   0           convnext_base_stage_3_block_0_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_33 (TFOpLa (None, 7, 7, 1024)   0           convnext_base_downsampling_block_
#                                                                  convnext_base_stage_3_block_0_ide
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_1_d (None, 7, 7, 1024)   51200       tf.__operators__.add_33[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_1_l (None, 7, 7, 1024)   2048        convnext_base_stage_3_block_1_dep
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_1_p (None, 7, 7, 4096)   4198400     convnext_base_stage_3_block_1_lay
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_1_g (None, 7, 7, 4096)   0           convnext_base_stage_3_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_1_p (None, 7, 7, 1024)   4195328     convnext_base_stage_3_block_1_gel
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_1_l (None, 7, 7, 1024)   1024        convnext_base_stage_3_block_1_poi
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_1_i (None, 7, 7, 1024)   0           convnext_base_stage_3_block_1_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_34 (TFOpLa (None, 7, 7, 1024)   0           tf.__operators__.add_33[0][0]
#                                                                  convnext_base_stage_3_block_1_ide
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_2_d (None, 7, 7, 1024)   51200       tf.__operators__.add_34[0][0]
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_2_l (None, 7, 7, 1024)   2048        convnext_base_stage_3_block_2_dep
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_2_p (None, 7, 7, 4096)   4198400     convnext_base_stage_3_block_2_lay
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_2_g (None, 7, 7, 4096)   0           convnext_base_stage_3_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_2_p (None, 7, 7, 1024)   4195328     convnext_base_stage_3_block_2_gel
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_2_l (None, 7, 7, 1024)   1024        convnext_base_stage_3_block_2_poi
# __________________________________________________________________________________________________
# convnext_base_stage_3_block_2_i (None, 7, 7, 1024)   0           convnext_base_stage_3_block_2_lay
# __________________________________________________________________________________________________
# tf.__operators__.add_35 (TFOpLa (None, 7, 7, 1024)   0           tf.__operators__.add_34[0][0]
#                                                                  convnext_base_stage_3_block_2_ide
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 7, 7, 1024)   2048        tf.__operators__.add_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          524800      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 15)           7695        dense[0][0]
# ==================================================================================================
# Total params: 88,098,959
# Trainable params: 88,098,959
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.applications import ResNet50
base_model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\Cifar100_32_model.h5")
base_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 16, 16, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 8, 8, 64)     0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 8, 8, 64)     0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 8, 8, 64)     0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 256)    16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 256)    0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 8, 8, 256)    0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 8, 8, 64)     0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 8, 8, 64)     0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 256)    0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 8, 8, 256)    0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 8, 8, 64)     0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 8, 8, 64)     0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 256)    0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 8, 8, 256)    0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 4, 4, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 4, 4, 128)    0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 512)    131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 512)    0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 4, 4, 512)    0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 4, 4, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 4, 4, 128)    0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 512)    0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 4, 4, 512)    0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 4, 4, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 4, 4, 128)    0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 512)    0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 4, 4, 512)    0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 4, 4, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 4, 4, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 512)    0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 4, 4, 512)    0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 2, 2, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 2, 2, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 2, 2, 1024)   0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 2, 2, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 2, 2, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 2, 2, 1024)   0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 2, 2, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 2, 2, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 2, 2, 1024)   0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 2, 2, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 2, 2, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 2, 2, 1024)   0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 2, 2, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 2, 2, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 2, 2, 1024)   0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 2, 2, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 2, 2, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 2, 2, 1024)   0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 1, 1, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 1, 1, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 1, 1, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 1, 1, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 1, 1, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 1, 1, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 1, 1, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 1, 1, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 1, 1, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 1, 1, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 1, 1, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 1, 1, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 1, 1, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 1, 1, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 1, 1, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 1, 1, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 400)          205200      dense[0][0]
# ==================================================================================================
# Total params: 24,842,000
# Trainable params: 24,788,880
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
