# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Load the Flowers-102 dataset
(ds_train, ds_test), ds_info = tfds.load('tf_flowers', split=['train[:80%]', 'train[80%:]'], as_supervised=True, with_info=True)

# Define a function to resize images
def resize_image(image, label):
    image = tf.image.resize(image, (32, 32))
    return image, label

# Apply resizing to the dataset
ds_train = ds_train.map(resize_image)
ds_test = ds_test.map(resize_image)

# Normalize pixel values to be in the range [0, 1]
ds_train = ds_train.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y))
ds_test = ds_test.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y))

# Shuffle and batch the datasets
ds_train = ds_train.shuffle(10000).batch(64)
ds_test = ds_test.batch(64)

# Convert labels to categorical format
def categorical_labels(images, labels):
    return images, tf.one_hot(labels, depth=102)  # 102 classes in Flowers-102 dataset

ds_train = ds_train.map(categorical_labels)
ds_test = ds_test.map(categorical_labels)

# Verify the shapes
for images, labels in ds_train.take(1):
    print("Images shape:", images.shape)
    print("Labels shape:", labels.shape)

for images, labels in ds_test.take(1):
    print("Images shape:", images.shape)
    print("Labels shape:", labels.shape)
# Out:
# Images shape: (64, 32, 32, 3)
# Labels shape: (64, 102)
# Images shape: (64, 32, 32, 3)
# Labels shape: (64, 102)

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# Create the ResNet model without the top (fully connected) layers
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
    
# Add the top layers for classification
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(102, activation='softmax'))  # Change the number of units and activation

# Assuming ds_train is your full dataset
# You need to have a reasonable amount of data for both training and validation for this to be effective

# Define the ratio of data to be used for validation
validation_split = 0.2

# Calculate the number of samples to be used for validation
validation_samples = int(validation_split * len(ds_train))

# Calculate the number of samples to be used for training
training_samples = len(ds_train) - validation_samples

# Split the data
ds_validation = ds_train.take(validation_samples)
ds_train = ds_train.skip(validation_samples)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# Train the model with early stopping
model.fit(ds_train, batch_size=32, epochs=100, validation_data=ds_validation)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 235s 1s/step - loss: 2.3335 - accuracy: 0.4634 - val_loss: 313.9972 - val_accuracy: 0.2746
# Epoch 2/100
# 30/30 [==============================] - 25s 852ms/step - loss: 1.2009 - accuracy: 0.6308 - val_loss: 41.3273 - val_accuracy: 0.2121
# Epoch 3/100
# 30/30 [==============================] - 35s 826ms/step - loss: 0.8693 - accuracy: 0.7008 - val_loss: 2.4442 - val_accuracy: 0.2522
# Epoch 4/100
# 30/30 [==============================] - 27s 917ms/step - loss: 0.7131 - accuracy: 0.7756 - val_loss: 3.1476 - val_accuracy: 0.2165
# Epoch 5/100
# 30/30 [==============================] - 25s 854ms/step - loss: 0.5244 - accuracy: 0.8274 - val_loss: 2.1073 - val_accuracy: 0.2545
# Epoch 6/100
# 30/30 [==============================] - 36s 820ms/step - loss: 0.4364 - accuracy: 0.8509 - val_loss: 2.2186 - val_accuracy: 0.2388
# Epoch 7/100
# 30/30 [==============================] - 24s 801ms/step - loss: 0.3367 - accuracy: 0.9043 - val_loss: 1.9270 - val_accuracy: 0.2545
# Epoch 8/100
# 30/30 [==============================] - 24s 813ms/step - loss: 0.2317 - accuracy: 0.9210 - val_loss: 2.1528 - val_accuracy: 0.2321
# Epoch 9/100
100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0505 - accuracy: 0.9864 - val_loss: 0.0426 - val_accuracy: 0.9866
# Epoch 88/100
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0468 - accuracy: 0.9848 - val_loss: 0.0259 - val_accuracy: 0.9911
# Epoch 89/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 0.0460 - val_accuracy: 0.9888
# Epoch 90/100
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0358 - accuracy: 0.9885 - val_loss: 0.1166 - val_accuracy: 0.9688
# Epoch 91/100
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0458 - accuracy: 0.9869 - val_loss: 0.0477 - val_accuracy: 0.9799
# Epoch 92/100
# 30/30 [==============================] - 2s 48ms/step - loss: 0.0331 - accuracy: 0.9885 - val_loss: 0.0209 - val_accuracy: 0.9955
# Epoch 93/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0320 - accuracy: 0.9895 - val_loss: 0.0577 - val_accuracy: 0.9866
# Epoch 94/100
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0420 - accuracy: 0.9859 - val_loss: 0.1347 - val_accuracy: 0.9598
# Epoch 95/100
# 30/30 [==============================] - 2s 49ms/step - loss: 0.0448 - accuracy: 0.9848 - val_loss: 0.0184 - val_accuracy: 0.9978
# Epoch 96/100
# 30/30 [==============================] - 2s 49ms/step - loss: 0.0333 - accuracy: 0.9864 - val_loss: 0.0353 - val_accuracy: 0.9888
# Epoch 97/100
# 30/30 [==============================] - 2s 48ms/step - loss: 0.0408 - accuracy: 0.9906 - val_loss: 0.0950 - val_accuracy: 0.9710
# Epoch 98/100
# 30/30 [==============================] - 2s 49ms/step - loss: 0.0511 - accuracy: 0.9838 - val_loss: 0.1097 - val_accuracy: 0.9643
# Epoch 99/100
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0250 - accuracy: 0.9911 - val_loss: 0.0289 - val_accuracy: 0.9888
# Epoch 100/100
# 30/30 [==============================] - 2s 48ms/step - loss: 0.0276 - accuracy: 0.9927 - val_loss: 0.0761 - val_accuracy: 0.9754

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = model.predict(ds_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Manually generate ground truth labels for evaluation
true_labels = []
for _, label in ds_test:
    true_labels.extend(label.numpy())

true_labels = np.argmax(true_labels, axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate F1 score
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Calculate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Assuming you have test_loss and test_accuracy available
# If not, you'll need to calculate them based on your model and test dataset
print(f"Test Accuracy: {accuracy}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# 12/12 [==============================] - 2s 54ms/step
# Test Accuracy: 0.6771117166212534
# Accuracy: 0.6771117166212534
# F1 Score: 0.6793667955021886

# %%
from tensorflow import keras
model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\flo_32_model.h5")

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
    
num_classes = 102  # Update with the actual number of classes in your target data
x = model.layers[-4].output  # Access the last 4th layer from the end
x = GlobalAveragePooling2D()(x)
output = Dense(num_classes, activation='softmax')(x)

# Create the new model with the updated head
new_model = keras.models.Model(inputs=model.input, outputs=output)

# Define the ratio of data to be used for validation
validation_split = 0.2

# Calculate the number of samples to be used for validation
validation_samples = int(validation_split * len(ds_train))

# Calculate the number of samples to be used for training
training_samples = len(ds_train) - validation_samples

# Split the data
ds_validation = ds_train.take(validation_samples)
ds_train = ds_train.skip(validation_samples)

# Compile the model
new_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define the early stopping callback
#early_stopping = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

# Train the model with early stopping
new_model.fit(ds_train, batch_size=32, epochs=100, validation_data=ds_validation)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 9s 84ms/step - loss: 2.0295 - accuracy: 0.4647 - val_loss: nan - val_accuracy: 0.2318
# Epoch 2/100
# 24/24 [==============================] - 1s 47ms/step - loss: 1.0227 - accuracy: 0.6551 - val_loss: nan - val_accuracy: 0.2708
# Epoch 3/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.9505 - accuracy: 0.7120 - val_loss: nan - val_accuracy: 0.2188
# Epoch 4/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.8241 - accuracy: 0.7127 - val_loss: nan - val_accuracy: 0.2188
# Epoch 5/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6637 - accuracy: 0.7592 - val_loss: nan - val_accuracy: 0.2630
# Epoch 6/100
# 24/24 [==============================] - 1s 44ms/step - loss: 0.6370 - accuracy: 0.8213 - val_loss: nan - val_accuracy: 0.2370
# Epoch 7/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.5607 - accuracy: 0.8397 - val_loss: nan - val_accuracy: 0.2396
# Epoch 8/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6992 - accuracy: 0.8318 - val_loss: nan - val_accuracy: 0.2552
# Epoch 9/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.4223 - accuracy: 0.8613 - val_loss: nan - val_accuracy: 0.2318
# Epoch 10/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.3954 - accuracy: 0.8763 - val_loss: nan - val_accuracy: 0.3333
# Epoch 11/100
# 24/24 [==============================] - 1s 45ms/step - loss: 0.3234 - accuracy: 0.9025 - val_loss: nan - val_accuracy: 0.2500
# Epoch 12/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.4352 - accuracy: 0.9031 - val_loss: nan - val_accuracy: 0.2656
# Epoch 13/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2403 - accuracy: 0.9234 - val_loss: nan - val_accuracy: 0.2370
# Epoch 14/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2867 - accuracy: 0.9018 - val_loss: nan - val_accuracy: 0.2448
# Epoch 15/100
# 24/24 [==============================] - 1s 44ms/step - loss: 0.3395 - accuracy: 0.8966 - val_loss: nan - val_accuracy: 0.2318
# Epoch 16/100
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2353 - accuracy: 0.9208 - val_loss: nan - val_accuracy: 0.2500
# Epoch 17/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1957 - accuracy: 0.9372 - val_loss: nan - val_accuracy: 0.2578
# Epoch 18/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2256 - accuracy: 0.9450 - val_loss: nan - val_accuracy: 0.2630
# Epoch 19/100
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2669 - accuracy: 0.9339 - val_loss: nan - val_accuracy: 0.2708
# Epoch 20/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2645 - accuracy: 0.9221 - val_loss: nan - val_accuracy: 0.1927
# Epoch 21/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2031 - accuracy: 0.9424 - val_loss: nan - val_accuracy: 0.2839
# Epoch 22/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.1418 - accuracy: 0.9575 - val_loss: nan - val_accuracy: 0.2891
# Epoch 23/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.1609 - accuracy: 0.9548 - val_loss: nan - val_accuracy: 0.2448
# Epoch 24/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1631 - accuracy: 0.9529 - val_loss: nan - val_accuracy: 0.2578
# Epoch 25/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.2431 - accuracy: 0.9339 - val_loss: nan - val_accuracy: 0.2396
# Epoch 26/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6466 - accuracy: 0.7958 - val_loss: nan - val_accuracy: 0.2604
# Epoch 27/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.5341 - accuracy: 0.8279 - val_loss: nan - val_accuracy: 0.2188
# Epoch 28/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3233 - accuracy: 0.8809 - val_loss: nan - val_accuracy: 0.2318
# Epoch 29/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2990 - accuracy: 0.9097 - val_loss: nan - val_accuracy: 0.2214
# Epoch 30/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1909 - accuracy: 0.9424 - val_loss: nan - val_accuracy: 0.2318
# Epoch 31/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.1677 - accuracy: 0.9634 - val_loss: nan - val_accuracy: 0.2161
# Epoch 32/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1366 - accuracy: 0.9581 - val_loss: nan - val_accuracy: 0.2682
# Epoch 33/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0979 - accuracy: 0.9751 - val_loss: nan - val_accuracy: 0.2786
# Epoch 34/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.1549 - accuracy: 0.9620 - val_loss: nan - val_accuracy: 0.2161
# Epoch 35/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1716 - accuracy: 0.9647 - val_loss: nan - val_accuracy: 0.2604
# Epoch 36/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1410 - accuracy: 0.9601 - val_loss: nan - val_accuracy: 0.2734
# Epoch 37/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2992 - accuracy: 0.9516 - val_loss: nan - val_accuracy: 0.2500
# Epoch 38/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.4298 - accuracy: 0.9097 - val_loss: nan - val_accuracy: 0.2474
# Epoch 39/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.2546 - accuracy: 0.9221 - val_loss: nan - val_accuracy: 0.2214
# Epoch 40/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2051 - accuracy: 0.9339 - val_loss: nan - val_accuracy: 0.2422
# Epoch 41/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.1244 - accuracy: 0.9666 - val_loss: nan - val_accuracy: 0.2448
# Epoch 42/100
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1724 - accuracy: 0.9614 - val_loss: nan - val_accuracy: 0.2552
# Epoch 43/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2199 - accuracy: 0.9437 - val_loss: nan - val_accuracy: 0.2786
# Epoch 44/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.3298 - accuracy: 0.9332 - val_loss: nan - val_accuracy: 0.2578
# Epoch 45/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.2781 - accuracy: 0.9241 - val_loss: nan - val_accuracy: 0.2552
# Epoch 46/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.2217 - accuracy: 0.9378 - val_loss: nan - val_accuracy: 0.3021
# Epoch 47/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.2935 - accuracy: 0.9503 - val_loss: nan - val_accuracy: 0.2448
# Epoch 48/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.1289 - accuracy: 0.9634 - val_loss: nan - val_accuracy: 0.2031
# Epoch 49/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1165 - accuracy: 0.9607 - val_loss: nan - val_accuracy: 0.2786
# Epoch 50/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1704 - accuracy: 0.9712 - val_loss: nan - val_accuracy: 0.2161
# Epoch 51/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1999 - accuracy: 0.9391 - val_loss: nan - val_accuracy: 0.2500
# Epoch 52/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.1341 - accuracy: 0.9562 - val_loss: nan - val_accuracy: 0.2682
# Epoch 53/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.1377 - accuracy: 0.9732 - val_loss: nan - val_accuracy: 0.2630
# Epoch 54/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1677 - accuracy: 0.9601 - val_loss: nan - val_accuracy: 0.2604
# Epoch 55/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.2372 - accuracy: 0.9228 - val_loss: nan - val_accuracy: 0.2604
# Epoch 56/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.2341 - accuracy: 0.9398 - val_loss: nan - val_accuracy: 0.2318
# Epoch 57/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.1152 - accuracy: 0.9653 - val_loss: nan - val_accuracy: 0.2604
# Epoch 58/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0816 - accuracy: 0.9732 - val_loss: nan - val_accuracy: 0.2396
# Epoch 59/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0825 - accuracy: 0.9732 - val_loss: nan - val_accuracy: 0.2214
# Epoch 60/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0625 - accuracy: 0.9810 - val_loss: nan - val_accuracy: 0.2448
# Epoch 61/100
# 24/24 [==============================] - 2s 60ms/step - loss: 0.0685 - accuracy: 0.9771 - val_loss: nan - val_accuracy: 0.2422
# Epoch 62/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0721 - accuracy: 0.9771 - val_loss: nan - val_accuracy: 0.2500
# Epoch 63/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0532 - accuracy: 0.9863 - val_loss: nan - val_accuracy: 0.2422
# Epoch 64/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0817 - accuracy: 0.9738 - val_loss: nan - val_accuracy: 0.2448
# Epoch 65/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.3912 - accuracy: 0.8992 - val_loss: nan - val_accuracy: 0.2526
# Epoch 66/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.3618 - accuracy: 0.8901 - val_loss: nan - val_accuracy: 0.2318
# Epoch 67/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.2119 - accuracy: 0.9332 - val_loss: nan - val_accuracy: 0.2786
# Epoch 68/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1349 - accuracy: 0.9627 - val_loss: nan - val_accuracy: 0.2682
# Epoch 69/100
# 24/24 [==============================] - 2s 62ms/step - loss: 0.1947 - accuracy: 0.9483 - val_loss: nan - val_accuracy: 0.2526
# Epoch 70/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.2779 - accuracy: 0.9385 - val_loss: nan - val_accuracy: 0.2344
# Epoch 71/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.5770 - accuracy: 0.8737 - val_loss: nan - val_accuracy: 0.2656
# Epoch 72/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.3335 - accuracy: 0.8855 - val_loss: nan - val_accuracy: 0.2214
# Epoch 73/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.4138 - accuracy: 0.9182 - val_loss: nan - val_accuracy: 0.2292
# Epoch 74/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.3085 - accuracy: 0.9391 - val_loss: nan - val_accuracy: 0.2344
# Epoch 75/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3552 - accuracy: 0.9058 - val_loss: nan - val_accuracy: 0.2656
# Epoch 76/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.4158 - accuracy: 0.8815 - val_loss: nan - val_accuracy: 0.2344
# Epoch 77/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2240 - accuracy: 0.9352 - val_loss: nan - val_accuracy: 0.2422
# Epoch 78/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.2461 - accuracy: 0.9568 - val_loss: nan - val_accuracy: 0.2656
# Epoch 79/100
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0874 - accuracy: 0.9764 - val_loss: nan - val_accuracy: 0.2734
# Epoch 80/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.1501 - accuracy: 0.9712 - val_loss: nan - val_accuracy: 0.2292
# Epoch 81/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6590 - accuracy: 0.8122 - val_loss: nan - val_accuracy: 0.2682
# Epoch 82/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.5633 - accuracy: 0.8115 - val_loss: nan - val_accuracy: 0.2734
# Epoch 83/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.3536 - accuracy: 0.8809 - val_loss: nan - val_accuracy: 0.2370
# Epoch 84/100
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2969 - accuracy: 0.9130 - val_loss: nan - val_accuracy: 0.2526
# Epoch 85/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.2384 - accuracy: 0.9346 - val_loss: nan - val_accuracy: 0.2396
# Epoch 86/100
# 24/24 [==============================] - 1s 47ms/step - loss: 0.2119 - accuracy: 0.9457 - val_loss: nan - val_accuracy: 0.2292
# Epoch 87/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1995 - accuracy: 0.9450 - val_loss: nan - val_accuracy: 0.2448
# Epoch 88/100
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2185 - accuracy: 0.9463 - val_loss: nan - val_accuracy: 0.2031
# Epoch 89/100
# 24/24 [==============================] - 1s 48ms/step - loss: 0.3944 - accuracy: 0.9084 - val_loss: nan - val_accuracy: 0.2266
# Epoch 90/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2782 - accuracy: 0.9241 - val_loss: nan - val_accuracy: 0.2396
# Epoch 91/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2293 - accuracy: 0.9555 - val_loss: nan - val_accuracy: 0.2760
# Epoch 92/100
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2228 - accuracy: 0.9607 - val_loss: nan - val_accuracy: 0.2812
# Epoch 93/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.1520 - accuracy: 0.9771 - val_loss: nan - val_accuracy: 0.2370
# Epoch 94/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1273 - accuracy: 0.9771 - val_loss: nan - val_accuracy: 0.2656
# Epoch 95/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.1217 - accuracy: 0.9777 - val_loss: nan - val_accuracy: 0.2630
# Epoch 96/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0815 - accuracy: 0.9791 - val_loss: nan - val_accuracy: 0.2188
# Epoch 97/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0778 - accuracy: 0.9784 - val_loss: nan - val_accuracy: 0.2292
# Epoch 98/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1090 - accuracy: 0.9758 - val_loss: nan - val_accuracy: 0.2682
# Epoch 99/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2263 - accuracy: 0.9516 - val_loss: nan - val_accuracy: 0.2578
# Epoch 100/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.1846 - accuracy: 0.9404 - val_loss: nan - val_accuracy: 0.2526

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import numpy as np

# Make predictions on the test dataset
predictions = new_model.predict(ds_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Manually generate ground truth labels for evaluation
true_labels = []
for _, label in ds_test:
    true_labels.extend(label.numpy())

true_labels = np.argmax(true_labels, axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate F1 score
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Calculate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Assuming you have test_loss and test_accuracy available
# If not, you'll need to calculate them based on your model and test dataset
print(f"Test Accuracy: {accuracy}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# 12/12 [==============================] - 1s 37ms/step
# Test Accuracy: 0.21662125340599456
# Accuracy: 0.21662125340599456
# F1 Score: 0.0771394832957517

# %%
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
