# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Load the Flowers-102 dataset
(ds_train, ds_test), ds_info = tfds.load('tf_flowers', split=['train[:80%]', 'train[80%:]'], as_supervised=True, with_info=True)

# Define a function to resize images
def resize_image(image, label):
    image = tf.image.resize(image, (32, 32))
    return image, label

# Apply resizing to the dataset
ds_train = ds_train.map(resize_image)
ds_test = ds_test.map(resize_image)

# Normalize pixel values to be in the range [0, 1]
ds_train = ds_train.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y))
ds_test = ds_test.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y))

# Shuffle and batch the datasets
ds_train = ds_train.shuffle(10000).batch(64)
ds_test = ds_test.batch(64)

# Convert labels to categorical format
def categorical_labels(images, labels):
    return images, tf.one_hot(labels, depth=102)  # 102 classes in Flowers-102 dataset

ds_train = ds_train.map(categorical_labels)
ds_test = ds_test.map(categorical_labels)

# Verify the shapes
for images, labels in ds_train.take(1):
    print("Images shape:", images.shape)
    print("Labels shape:", labels.shape)

for images, labels in ds_test.take(1):
    print("Images shape:", images.shape)
    print("Labels shape:", labels.shape)
# Out:
# Images shape: (64, 32, 32, 3)
# Labels shape: (64, 102)
# Images shape: (64, 32, 32, 3)
# Labels shape: (64, 102)

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# Create the ResNet model without the top (fully connected) layers
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
    
# Add the top layers for classification
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(102, activation='softmax'))  # Change the number of units and activation

# Assuming ds_train is your full dataset
# You need to have a reasonable amount of data for both training and validation for this to be effective

# Define the ratio of data to be used for validation
validation_split = 0.2

# Calculate the number of samples to be used for validation
validation_samples = int(validation_split * len(ds_train))

# Calculate the number of samples to be used for training
training_samples = len(ds_train) - validation_samples

# Split the data
ds_validation = ds_train.take(validation_samples)
ds_train = ds_train.skip(validation_samples)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# Train the model with early stopping
model.fit(ds_train, batch_size=32, epochs=50, validation_data=ds_validation)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 9s 427ms/step - loss: 3.5655 - accuracy: 0.2837 - val_loss: 9.9198 - val_accuracy: 0.1406
# Epoch 2/100
# 8/8 [==============================] - 1s 124ms/step - loss: 1.7670 - accuracy: 0.5238 - val_loss: 8.3835 - val_accuracy: 0.2656
# Epoch 3/100
# 8/8 [==============================] - 1s 95ms/step - loss: 1.5308 - accuracy: 0.5794 - val_loss: 27.6521 - val_accuracy: 0.1875
# Epoch 4/100
# 8/8 [==============================] - 1s 80ms/step - loss: 1.5735 - accuracy: 0.5655 - val_loss: 144.7723 - val_accuracy: 0.2031
# Epoch 5/100
# 8/8 [==============================] - 1s 88ms/step - loss: 1.2856 - accuracy: 0.5873 - val_loss: 206.8188 - val_accuracy: 0.1406
# Epoch 6/100
# 8/8 [==============================] - 1s 80ms/step - loss: 1.2223 - accuracy: 0.6806 - val_loss: 187.7796 - val_accuracy: 0.2344
# Epoch 7/100
# 8/8 [==============================] - 1s 103ms/step - loss: 0.9933 - accuracy: 0.6528 - val_loss: 377.0417 - val_accuracy: 0.2656
# Epoch 8/100
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6193 - accuracy: 0.7897 - val_loss: 17.2392 - val_accuracy: 0.2656
# Epoch 50/100
# 8/8 [==============================] - 1s 87ms/step - loss: 0.4859 - accuracy: 0.8452 - val_loss: 8.3455 - val_accuracy: 0.2344
# Epoch 51/100
# 8/8 [==============================] - 1s 80ms/step - loss: 0.4920 - accuracy: 0.8274 - val_loss: 6.5556 - val_accuracy: 0.1406
# Epoch 52/100
# 8/8 [==============================] - 1s 83ms/step - loss: 0.5082 - accuracy: 0.8532 - val_loss: 5.9892 - val_accuracy: 0.2344
# Epoch 53/100
# 8/8 [==============================] - 1s 68ms/step - loss: 0.5584 - accuracy: 0.8313 - val_loss: 5.0282 - val_accuracy: 0.2812
# Epoch 54/100
# 8/8 [==============================] - 1s 68ms/step - loss: 0.5516 - accuracy: 0.8591 - val_loss: 4.9668 - val_accuracy: 0.2812
# Epoch 55/100
# 8/8 [==============================] - 1s 76ms/step - loss: 1.0950 - accuracy: 0.7679 - val_loss: 4.6329 - val_accuracy: 0.1250
# Epoch 56/100
# 8/8 [==============================] - 1s 72ms/step - loss: 0.8901 - accuracy: 0.7361 - val_loss: 10.0972 - val_accuracy: 0.2188
# Epoch 57/100
# 8/8 [==============================] - 1s 74ms/step - loss: 0.7381 - accuracy: 0.7321 - val_loss: 8.8918 - val_accuracy: 0.1562
# Epoch 58/100
# 8/8 [==============================] - 1s 68ms/step - loss: 1.3726 - accuracy: 0.6984 - val_loss: 6.0595 - val_accuracy: 0.2344
# Epoch 59/100
# 8/8 [==============================] - 1s 80ms/step - loss: 1.0903 - accuracy: 0.6409 - val_loss: 3.0344 - val_accuracy: 0.2969
# Epoch 60/100
# 8/8 [==============================] - 1s 80ms/step - loss: 0.8387 - accuracy: 0.7222 - val_loss: 12.6579 - val_accuracy: 0.1719

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = model.predict(ds_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Manually generate ground truth labels for evaluation
true_labels = []
for _, label in ds_test:
    true_labels.extend(label.numpy())

true_labels = np.argmax(true_labels, axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate F1 score
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Calculate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Assuming you have test_loss and test_accuracy available
# If not, you'll need to calculate them based on your model and test dataset
print(f"Test Accuracy: {accuracy}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# Test Accuracy: 0.22343324250681199
# Accuracy: 0.22343324250681199
# F1 Score: 0.09985420155195886

# %%
from tensorflow import keras
model = keras.models.load_model(r"C:\Users\shaif\Downloads\Flowers102_32_model.h5")

from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
    
num_classes = 102  # Update with the actual number of classes in your target data
x = model.layers[-4].output  # Access the last 4th layer from the end
x = GlobalAveragePooling2D()(x)
output = Dense(num_classes, activation='softmax')(x)

# Create the new model with the updated head
new_model = keras.models.Model(inputs=model.input, outputs=output)

# Define the ratio of data to be used for validation
validation_split = 0.2

# Calculate the number of samples to be used for validation
validation_samples = int(validation_split * len(ds_train))

# Calculate the number of samples to be used for training
training_samples = len(ds_train) - validation_samples

# Split the data
ds_validation = ds_train.take(validation_samples)
ds_train = ds_train.skip(validation_samples)

# Compile the model
new_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define the early stopping callback
#early_stopping = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

# Train the model with early stopping
new_model.fit(ds_train, batch_size=32, epochs=50, validation_data=ds_validation)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 8s 265ms/step - loss: 3.6579 - accuracy: 0.3682 - val_loss: 39.3004 - val_accuracy: 0.1875
# Epoch 2/100
# 7/7 [==============================] - 1s 96ms/step - loss: 1.8600 - accuracy: 0.4455 - val_loss: 872.7832 - val_accuracy: 0.1406
# Epoch 3/100
# 7/7 [==============================] - 1s 85ms/step - loss: 1.1912 - accuracy: 0.5545 - val_loss: 1712.9141 - val_accuracy: 0.1094
# Epoch 4/100
# 7/7 [==============================] - 1s 119ms/step - loss: 1.1004 - accuracy: 0.6000 - val_loss: 1600.1246 - val_accuracy: 0.2031
# Epoch 5/100
# 7/7 [==============================] - 1s 127ms/step - loss: 1.0417 - accuracy: 0.6136 - val_loss: 940.4776 - val_accuracy: 0.2188
# Epoch 6/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.9728 - accuracy: 0.6159 - val_loss: 529.0860 - val_accuracy: 0.1562
# Epoch 7/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.8736 - accuracy: 0.6955 - val_loss: 319.8215 - val_accuracy: 0.2031
# Epoch 8/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.8440 - accuracy: 0.7273 - val_loss: 260.3022 - val_accuracy: 0.1719
# Epoch 9/100
# 7/7 [==============================] - 1s 114ms/step - loss: 0.7786 - accuracy: 0.7386 - val_loss: 79.1299 - val_accuracy: 0.1719
# Epoch 10/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.7756 - accuracy: 0.7341 - val_loss: 88.4831 - val_accuracy: 0.1562
# Epoch 11/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.7624 - accuracy: 0.7568 - val_loss: 25.2843 - val_accuracy: 0.2500
# Epoch 12/100
# 7/7 [==============================] - 1s 158ms/step - loss: 0.5328 - accuracy: 0.8341 - val_loss: 10.2500 - val_accuracy: 0.2969
# Epoch 13/100
# 7/7 [==============================] - 1s 107ms/step - loss: 0.7111 - accuracy: 0.7773 - val_loss: 13.4182 - val_accuracy: 0.3906
# Epoch 14/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.6618 - accuracy: 0.7932 - val_loss: 1.8983 - val_accuracy: 0.5938
# Epoch 15/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.6702 - accuracy: 0.8295 - val_loss: 0.8515 - val_accuracy: 0.6875
# Epoch 16/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.6883 - accuracy: 0.8159 - val_loss: 0.9247 - val_accuracy: 0.6562
# Epoch 17/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0
100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.4474 - accuracy: 0.8477 - val_loss: 1.0108 - val_accuracy: 0.7188
# Epoch 41/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.3336 - accuracy: 0.8886 - val_loss: 0.8424 - val_accuracy: 0.7031
# Epoch 42/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.3806 - accuracy: 0.8727 - val_loss: 0.5192 - val_accuracy: 0.8281
# Epoch 43/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.2910 - accuracy: 0.9023 - val_loss: 1.1619 - val_accuracy: 0.8281
# Epoch 44/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.2994 - accuracy: 0.9091 - val_loss: 0.4714 - val_accuracy: 0.8750
# Epoch 45/100
# 7/7 [==============================] - 1s 72ms/step - loss: 0.2464 - accuracy: 0.9273 - val_loss: 0.3932 - val_accuracy: 0.8281
# Epoch 46/100
# 7/7 [==============================] - 1s 104ms/step - loss: 0.4422 - accuracy: 0.9136 - val_loss: 1.3531 - val_accuracy: 0.7188
# Epoch 47/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.5213 - accuracy: 0.8545 - val_loss: 0.4961 - val_accuracy: 0.8281
# Epoch 48/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.5250 - accuracy: 0.8591 - val_loss: 1.4680 - val_accuracy: 0.6719
# Epoch 49/100
# 7/7 [==============================] - 1s 71ms/step - loss: 0.4843 - accuracy: 0.8591 - val_loss: 12.0771 - val_accuracy: 0.7344
# Epoch 50/100
# 7/7 [==============================] - 0s 64ms/step - loss: 0.5166 - accuracy: 0.8682 - val_loss: 4.1191 - val_accuracy: 0.5938
# Epoch 51/100
# 7/7 [==============================] - 1s 101ms/step - loss: 0.3845 - accuracy: 0.8864 - val_loss: 1.6617 - val_accuracy: 0.7812
# Epoch 52/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.4082 - accuracy: 0.8682 - val_loss: 0.9420 - val_accuracy: 0.8281
# Epoch 53/100
# 7/7 [==============================] - 1s 103ms/step - loss: 0.4419 - accuracy: 0.8886 - val_loss: 1.1166 - val_accuracy: 0.8594
# Epoch 54/100
# 7/7 [==============================] - 1s 69ms/step - loss: 0.3998 - accuracy: 0.8955 - val_loss: 1.2504 - val_accuracy: 0.9062
# Epoch 55/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.2885 - accuracy: 0.9182 - val_loss: 0.4147 - val_accuracy: 0.8906
# Epoch 56/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.3131 - accuracy: 0.9045 - val_loss: 0.3801 - val_accuracy: 0.8906

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = new_model.predict(ds_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Manually generate ground truth labels for evaluation
true_labels = []
for _, label in ds_test:
    true_labels.extend(label.numpy())

true_labels = np.argmax(true_labels, axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate F1 score
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Calculate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Assuming you have test_loss and test_accuracy available
# If not, you'll need to calculate them based on your model and test dataset
print(f"Test Accuracy: {accuracy}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# Test Accuracy: 0.5626702997275205
# Accuracy: 0.5626702997275205
# F1 Score: 0.5439608092675009
