# %%
import glob
invasive_dirs = [
    r'E:\VeligerData\invasive',
    r'E:\VeligerData\Baylor 2022-03-21_2\Veligers',
    
  ]

# Non-Invasive category
non_invasive_dirs = [
    r'E:\VeligerData\noninvasive',
    r'E:\VeligerData\Baylor 2022-03-21_2\NonVeligers\Images_001',
   ]

# Ostracod category
ostracod_dirs = [
    r'E:\VeligerData\Ostracod Day 2 Image12 Short To Baylor\Ostracod Day 2 Image12 To Baylor\Sorted Images\Ostracods',
    r'E:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1 To Baylor\Preserved Ostracods 1 To Baylor\Sorted Images\Preserve Ostracods',
    r'E:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Ostracods 1a To Baylor\Preserved Ostracods 1a To Baylor\Sorted Images\Preserved Ostracods 1a',
    r'E:\VeligerData\Ostracods Day 2 Image3 To Baylor_2\Ostracods Day 2 Image3 To Baylor\Sorted Images\Ostracods',
    r'E:\VeligerData\Ostracods Day 2 Image12 To Baylor_3\Ostracods Day 2 Image12 To Baylor\Sorted Images\Ostracods',  
]

# List to store subdirectories
invasive_subdirs = []
non_invasive_subdirs = []
ostracod_subdirs = []

# Collect subdirectories in the invasive category
for invasive_dir in invasive_dirs:
    invasive_subdirs.extend(glob.glob(invasive_dir))

# Collect subdirectories in the non-invasive category
for non_invasive_dir in non_invasive_dirs:
    non_invasive_subdirs.extend(glob.glob(non_invasive_dir))
    
for ostracod_dir in ostracod_dirs:
    ostracod_subdirs.extend(glob.glob(ostracod_dir))
    
import glob
from PIL import Image

# List of directories in x
x = non_invasive_subdirs

# List to store subdirectories
y1 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y1.extend(subdirectories)

import glob

# List of directories in x
x = invasive_subdirs

# List to store subdirectories
y2 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y2.extend(subdirectories)

    
import glob

# List of directories in x
x = ostracod_subdirs

# List to store subdirectories
y3 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y3.extend(subdirectories)

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image

def preprocess_images(y1, label_num, target_size=(40, 40)):
    # List to store image files
    image_files = []
    # List to store labels
    labels = []

    # Retrieve image files and create labels for each directory in y1
    for directory in y1:
        for root, dirs, files in os.walk(directory):
            for file in files:
                # Check if the file has an image extension
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    # Add the file path to the image_files list
                    image_files.append(os.path.join(root, file))
                    # Add the label to the labels list
                    

    # List to store preprocessed images
    images = []

    # Preprocess each image
    for file in image_files:
        try:
            # Read the image using PIL
            image = Image.open(file)
            # Resize the image using tf.image.resize_with_crop_or_pad()
            image = tf.image.resize_with_crop_or_pad(
                tf.keras.preprocessing.image.img_to_array(image),
                target_size[0],
                target_size[1]
            )
            # Normalize the image pixels for ML training
            image = image / 255.0
            # Add the preprocessed image to the images list
            images.append(image)
            labels.append(label_num)
        except Exception as e:
            print(f"Error processing image: {file}. Skipping...")
            continue

    # Convert the images and labels lists to numpy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels


X0,Y0 = preprocess_images(y1, label_num = 0)
X1,Y1 = preprocess_images(y2, label_num = 1)
X2,Y2 = preprocess_images(y3, label_num = 2)
# Out:
# Error processing image: E:\VeligerData\Ostracod Day 2 Image12 Short To Baylor\Ostracod Day 2 Image12 To Baylor\Sorted Images\Ostracods\Object_002\._Image_032.png. Skipping...
# Error processing image: E:\VeligerData\Ostracod Day 2 Image12 Short To Baylor\Ostracod Day 2 Image12 To Baylor\Sorted Images\Ostracods\Object_002\._Image_036.png. Skipping...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Concatenate the image arrays
train_images = np.concatenate((X0, X1, X2), axis=0)

# Combine the label arrays
train_labels = np.concatenate((Y0, Y1, Y2), axis=0)

# Convert the labels to categorical
train_labels_categorical = to_categorical(train_labels)

# Set the dtype of train_images to float32
train_images = train_images.astype('float32')

# Split the data into train and test sets
from sklearn.utils import shuffle

# Shuffle the data
train_images, train_labels_categorical = shuffle(train_images, train_labels_categorical)

# Now the shuffled data is assigned to the same variable names
X_train, X_test, Y_train, Y_test = train_test_split(train_images, train_labels_categorical, test_size=0.05, random_state=42)

# %%
np.shape(X_train)
# Out:
# (116952, 40, 40, 3)

# %%
import numpy as np
import pandas as pd
from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), input_shape=(40, 40, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation="relu"))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(16, (3, 3)))
model.add(layers.Flatten())
model.add(layers.Dense(64))
model.add(layers.Dense(10))
model.add(layers.Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 38, 38, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 19, 19, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 17, 17, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 16)          4624
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
#  dense_2 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 52,379
# Trainable params: 52,379
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_weights = np.zeros(3)

unique_labels, counts = np.unique(train_labels, return_counts=True)

total_samples = np.sum(counts)

for i, label in enumerate(unique_labels):
    class_weights[label] = total_samples / (len(unique_labels) * counts[i])

print("Class weights:", class_weights)
# Out:
# Class weights: [ 0.36473424  5.32483295 14.18875366]

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics='accuracy')
class_weights = [1,1,1]
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/50
# 3365/3365 [==============================] - 31s 7ms/step - loss: 0.1272 - accuracy: 0.9518 - val_loss: 0.0937 - val_accuracy: 0.9623
# Epoch 2/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.1013 - accuracy: 0.9606 - val_loss: 0.0862 - val_accuracy: 0.9656
# Epoch 3/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0921 - accuracy: 0.9644 - val_loss: 0.1289 - val_accuracy: 0.9537
# Epoch 4/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0881 - accuracy: 0.9652 - val_loss: 0.0866 - val_accuracy: 0.9636
# Epoch 5/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0858 - accuracy: 0.9664 - val_loss: 0.0812 - val_accuracy: 0.9689
# Epoch 6/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0819 - accuracy: 0.9675 - val_loss: 0.0806 - val_accuracy: 0.9676
# Epoch 7/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0799 - accuracy: 0.9685 - val_loss: 0.0783 - val_accuracy: 0.9674
# Epoch 8/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0781 - accuracy: 0.9682 - val_loss: 0.0781 - val_accuracy: 0.9698
# Epoch 9/50
# 3365/3365 [==============================] - 22s 7ms/step - loss: 0.0759 - accuracy: 0.9697 - val_loss: 0.0778 - val_accuracy: 0.9697
# Epoch 10/50
# 3365/3365 [==============================] - 22s 6ms/step - loss: 0.0750 - accuracy: 0.9704 - val_loss: 0.0877 - val_accuracy: 0.9674
# Epoch 11/50
# 3365/3365 [==============================] - 22s 6ms/step - loss: 0.0716 - accuracy: 0.9711 - val_loss: 0.0768 - val_accuracy: 0.9702
# Epoch 12/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0711 - accuracy: 0.9716 - val_loss: 0.0821 - val_accuracy: 0.9672
# Epoch 13/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0697 - accuracy: 0.9724 - val_loss: 0.0792 - val_accuracy: 0.9684
# Epoch 14/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0684 - accuracy: 0.9730 - val_loss: 0.0792 - val_accuracy: 0.9687
# Epoch 15/50
# 3365/3365 [==============================] - 22s 6ms/step - loss: 0.0679 - accuracy: 0.9725 - val_loss: 0.0782 - val_accuracy: 0.9688
# Epoch 16/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0664 - accuracy: 0.9736 - val_loss: 0.0820 - val_accuracy: 0.9685
# Epoch 17/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0648 - accuracy: 0.9742 - val_loss: 0.0753 - val_accuracy: 0.9702
# Epoch 18/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0643 - accuracy: 0.9743 - val_loss: 0.0767 - val_accuracy: 0.9712
# Epoch 19/50
# 3365/3365 [==============================] - 25s 7ms/step - loss: 0.0661 - accuracy: 0.9736 - val_loss: 0.0742 - val_accuracy: 0.9720
# Epoch 20/50
# 3365/3365 [==============================] - 23s 7ms/step - loss: 0.0624 - accuracy: 0.9752 - val_loss: 0.0854 - val_accuracy: 0.9680
# Epoch 21/50
# 3365/3365 [==============================] - 22s 7ms/step - loss: 0.0617 - accuracy: 0.9755 - val_loss: 0.0773 - val_accuracy: 0.9688
# Epoch 22/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0615 - accuracy: 0.9758 - val_loss: 0.0769 - val_accuracy: 0.9691
# Epoch 23/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0598 - accuracy: 0.9760 - val_loss: 0.0911 - val_accuracy: 0.9651
# Epoch 24/50
# 3365/3365 [==============================] - 24s 7ms/step - loss: 0.0593 - accuracy: 0.9765 - val_loss: 0.0762 - val_accuracy: 0.9719
# Epoch 25/50
# 3365/3365 [==============================] - 24s 7ms/step - loss: 0.0590 - accuracy: 0.9767 - val_loss: 0.0787 - val_accuracy: 0.9707
# Epoch 26/50
# 3365/3365 [==============================] - 22s 7ms/step - loss: 0.0577 - accuracy: 0.9769 - val_loss: 0.0744 - val_accuracy: 0.9729
# Epoch 27/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0575 - accuracy: 0.9772 - val_loss: 0.0757 - val_accuracy: 0.9704
# Epoch 28/50
# 3365/3365 [==============================] - 11s 3ms/step - loss: 0.0569 - accuracy: 0.9774 - val_loss: 0.0761 - val_accuracy: 0.9707
# Epoch 29/50
# 3365/3365 [==============================] - 18s 5ms/step - loss: 0.0554 - accuracy: 0.9778 - val_loss: 0.0798 - val_accuracy: 0.9684
# Epoch 30/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0548 - accuracy: 0.9782 - val_loss: 0.0837 - val_accuracy: 0.9720
# Epoch 31/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0551 - accuracy: 0.9782 - val_loss: 0.0743 - val_accuracy: 0.9717
# Epoch 32/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0545 - accuracy: 0.9779 - val_loss: 0.0734 - val_accuracy: 0.9706
# Epoch 33/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0532 - accuracy: 0.9793 - val_loss: 0.0750 - val_accuracy: 0.9708
# Epoch 34/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0525 - accuracy: 0.9786 - val_loss: 0.0747 - val_accuracy: 0.9720
# Epoch 35/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0519 - accuracy: 0.9794 - val_loss: 0.0838 - val_accuracy: 0.9688
# Epoch 36/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0519 - accuracy: 0.9798 - val_loss: 0.0812 - val_accuracy: 0.9716
# Epoch 37/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0513 - accuracy: 0.9794 - val_loss: 0.1000 - val_accuracy: 0.9620
# Epoch 38/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0507 - accuracy: 0.9798 - val_loss: 0.0808 - val_accuracy: 0.9696
# Epoch 39/50
# 3365/3365 [==============================] - 22s 6ms/step - loss: 0.0505 - accuracy: 0.9797 - val_loss: 0.0819 - val_accuracy: 0.9714
# Epoch 40/50
# 3365/3365 [==============================] - 22s 7ms/step - loss: 0.0500 - accuracy: 0.9800 - val_loss: 0.0870 - val_accuracy: 0.9712
# Epoch 41/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0492 - accuracy: 0.9804 - val_loss: 0.0803 - val_accuracy: 0.9727
# Epoch 42/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0483 - accuracy: 0.9808 - val_loss: 0.0801 - val_accuracy: 0.9705
# Epoch 43/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0478 - accuracy: 0.9812 - val_loss: 0.0940 - val_accuracy: 0.9713
# Epoch 44/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0480 - accuracy: 0.9809 - val_loss: 0.0807 - val_accuracy: 0.9700
# Epoch 45/50
# 3365/3365 [==============================] - 22s 6ms/step - loss: 0.0476 - accuracy: 0.9812 - val_loss: 0.0870 - val_accuracy: 0.9714
# Epoch 46/50
# 3365/3365 [==============================] - 22s 6ms/step - loss: 0.0460 - accuracy: 0.9817 - val_loss: 0.1181 - val_accuracy: 0.9583
# Epoch 47/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0460 - accuracy: 0.9816 - val_loss: 0.0968 - val_accuracy: 0.9680
# Epoch 48/50
# 3365/3365 [==============================] - 20s 6ms/step - loss: 0.0457 - accuracy: 0.9816 - val_loss: 0.0970 - val_accuracy: 0.9688
# Epoch 49/50
# 3365/3365 [==============================] - 19s 6ms/step - loss: 0.0450 - accuracy: 0.9820 - val_loss: 0.0847 - val_accuracy: 0.9704
# Epoch 50/50
# 3365/3365 [==============================] - 21s 6ms/step - loss: 0.0457 - accuracy: 0.9821 - val_loss: 0.0897 - val_accuracy: 0.9727

# %%
from tensorflow.keras.models import load_model

# Define the path to the model file
model_path = r'E:\ML_notebooks\premodel.h5'

# Load the model with custom_objects argument
#model = load_model(model_path)

# %%
invasive_dirs = [
    r'E:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1 To Baylor\Preserved Zebra Ped 1 To Baylor\Sorted Images\Pedi-Zebra Veligers',
    r'E:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1a To Baylor\Preserved Zebra Ped 1a To Baylor\Sorted Images\Preserved Zebra Ped 1a',    
    r'E:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Zebra Pediveliger Image1a\Zebra Pediveligers',
    r'E:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Umbonal',
    r'E:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Umbonal',
    r'E:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Zebra D-Hinge',
]

# Non-Invasive category
non_invasive_dirs = [
    r'E:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1 To Baylor\Preserved Zebra Ped 1 To Baylor\Sorted Images\Not',
    r'E:\VeligerData\Ostracod vs Pedi-Veliger Examples\Ostracod vs Pedi-Veliger Examples\Preserved Zebra Ped 1a To Baylor\Preserved Zebra Ped 1a To Baylor\Sorted Images\Not',  
    r'E:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Not',
    r'E:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Not',
    r'E:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Not',
]

# Ostracod category
ostracod_dirs = [
    r'E:\VeligerData\Ostracods Day 2 Image1 To Baylor\Ostracods',
    r'E:\VeligerData\To Baylor 2023-01-30\To Baylor 2023-01-30\Ostracod Image1\Ostracods1',
    r'E:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Ostracod',
  ]

# List to store subdirectories
invasive_subdirs = []
non_invasive_subdirs = []
ostracod_subdirs = []

# Collect subdirectories in the invasive category
for invasive_dir in invasive_dirs:
    invasive_subdirs.extend(glob.glob(invasive_dir))

# Collect subdirectories in the non-invasive category
for non_invasive_dir in non_invasive_dirs:
    non_invasive_subdirs.extend(glob.glob(non_invasive_dir))
    
for ostracod_dir in ostracod_dirs:
    ostracod_subdirs.extend(glob.glob(ostracod_dir))

# %%
import glob
from PIL import Image

# List of directories in x
x = non_invasive_subdirs

# List to store subdirectories
y1 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y1.extend(subdirectories)

import glob

# List of directories in x
x = invasive_subdirs

# List to store subdirectories
y2 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y2.extend(subdirectories)

    
import glob

# List of directories in x
x = ostracod_subdirs

# List to store subdirectories
y3 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y3.extend(subdirectories)

    

    
import os
import numpy as np
import tensorflow as tf
from PIL import Image

def preprocess_images(y1, label_num, target_size=(40, 40)):
    # List to store image files
    image_files = []
    # List to store labels
    labels = []

    # Retrieve image files and create labels for each directory in y1
    for directory in y1:
        for root, dirs, files in os.walk(directory):
            for file in files:
                # Check if the file has an image extension
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    # Add the file path to the image_files list
                    image_files.append(os.path.join(root, file))
                    # Add the label to the labels list
                    

    # List to store preprocessed images
    images = []

    # Preprocess each image
    for file in image_files:
        try:
            # Read the image using PIL
            image = Image.open(file)
            # Resize the image using tf.image.resize_with_crop_or_pad()
            image = tf.image.resize_with_crop_or_pad(
                tf.keras.preprocessing.image.img_to_array(image),
                target_size[0],
                target_size[1]
            )
            # Normalize the image pixels for ML training
            image = image / 255.0
            # Add the preprocessed image to the images list
            images.append(image)
            labels.append(label_num)
        except Exception as e:
            print(f"Error processing image: {file}. Skipping...")
            continue

    # Convert the images and labels lists to numpy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels


X0,Y0 = preprocess_images(y1, label_num = 0)
X1,Y1 = preprocess_images(y2, label_num = 1)
X2,Y2 = preprocess_images(y3, label_num = 2)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Concatenate the image arrays
train_images = np.concatenate((X0, X1, X2), axis=0)

# Combine the label arrays
train_labels = np.concatenate((Y0, Y1, Y2), axis=0)

# Convert the labels to categorical
train_labels_categorical = to_categorical(train_labels)

# Set the dtype of train_images to float32
train_images = train_images.astype('float32')


# Split the data into train and test sets
from sklearn.utils import shuffle

# Assuming you have the original train_images and train_labels_categorical

# Shuffle the data
train_images, train_labels_categorical = shuffle(train_images, train_labels_categorical)

# Now the shuffled data is assigned to the same variable names

X_train, X_test1, Y_train, Y_test1 = train_test_split(train_images, train_labels_categorical, test_size=0.01, random_state=42)

# %%
from tensorflow.keras.models import load_model
# Assuming you have a Keras model named "model"
model.save("premodel.h5")

# %%
np.shape(X_train)
# Out:
# (43109, 40, 40, 3)

# %%
class_weights = np.zeros(3)

unique_labels, counts = np.unique(train_labels, return_counts=True)

total_samples = np.sum(counts)

for i, label in enumerate(unique_labels):
    class_weights[label] = total_samples / (len(unique_labels) * counts[i])

print("Class weights:", class_weights)
# Out:
# Class weights: [1.29876521 0.47538729 7.90577342]

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics='accuracy')
class_weights = [1,1,1]
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/50
# 1213/1213 [==============================] - 9s 7ms/step - loss: 0.4323 - accuracy: 0.8748 - val_loss: 0.2785 - val_accuracy: 0.9105
# Epoch 2/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.2288 - accuracy: 0.9238 - val_loss: 0.3007 - val_accuracy: 0.9047
# Epoch 3/50
# 1213/1213 [==============================] - 9s 8ms/step - loss: 0.2026 - accuracy: 0.9326 - val_loss: 0.2417 - val_accuracy: 0.9142
# Epoch 4/50
# 1213/1213 [==============================] - 9s 7ms/step - loss: 0.1850 - accuracy: 0.9386 - val_loss: 0.2104 - val_accuracy: 0.9283
# Epoch 5/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.1704 - accuracy: 0.9424 - val_loss: 0.2521 - val_accuracy: 0.9139
# Epoch 6/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.1615 - accuracy: 0.9461 - val_loss: 0.2033 - val_accuracy: 0.9334
# Epoch 7/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.1542 - accuracy: 0.9485 - val_loss: 0.3289 - val_accuracy: 0.9149
# Epoch 8/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.1495 - accuracy: 0.9492 - val_loss: 0.1808 - val_accuracy: 0.9364
# Epoch 9/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.1380 - accuracy: 0.9539 - val_loss: 0.1827 - val_accuracy: 0.9353
# Epoch 10/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.1377 - accuracy: 0.9536 - val_loss: 0.1759 - val_accuracy: 0.9344
# Epoch 11/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.1296 - accuracy: 0.9553 - val_loss: 0.1725 - val_accuracy: 0.9436
# Epoch 12/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.1280 - accuracy: 0.9566 - val_loss: 0.2001 - val_accuracy: 0.9371
# Epoch 13/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.1254 - accuracy: 0.9560 - val_loss: 0.1629 - val_accuracy: 0.9462
# Epoch 14/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.1204 - accuracy: 0.9601 - val_loss: 0.1860 - val_accuracy: 0.9353
# Epoch 15/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.1138 - accuracy: 0.9595 - val_loss: 0.1743 - val_accuracy: 0.9427
# Epoch 16/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.1111 - accuracy: 0.9613 - val_loss: 0.1878 - val_accuracy: 0.9341
# Epoch 17/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.1119 - accuracy: 0.9605 - val_loss: 0.1676 - val_accuracy: 0.9448
# Epoch 18/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.1042 - accuracy: 0.9644 - val_loss: 0.1717 - val_accuracy: 0.9432
# Epoch 19/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.1028 - accuracy: 0.9640 - val_loss: 0.1910 - val_accuracy: 0.9383
# Epoch 20/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.1024 - accuracy: 0.9637 - val_loss: 0.1619 - val_accuracy: 0.9441
# Epoch 21/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0968 - accuracy: 0.9667 - val_loss: 0.1700 - val_accuracy: 0.9411
# Epoch 22/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0951 - accuracy: 0.9674 - val_loss: 0.1717 - val_accuracy: 0.9427
# Epoch 23/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0958 - accuracy: 0.9669 - val_loss: 0.1655 - val_accuracy: 0.9462
# Epoch 24/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0921 - accuracy: 0.9671 - val_loss: 0.1667 - val_accuracy: 0.9483
# Epoch 25/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.0887 - accuracy: 0.9688 - val_loss: 0.1755 - val_accuracy: 0.9402
# Epoch 26/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.0888 - accuracy: 0.9689 - val_loss: 0.1741 - val_accuracy: 0.9448
# Epoch 27/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.0884 - accuracy: 0.9682 - val_loss: 0.1727 - val_accuracy: 0.9460
# Epoch 28/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.0849 - accuracy: 0.9696 - val_loss: 0.1660 - val_accuracy: 0.9446
# Epoch 29/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.0835 - accuracy: 0.9704 - val_loss: 0.1671 - val_accuracy: 0.9406
# Epoch 30/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0829 - accuracy: 0.9698 - val_loss: 0.1638 - val_accuracy: 0.9441
# Epoch 31/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.0795 - accuracy: 0.9710 - val_loss: 0.1801 - val_accuracy: 0.9448
# Epoch 32/50
# 1213/1213 [==============================] - 10s 8ms/step - loss: 0.0798 - accuracy: 0.9714 - val_loss: 0.1651 - val_accuracy: 0.9453
# Epoch 33/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0770 - accuracy: 0.9718 - val_loss: 0.1710 - val_accuracy: 0.9376
# Epoch 34/50
# 1213/1213 [==============================] - 8s 7ms/step - loss: 0.0750 - accuracy: 0.9725 - val_loss: 0.1884 - val_accuracy: 0.9425
# Epoch 35/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0761 - accuracy: 0.9722 - val_loss: 0.1631 - val_accuracy: 0.9501
# Epoch 36/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0755 - accuracy: 0.9728 - val_loss: 0.1947 - val_accuracy: 0.9362
# Epoch 37/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0726 - accuracy: 0.9742 - val_loss: 0.1762 - val_accuracy: 0.9406
# Epoch 38/50
# 1213/1213 [==============================] - 9s 7ms/step - loss: 0.0712 - accuracy: 0.9736 - val_loss: 0.1631 - val_accuracy: 0.9473
# Epoch 39/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0701 - accuracy: 0.9750 - val_loss: 0.1860 - val_accuracy: 0.9455
# Epoch 40/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0714 - accuracy: 0.9740 - val_loss: 0.1822 - val_accuracy: 0.9448
# Epoch 41/50
# 1213/1213 [==============================] - 8s 6ms/step - loss: 0.0696 - accuracy: 0.9751 - val_loss: 0.1996 - val_accuracy: 0.9422
# Epoch 42/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0664 - accuracy: 0.9764 - val_loss: 0.1737 - val_accuracy: 0.9453
# Epoch 43/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0705 - accuracy: 0.9752 - val_loss: 0.1719 - val_accuracy: 0.9450
# Epoch 44/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0664 - accuracy: 0.9750 - val_loss: 0.1901 - val_accuracy: 0.9422
# Epoch 45/50
# 1213/1213 [==============================] - 7s 6ms/step - loss: 0.0637 - accuracy: 0.9771 - val_loss: 0.1874 - val_accuracy: 0.9490
# Epoch 46/50
# 1213/1213 [==============================] - 7s 5ms/step - loss: 0.0635 - accuracy: 0.9770 - val_loss: 0.1784 - val_accuracy: 0.9443
# Epoch 47/50
#  115/1213 [=>............................] - ETA: 6s - loss: 0.0485 - accuracy: 0.9821

# %%
pred = model.predict(X_test)
p = np.argmax(pred, axis=1)
res = p
        
test = []
for i in Y_test:
    if(i[0]==1):
        test.append(0)
    elif(i[1]==1):
        test.append(1)
    else:
        test.append(2)
        
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(test,np.argmax(Y_test, axis=1))
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
# Define the image path
from PIL import Image
image_path = r"D:\VeligerData\Baylor 2022-03-21_2\Veligers\Object_031\Image_009.png"
# Read the image using PIL
image = Image.open(image_path)
# Define the target size for resizing
target_size = (40, 40)
# Resize the image using TensorFlow's resize_with_crop_or_pad function
resized_image = tf.image.resize_with_crop_or_pad( tf.keras.preprocessing.image.img_to_array(image), target_size[0],   target_size[1]
)
# Expand the dimensions to match the model's input shape
expanded_image = tf.expand_dims(resized_image, axis=0)
# Evaluate the TensorFlow tensor and obtain the NumPy array
resized_array = tf.keras.backend.eval(expanded_image)
normalized_image = resized_array / 255.0
x = model.predict(normalized_image)
x

# %%
from tensorflow.keras.models import load_model
# Assuming you have a Keras model named "model"
model.save("finetuned_image_model.h5")
