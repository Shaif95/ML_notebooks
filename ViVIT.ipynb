# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns
import shutil
import keras
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16

# %%
from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
from glob import glob
trn1='D:/Inv_Data_Imbalance/data/invasive-aquatic-species-data/invasive/*/'
trn2='D:/Inv_Data_Imbalance/data/invasive-aquatic-species-data/noninvasive/*/'
tr1= glob(trn1)
tr2= glob(trn2)
tr1= shuffle(tr1)
tr2= shuffle(tr2)

tran_index_inv = np.round( len(tr1)* .7 )
tran_index_noninv = np.round( len(tr2)* .7  )
tran_index_noninv
# Out:
# 2590.0

# %%
data = []
label = []
breath = []
total = 0

for j in tr1[:(int) (tran_index_inv)]:
    label.append(1)
    a = glob(j+'/*')
    breath.append(len(a))
    total = total + len(a)
    
for j in tr2[:(int) (tran_index_noninv)]:
    label.append(0)
    a = glob(j+'/*')
    breath.append(len(a)) 
    total = total + len(a)

for j in range(0,len(tr1[:(int) (tran_index_inv)])):
    a = glob(tr1[j]+'/*')
    for k in range(0,6):
        data.append(a[k])

for j in range(0,len(tr2[:(int) (tran_index_noninv)])):
    a = glob(tr2[j]+'/*')
    for k in range(0,6):
        data.append(a[k])        
        

imgdata=[]
for i in range(len(data)):
    a = Image.open(data[i])
    b = a.resize((28, 28))
    c = np.array(b)
    imgdata.append(c.reshape(28,28,3))
    
from tensorflow.keras.utils import to_categorical
idata = np.array(imgdata)
X_train = idata
X_train = X_train.astype('float32') / 255.
X_train = np.reshape(X_train, (len(X_train),28,28,3))

# %%
end= 0
train_df= []
breath = 6

i = 0
for i in range(0, len(label)):
    deff = []
    for k in range(0, (breath)):
        
        index = (i*6+k)
        
        deff.append(X_train[index])
        
    train_df.append(deff)

#Y_train = to_categorical(label)
Y_train =(label)
train_df = np.array(train_df)
train_df,Y_train = shuffle(train_df,Y_train)
np.shape(train_df)
# Out:
# (3062, 6, 28, 28, 3)

# %%
data = []
label = []
breath = []
total = 0

for j in tr1[(int) (tran_index_inv) + 1 :]:
    label.append(1)
    a = glob(j+'/*')
    breath.append(len(a))
    total = total + len(a)
    
for j in tr2[ (int)(tran_index_noninv) + 1:]:
    label.append(0)
    a = glob(j+'/*')
    breath.append(len(a)) 
    total = total + len(a)

for j in range(0,len(tr1[(int) (tran_index_inv) + 1 :])):
    a = glob(tr1[j]+'/*')
    for k in range(0,6):
        data.append(a[k])

for j in range(0,len(tr2[ (int)(tran_index_noninv) + 1:])):
    a = glob(tr2[j]+'/*')
    for k in range(0,6):
        data.append(a[k])        
        

imgdata=[]
for i in range(len(data)):
    a = Image.open(data[i])
    b = a.resize((28, 28))
    c = np.array(b)
    imgdata.append(c.reshape(28,28,3))
    
from tensorflow.keras.utils import to_categorical
idata = np.array(imgdata)
X_test = idata
X_test = X_test.astype('float32') / 255.
X_test = np.reshape(X_test, (len(X_test),28,28,3))

# %%
end= 0
test_df= []
breath = 6

i = 0
for i in range(0, len(label)):
    deff = []
    for k in range(0, (breath)):
        
        index = (i*6+k)
        
        deff.append(X_test[index])
        
    test_df.append(deff)
    
#Y_test = to_categorical(label)
Y_test = (label)
test_df = np.array(test_df)
test_df,Y_test = shuffle(test_df,Y_test)
np.shape(test_df)
# Out:
# (1310, 6, 28, 28, 3)

# %%
DATASET_NAME = "organmnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = ( 6, 28, 28, 3 )
NUM_CLASSES = 2

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 60

# TUBELET EMBEDDING
PATCH_SIZE = (4, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 2
NUM_LAYERS = 2

# %%
X_train, X_val, y_train, y_val = train_test_split( train_df,Y_train , test_size=0.25, random_state=42)

# %%
@tf.function
def preprocess(frames: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels."""
    # Preprocess images
    frames = tf.image.convert_image_dtype(
        frames[
            ..., tf.newaxis
        ],  # The new axis is to help for further processing with Conv3D layers
        tf.float32,
    )
    # Parse label
    label = tf.cast(label, tf.float32)
    return frames, label


def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    """Utility function to prepare the dataloader."""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader


trainloader = prepare_dataloader(X_train , y_train , "train")
validloader = prepare_dataloader(X_val, y_val, "valid")
testloader = prepare_dataloader(test_df,Y_test, "test")

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %%
class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = tf.range(start=0, limit=num_tokens, delta=1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=tf.nn.gelu),
                layers.Dense(units=embed_dim, activation=tf.nn.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
# TUBELET EMBEDDING
PATCH_SIZE = (4, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

NUM_HEADS = 3
NUM_LAYERS = 6

md = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

#md.summary()

# %%
def run_experiment():
    # Initialize model
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # Compile the model with the optimizer, loss function
    # and the metrics.
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    # Train the model.
    _ = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

    _, accuracy, top_5_accuracy = model.evaluate(testloader)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return model


model = run_experiment()
# Out:
# Epoch 1/60
# 72/72 [==============================] - 10s 66ms/step - loss: 0.4551 - accuracy: 0.8454 - top-5-accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.8290 - val_top-5-accuracy: 1.0000
# Epoch 2/60
# 72/72 [==============================] - 4s 55ms/step - loss: 0.3512 - accuracy: 0.8515 - top-5-accuracy: 1.0000 - val_loss: 0.3234 - val_accuracy: 0.8773 - val_top-5-accuracy: 1.0000
# Epoch 3/60
# 72/72 [==============================] - 4s 52ms/step - loss: 0.2623 - accuracy: 0.8780 - top-5-accuracy: 1.0000 - val_loss: 0.2855 - val_accuracy: 0.8525 - val_top-5-accuracy: 1.0000
# Epoch 4/60
# 72/72 [==============================] - 4s 62ms/step - loss: 0.2227 - accuracy: 0.8981 - top-5-accuracy: 1.0000 - val_loss: 0.2328 - val_accuracy: 0.8916 - val_top-5-accuracy: 1.0000
# Epoch 5/60
# 72/72 [==============================] - 4s 60ms/step - loss: 0.1914 - accuracy: 0.9168 - top-5-accuracy: 1.0000 - val_loss: 0.2140 - val_accuracy: 0.9047 - val_top-5-accuracy: 1.0000
# Epoch 6/60
# 72/72 [==============================] - 4s 57ms/step - loss: 0.2004 - accuracy: 0.9098 - top-5-accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9178 - val_top-5-accuracy: 1.0000
# Epoch 7/60
# 72/72 [==============================] - 4s 57ms/step - loss: 0.1799 - accuracy: 0.9233 - top-5-accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9230 - val_top-5-accuracy: 1.0000
# Epoch 8/60
# 72/72 [==============================] - 4s 56ms/step - loss: 0.1623 - accuracy: 0.9342 - top-5-accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9151 - val_top-5-accuracy: 1.0000
# Epoch 9/60
# 72/72 [==============================] - 4s 52ms/step - loss: 0.1557 - accuracy: 0.9390 - top-5-accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9086 - val_top-5-accuracy: 1.0000
# Epoch 10/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.1433 - accuracy: 0.9421 - top-5-accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9125 - val_top-5-accuracy: 1.0000
# Epoch 11/60
# 72/72 [==============================] - 4s 56ms/step - loss: 0.1626 - accuracy: 0.9334 - top-5-accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.8982 - val_top-5-accuracy: 1.0000
# Epoch 12/60
# 72/72 [==============================] - 4s 52ms/step - loss: 0.1403 - accuracy: 0.9399 - top-5-accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9112 - val_top-5-accuracy: 1.0000
# Epoch 13/60
# 72/72 [==============================] - 4s 54ms/step - loss: 0.1424 - accuracy: 0.9377 - top-5-accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9138 - val_top-5-accuracy: 1.0000
# Epoch 14/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.1280 - accuracy: 0.9460 - top-5-accuracy: 1.0000 - val_loss: 0.2389 - val_accuracy: 0.9086 - val_top-5-accuracy: 1.0000
# Epoch 15/60
# 72/72 [==============================] - 4s 59ms/step - loss: 0.1258 - accuracy: 0.9499 - top-5-accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9060 - val_top-5-accuracy: 1.0000
# Epoch 16/60
# 72/72 [==============================] - 5s 68ms/step - loss: 0.1219 - accuracy: 0.9490 - top-5-accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 0.9060 - val_top-5-accuracy: 1.0000
# Epoch 17/60
# 72/72 [==============================] - 5s 65ms/step - loss: 0.1133 - accuracy: 0.9586 - top-5-accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9204 - val_top-5-accuracy: 1.0000
# Epoch 18/60
# 72/72 [==============================] - 5s 74ms/step - loss: 0.1051 - accuracy: 0.9543 - top-5-accuracy: 1.0000 - val_loss: 0.2813 - val_accuracy: 0.9112 - val_top-5-accuracy: 1.0000
# Epoch 19/60
# 72/72 [==============================] - 5s 63ms/step - loss: 0.1100 - accuracy: 0.9560 - top-5-accuracy: 1.0000 - val_loss: 0.3677 - val_accuracy: 0.8825 - val_top-5-accuracy: 1.0000
# Epoch 20/60
# 72/72 [==============================] - 4s 56ms/step - loss: 0.1094 - accuracy: 0.9530 - top-5-accuracy: 1.0000 - val_loss: 0.2467 - val_accuracy: 0.9138 - val_top-5-accuracy: 1.0000
# Epoch 21/60
# 72/72 [==============================] - 4s 61ms/step - loss: 0.0992 - accuracy: 0.9630 - top-5-accuracy: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9321 - val_top-5-accuracy: 1.0000
# Epoch 22/60
# 72/72 [==============================] - 4s 61ms/step - loss: 0.1018 - accuracy: 0.9595 - top-5-accuracy: 1.0000 - val_loss: 0.2716 - val_accuracy: 0.9191 - val_top-5-accuracy: 1.0000
# Epoch 23/60
# 72/72 [==============================] - 4s 60ms/step - loss: 0.0951 - accuracy: 0.9608 - top-5-accuracy: 1.0000 - val_loss: 0.2539 - val_accuracy: 0.9204 - val_top-5-accuracy: 1.0000
# Epoch 24/60
# 72/72 [==============================] - 4s 61ms/step - loss: 0.1090 - accuracy: 0.9538 - top-5-accuracy: 1.0000 - val_loss: 0.2836 - val_accuracy: 0.9021 - val_top-5-accuracy: 1.0000
# Epoch 25/60
# 72/72 [==============================] - 4s 56ms/step - loss: 0.0949 - accuracy: 0.9591 - top-5-accuracy: 1.0000 - val_loss: 0.3349 - val_accuracy: 0.9008 - val_top-5-accuracy: 1.0000
# Epoch 26/60
# 72/72 [==============================] - 4s 55ms/step - loss: 0.0870 - accuracy: 0.9634 - top-5-accuracy: 1.0000 - val_loss: 0.2950 - val_accuracy: 0.9073 - val_top-5-accuracy: 1.0000
# Epoch 27/60
# 72/72 [==============================] - 4s 54ms/step - loss: 0.0821 - accuracy: 0.9713 - top-5-accuracy: 1.0000 - val_loss: 0.3238 - val_accuracy: 0.9230 - val_top-5-accuracy: 1.0000
# Epoch 28/60
# 72/72 [==============================] - 4s 54ms/step - loss: 0.1180 - accuracy: 0.9569 - top-5-accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9243 - val_top-5-accuracy: 1.0000
# Epoch 29/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0869 - accuracy: 0.9652 - top-5-accuracy: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.9217 - val_top-5-accuracy: 1.0000
# Epoch 30/60
# 72/72 [==============================] - 4s 56ms/step - loss: 0.0620 - accuracy: 0.9774 - top-5-accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9138 - val_top-5-accuracy: 1.0000
# Epoch 31/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0588 - accuracy: 0.9747 - top-5-accuracy: 1.0000 - val_loss: 0.3788 - val_accuracy: 0.9178 - val_top-5-accuracy: 1.0000
# Epoch 32/60
# 72/72 [==============================] - 4s 52ms/step - loss: 0.0588 - accuracy: 0.9747 - top-5-accuracy: 1.0000 - val_loss: 0.3225 - val_accuracy: 0.9308 - val_top-5-accuracy: 1.0000
# Epoch 33/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0783 - accuracy: 0.9686 - top-5-accuracy: 1.0000 - val_loss: 0.2622 - val_accuracy: 0.9230 - val_top-5-accuracy: 1.0000
# Epoch 34/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0613 - accuracy: 0.9743 - top-5-accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9125 - val_top-5-accuracy: 1.0000
# Epoch 35/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0516 - accuracy: 0.9808 - top-5-accuracy: 1.0000 - val_loss: 0.3113 - val_accuracy: 0.9243 - val_top-5-accuracy: 1.0000
# Epoch 36/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0572 - accuracy: 0.9778 - top-5-accuracy: 1.0000 - val_loss: 0.3059 - val_accuracy: 0.9243 - val_top-5-accuracy: 1.0000
# Epoch 37/60
# 72/72 [==============================] - 4s 50ms/step - loss: 0.0443 - accuracy: 0.9804 - top-5-accuracy: 1.0000 - val_loss: 0.3322 - val_accuracy: 0.9217 - val_top-5-accuracy: 1.0000
# Epoch 38/60
# 72/72 [==============================] - 4s 54ms/step - loss: 0.0485 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.3754 - val_accuracy: 0.9151 - val_top-5-accuracy: 1.0000
# Epoch 39/60
# 72/72 [==============================] - 4s 52ms/step - loss: 0.0446 - accuracy: 0.9834 - top-5-accuracy: 1.0000 - val_loss: 0.3073 - val_accuracy: 0.9230 - val_top-5-accuracy: 1.0000
# Epoch 40/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0325 - accuracy: 0.9856 - top-5-accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.9151 - val_top-5-accuracy: 1.0000
# Epoch 41/60
# 72/72 [==============================] - 4s 55ms/step - loss: 0.0409 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.3452 - val_accuracy: 0.9204 - val_top-5-accuracy: 1.0000
# Epoch 42/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0410 - accuracy: 0.9834 - top-5-accuracy: 1.0000 - val_loss: 0.3257 - val_accuracy: 0.9191 - val_top-5-accuracy: 1.0000
# Epoch 43/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0402 - accuracy: 0.9852 - top-5-accuracy: 1.0000 - val_loss: 0.3426 - val_accuracy: 0.9217 - val_top-5-accuracy: 1.0000
# Epoch 44/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0397 - accuracy: 0.9856 - top-5-accuracy: 1.0000 - val_loss: 0.3907 - val_accuracy: 0.8930 - val_top-5-accuracy: 1.0000
# Epoch 45/60
# 72/72 [==============================] - 4s 52ms/step - loss: 0.0437 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.3356 - val_accuracy: 0.9256 - val_top-5-accuracy: 1.0000
# Epoch 46/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0345 - accuracy: 0.9869 - top-5-accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.9151 - val_top-5-accuracy: 1.0000
# Epoch 47/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0271 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.3686 - val_accuracy: 0.9243 - val_top-5-accuracy: 1.0000
# Epoch 48/60
# 72/72 [==============================] - 4s 54ms/step - loss: 0.0284 - accuracy: 0.9900 - top-5-accuracy: 1.0000 - val_loss: 0.3407 - val_accuracy: 0.9243 - val_top-5-accuracy: 1.0000
# Epoch 49/60
# 72/72 [==============================] - 4s 50ms/step - loss: 0.0388 - accuracy: 0.9865 - top-5-accuracy: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.9138 - val_top-5-accuracy: 1.0000
# Epoch 50/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0330 - accuracy: 0.9874 - top-5-accuracy: 1.0000 - val_loss: 0.3494 - val_accuracy: 0.9243 - val_top-5-accuracy: 1.0000
# Epoch 51/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0433 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.3061 - val_accuracy: 0.9138 - val_top-5-accuracy: 1.0000
# Epoch 52/60
# 72/72 [==============================] - 4s 50ms/step - loss: 0.0305 - accuracy: 0.9891 - top-5-accuracy: 1.0000 - val_loss: 0.3035 - val_accuracy: 0.9191 - val_top-5-accuracy: 1.0000
# Epoch 53/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0134 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.3790 - val_accuracy: 0.9204 - val_top-5-accuracy: 1.0000
# Epoch 54/60
# 72/72 [==============================] - 4s 51ms/step - loss: 0.0379 - accuracy: 0.9852 - top-5-accuracy: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.9204 - val_top-5-accuracy: 1.0000
# Epoch 55/60
# 72/72 [==============================] - 4s 55ms/step - loss: 0.0229 - accuracy: 0.9904 - top-5-accuracy: 1.0000 - val_loss: 0.3761 - val_accuracy: 0.9191 - val_top-5-accuracy: 1.0000
# Epoch 56/60
# 72/72 [==============================] - 4s 54ms/step - loss: 0.0185 - accuracy: 0.9922 - top-5-accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.9138 - val_top-5-accuracy: 1.0000
# Epoch 57/60
# 72/72 [==============================] - 4s 53ms/step - loss: 0.0304 - accuracy: 0.9887 - top-5-accuracy: 1.0000 - val_loss: 0.4104 - val_accuracy: 0.9138 - val_top-5-accuracy: 1.0000
# Epoch 58/60
# 72/72 [==============================] - 4s 61ms/step - loss: 0.0500 - accuracy: 0.9808 - top-5-accuracy: 1.0000 - val_loss: 0.2926 - val_accuracy: 0.9204 - val_top-5-accuracy: 1.0000
# Epoch 59/60
# 72/72 [==============================] - 4s 57ms/step - loss: 0.0197 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.3752 - val_accuracy: 0.9217 - val_top-5-accuracy: 1.0000
# Epoch 60/60
# 72/72 [==============================] - 4s 54ms/step - loss: 0.0056 - accuracy: 0.9983 - top-5-accuracy: 1.0000 - val_loss: 0.4702 - val_accuracy: 0.9256 - val_top-5-accuracy: 1.0000
# 41/41 [==============================] - 1s 18ms/step - loss: 0.1267 - accuracy: 0.9824 - top-5-accuracy: 1.0000
# Test accuracy: 98.24%
# Test top 5 accuracy: 100.0%

# %%
Y_test = Y_test[:2000]
pred = model.predict(test_df[:2000])
p = np.round(pred)

y_p = []
for i in range(len(p)):
    if ( p[i][0] == 0 ):
        y_p.append(1)
    else :
        y_p.append(0)
y_p = np.array(y_p)
y_t = Y_test

from sklearn.metrics import confusion_matrix
a=(confusion_matrix(y_t, y_p , labels=[0,1]))
a.T
# Out:
# array([[1103,   17],
#        [   6,  184]], dtype=int64)

# %%
t = a[1][1]/(((a[0][1]+a[1][0])/2)+a[1][1])
t
# Out:
# 0.9411764705882353
