# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd
#import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns
import shutil
import keras
from PIL import Image
#import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()
from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to C:\Users\chowd\tensorflow_datasets\imdb_reviews\plain_text\1.0.0...
# Dataset imdb_reviews downloaded and prepared to C:\Users\chowd\tensorflow_datasets\imdb_reviews\plain_text\1.0.0. Subsequent calls will reuse this data.
# Total examples: 50000

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )


vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=10
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(10,)),
            layers.Embedding(input_dim=3000, output_dim=8),
            layers.Bidirectional(layers.LSTM(8, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(10, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.h5", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.h5")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 10, 8)             24000
#
#  bidirectional_5 (Bidirectio  (None, 10, 16)           1088
#  nal)
#
#  global_max_pooling1d_5 (Glo  (None, 16)               0
#  balMaxPooling1D)
#
#  dense_10 (Dense)            (None, 10)                170
#
#  dropout_5 (Dropout)         (None, 10)                0
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 25,269
# Trainable params: 25,269
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.6781 - binary_accuracy: 0.5901 - false_negatives_5: 5922.0000 - false_positives_5: 10475.0000
# Epoch 1: val_loss improved from inf to 0.68950, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 8s 24ms/step - loss: 0.6781 - binary_accuracy: 0.5901 - false_negatives_5: 5922.0000 - false_positives_5: 10475.0000 - val_loss: 0.6895 - val_binary_accuracy: 0.5044 - val_false_negatives_5: 2474.0000 - val_false_positives_5: 4.0000
# Epoch 2/20
# 153/157 [============================>.] - ETA: 0s - loss: 0.6461 - binary_accuracy: 0.6495 - false_negatives_5: 6049.0000 - false_positives_5: 7680.0000
# Epoch 2: val_loss improved from 0.68950 to 0.63294, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 2s 14ms/step - loss: 0.6455 - binary_accuracy: 0.6506 - false_negatives_5: 6217.0000 - false_positives_5: 7758.0000 - val_loss: 0.6329 - val_binary_accuracy: 0.6510 - val_false_negatives_5: 1255.0000 - val_false_positives_5: 490.0000
# Epoch 3/20
# 153/157 [============================>.] - ETA: 0s - loss: 0.5985 - binary_accuracy: 0.6969 - false_negatives_5: 6360.0000 - false_positives_5: 5510.0000
# Epoch 3: val_loss improved from 0.63294 to 0.61790, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5985 - binary_accuracy: 0.6972 - false_negatives_5: 6540.0000 - false_positives_5: 5572.0000 - val_loss: 0.6179 - val_binary_accuracy: 0.6562 - val_false_negatives_5: 1320.0000 - val_false_positives_5: 399.0000
# Epoch 4/20
# 155/157 [============================>.] - ETA: 0s - loss: 0.5764 - binary_accuracy: 0.7148 - false_negatives_5: 6298.0000 - false_positives_5: 5017.0000
# Epoch 4: val_loss improved from 0.61790 to 0.60154, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5763 - binary_accuracy: 0.7151 - false_negatives_5: 6355.0000 - false_positives_5: 5042.0000 - val_loss: 0.6015 - val_binary_accuracy: 0.6596 - val_false_negatives_5: 977.0000 - val_false_positives_5: 725.0000
# Epoch 5/20
# 153/157 [============================>.] - ETA: 0s - loss: 0.5666 - binary_accuracy: 0.7217 - false_negatives_5: 6155.0000 - false_positives_5: 4744.0000
# Epoch 5: val_loss did not improve from 0.60154
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5673 - binary_accuracy: 0.7213 - false_negatives_5: 6309.0000 - false_positives_5: 4838.0000 - val_loss: 0.6081 - val_binary_accuracy: 0.6600 - val_false_negatives_5: 1257.0000 - val_false_positives_5: 443.0000
# Epoch 6/20
# 155/157 [============================>.] - ETA: 0s - loss: 0.5595 - binary_accuracy: 0.7249 - false_negatives_5: 6353.0000 - false_positives_5: 4561.0000
# Epoch 6: val_loss did not improve from 0.60154
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5595 - binary_accuracy: 0.7249 - false_negatives_5: 6408.0000 - false_positives_5: 4597.0000 - val_loss: 0.6131 - val_binary_accuracy: 0.6466 - val_false_negatives_5: 1389.0000 - val_false_positives_5: 378.0000
# Epoch 7/20
# 157/157 [==============================] - ETA: 0s - loss: 0.5519 - binary_accuracy: 0.7264 - false_negatives_5: 6394.0000 - false_positives_5: 4550.0000
# Epoch 7: val_loss improved from 0.60154 to 0.59885, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5519 - binary_accuracy: 0.7264 - false_negatives_5: 6394.0000 - false_positives_5: 4550.0000 - val_loss: 0.5988 - val_binary_accuracy: 0.6630 - val_false_negatives_5: 1071.0000 - val_false_positives_5: 614.0000
# Epoch 8/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.5523 - binary_accuracy: 0.7286 - false_negatives_5: 6464.0000 - false_positives_5: 4373.0000
# Epoch 8: val_loss improved from 0.59885 to 0.59854, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5522 - binary_accuracy: 0.7287 - false_negatives_5: 6474.0000 - false_positives_5: 4377.0000 - val_loss: 0.5985 - val_binary_accuracy: 0.6632 - val_false_negatives_5: 1071.0000 - val_false_positives_5: 613.0000
# Epoch 9/20
# 157/157 [==============================] - ETA: 0s - loss: 0.5466 - binary_accuracy: 0.7282 - false_negatives_5: 6555.0000 - false_positives_5: 4317.0000
# Epoch 9: val_loss did not improve from 0.59854
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5466 - binary_accuracy: 0.7282 - false_negatives_5: 6555.0000 - false_positives_5: 4317.0000 - val_loss: 0.6440 - val_binary_accuracy: 0.6186 - val_false_negatives_5: 1714.0000 - val_false_positives_5: 193.0000
# Epoch 10/20
# 157/157 [==============================] - ETA: 0s - loss: 0.5440 - binary_accuracy: 0.7297 - false_negatives_5: 6742.0000 - false_positives_5: 4070.0000
# Epoch 10: val_loss did not improve from 0.59854
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5440 - binary_accuracy: 0.7297 - false_negatives_5: 6742.0000 - false_positives_5: 4070.0000 - val_loss: 0.6040 - val_binary_accuracy: 0.6582 - val_false_negatives_5: 1211.0000 - val_false_positives_5: 498.0000
# Epoch 11/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.5419 - binary_accuracy: 0.7322 - false_negatives_5: 6611.0000 - false_positives_5: 4082.0000
# Epoch 11: val_loss did not improve from 0.59854
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5420 - binary_accuracy: 0.7322 - false_negatives_5: 6623.0000 - false_positives_5: 4088.0000 - val_loss: 0.6084 - val_binary_accuracy: 0.6498 - val_false_negatives_5: 1364.0000 - val_false_positives_5: 387.0000
# Epoch 12/20
# 155/157 [============================>.] - ETA: 0s - loss: 0.5384 - binary_accuracy: 0.7348 - false_negatives_5: 6366.0000 - false_positives_5: 4158.0000
# Epoch 12: val_loss did not improve from 0.59854
# 157/157 [==============================] - 4s 24ms/step - loss: 0.5387 - binary_accuracy: 0.7346 - false_negatives_5: 6429.0000 - false_positives_5: 4188.0000 - val_loss: 0.6007 - val_binary_accuracy: 0.6622 - val_false_negatives_5: 1178.0000 - val_false_positives_5: 511.0000
# Epoch 12: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.5938785672187805, 'binary_accuracy': 0.6672000288963318, 'false_negatives_5': 1077.0, 'false_positives_5': 587.0}
# ----------------------------------------------------------------------------------------------------

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=2,
    sampling_size=5000,
):


    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=2, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 10, 8)             24000
#
#  bidirectional_6 (Bidirectio  (None, 10, 16)           1088
#  nal)
#
#  global_max_pooling1d_6 (Glo  (None, 16)               0
#  balMaxPooling1D)
#
#  dense_12 (Dense)            (None, 10)                170
#
#  dropout_6 (Dropout)         (None, 10)                0
#
#  dense_13 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 25,269
# Trainable params: 25,269
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 15000 samples
# Epoch 1/20
# 56/59 [===========================>..] - ETA: 0s - loss: 0.6927 - binary_accuracy: 0.5037 - false_negatives_6: 6044.0000 - false_positives_6: 1071.0000
# Epoch 1: val_loss improved from inf to 0.69203, saving model to AL_Model.h5
# 59/59 [==============================] - 6s 28ms/step - loss: 0.6928 - binary_accuracy: 0.5035 - false_negatives_6: 6333.0000 - false_positives_6: 1114.0000 - val_loss: 0.6920 - val_binary_accuracy: 0.5554 - val_false_negatives_6: 1847.0000 - val_false_positives_6: 376.0000
# Epoch 2/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.6897 - binary_accuracy: 0.5428 - false_negatives_6: 5287.0000 - false_positives_6: 1502.0000
# Epoch 2: val_loss improved from 0.69203 to 0.68741, saving model to AL_Model.h5
# 59/59 [==============================] - 1s 18ms/step - loss: 0.6897 - binary_accuracy: 0.5425 - false_negatives_6: 5338.0000 - false_positives_6: 1524.0000 - val_loss: 0.6874 - val_binary_accuracy: 0.5732 - val_false_negatives_6: 1837.0000 - val_false_positives_6: 297.0000
# Epoch 3/20
# 57/59 [===========================>..] - ETA: 0s - loss: 0.6803 - binary_accuracy: 0.5879 - false_negatives_6: 4503.0000 - false_positives_6: 1510.0000
# Epoch 3: val_loss improved from 0.68741 to 0.67253, saving model to AL_Model.h5
# 59/59 [==============================] - 1s 18ms/step - loss: 0.6802 - binary_accuracy: 0.5874 - false_negatives_6: 4638.0000 - false_positives_6: 1551.0000 - val_loss: 0.6725 - val_binary_accuracy: 0.6090 - val_false_negatives_6: 1464.0000 - val_false_positives_6: 491.0000
# Epoch 4/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.6538 - binary_accuracy: 0.6441 - false_negatives_6: 3477.0000 - false_positives_6: 1808.0000
# Epoch 4: val_loss improved from 0.67253 to 0.65011, saving model to AL_Model.h5
# 59/59 [==============================] - 1s 17ms/step - loss: 0.6538 - binary_accuracy: 0.6439 - false_negatives_6: 3512.0000 - false_positives_6: 1830.0000 - val_loss: 0.6501 - val_binary_accuracy: 0.6490 - val_false_negatives_6: 819.0000 - val_false_positives_6: 936.0000
# Epoch 5/20
# 58/59 [============================>.] - ETA: 0s - loss: 0.6243 - binary_accuracy: 0.6892 - false_negatives_6: 2316.0000 - false_positives_6: 2299.0000
# Epoch 5: val_loss improved from 0.65011 to 0.63815, saving model to AL_Model.h5
# 59/59 [==============================] - 1s 17ms/step - loss: 0.6240 - binary_accuracy: 0.6893 - false_negatives_6: 2340.0000 - false_positives_6: 2320.0000 - val_loss: 0.6382 - val_binary_accuracy: 0.6474 - val_false_negatives_6: 977.0000 - val_false_positives_6: 786.0000
# Epoch 6/20
# 57/59 [===========================>..] - ETA: 0s - loss: 0.6026 - binary_accuracy: 0.7083 - false_negatives_6: 1754.0000 - false_positives_6: 2502.0000
# Epoch 6: val_loss improved from 0.63815 to 0.63047, saving model to AL_Model.h5
# 59/59 [==============================] - 1s 17ms/step - loss: 0.6021 - binary_accuracy: 0.7081 - false_negatives_6: 1810.0000 - false_positives_6: 2569.0000 - val_loss: 0.6305 - val_binary_accuracy: 0.6516 - val_false_negatives_6: 667.0000 - val_false_positives_6: 1075.0000
# Epoch 7/20
# 57/59 [===========================>..] - ETA: 0s - loss: 0.5833 - binary_accuracy: 0.7196 - false_negatives_6: 1407.0000 - false_positives_6: 2685.0000
# Epoch 7: val_loss improved from 0.63047 to 0.62725, saving model to AL_Model.h5
# 59/59 [==============================] - 1s 17ms/step - loss: 0.5829 - binary_accuracy: 0.7191 - false_negatives_6: 1446.0000 - false_positives_6: 2767.0000 - val_loss: 0.6273 - val_binary_accuracy: 0.6544 - val_false_negatives_6: 608.0000 - val_false_positives_6: 1120.0000
# Epoch 8/20
# 57/59 [===========================>..] - ETA: 0s - loss: 0.5659 - binary_accuracy: 0.7277 - false_negatives_6: 1282.0000 - false_positives_6: 2691.0000
# Epoch 8: val_loss did not improve from 0.62725
# 59/59 [==============================] - 1s 16ms/step - loss: 0.5655 - binary_accuracy: 0.7280 - false_negatives_6: 1313.0000 - false_positives_6: 2767.0000 - val_loss: 0.6303 - val_binary_accuracy: 0.6558 - val_false_negatives_6: 708.0000 - val_false_positives_6: 1013.0000
# Epoch 9/20
# 55/59 [==========================>...] - ETA: 0s - loss: 0.5507 - binary_accuracy: 0.7344 - false_negatives_6: 1175.0000 - false_positives_6: 2565.0000
# Epoch 9: val_loss did not improve from 0.62725
# 59/59 [==============================] - 1s 16ms/step - loss: 0.5519 - binary_accuracy: 0.7339 - false_negatives_6: 1245.0000 - false_positives_6: 2747.0000 - val_loss: 0.6295 - val_binary_accuracy: 0.6544 - val_false_negatives_6: 611.0000 - val_false_positives_6: 1117.0000
# Epoch 9: early stopping
# 20/20 [==============================] - 1s 7ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 651.0, Number of ones incorrectly classified: 1080.0
# Sample ratio for positives: 0.6239168110918544, Sample ratio for negatives:0.37608318890814557
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.5710 - binary_accuracy: 0.7162 - false_negatives_7: 1714.0000 - false_positives_7: 3953.0000
# Epoch 1: val_loss improved from 0.62725 to 0.62624, saving model to AL_Model.h5
# 79/79 [==============================] - 6s 24ms/step - loss: 0.5712 - binary_accuracy: 0.7161 - false_negatives_7: 1717.0000 - false_positives_7: 3961.0000 - val_loss: 0.6262 - val_binary_accuracy: 0.6418 - val_false_negatives_7: 406.0000 - val_false_positives_7: 1385.0000
# Epoch 2/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.5601 - binary_accuracy: 0.7266 - false_negatives_7: 1699.0000 - false_positives_7: 3760.0000
# Epoch 2: val_loss improved from 0.62624 to 0.62001, saving model to AL_Model.h5
# 79/79 [==============================] - 2s 23ms/step - loss: 0.5601 - binary_accuracy: 0.7265 - false_negatives_7: 1702.0000 - false_positives_7: 3767.0000 - val_loss: 0.6200 - val_binary_accuracy: 0.6602 - val_false_negatives_7: 672.0000 - val_false_positives_7: 1027.0000
# Epoch 3/20
# 75/79 [===========================>..] - ETA: 0s - loss: 0.5502 - binary_accuracy: 0.7335 - false_negatives_7: 1628.0000 - false_positives_7: 3488.0000
# Epoch 3: val_loss did not improve from 0.62001
# 79/79 [==============================] - 1s 15ms/step - loss: 0.5495 - binary_accuracy: 0.7340 - false_negatives_7: 1704.0000 - false_positives_7: 3615.0000 - val_loss: 0.6327 - val_binary_accuracy: 0.6484 - val_false_negatives_7: 347.0000 - val_false_positives_7: 1411.0000
# Epoch 4/20
# 75/79 [===========================>..] - ETA: 0s - loss: 0.5410 - binary_accuracy: 0.7415 - false_negatives_7: 1557.0000 - false_positives_7: 3406.0000
# Epoch 4: val_loss did not improve from 0.62001
# 79/79 [==============================] - 1s 15ms/step - loss: 0.5422 - binary_accuracy: 0.7399 - false_negatives_7: 1641.0000 - false_positives_7: 3560.0000 - val_loss: 0.6261 - val_binary_accuracy: 0.6628 - val_false_negatives_7: 616.0000 - val_false_positives_7: 1070.0000
# Epoch 5/20
# 79/79 [==============================] - ETA: 0s - loss: 0.5368 - binary_accuracy: 0.7430 - false_negatives_7: 1643.0000 - false_positives_7: 3496.0000
# Epoch 5: val_loss did not improve from 0.62001
# 79/79 [==============================] - 1s 15ms/step - loss: 0.5368 - binary_accuracy: 0.7430 - false_negatives_7: 1643.0000 - false_positives_7: 3496.0000 - val_loss: 0.6291 - val_binary_accuracy: 0.6516 - val_false_negatives_7: 465.0000 - val_false_positives_7: 1277.0000
# Epoch 6/20
# 76/79 [===========================>..] - ETA: 0s - loss: 0.5309 - binary_accuracy: 0.7435 - false_negatives_7: 1597.0000 - false_positives_7: 3393.0000
# Epoch 6: val_loss did not improve from 0.62001
# 79/79 [==============================] - 1s 17ms/step - loss: 0.5310 - binary_accuracy: 0.7433 - false_negatives_7: 1656.0000 - false_positives_7: 3478.0000 - val_loss: 0.6500 - val_binary_accuracy: 0.6410 - val_false_negatives_7: 337.0000 - val_false_positives_7: 1458.0000
# Epoch 6: early stopping
# 20/20 [==============================] - 1s 9ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 697.0, Number of ones incorrectly classified: 1011.0
# Sample ratio for positives: 0.59192037470726, Sample ratio for negatives:0.40807962529274006
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 96/98 [============================>.] - ETA: 0s - loss: 0.5625 - binary_accuracy: 0.7225 - false_negatives_8: 2151.0000 - false_positives_8: 4668.0000
# Epoch 1: val_loss improved from 0.62001 to 0.61724, saving model to AL_Model.h5
# 98/98 [==============================] - 12s 40ms/step - loss: 0.5627 - binary_accuracy: 0.7222 - false_negatives_8: 2191.0000 - false_positives_8: 4753.0000 - val_loss: 0.6172 - val_binary_accuracy: 0.6582 - val_false_negatives_8: 437.0000 - val_false_positives_8: 1272.0000
# Epoch 2/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.5526 - binary_accuracy: 0.7287 - false_negatives_8: 2165.0000 - false_positives_8: 4571.0000
# Epoch 2: val_loss improved from 0.61724 to 0.61496, saving model to AL_Model.h5
# 98/98 [==============================] - 2s 24ms/step - loss: 0.5523 - binary_accuracy: 0.7291 - false_negatives_8: 2171.0000 - false_positives_8: 4600.0000 - val_loss: 0.6150 - val_binary_accuracy: 0.6610 - val_false_negatives_8: 466.0000 - val_false_positives_8: 1229.0000
# Epoch 3/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.5470 - binary_accuracy: 0.7337 - false_negatives_8: 2060.0000 - false_positives_8: 4553.0000
# Epoch 3: val_loss improved from 0.61496 to 0.61445, saving model to AL_Model.h5
# 98/98 [==============================] - 2s 24ms/step - loss: 0.5469 - binary_accuracy: 0.7339 - false_negatives_8: 2070.0000 - false_positives_8: 4582.0000 - val_loss: 0.6145 - val_binary_accuracy: 0.6632 - val_false_negatives_8: 661.0000 - val_false_positives_8: 1023.0000
# Epoch 4/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.5406 - binary_accuracy: 0.7379 - false_negatives_8: 2117.0000 - false_positives_8: 4392.0000
# Epoch 4: val_loss improved from 0.61445 to 0.61233, saving model to AL_Model.h5
# 98/98 [==============================] - 2s 25ms/step - loss: 0.5408 - binary_accuracy: 0.7376 - false_negatives_8: 2132.0000 - false_positives_8: 4427.0000 - val_loss: 0.6123 - val_binary_accuracy: 0.6640 - val_false_negatives_8: 627.0000 - val_false_positives_8: 1053.0000
# Epoch 5/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.5348 - binary_accuracy: 0.7442 - false_negatives_8: 2094.0000 - false_positives_8: 4257.0000
# Epoch 5: val_loss improved from 0.61233 to 0.61202, saving model to AL_Model.h5
# 98/98 [==============================] - 2s 25ms/step - loss: 0.5352 - binary_accuracy: 0.7438 - false_negatives_8: 2107.0000 - false_positives_8: 4297.0000 - val_loss: 0.6120 - val_binary_accuracy: 0.6596 - val_false_negatives_8: 557.0000 - val_false_positives_8: 1145.0000
# Epoch 6/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.5330 - binary_accuracy: 0.7453 - false_negatives_8: 2015.0000 - false_positives_8: 4309.0000
# Epoch 6: val_loss did not improve from 0.61202
# 98/98 [==============================] - 2s 24ms/step - loss: 0.5328 - binary_accuracy: 0.7455 - false_negatives_8: 2024.0000 - false_positives_8: 4339.0000 - val_loss: 0.6247 - val_binary_accuracy: 0.6566 - val_false_negatives_8: 497.0000 - val_false_positives_8: 1220.0000
# Epoch 7/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.5273 - binary_accuracy: 0.7463 - false_negatives_8: 2043.0000 - false_positives_8: 4258.0000
# Epoch 7: val_loss did not improve from 0.61202
# 98/98 [==============================] - 2s 24ms/step - loss: 0.5273 - binary_accuracy: 0.7464 - false_negatives_8: 2058.0000 - false_positives_8: 4281.0000 - val_loss: 0.6272 - val_binary_accuracy: 0.6560 - val_false_negatives_8: 445.0000 - val_false_positives_8: 1275.0000
# Epoch 8/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.5220 - binary_accuracy: 0.7521 - false_negatives_8: 2013.0000 - false_positives_8: 4143.0000
# Epoch 8: val_loss did not improve from 0.61202
# 98/98 [==============================] - 2s 25ms/step - loss: 0.5218 - binary_accuracy: 0.7524 - false_negatives_8: 2024.0000 - false_positives_8: 4165.0000 - val_loss: 0.6300 - val_binary_accuracy: 0.6546 - val_false_negatives_8: 464.0000 - val_false_positives_8: 1263.0000
# Epoch 9/20
# 98/98 [==============================] - ETA: 0s - loss: 0.5233 - binary_accuracy: 0.7522 - false_negatives_8: 2030.0000 - false_positives_8: 4164.0000
# Epoch 9: val_loss did not improve from 0.61202
# 98/98 [==============================] - 2s 24ms/step - loss: 0.5233 - binary_accuracy: 0.7522 - false_negatives_8: 2030.0000 - false_positives_8: 4164.0000 - val_loss: 0.6266 - val_binary_accuracy: 0.6582 - val_false_negatives_8: 670.0000 - val_false_positives_8: 1039.0000
# Epoch 9: early stopping
# 20/20 [==============================] - 1s 11ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 568.0, Number of ones incorrectly classified: 1157.0
# Sample ratio for positives: 0.6707246376811594, Sample ratio for negatives:0.3292753623188406
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 116/118 [============================>.] - ETA: 0s - loss: 0.5461 - binary_accuracy: 0.7345 - false_negatives_9: 2400.0000 - false_positives_9: 5484.0000
# Epoch 1: val_loss improved from 0.61202 to 0.60996, saving model to AL_Model.h5
# 118/118 [==============================] - 13s 47ms/step - loss: 0.5458 - binary_accuracy: 0.7346 - false_negatives_9: 2419.0000 - false_positives_9: 5543.0000 - val_loss: 0.6100 - val_binary_accuracy: 0.6650 - val_false_negatives_9: 737.0000 - val_false_positives_9: 938.0000
# Epoch 2/20
#  85/118 [====================>.........] - ETA: 0s - loss: 0.5333 - binary_accuracy: 0.7403 - false_negatives_9: 1796.0000 - false_positives_9: 3855.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9720\3133415081.py in <module>
#     134
#     135
# --> 136 active_learning_model = train_active_learning_models(train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset)
#
# ~\AppData\Local\Temp\ipykernel_9720\3133415081.py in train_active_learning_models(train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset, num_iterations, sampling_size)
#     104             ],
#     105         )
# --> 106         history = model.fit(
#     107             train_dataset.cache().shuffle(20000).batch(256),
#     108             validation_data=val_dataset,
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# !pip install fiftyone
# Out:
# Collecting fiftyone
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chsha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chsha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chsha\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\chsha\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\chsha\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
#   Downloading fiftyone-0.17.2-py3-none-any.whl (2.2 MB)
# Collecting aiofiles
#   Downloading aiofiles-22.1.0-py3-none-any.whl (14 kB)
# Collecting Deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: scikit-image in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (0.18.3)
# Collecting pprintpp
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Collecting sseclient-py<2,>=1.7.2
#   Downloading sseclient_py-1.7.2-py2.py3-none-any.whl (8.4 kB)
# Collecting ndjson
#   Downloading ndjson-0.3.1-py2.py3-none-any.whl (5.3 kB)
# Requirement already satisfied: psutil in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (5.8.0)
# Requirement already satisfied: matplotlib in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (3.4.3)
# Collecting dacite>=1.6.0
#   Downloading dacite-1.6.0-py3-none-any.whl (12 kB)
# Collecting sse-starlette<1,>=0.10.3
#   Downloading sse_starlette-0.10.3-py3-none-any.whl (8.0 kB)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.6.0.66-cp36-abi3-win_amd64.whl (35.5 MB)
# Collecting plotly>=4.14
#   Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
# Collecting mongoengine==0.20.0
#   Downloading mongoengine-0.20.0-py3-none-any.whl (106 kB)
# Requirement already satisfied: scikit-learn in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (1.1.1)
# Collecting motor<3,>=2.3
#   Downloading motor-2.5.1-py3-none-any.whl (55 kB)
# Requirement already satisfied: numpy in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (1.20.3)
# Collecting fiftyone-brain<0.10,>=0.9.1
#   Downloading fiftyone_brain-0.9.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: setuptools in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (58.0.4)
# Collecting universal-analytics-python3<2,>=1.0.1
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: xmltodict in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (0.12.0)
# Collecting voxel51-eta<0.9,>=0.8.1
#   Downloading voxel51_eta-0.8.1-py2.py3-none-any.whl (564 kB)
# Collecting eventlet
#   Downloading eventlet-0.33.1-py2.py3-none-any.whl (226 kB)
# Requirement already satisfied: packaging in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (21.0)
# Requirement already satisfied: PyYAML in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (6.0)
# Collecting argcomplete
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting boto3
#   Downloading boto3-1.24.89-py3-none-any.whl (132 kB)
# Collecting starlette==0.16.0
#   Downloading starlette-0.16.0-py3-none-any.whl (61 kB)
# Collecting fiftyone-db<0.4,>=0.3
#   Downloading fiftyone_db-0.3.0-py3-none-win_amd64.whl (16.6 MB)
# Requirement already satisfied: future in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (0.18.2)
# Collecting pymongo<4,>=3.11
#   Downloading pymongo-3.12.3-cp39-cp39-win_amd64.whl (398 kB)
# Collecting Jinja2>=3
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# Requirement already satisfied: pytz in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (2021.3)
# Requirement already satisfied: pandas in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (1.3.4)
# Collecting strawberry-graphql==0.96.0
#   Downloading strawberry_graphql-0.96.0-py3-none-any.whl (135 kB)
# Collecting hypercorn>=0.13.2
#   Downloading Hypercorn-0.14.3-py3-none-any.whl (57 kB)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: Pillow>=6.2 in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone) (8.4.0)
# Collecting anyio<4,>=3.0.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
# Requirement already satisfied: typing_extensions<5.0.0,>=3.7.4 in c:\users\chsha\anaconda3\lib\site-packages (from strawberry-graphql==0.96.0->fiftyone) (3.10.0.2)
# Requirement already satisfied: click<9.0,>=7.0 in c:\users\chsha\anaconda3\lib\site-packages (from strawberry-graphql==0.96.0->fiftyone) (8.0.3)
# Collecting sentinel<0.4.0,>=0.3.0
#   Downloading sentinel-0.3.0-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: pygments<3.0,>=2.3 in c:\users\chsha\anaconda3\lib\site-packages (from strawberry-graphql==0.96.0->fiftyone) (2.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.0 in c:\users\chsha\anaconda3\lib\site-packages (from strawberry-graphql==0.96.0->fiftyone) (2.8.2)
# Collecting graphql-core<3.2.0,>=3.1.0
#   Downloading graphql_core-3.1.7-py3-none-any.whl (189 kB)
# Collecting python-multipart<0.0.6,>=0.0.5
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting backports.cached-property<2.0.0,>=1.0.1
#   Downloading backports.cached_property-1.0.2-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\chsha\anaconda3\lib\site-packages (from anyio<4,>=3.0.0->starlette==0.16.0->fiftyone) (3.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chsha\anaconda3\lib\site-packages (from anyio<4,>=3.0.0->starlette==0.16.0->fiftyone) (1.2.0)
# Requirement already satisfied: colorama in c:\users\chsha\anaconda3\lib\site-packages (from click<9.0,>=7.0->strawberry-graphql==0.96.0->fiftyone) (0.4.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\chsha\anaconda3\lib\site-packages (from fiftyone-brain<0.10,>=0.9.1->fiftyone) (1.7.1)
# Collecting priority
#   Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: toml in c:\users\chsha\anaconda3\lib\site-packages (from hypercorn>=0.13.2->fiftyone) (0.10.2)
# Collecting h11
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting h2>=3.1.0
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
# Collecting wsproto>=0.14.0
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting hpack<5,>=4.0
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting hyperframe<7,>=6.0
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.5 in c:\users\chsha\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.7.0->strawberry-graphql==0.96.0->fiftyone) (1.16.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chsha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chsha\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chsha\anaconda3\lib\site-packages)

# %%
import fiftyone.zoo as foz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13632/3963530278.py in <module>
# ----> 1 import fiftyone.zoo as foz
#
# ModuleNotFoundError: No module named 'fiftyone'

# %%
pip install fiftyone
