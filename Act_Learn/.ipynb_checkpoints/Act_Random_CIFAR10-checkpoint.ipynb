# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd
#import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns
import shutil
import keras
from PIL import Image
#import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_labels = to_categorical(train_labels)
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')
train_images = train_images / 255
test_images = test_images / 255

# %%
np.shape(x_train)
# Out:
# (18000, 32, 32, 3)

# %%
x_train, x_unlab, y_train, y_unlab = train_test_split( train_images, train_labels , test_size=0.6, random_state=42 )

# %%
X_train, X_test, Y_train, Y_test = train_test_split( x_train,y_train , test_size=0.5, random_state=40 )

# %%
len(X_train)
# Out:
# 10000

# %%
arr = np.concatenate((X_train, x_unlab))
X_all = arr
arr = np.concatenate((Y_train, y_unlab))
Y_all = arr

# %%
len(Y_all)
# Out:
# 40000

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["accuracy"]
    val_accuracy = val_accuracy + history.history["val_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'num_patches': self.num_patches,
            'projection': self.projection,
            'position_embedding': self.position_embedding
        })
        return config

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection =keras.Sequential(
            [
                (layers.Conv2D(4, (3, 3), strides=(2,2),activation='relu')),
                TimeDistributed(Flatten()),
                layers.LSTM(projection_dim,return_sequences=True,dropout=0.1),
            ]) 
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE

def create_model():
    
    
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), input_shape=(32, 32, 3)))
    model.add(layers.Conv2D(32, (3, 3), activation="relu"))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3),))
    model.add(layers.Conv2D(64, (3, 3),))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3),))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(.2))
    model.add(layers.Flatten()) 
    model.add(layers.Dense(32))
    model.add(layers.Dropout(.2))
    model.add(layers.Dense(10, activation="softmax"))

    model.summary()
    return model

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE

def create_model():
    
    
    model = tf.keras.applications.MobileNetV3Small(
    input_shape=(32,32,3),
    alpha=1.0,
    minimalistic=True,
    include_top=True,
    weights=None,
    input_tensor=None,
    classes=10,
    pooling=None,
    dropout_rate=0.2,
    classifier_activation="softmax",
    include_preprocessing=True,
)

    model.summary()
    return model

# %%
# callbacks=[keras.callbacks.EarlyStopping(patience=4, verbose=1), ],

def train_all_data_model(X_train, X_test, Y_train, Y_test):
    
    X_train, Y_train = shuffle(X_train, Y_train)
    
    model = create_model()
    model.compile( loss="categorical_crossentropy",  optimizer="Adam",  metrics='accuracy' )
    
    early_stopping = keras.callbacks.EarlyStopping(patience=15, verbose=1)

    history = model.fit( X_train, Y_train, batch_size = 64, epochs=100,
                        validation_split=.20,callbacks=[ keras.callbacks.ModelCheckpoint( "FullModelCheckpoint.h5",
                        verbose=1, save_best_only=True ) ], )

    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["accuracy"],
        history.history["val_accuracy"],
    )


    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate( X_test, Y_test , verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


full_dataset_model = train_full_model(X_all, X_test, Y_all, Y_test)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_45 (Conv2D)          (None, 30, 30, 32)        896
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 32)        9248
#
#  max_pooling2d_27 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 12, 12, 64)        18496
#
#  conv2d_48 (Conv2D)          (None, 10, 10, 64)        36928
#
#  max_pooling2d_28 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 3, 3, 128)         73856
#
#  max_pooling2d_29 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_9 (Flatten)         (None, 128)               0
#
#  dense_18 (Dense)            (None, 32)                4128
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_19 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 143,882
# Trainable params: 143,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 500/500 [==============================] - ETA: 0s - loss: 1.6928 - accuracy: 0.3782
# Epoch 1: val_loss improved from inf to 1.35668, saving model to FullModelCheckpoint.h5
# 500/500 [==============================] - 53s 105ms/step - loss: 1.6928 - accuracy: 0.3782 - val_loss: 1.3567 - val_accuracy: 0.5091
# Epoch 2/100
# 500/500 [==============================] - ETA: 0s - loss: 1.3354 - accuracy: 0.5306
# Epoch 2: val_loss improved from 1.35668 to 1.19889, saving model to FullModelCheckpoint.h5
# 500/500 [==============================] - 56s 112ms/step - loss: 1.3354 - accuracy: 0.5306 - val_loss: 1.1989 - val_accuracy: 0.5801
# Epoch 3/100
# 500/500 [==============================] - ETA: 0s - loss: 1.1986 - accuracy: 0.5798
# Epoch 3: val_loss improved from 1.19889 to 1.11438, saving model to FullModelCheckpoint.h5
# 500/500 [==============================] - 57s 114ms/step - loss: 1.1986 - accuracy: 0.5798 - val_loss: 1.1144 - val_accuracy: 0.6151
# Epoch 4/100
# 500/500 [==============================] - ETA: 0s - loss: 1.1239 - accuracy: 0.6078
# Epoch 4: val_loss improved from 1.11438 to 1.05055, saving model to FullModelCheckpoint.h5
# 500/500 [==============================] - 60s 120ms/step - loss: 1.1239 - accuracy: 0.6078 - val_loss: 1.0506 - val_accuracy: 0.6332
# Epoch 5/100
# 500/500 [==============================] - ETA: 0s - loss: 1.0476 - accuracy: 0.6369
# Epoch 5: val_loss improved from 1.05055 to 1.04646, saving model to FullModelCheckpoint.h5
# 500/500 [==============================] - 60s 120ms/step - loss: 1.0476 - accuracy: 0.6369 - val_loss: 1.0465 - val_accuracy: 0.6364
# Epoch 6/100
# 500/500 [==============================] - ETA: 0s - loss: 0.9941 - accuracy: 0.6566
# Epoch 6: val_loss did not improve from 1.04646
# 500/500 [==============================] - 57s 113ms/step - loss: 0.9941 - accuracy: 0.6566 - val_loss: 1.0486 - val_accuracy: 0.6466
# Epoch 7/100
# 500/500 [==============================] - ETA: 0s - loss: 0.9470 - accuracy: 0.6735
# Epoch 7: val_loss improved from 1.04646 to 0.98803, saving model to FullModelCheckpoint.h5
# 500/500 [==============================] - 61s 123ms/step - loss: 0.9470 - accuracy: 0.6735 - val_loss: 0.9880 - val_accuracy: 0.6609
# Epoch 8/100
# 500/500 [==============================] - ETA: 0s - loss: 0.9024 - accuracy: 0.6864
# Epoch 8: val_loss did not improve from 0.98803
# 500/500 [==============================] - 58s 115ms/step - loss: 0.9024 - accuracy: 0.6864 - val_loss: 1.0049 - val_accuracy: 0.6564
# Epoch 9/100
# 500/500 [==============================] - ETA: 0s - loss: 0.8627 - accuracy: 0.7002
# Epoch 9: val_loss did not improve from 0.98803
# 500/500 [==============================] - 58s 116ms/step - loss: 0.8627 - accuracy: 0.7002 - val_loss: 0.9971 - val_accuracy: 0.6684
# Epoch 10/100
# 500/500 [==============================] - ETA: 0s - loss: 0.8166 - accuracy: 0.7145
# Epoch 10: val_loss improved from 0.98803 to 0.98252, saving model to FullModelCheckpoint.h5
# 500/500 [==============================] - 60s 120ms/step - loss: 0.8166 - accuracy: 0.7145 - val_loss: 0.9825 - val_accuracy: 0.6719
# Epoch 11/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7786 - accuracy: 0.7274
# Epoch 11: val_loss did not improve from 0.98252
# 500/500 [==============================] - 59s 119ms/step - loss: 0.7786 - accuracy: 0.7274 - val_loss: 1.0041 - val_accuracy: 0.6655
# Epoch 12/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7506 - accuracy: 0.7388
# Epoch 12: val_loss did not improve from 0.98252
# 500/500 [==============================] - 60s 120ms/step - loss: 0.7506 - accuracy: 0.7388 - val_loss: 1.0301 - val_accuracy: 0.6612
# Epoch 13/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7145 - accuracy: 0.7507
# Epoch 13: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 127ms/step - loss: 0.7145 - accuracy: 0.7507 - val_loss: 1.0258 - val_accuracy: 0.6708
# Epoch 14/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6725 - accuracy: 0.7635
# Epoch 14: val_loss did not improve from 0.98252
# 500/500 [==============================] - 60s 121ms/step - loss: 0.6725 - accuracy: 0.7635 - val_loss: 1.0212 - val_accuracy: 0.6749
# Epoch 15/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6493 - accuracy: 0.7707
# Epoch 15: val_loss did not improve from 0.98252
# 500/500 [==============================] - 62s 124ms/step - loss: 0.6493 - accuracy: 0.7707 - val_loss: 1.0776 - val_accuracy: 0.6670
# Epoch 16/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6267 - accuracy: 0.7806
# Epoch 16: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 126ms/step - loss: 0.6267 - accuracy: 0.7806 - val_loss: 1.0855 - val_accuracy: 0.6645
# Epoch 17/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6063 - accuracy: 0.7857
# Epoch 17: val_loss did not improve from 0.98252
# 500/500 [==============================] - 60s 121ms/step - loss: 0.6063 - accuracy: 0.7857 - val_loss: 1.1735 - val_accuracy: 0.6519
# Epoch 18/100
# 500/500 [==============================] - ETA: 0s - loss: 0.5644 - accuracy: 0.8010
# Epoch 18: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 127ms/step - loss: 0.5644 - accuracy: 0.8010 - val_loss: 1.1435 - val_accuracy: 0.6661
# Epoch 19/100
# 500/500 [==============================] - ETA: 0s - loss: 0.5588 - accuracy: 0.8028
# Epoch 19: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 127ms/step - loss: 0.5588 - accuracy: 0.8028 - val_loss: 1.1272 - val_accuracy: 0.6639
# Epoch 20/100
# 500/500 [==============================] - ETA: 0s - loss: 0.5330 - accuracy: 0.8107
# Epoch 20: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 126ms/step - loss: 0.5330 - accuracy: 0.8107 - val_loss: 1.1546 - val_accuracy: 0.6590
# Epoch 21/100
# 500/500 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.8166
# Epoch 21: val_loss did not improve from 0.98252
# 500/500 [==============================] - 62s 125ms/step - loss: 0.5162 - accuracy: 0.8166 - val_loss: 1.2290 - val_accuracy: 0.6525
# Epoch 22/100
# 500/500 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.8279
# Epoch 22: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 115ms/step - loss: 0.4853 - accuracy: 0.8279 - val_loss: 1.1724 - val_accuracy: 0.6596
# Epoch 23/100
# 500/500 [==============================] - ETA: 0s - loss: 0.4780 - accuracy: 0.8280
# Epoch 23: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 114ms/step - loss: 0.4780 - accuracy: 0.8280 - val_loss: 1.2067 - val_accuracy: 0.6708
# Epoch 24/100
# 500/500 [==============================] - ETA: 0s - loss: 0.4540 - accuracy: 0.8400
# Epoch 24: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 115ms/step - loss: 0.4540 - accuracy: 0.8400 - val_loss: 1.2365 - val_accuracy: 0.6643
# Epoch 25/100
# 500/500 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.8435
# Epoch 25: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 115ms/step - loss: 0.4366 - accuracy: 0.8435 - val_loss: 1.3606 - val_accuracy: 0.6428
# Epoch 26/100
# 500/500 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.8477
# Epoch 26: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 115ms/step - loss: 0.4283 - accuracy: 0.8477 - val_loss: 1.2815 - val_accuracy: 0.6582
# Epoch 27/100
# 500/500 [==============================] - ETA: 0s - loss: 0.4185 - accuracy: 0.8527
# Epoch 27: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 114ms/step - loss: 0.4185 - accuracy: 0.8527 - val_loss: 1.3558 - val_accuracy: 0.6571
# Epoch 28/100
# 500/500 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8584
# Epoch 28: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 109ms/step - loss: 0.4059 - accuracy: 0.8584 - val_loss: 1.3218 - val_accuracy: 0.6586
# Epoch 29/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8609
# Epoch 29: val_loss did not improve from 0.98252
# 500/500 [==============================] - 56s 111ms/step - loss: 0.3907 - accuracy: 0.8609 - val_loss: 1.3882 - val_accuracy: 0.6506
# Epoch 30/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8646
# Epoch 30: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 110ms/step - loss: 0.3878 - accuracy: 0.8646 - val_loss: 1.4005 - val_accuracy: 0.6549
# Epoch 31/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.8677
# Epoch 31: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 110ms/step - loss: 0.3746 - accuracy: 0.8677 - val_loss: 1.3884 - val_accuracy: 0.6568
# Epoch 32/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8699
# Epoch 32: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 110ms/step - loss: 0.3684 - accuracy: 0.8699 - val_loss: 1.4950 - val_accuracy: 0.6444
# Epoch 33/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8738
# Epoch 33: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 115ms/step - loss: 0.3550 - accuracy: 0.8738 - val_loss: 1.4282 - val_accuracy: 0.6536
# Epoch 34/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8776
# Epoch 34: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 113ms/step - loss: 0.3465 - accuracy: 0.8776 - val_loss: 1.4517 - val_accuracy: 0.6534
# Epoch 35/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8820
# Epoch 35: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 113ms/step - loss: 0.3369 - accuracy: 0.8820 - val_loss: 1.4201 - val_accuracy: 0.6495
# Epoch 36/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8849
# Epoch 36: val_loss did not improve from 0.98252
# 500/500 [==============================] - 56s 113ms/step - loss: 0.3289 - accuracy: 0.8849 - val_loss: 1.5220 - val_accuracy: 0.6553
# Epoch 37/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3315 - accuracy: 0.8852
# Epoch 37: val_loss did not improve from 0.98252
# 500/500 [==============================] - 58s 117ms/step - loss: 0.3315 - accuracy: 0.8852 - val_loss: 1.6019 - val_accuracy: 0.6330
# Epoch 38/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8873
# Epoch 38: val_loss did not improve from 0.98252
# 500/500 [==============================] - 61s 122ms/step - loss: 0.3268 - accuracy: 0.8873 - val_loss: 1.4788 - val_accuracy: 0.6486
# Epoch 39/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3036 - accuracy: 0.8942
# Epoch 39: val_loss did not improve from 0.98252
# 500/500 [==============================] - 62s 125ms/step - loss: 0.3036 - accuracy: 0.8942 - val_loss: 1.5447 - val_accuracy: 0.6559
# Epoch 40/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8915
# Epoch 40: val_loss did not improve from 0.98252
# 500/500 [==============================] - 60s 120ms/step - loss: 0.3064 - accuracy: 0.8915 - val_loss: 1.5418 - val_accuracy: 0.6543
# Epoch 41/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3133 - accuracy: 0.8910
# Epoch 41: val_loss did not improve from 0.98252
# 500/500 [==============================] - 65s 129ms/step - loss: 0.3133 - accuracy: 0.8910 - val_loss: 1.5551 - val_accuracy: 0.6455
# Epoch 42/100
# 500/500 [==============================] - ETA: 0s - loss: 0.3009 - accuracy: 0.8925
# Epoch 42: val_loss did not improve from 0.98252
# 500/500 [==============================] - 56s 113ms/step - loss: 0.3009 - accuracy: 0.8925 - val_loss: 1.5664 - val_accuracy: 0.6451
# Epoch 43/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2959 - accuracy: 0.8974
# Epoch 43: val_loss did not improve from 0.98252
# 500/500 [==============================] - 59s 118ms/step - loss: 0.2959 - accuracy: 0.8974 - val_loss: 1.6095 - val_accuracy: 0.6405
# Epoch 44/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8984
# Epoch 44: val_loss did not improve from 0.98252
# 500/500 [==============================] - 58s 116ms/step - loss: 0.2888 - accuracy: 0.8984 - val_loss: 1.6081 - val_accuracy: 0.6453
# Epoch 45/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.9004
# Epoch 45: val_loss did not improve from 0.98252
# 500/500 [==============================] - 59s 117ms/step - loss: 0.2883 - accuracy: 0.9004 - val_loss: 1.6394 - val_accuracy: 0.6501
# Epoch 46/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.9024
# Epoch 46: val_loss did not improve from 0.98252
# 500/500 [==============================] - 57s 115ms/step - loss: 0.2742 - accuracy: 0.9024 - val_loss: 1.5851 - val_accuracy: 0.6568
# Epoch 47/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.9013
# Epoch 47: val_loss did not improve from 0.98252
# 500/500 [==============================] - 58s 117ms/step - loss: 0.2838 - accuracy: 0.9013 - val_loss: 1.6101 - val_accuracy: 0.6466
# Epoch 48/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9092
# Epoch 48: val_loss did not improve from 0.98252
# 500/500 [==============================] - 60s 119ms/step - loss: 0.2588 - accuracy: 0.9092 - val_loss: 1.7233 - val_accuracy: 0.6549
# Epoch 49/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2703 - accuracy: 0.9053
# Epoch 49: val_loss did not improve from 0.98252
# 500/500 [==============================] - 58s 116ms/step - loss: 0.2703 - accuracy: 0.9053 - val_loss: 1.6753 - val_accuracy: 0.6524
# Epoch 50/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.9081
# Epoch 50: val_loss did not improve from 0.98252
# 500/500 [==============================] - 56s 112ms/step - loss: 0.2653 - accuracy: 0.9081 - val_loss: 1.7054 - val_accuracy: 0.6496
# Epoch 51/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.9087
# Epoch 51: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 109ms/step - loss: 0.2622 - accuracy: 0.9087 - val_loss: 1.7310 - val_accuracy: 0.6466
# Epoch 52/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.9088
# Epoch 52: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 109ms/step - loss: 0.2604 - accuracy: 0.9088 - val_loss: 1.7204 - val_accuracy: 0.6480
# Epoch 53/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9107
# Epoch 53: val_loss did not improve from 0.98252
# 500/500 [==============================] - 54s 108ms/step - loss: 0.2541 - accuracy: 0.9107 - val_loss: 1.7867 - val_accuracy: 0.6442
# Epoch 54/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9117
# Epoch 54: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 110ms/step - loss: 0.2535 - accuracy: 0.9117 - val_loss: 1.7302 - val_accuracy: 0.6501
# Epoch 55/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.9119
# Epoch 55: val_loss did not improve from 0.98252
# 500/500 [==============================] - 54s 108ms/step - loss: 0.2476 - accuracy: 0.9119 - val_loss: 1.7647 - val_accuracy: 0.6491
# Epoch 56/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2529 - accuracy: 0.9135
# Epoch 56: val_loss did not improve from 0.98252
# 500/500 [==============================] - 54s 107ms/step - loss: 0.2529 - accuracy: 0.9135 - val_loss: 1.7376 - val_accuracy: 0.6484
# Epoch 57/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2422 - accuracy: 0.9161
# Epoch 57: val_loss did not improve from 0.98252
# 500/500 [==============================] - 53s 106ms/step - loss: 0.2422 - accuracy: 0.9161 - val_loss: 1.7726 - val_accuracy: 0.6457
# Epoch 58/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9152
# Epoch 58: val_loss did not improve from 0.98252
# 500/500 [==============================] - 55s 109ms/step - loss: 0.2445 - accuracy: 0.9152 - val_loss: 1.7818 - val_accuracy: 0.6409
# Epoch 59/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9216
# Epoch 59: val_loss did not improve from 0.98252
# 500/500 [==============================] - 53s 107ms/step - loss: 0.2294 - accuracy: 0.9216 - val_loss: 1.7727 - val_accuracy: 0.6534
# Epoch 60/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.9218
# Epoch 60: val_loss did not improve from 0.98252
# 500/500 [==============================] - 52s 103ms/step - loss: 0.2288 - accuracy: 0.9218 - val_loss: 1.8429 - val_accuracy: 0.6382
# Epoch 61/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9202
# Epoch 61: val_loss did not improve from 0.98252
# 500/500 [==============================] - 58s 117ms/step - loss: 0.2316 - accuracy: 0.9202 - val_loss: 1.8977 - val_accuracy: 0.6391
# Epoch 62/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9217
# Epoch 62: val_loss did not improve from 0.98252
# 500/500 [==============================] - 64s 127ms/step - loss: 0.2296 - accuracy: 0.9217 - val_loss: 1.8477 - val_accuracy: 0.6455
# Epoch 63/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2196 - accuracy: 0.9237
# Epoch 63: val_loss did not improve from 0.98252
# 500/500 [==============================] - 62s 125ms/step - loss: 0.2196 - accuracy: 0.9237 - val_loss: 1.8594 - val_accuracy: 0.6521
# Epoch 64/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9241
# Epoch 64: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 125ms/step - loss: 0.2198 - accuracy: 0.9241 - val_loss: 1.8582 - val_accuracy: 0.6438
# Epoch 65/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9218
# Epoch 65: val_loss did not improve from 0.98252
# 500/500 [==============================] - 68s 137ms/step - loss: 0.2249 - accuracy: 0.9218 - val_loss: 1.8711 - val_accuracy: 0.6460
# Epoch 66/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9225
# Epoch 66: val_loss did not improve from 0.98252
# 500/500 [==============================] - 68s 136ms/step - loss: 0.2304 - accuracy: 0.9225 - val_loss: 1.8209 - val_accuracy: 0.6541
# Epoch 67/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9265
# Epoch 67: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 126ms/step - loss: 0.2112 - accuracy: 0.9265 - val_loss: 1.8430 - val_accuracy: 0.6471
# Epoch 68/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9240
# Epoch 68: val_loss did not improve from 0.98252
# 500/500 [==============================] - 64s 127ms/step - loss: 0.2158 - accuracy: 0.9240 - val_loss: 1.9104 - val_accuracy: 0.6476
# Epoch 69/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9237
# Epoch 69: val_loss did not improve from 0.98252
# 500/500 [==============================] - 58s 116ms/step - loss: 0.2223 - accuracy: 0.9237 - val_loss: 1.8595 - val_accuracy: 0.6466
# Epoch 70/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9262
# Epoch 70: val_loss did not improve from 0.98252
# 500/500 [==============================] - 56s 112ms/step - loss: 0.2136 - accuracy: 0.9262 - val_loss: 1.9108 - val_accuracy: 0.6394
# Epoch 71/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2126 - accuracy: 0.9259
# Epoch 71: val_loss did not improve from 0.98252
# 500/500 [==============================] - 58s 115ms/step - loss: 0.2126 - accuracy: 0.9259 - val_loss: 1.8854 - val_accuracy: 0.6411
# Epoch 72/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9282
# Epoch 72: val_loss did not improve from 0.98252
# 500/500 [==============================] - 61s 122ms/step - loss: 0.2117 - accuracy: 0.9282 - val_loss: 1.9570 - val_accuracy: 0.6417
# Epoch 73/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9295
# Epoch 73: val_loss did not improve from 0.98252
# 500/500 [==============================] - 67s 134ms/step - loss: 0.2065 - accuracy: 0.9295 - val_loss: 2.0020 - val_accuracy: 0.6460
# Epoch 74/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9275
# Epoch 74: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 127ms/step - loss: 0.2093 - accuracy: 0.9275 - val_loss: 1.9538 - val_accuracy: 0.6496
# Epoch 75/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9312
# Epoch 75: val_loss did not improve from 0.98252
# 500/500 [==============================] - 62s 125ms/step - loss: 0.2025 - accuracy: 0.9312 - val_loss: 2.1223 - val_accuracy: 0.6286
# Epoch 76/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9263
# Epoch 76: val_loss did not improve from 0.98252
# 500/500 [==============================] - 65s 131ms/step - loss: 0.2048 - accuracy: 0.9263 - val_loss: 1.9744 - val_accuracy: 0.6444
# Epoch 77/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2011 - accuracy: 0.9311
# Epoch 77: val_loss did not improve from 0.98252
# 500/500 [==============================] - 65s 130ms/step - loss: 0.2011 - accuracy: 0.9311 - val_loss: 2.0513 - val_accuracy: 0.6346
# Epoch 78/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.9278
# Epoch 78: val_loss did not improve from 0.98252
# 500/500 [==============================] - 69s 139ms/step - loss: 0.2069 - accuracy: 0.9278 - val_loss: 2.0410 - val_accuracy: 0.6445
# Epoch 79/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.9289
# Epoch 79: val_loss did not improve from 0.98252
# 500/500 [==============================] - 66s 131ms/step - loss: 0.2056 - accuracy: 0.9289 - val_loss: 1.9817 - val_accuracy: 0.6438
# Epoch 80/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9321
# Epoch 80: val_loss did not improve from 0.98252
# 500/500 [==============================] - 62s 124ms/step - loss: 0.1980 - accuracy: 0.9321 - val_loss: 1.9853 - val_accuracy: 0.6441
# Epoch 81/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9353
# Epoch 81: val_loss did not improve from 0.98252
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1897 - accuracy: 0.9353 - val_loss: 2.1466 - val_accuracy: 0.6320
# Epoch 82/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9296
# Epoch 82: val_loss did not improve from 0.98252
# 500/500 [==============================] - 62s 124ms/step - loss: 0.2104 - accuracy: 0.9296 - val_loss: 1.9654 - val_accuracy: 0.6445
# Epoch 83/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9335
# Epoch 83: val_loss did not improve from 0.98252
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1880 - accuracy: 0.9335 - val_loss: 2.1811 - val_accuracy: 0.6365
# Epoch 84/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9322
# Epoch 84: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1984 - accuracy: 0.9322 - val_loss: 2.0377 - val_accuracy: 0.6395
# Epoch 85/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9368
# Epoch 85: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1880 - accuracy: 0.9368 - val_loss: 2.0681 - val_accuracy: 0.6486
# Epoch 86/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9364
# Epoch 86: val_loss did not improve from 0.98252
# 500/500 [==============================] - 61s 121ms/step - loss: 0.1885 - accuracy: 0.9364 - val_loss: 2.0337 - val_accuracy: 0.6370
# Epoch 87/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9350
# Epoch 87: val_loss did not improve from 0.98252
# 500/500 [==============================] - 64s 127ms/step - loss: 0.1913 - accuracy: 0.9350 - val_loss: 2.1176 - val_accuracy: 0.6494
# Epoch 88/100
# 500/500 [==============================] - ETA: 0s - loss: 0.2041 - accuracy: 0.9316
# Epoch 88: val_loss did not improve from 0.98252
# 500/500 [==============================] - 64s 129ms/step - loss: 0.2041 - accuracy: 0.9316 - val_loss: 2.0105 - val_accuracy: 0.6499
# Epoch 89/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9350
# Epoch 89: val_loss did not improve from 0.98252
# 500/500 [==============================] - 69s 138ms/step - loss: 0.1912 - accuracy: 0.9350 - val_loss: 2.0365 - val_accuracy: 0.6463
# Epoch 90/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9389
# Epoch 90: val_loss did not improve from 0.98252
# 500/500 [==============================] - 69s 139ms/step - loss: 0.1816 - accuracy: 0.9389 - val_loss: 2.0801 - val_accuracy: 0.6384
# Epoch 91/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9374
# Epoch 91: val_loss did not improve from 0.98252
# 500/500 [==============================] - 73s 147ms/step - loss: 0.1816 - accuracy: 0.9374 - val_loss: 2.1102 - val_accuracy: 0.6430
# Epoch 92/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9340
# Epoch 92: val_loss did not improve from 0.98252
# 500/500 [==============================] - 70s 141ms/step - loss: 0.1953 - accuracy: 0.9340 - val_loss: 2.1096 - val_accuracy: 0.6380
# Epoch 93/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9387
# Epoch 93: val_loss did not improve from 0.98252
# 500/500 [==============================] - 66s 131ms/step - loss: 0.1754 - accuracy: 0.9387 - val_loss: 2.1221 - val_accuracy: 0.6419
# Epoch 94/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9386
# Epoch 94: val_loss did not improve from 0.98252
# 500/500 [==============================] - 69s 137ms/step - loss: 0.1827 - accuracy: 0.9386 - val_loss: 2.1339 - val_accuracy: 0.6431
# Epoch 95/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9366
# Epoch 95: val_loss did not improve from 0.98252
# 500/500 [==============================] - 66s 132ms/step - loss: 0.1870 - accuracy: 0.9366 - val_loss: 2.1601 - val_accuracy: 0.6352
# Epoch 96/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1858 - accuracy: 0.9373
# Epoch 96: val_loss did not improve from 0.98252
# 500/500 [==============================] - 68s 136ms/step - loss: 0.1858 - accuracy: 0.9373 - val_loss: 2.0988 - val_accuracy: 0.6391
# Epoch 97/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9411
# Epoch 97: val_loss did not improve from 0.98252
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1764 - accuracy: 0.9411 - val_loss: 2.0359 - val_accuracy: 0.6495
# Epoch 98/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9386
# Epoch 98: val_loss did not improve from 0.98252
# 500/500 [==============================] - 64s 128ms/step - loss: 0.1796 - accuracy: 0.9386 - val_loss: 2.1345 - val_accuracy: 0.6460
# Epoch 99/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1869 - accuracy: 0.9371
# Epoch 99: val_loss did not improve from 0.98252
# 500/500 [==============================] - 69s 137ms/step - loss: 0.1869 - accuracy: 0.9371 - val_loss: 2.1018 - val_accuracy: 0.6491
# Epoch 100/100
# 500/500 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9395
# Epoch 100: val_loss did not improve from 0.98252
# 500/500 [==============================] - 65s 131ms/step - loss: 0.1764 - accuracy: 0.9395 - val_loss: 2.1293 - val_accuracy: 0.6399
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 2.2606823444366455, 'accuracy': 0.6251000165939331}
# ----------------------------------------------------------------------------------------------------

# %%
# callbacks=[keras.callbacks.EarlyStopping(patience=4, verbose=1), ],

def train_full_model(X_train, X_test, Y_train, Y_test):
    
    X_train, Y_train = shuffle(X_train, Y_train)
    
    model = create_model()
    model.compile( loss="categorical_crossentropy",  optimizer="Adam",  metrics='accuracy' )
    
    early_stopping = keras.callbacks.EarlyStopping(patience=15, verbose=1)

    history = model.fit( X_train, Y_train, batch_size = 64, epochs=100,
                        validation_split=.20,callbacks=[ keras.callbacks.ModelCheckpoint( "FullModelCheckpoint.h5",
                        verbose=1, save_best_only=True ) ], )

    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["accuracy"],
        history.history["val_accuracy"],
    )


    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate( X_test, Y_test , verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


full_dataset_model = train_full_model(X_train, X_test, Y_train, Y_test)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 30, 30, 32)        896
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 32)        9248
#
#  max_pooling2d_24 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 12, 12, 64)        18496
#
#  conv2d_43 (Conv2D)          (None, 10, 10, 64)        36928
#
#  max_pooling2d_25 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 3, 3, 128)         73856
#
#  max_pooling2d_26 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout (Dropout)           (None, 1, 1, 128)         0
#
#  flatten_8 (Flatten)         (None, 128)               0
#
#  dense_16 (Dense)            (None, 32)                4128
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_17 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 143,882
# Trainable params: 143,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 125/125 [==============================] - ETA: 0s - loss: 2.0299 - accuracy: 0.2422
# Epoch 1: val_loss improved from inf to 1.81548, saving model to FullModelCheckpoint.h5
# 125/125 [==============================] - 12s 94ms/step - loss: 2.0299 - accuracy: 0.2422 - val_loss: 1.8155 - val_accuracy: 0.3680
# Epoch 2/100
# 125/125 [==============================] - ETA: 0s - loss: 1.7231 - accuracy: 0.3661
# Epoch 2: val_loss improved from 1.81548 to 1.51883, saving model to FullModelCheckpoint.h5
# 125/125 [==============================] - 12s 96ms/step - loss: 1.7231 - accuracy: 0.3661 - val_loss: 1.5188 - val_accuracy: 0.4560
# Epoch 3/100
# 125/125 [==============================] - ETA: 0s - loss: 1.5493 - accuracy: 0.4409
# Epoch 3: val_loss improved from 1.51883 to 1.49233, saving model to FullModelCheckpoint.h5
# 125/125 [==============================] - 13s 104ms/step - loss: 1.5493 - accuracy: 0.4409 - val_loss: 1.4923 - val_accuracy: 0.4640
# Epoch 4/100
# 125/125 [==============================] - ETA: 0s - loss: 1.4421 - accuracy: 0.4864
# Epoch 4: val_loss improved from 1.49233 to 1.41137, saving model to FullModelCheckpoint.h5
# 125/125 [==============================] - 13s 106ms/step - loss: 1.4421 - accuracy: 0.4864 - val_loss: 1.4114 - val_accuracy: 0.4900
# Epoch 5/100
# 125/125 [==============================] - ETA: 0s - loss: 1.3355 - accuracy: 0.5194
# Epoch 5: val_loss improved from 1.41137 to 1.37255, saving model to FullModelCheckpoint.h5
# 125/125 [==============================] - 13s 108ms/step - loss: 1.3355 - accuracy: 0.5194 - val_loss: 1.3725 - val_accuracy: 0.5190
# Epoch 6/100
# 125/125 [==============================] - ETA: 0s - loss: 1.2655 - accuracy: 0.5493
# Epoch 6: val_loss improved from 1.37255 to 1.28282, saving model to FullModelCheckpoint.h5
# 125/125 [==============================] - 14s 110ms/step - loss: 1.2655 - accuracy: 0.5493 - val_loss: 1.2828 - val_accuracy: 0.5490
# Epoch 7/100
# 125/125 [==============================] - ETA: 0s - loss: 1.1837 - accuracy: 0.5844
# Epoch 7: val_loss did not improve from 1.28282
# 125/125 [==============================] - 13s 108ms/step - loss: 1.1837 - accuracy: 0.5844 - val_loss: 1.3297 - val_accuracy: 0.5495
# Epoch 8/100
# 125/125 [==============================] - ETA: 0s - loss: 1.0799 - accuracy: 0.6226
# Epoch 8: val_loss improved from 1.28282 to 1.24435, saving model to FullModelCheckpoint.h5
# 125/125 [==============================] - 13s 106ms/step - loss: 1.0799 - accuracy: 0.6226 - val_loss: 1.2443 - val_accuracy: 0.5585
# Epoch 9/100
val_loss did not improve from 1.23894
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0957 - accuracy: 0.9686 - val_loss: 3.7708 - val_accuracy: 0.5190
# Epoch 98/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9699
# Epoch 98: val_loss did not improve from 1.23894
# 125/125 [==============================] - 14s 116ms/step - loss: 0.0984 - accuracy: 0.9699 - val_loss: 3.4374 - val_accuracy: 0.5365
# Epoch 99/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9695
# Epoch 99: val_loss did not improve from 1.23894
# 125/125 [==============================] - 14s 115ms/step - loss: 0.0970 - accuracy: 0.9695 - val_loss: 3.6707 - val_accuracy: 0.5290
# Epoch 100/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9761
# Epoch 100: val_loss did not improve from 1.23894
# 125/125 [==============================] - 14s 113ms/step - loss: 0.0753 - accuracy: 0.9761 - val_loss: 3.6300 - val_accuracy: 0.5385
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 3.9302046298980713, 'accuracy': 0.5254999995231628}
# ----------------------------------------------------------------------------------------------------

# %%
def train(model,X_train, Y_train):
    
    X_train, Y_train = shuffle(X_train, Y_train)
    
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    
    early_stopping = keras.callbacks.EarlyStopping(patience=15, verbose=1)

    print(f"Starting to train with {len(Y_train)} samples")

    history = model.fit(X_train, Y_train, batch_size = 64, epochs=20,validation_split=.20,
                        callbacks=[checkpoint,early_stopping],
    )
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["accuracy"],
        history.history["val_accuracy"],
    )

    return model

# %%
def test(model, X_test, Y_test):
    print("-" * 100)
    print("Test set evaluation: ", model.evaluate( X_test, Y_test , verbose=0, return_dict=True), )
    print("-" * 100)

# %%
from sklearn.metrics import confusion_matrix
import random

def train_active_learning_models(
    X_train,
    Y_train,
    x_unlab,
    y_unlab,
    X_test,
    Y_test,
    num_iterations=5
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="categorical_crossentropy",
        optimizer="Adam",
        metrics='accuracy',
    )
    
    model = train(model,X_train, Y_train)
    
    d = 100/num_iterations
    l = len(y_unlab)
    x = int(np.round( l/d ))
    
    for iteration in range(num_iterations-1):
        
        l = len(y_unlab)
        
        print("\n\n")
        
        print("Iteration : ")
        
        print(iteration)
        
        print("\n\n")
         
        #generate random number and substract from all numbers
        rnd = random.sample(range(1, l), x)
        all = list(range(1, l))
        main_list = list(set(all) - set(rnd))
        
        #add those index to from unlablled set to training set
        new_lab = x_unlab[rnd]
        arr = np.concatenate((X_train, new_lab))
        X_train = arr

        #predict on the set and add to training data
        new_y = np.round(model.predict(new_lab))
        arr = np.concatenate((Y_train, new_y))
        Y_train = arr
        
        
        #create the new unlabelled set
        x_unlab = x_unlab[main_list]

        #create the new unlabelled label set
        y_unlab = y_unlab[main_list]
        
        #test on data
        test(model, X_test, Y_test)
        
        #train on data
        model = train(model,X_train, Y_train)
        
    #Final round training set
    arr = np.concatenate((X_train, x_unlab))
    X_train = arr

    #Final round training label set
    new_y = np.round(model.predict(x_unlab))
    arr = np.concatenate((Y_train, new_y))
    Y_train = arr
    
    #train final
    model = train(model,X_train, Y_train)
    
    #test for final time
    test(model, X_test, Y_test)
        
    #return model
    return model

active_learning_model = train_active_learning_models(X_train,Y_train,x_unlab,y_unlab,X_test,Y_test,num_iterations=5)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_50 (Conv2D)          (None, 30, 30, 32)        896
#
#  conv2d_51 (Conv2D)          (None, 28, 28, 32)        9248
#
#  max_pooling2d_30 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_52 (Conv2D)          (None, 12, 12, 64)        18496
#
#  conv2d_53 (Conv2D)          (None, 10, 10, 64)        36928
#
#  max_pooling2d_31 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 3, 3, 128)         73856
#
#  max_pooling2d_32 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_10 (Flatten)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 32)                4128
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_21 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 143,882
# Trainable params: 143,882
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 10000 samples
# Epoch 1/100
# 125/125 [==============================] - ETA: 0s - loss: 1.9497 - accuracy: 0.2772
# Epoch 1: val_loss improved from inf to 1.68999, saving model to AL_Model.h5
# 125/125 [==============================] - 24s 159ms/step - loss: 1.9497 - accuracy: 0.2772 - val_loss: 1.6900 - val_accuracy: 0.3860
# Epoch 2/100
# 125/125 [==============================] - ETA: 0s - loss: 1.6438 - accuracy: 0.3899
# Epoch 2: val_loss improved from 1.68999 to 1.51546, saving model to AL_Model.h5
# 125/125 [==============================] - 20s 161ms/step - loss: 1.6438 - accuracy: 0.3899 - val_loss: 1.5155 - val_accuracy: 0.4485
# Epoch 3/100
# 125/125 [==============================] - ETA: 0s - loss: 1.4863 - accuracy: 0.4605
# Epoch 3: val_loss improved from 1.51546 to 1.37912, saving model to AL_Model.h5
# 125/125 [==============================] - 19s 148ms/step - loss: 1.4863 - accuracy: 0.4605 - val_loss: 1.3791 - val_accuracy: 0.5035
# Epoch 4/100
# 125/125 [==============================] - ETA: 0s - loss: 1.3776 - accuracy: 0.5029
# Epoch 4: val_loss improved from 1.37912 to 1.31100, saving model to AL_Model.h5
# 125/125 [==============================] - 17s 137ms/step - loss: 1.3776 - accuracy: 0.5029 - val_loss: 1.3110 - val_accuracy: 0.5275
# Epoch 5/100
# 125/125 [==============================] - ETA: 0s - loss: 1.2714 - accuracy: 0.5429
# Epoch 5: val_loss improved from 1.31100 to 1.29652, saving model to AL_Model.h5
# 125/125 [==============================] - 16s 129ms/step - loss: 1.2714 - accuracy: 0.5429 - val_loss: 1.2965 - val_accuracy: 0.5355
# Epoch 6/100
# 125/125 [==============================] - ETA: 0s - loss: 1.2026 - accuracy: 0.5674
# Epoch 6: val_loss improved from 1.29652 to 1.28756, saving model to AL_Model.h5
# 125/125 [==============================] - 16s 125ms/step - loss: 1.2026 - accuracy: 0.5674 - val_loss: 1.2876 - val_accuracy: 0.5515
# Epoch 7/100
# 125/125 [==============================] - ETA: 0s - loss: 1.1065 - accuracy: 0.6033
# Epoch 7: val_loss improved from 1.28756 to 1.27718, saving model to AL_Model.h5
# 125/125 [==============================] - 16s 126ms/step - loss: 1.1065 - accuracy: 0.6033 - val_loss: 1.2772 - val_accuracy: 0.5430
100
# 125/125 [==============================] - ETA: 0s - loss: 0.3466 - accuracy: 0.8788
# Epoch 21: val_loss did not improve from 1.25535
# 125/125 [==============================] - 16s 130ms/step - loss: 0.3466 - accuracy: 0.8788 - val_loss: 1.8174 - val_accuracy: 0.5650
# Epoch 22/100
# 125/125 [==============================] - ETA: 0s - loss: 0.3241 - accuracy: 0.8899
# Epoch 22: val_loss did not improve from 1.25535
# 125/125 [==============================] - 17s 138ms/step - loss: 0.3241 - accuracy: 0.8899 - val_loss: 1.9596 - val_accuracy: 0.5455
# Epoch 23/100
# 125/125 [==============================] - ETA: 0s - loss: 0.3078 - accuracy: 0.8925
# Epoch 23: val_loss did not improve from 1.25535
# 125/125 [==============================] - 16s 131ms/step - loss: 0.3078 - accuracy: 0.8925 - val_loss: 2.1358 - val_accuracy: 0.5385
# Epoch 24/100
# 125/125 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.9026
# Epoch 24: val_loss did not improve from 1.25535
# 125/125 [==============================] - 16s 129ms/step - loss: 0.2780 - accuracy: 0.9026 - val_loss: 2.1596 - val_accuracy: 0.5390
# Epoch 25/100
# 125/125 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9066
# Epoch 25: val_loss did not improve from 1.25535
# 125/125 [==============================] - 16s 124ms/step - loss: 0.2722 - accuracy: 0.9066 - val_loss: 2.1219 - val_accuracy: 0.5570
# Epoch 25: early stopping
# Iteration :
# 0
#
#
#
# 47/47 [==============================] - 1s 18ms/step
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 2.2021324634552, 'accuracy': 0.5498999953269958}
# ----------------------------------------------------------------------------------------------------
# Starting to train with 11500 samples
# Epoch 1/100
# 144/144 [==============================] - ETA: 0s - loss: 0.7465 - accuracy: 0.7662
# Epoch 1: val_loss improved from inf to 0.51626, saving model to AL_Model.h5
# 144/144 [==============================] - 19s 131ms/step - loss: 0.7465 - accuracy: 0.7662 - val_loss: 0.5163 - val_accuracy: 0.8383
# Epoch 2/100
# 144/144 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.8263
# Epoch 2: val_loss improved from 0.51626 to 0.50567, saving model to AL_Model.h5
# 144/144 [==============================] - 15s 105ms/step - loss: 0.5009 - accuracy: 0.8263 - val_loss: 0.5057 - val_accuracy: 0.8439
# Epoch 3/100
# 144/144 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8616
# Epoch 3: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 104ms/step - loss: 0.3989 - accuracy: 0.8616 - val_loss: 0.5151 - val_accuracy: 0.8413
# Epoch 4/100
# 144/144 [==============================] - ETA: 0s - loss: 0.3608 - accuracy: 0.8641
# Epoch 4: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 101ms/step - loss: 0.3608 - accuracy: 0.8641 - val_loss: 0.5492 - val_accuracy: 0.8204
# Epoch 5/100
# 144/144 [==============================] - ETA: 0s - loss: 0.3456 - accuracy: 0.8709
# Epoch 5: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 103ms/step - loss: 0.3456 - accuracy: 0.8709 - val_loss: 0.5899 - val_accuracy: 0.8170
# Epoch 6/100
# 144/144 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.8855
# Epoch 6: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 104ms/step - loss: 0.3053 - accuracy: 0.8855 - val_loss: 0.6493 - val_accuracy: 0.7983
# Epoch 7/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.8880
# Epoch 7: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2913 - accuracy: 0.8880 - val_loss: 0.7051 - val_accuracy: 0.7787
# Epoch 8/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.8897
# Epoch 8: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 103ms/step - loss: 0.2869 - accuracy: 0.8897 - val_loss: 0.6754 - val_accuracy: 0.8013
# Epoch 9/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.9048
# Epoch 9: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 102ms/step - loss: 0.2435 - accuracy: 0.9048 - val_loss: 0.7538 - val_accuracy: 0.7648
# Epoch 10/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.9009
# Epoch 10: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 105ms/step - loss: 0.2599 - accuracy: 0.9009 - val_loss: 0.7367 - val_accuracy: 0.7765
# Epoch 11/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9076
# Epoch 11: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 106ms/step - loss: 0.2242 - accuracy: 0.9076 - val_loss: 0.7828 - val_accuracy: 0.7709
# Epoch 12/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9139
# Epoch 12: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 106ms/step - loss: 0.2241 - accuracy: 0.9139 - val_loss: 0.8044 - val_accuracy: 0.7617
# Epoch 13/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2244 - accuracy: 0.9120
# Epoch 13: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 106ms/step - loss: 0.2244 - accuracy: 0.9120 - val_loss: 0.8365 - val_accuracy: 0.7539
# Epoch 14/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9098
# Epoch 14: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 107ms/step - loss: 0.2261 - accuracy: 0.9098 - val_loss: 0.8379 - val_accuracy: 0.7565
# Epoch 15/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2128 - accuracy: 0.9189
# Epoch 15: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 107ms/step - loss: 0.2128 - accuracy: 0.9189 - val_loss: 0.8502 - val_accuracy: 0.7448
# Epoch 16/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9165
# Epoch 16: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 106ms/step - loss: 0.2104 - accuracy: 0.9165 - val_loss: 0.9863 - val_accuracy: 0.7239
# Epoch 17/100
# 144/144 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9201
# Epoch 17: val_loss did not improve from 0.50567
# 144/144 [==============================] - 15s 106ms/step - loss: 0.2138 - accuracy: 0.9201 - val_loss: 0.8977 - val_accuracy: 0.7443
# Epoch 17: early stopping
# Iteration :
# 1
#
#
#
# 47/47 [==============================] - 1s 12ms/step
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 2.3720366954803467, 'accuracy': 0.5444999933242798}
# ----------------------------------------------------------------------------------------------------
# Starting to train with 13000 samples
# Epoch 1/100
# 163/163 [==============================] - ETA: 0s - loss: 0.5747 - accuracy: 0.8130
# Epoch 1: val_loss improved from inf to 0.37538, saving model to AL_Model.h5
# 163/163 [==============================] - 17s 107ms/step - loss: 0.5747 - accuracy: 0.8130 - val_loss: 0.3754 - val_accuracy: 0.8635
# Epoch 2/100
# 163/163 [==============================] - ETA: 0s - loss: 0.3770 - accuracy: 0.8546
# Epoch 2: val_loss improved from 0.37538 to 0.30703, saving model to AL_Model.h5
# 163/163 [==============================] - 17s 107ms/step - loss: 0.3770 - accuracy: 0.8546 - val_loss: 0.3070 - val_accuracy: 0.8850
# Epoch 3/100
# 163/163 [==============================] - ETA: 0s - loss: 0.3507 - accuracy: 0.8644
# Epoch 3: val_loss did not improve from 0.30703
# 163/163 [==============================] - 17s
val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 18s 101ms/step - loss: 352856091656192.0000 - accuracy: 0.1109 - val_loss: 374076317106176.0000 - val_accuracy: 0.1897
# Epoch 10/100
# 181/182 [============================>.] - ETA: 0s - loss: 536185327845376.0000 - accuracy: 0.1123
# Epoch 10: val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 18s 100ms/step - loss: 536390915850240.0000 - accuracy: 0.1122 - val_loss: 819549150642176.0000 - val_accuracy: 0.0903
# Epoch 11/100
# 181/182 [============================>.] - ETA: 0s - loss: 725949398122496.0000 - accuracy: 0.1105
# Epoch 11: val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 19s 102ms/step - loss: 725669822595072.0000 - accuracy: 0.1105 - val_loss: 702320098672640.0000 - val_accuracy: 0.0907
# Epoch 12/100
# 181/182 [============================>.] - ETA: 0s - loss: 918308501061632.0000 - accuracy: 0.1039
# Epoch 12: val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 18s 100ms/step - loss: 918594787475456.0000 - accuracy: 0.1037 - val_loss: 1122480777330688.0000 - val_accuracy: 0.0931
# Epoch 13/100
# 181/182 [============================>.] - ETA: 0s - loss: 1164208062332928.0000 - accuracy: 0.1064
# Epoch 13: val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 19s 102ms/step - loss: 1164082300321792.0000 - accuracy: 0.1063 - val_loss: 990650111623168.0000 - val_accuracy: 0.0872
# Epoch 14/100
# 181/182 [============================>.] - ETA: 0s - loss: 1709922848866304.0000 - accuracy: 0.1113
# Epoch 14: val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 19s 103ms/step - loss: 1708913665769472.0000 - accuracy: 0.1113 - val_loss: 1416696170545152.0000 - val_accuracy: 0.0903
# Epoch 15/100
# 181/182 [============================>.] - ETA: 0s - loss: 1928919204757504.0000 - accuracy: 0.1108
# Epoch 15: val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 19s 104ms/step - loss: 1928871557464064.0000 - accuracy: 0.1107 - val_loss: 1707030456827904.0000 - val_accuracy: 0.1897
# Epoch 16/100
# 181/182 [============================>.] - ETA: 0s - loss: 2339443453198336.0000 - accuracy: 0.1126
# Epoch 16: val_loss did not improve from 9510920912896.00000
# 182/182 [==============================] - 19s 104ms/step - loss: 2339926637019136.0000 - accuracy: 0.1124 - val_loss: 1898663978729472.0000 - val_accuracy: 0.1897
# Epoch 16: early stopping
# Iteration :
# 3
#
#
#
# 47/47 [==============================] - 1s 12ms/step
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 2207665400840192.0, 'accuracy': 0.09769999980926514}
# ----------------------------------------------------------------------------------------------------
# Starting to train with 16000 samples
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 3198303499976704.0000 - accuracy: 0.1342
# Epoch 1: val_loss improved from inf to 4383322021036032.00000, saving model to AL_Model.h5
# 200/200 [==============================] - 21s 104ms/step - loss: 3198303499976704.0000 - accuracy: 0.1342 - val_loss: 4383322021036032.0000 - val_accuracy: 0.0816
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 4361913219678208.0000 - accuracy: 0.1330
# Epoch 2: val_loss improved from 4383322021036032.00000 to 2718893881688064.00000, saving model to AL_Model.h5
# 200/200 [==============================] - 21s 105ms/step - loss: 4361913219678208.0000 - accuracy: 0.1330 - val_loss: 2718893881688064.0000 - val_accuracy: 0.0819
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 4910894597275648.0000 - accuracy: 0.1307
# Epoch 3: val_loss did not improve from 2718893881688064.00000
# 200/200 [==============================] - 21s 105ms/step - loss: 4910894597275648.0000 - accuracy: 0.1307 - val_loss: 5532173964673024.0000 - val_accuracy: 0.1034
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss:
# Epoch 1: val_loss improved from inf to 36933991441367040.00000, saving model to AL_Model.h5
# 500/500 [==============================] - 51s 103ms/step - loss: 47200208819322880.0000 - accuracy: 0.4141 - val_loss: 36933991441367040.0000 - val_accuracy: 0.6384
# Epoch 2/100
# 500/500 [==============================] - ETA: 0s - loss: 54805079777083392.0000 - accuracy: 0.4098
# Epoch 2: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 54s 107ms/step - loss: 54805079777083392.0000 - accuracy: 0.4098 - val_loss: 59603284096188416.0000 - val_accuracy: 0.6384
# Epoch 3/100
# 500/500 [==============================] - ETA: 0s - loss: 63135370711138304.0000 - accuracy: 0.4145
# Epoch 3: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 52s 104ms/step - loss: 63135370711138304.0000 - accuracy: 0.4145 - val_loss: 49506876840214528.0000 - val_accuracy: 0.6384
# Epoch 4/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.4115
# Epoch 4: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 53s 107ms/step - loss: nan - accuracy: 0.4115 - val_loss: nan - val_accuracy: 0.0353
# Epoch 5/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 5: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 53s 105ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 6/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 6: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 53s 106ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 7/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 7: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 52s 104ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 8/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 8: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 52s 105ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 9/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 9: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 53s 105ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 10/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 10: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 53s 105ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 11/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 11: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 52s 103ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 12/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 12: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 53s 106ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 13/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 13: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 52s 103ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 14/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 14: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 51s 103ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 15/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 15: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 52s 104ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 16/100
# 500/500 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0404
# Epoch 16: val_loss did not improve from 36933991441367040.00000
# 500/500 [==============================] - 52s 104ms/step - loss: nan - accuracy: 0.0404 - val_loss: nan - val_accuracy: 0.0353
# Epoch 16: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': nan, 'accuracy': 0.1023000031709671}
# ----------------------------------------------------------------------------------------------------
