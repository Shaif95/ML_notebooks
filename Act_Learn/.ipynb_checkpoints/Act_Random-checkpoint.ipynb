# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections

from glob import glob
import numpy as np
import pandas as pd
#import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns
import shutil
import keras
from PIL import Image
#import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()
from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
from glob import glob
trn1='D:/INV/data/invasive-aquatic-species-data/invasive/*/'
trn2='D:/INV/data/invasive-aquatic-species-data/noninvasive/*/'
tr1= glob(trn1)
tr2= glob(trn2)
tr1= shuffle(tr1)
tr2= shuffle(tr2)

tran_index_inv = np.round( len(tr1)* .99 )
tran_index_noninv = np.round( len(tr2)* .99  )
tran_index_noninv
# Out:
# 3663.0

# %%
data = []
label = []
for i in tr1[:(int) (tran_index_inv)]:
    for j in glob(i+'/*'):
        data.append(j)
        label.append(1)


for i in tr2[:(int)(tran_index_noninv)]:
    for j in glob(i+'/*'):
        data.append(j)
        label.append(0)

imgdata=[]
for i in range(len(data)):
    a = Image.open(data[i])
    b = a.resize((20, 20))
    c = np.array(b)
    imgdata.append(c.reshape(20,20,3))

# %%
from tensorflow.keras.utils import to_categorical
idata = np.array(imgdata)
train_df = idata
train_df = train_df.astype('float32') / 255.
train_df = np.reshape(train_df, (len(train_df),20,20,3))
YY_train = to_categorical(label)

train_df,YY_train = shuffle(train_df,YY_train)

# %%
x_train, x_unlab, y_train, y_unlab = train_test_split( train_df,YY_train , test_size=0.8, random_state=42 )

# %%
X_train, X_test, Y_train, Y_test = train_test_split( x_train,y_train , test_size=0.5, random_state=41 )

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["accuracy"]
    val_accuracy = val_accuracy + history.history["val_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'num_patches': self.num_patches,
            'projection': self.projection,
            'position_embedding': self.position_embedding
        })
        return config

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection =keras.Sequential(
            [
                (layers.Conv2D(4, (3, 3), strides=(2,2),activation='relu')),
                TimeDistributed(Flatten()),
                layers.LSTM(projection_dim,return_sequences=True,dropout=0.1),
            ]) 
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE

def create_model():
    
    
    model = models.Sequential()
    model.add(layers.Conv2D(2, (3, 3), input_shape=(20, 20, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten()) 
    model.add(layers.Dense(16))
    model.add(layers.Dense(2, activation="softmax"))

    model.summary()
    return model

# %%
# callbacks=[keras.callbacks.EarlyStopping(patience=4, verbose=1), ],

def train_full_model(X_train, X_test, Y_train, Y_test):
    model = create_model()
    model.compile( loss="categorical_crossentropy",  optimizer="Adam",  metrics='accuracy' )

    history = model.fit( X_train, Y_train, batch_size = 256, epochs=10,
                        validation_split=.30,callbacks=[ keras.callbacks.EarlyStopping(patience=2, verbose=1),
                        keras.callbacks.ModelCheckpoint( "FullModelCheckpoint.h5",
                        verbose=1, save_best_only=True ), ], )

    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["accuracy"],
        history.history["val_accuracy"],
    )


    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate( X_test, Y_test , verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


full_dataset_model = train_full_model(X_train, X_test, Y_train, Y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 18, 18, 2)         56
#
#  max_pooling2d (MaxPooling2D  (None, 9, 9, 2)          0
#  )
#
#  flatten (Flatten)           (None, 162)               0
#
#  dense (Dense)               (None, 16)                2608
#
#  dense_1 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 2,698
# Trainable params: 2,698
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 30/31 [============================>.] - ETA: 0s - loss: 0.4414 - accuracy: 0.8257
# Epoch 1: val_loss improved from inf to 0.39349, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 24ms/step - loss: 0.4403 - accuracy: 0.8257 - val_loss: 0.3935 - val_accuracy: 0.8361
# Epoch 2/10
# 30/31 [============================>.] - ETA: 0s - loss: 0.3632 - accuracy: 0.8311
# Epoch 2: val_loss improved from 0.39349 to 0.33216, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3636 - accuracy: 0.8306 - val_loss: 0.3322 - val_accuracy: 0.8489
# Epoch 3/10
# 31/31 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.8533
# Epoch 3: val_loss improved from 0.33216 to 0.28302, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3053 - accuracy: 0.8533 - val_loss: 0.2830 - val_accuracy: 0.8638
# Epoch 4/10
# 28/31 [==========================>...] - ETA: 0s - loss: 0.2698 - accuracy: 0.8722
# Epoch 4: val_loss improved from 0.28302 to 0.26669, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2716 - accuracy: 0.8702 - val_loss: 0.2667 - val_accuracy: 0.8713
# Epoch 5/10
# 30/31 [============================>.] - ETA: 0s - loss: 0.2526 - accuracy: 0.8807
# Epoch 5: val_loss improved from 0.26669 to 0.25086, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2529 - accuracy: 0.8806 - val_loss: 0.2509 - val_accuracy: 0.8818
# Epoch 6/10
# 28/31 [==========================>...] - ETA: 0s - loss: 0.2457 - accuracy: 0.8836
# Epoch 6: val_loss improved from 0.25086 to 0.24418, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2450 - accuracy: 0.8842 - val_loss: 0.2442 - val_accuracy: 0.8907
# Epoch 7/10
# 30/31 [============================>.] - ETA: 0s - loss: 0.2385 - accuracy: 0.8867
# Epoch 7: val_loss improved from 0.24418 to 0.24061, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2386 - accuracy: 0.8867 - val_loss: 0.2406 - val_accuracy: 0.8916
# Epoch 8/10
# 31/31 [==============================] - ETA: 0s - loss: 0.2369 - accuracy: 0.8885
# Epoch 8: val_loss improved from 0.24061 to 0.23880, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2369 - accuracy: 0.8885 - val_loss: 0.2388 - val_accuracy: 0.8961
# Epoch 9/10
# 30/31 [============================>.] - ETA: 0s - loss: 0.2338 - accuracy: 0.8915
# Epoch 9: val_loss did not improve from 0.23880
# 31/31 [==============================] - 0s 16ms/step - loss: 0.2333 - accuracy: 0.8916 - val_loss: 0.2421 - val_accuracy: 0.8967
# Epoch 10/10
# 28/31 [==========================>...] - ETA: 0s - loss: 0.2329 - accuracy: 0.8945
# Epoch 10: val_loss improved from 0.23880 to 0.23700, saving model to FullModelCheckpoint.h5
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2331 - accuracy: 0.8947 - val_loss: 0.2370 - val_accuracy: 0.8973
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.22453179955482483, 'accuracy': 0.8994894027709961}
# ----------------------------------------------------------------------------------------------------

# %%
def train(model,X_train, Y_train):
    
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    
    early_stopping = keras.callbacks.EarlyStopping(patience=8, verbose=1)

    print(f"Starting to train with {len(Y_train)} samples")

    history = model.fit(X_train, Y_train, batch_size = 256, epochs=10,validation_split=.20,
                        callbacks=[checkpoint],
    )
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["accuracy"],
        history.history["val_accuracy"],
    )

    return model

# %%
def test(model, X_test, Y_test):
    print("-" * 100)
    print("Test set evaluation: ", model.evaluate( X_test, Y_test , verbose=0, return_dict=True), )
    print("-" * 100)

# %%
from sklearn.metrics import confusion_matrix
import random

def train_active_learning_models(
    X_train,
    Y_train,
    x_unlab,
    y_unlab,
    X_test,
    Y_test,
    num_iterations=5
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="categorical_crossentropy",
        optimizer="Adam",
        metrics='accuracy',
    )
    
    model = train(model,X_train, Y_train)
    
    l = len(y_unlab)
    x = int(np.round( l/20 ))
    
    for iteration in range(num_iterations-1):
        
        l = len(y_unlab)
        
        print("\n\n")
        
        print("Iteration : ")
        
        print(iteration)
        
        print("\n\n")
         
        #generate random number and substract from all numbers
        rnd = random.sample(range(1, l), x)
        all = list(range(1, l))
        main_list = list(set(all) - set(rnd))
        
        #add those index to from unlablled set to training set
        new_lab = x_unlab[rnd]
        arr = np.concatenate((X_train, new_lab))
        X_train = arr

        #predict on the set and add to training data
        new_y = np.round(model.predict(new_lab))
        arr = np.concatenate((Y_train, new_y))
        Y_train = arr
        
        
        #create the new unlabelled set
        x_unlab = x_unlab[main_list]

        #create the new unlabelled label set
        y_unlab = y_unlab[main_list]
        
        #test on data
        test(model, X_test, Y_test)
        
        #train on data
        model = train(model,X_train, Y_train)
        
    #Final round training set
    arr = np.concatenate((X_train, x_unlab))
    X_train = arr

    #Final round training label set
    new_y = np.round(model.predict(x_unlab))
    arr = np.concatenate((Y_train, new_y))
    Y_train = arr
    
    #train final
    model = train(model,X_train, Y_train)
    
    #test for final time
    test(model, X_test, Y_test)
        
    #return model
    return model

active_learning_model = train_active_learning_models(X_train,Y_train,x_unlab,y_unlab,X_test,Y_test,num_iterations=5)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 18, 18, 2)         56
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 2)          0
#  2D)
#
#  flatten_3 (Flatten)         (None, 162)               0
#
#  dense_6 (Dense)             (None, 16)                2608
#
#  dense_7 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 2,698
# Trainable params: 2,698
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 11163 samples
# Epoch 1/10
# 35/35 [==============================] - ETA: 0s - loss: 0.5364 - accuracy: 0.7716
# Epoch 1: val_loss improved from inf to 0.46931, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 18ms/step - loss: 0.5364 - accuracy: 0.7716 - val_loss: 0.4693 - val_accuracy: 0.8356
# Epoch 2/10
# 31/35 [=========================>....] - ETA: 0s - loss: 0.4468 - accuracy: 0.8315
# Epoch 2: val_loss improved from 0.46931 to 0.41850, saving model to AL_Model.h5
# 35/35 [==============================] - 0s 14ms/step - loss: 0.4440 - accuracy: 0.8315 - val_loss: 0.4185 - val_accuracy: 0.8356
# Epoch 3/10
# 33/35 [===========================>..] - ETA: 0s - loss: 0.3868 - accuracy: 0.8313
# Epoch 3: val_loss improved from 0.41850 to 0.34780, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 16ms/step - loss: 0.3846 - accuracy: 0.8321 - val_loss: 0.3478 - val_accuracy: 0.8356
# Epoch 4/10
# 35/35 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.8535
# Epoch 4: val_loss improved from 0.34780 to 0.27825, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 19ms/step - loss: 0.3114 - accuracy: 0.8535 - val_loss: 0.2783 - val_accuracy: 0.8804
# Epoch 5/10
# 34/35 [============================>.] - ETA: 0s - loss: 0.2615 - accuracy: 0.8794
# Epoch 5: val_loss improved from 0.27825 to 0.24713, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2621 - accuracy: 0.8793 - val_loss: 0.2471 - val_accuracy: 0.8871
# Epoch 6/10
# 33/35 [===========================>..] - ETA: 0s - loss: 0.2429 - accuracy: 0.8875
# Epoch 6: val_loss improved from 0.24713 to 0.23614, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 18ms/step - loss: 0.2429 - accuracy: 0.8877 - val_loss: 0.2361 - val_accuracy: 0.8916
# Epoch 7/10
# 33/35 [===========================>..] - ETA: 0s - loss: 0.2332 - accuracy: 0.8930
# Epoch 7: val_loss improved from 0.23614 to 0.23253, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 22ms/step - loss: 0.2331 - accuracy: 0.8927 - val_loss: 0.2325 - val_accuracy: 0.8943
# Epoch 8/10
# 34/35 [============================>.] - ETA: 0s - loss: 0.2276 - accuracy: 0.8980
# Epoch 8: val_loss improved from 0.23253 to 0.23093, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 23ms/step - loss: 0.2286 - accuracy: 0.8975 - val_loss: 0.2309 - val_accuracy: 0.9001
# Epoch 9/10
# 34/35 [============================>.] - ETA: 0s - loss: 0.2307 - accuracy: 0.8977
# Epoch 9: val_loss improved from 0.23093 to 0.22880, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 23ms/step - loss: 0.2295 - accuracy: 0.8983 - val_loss: 0.2288 - val_accuracy: 0.8997
# Epoch 10/10
# 34/35 [============================>.] - ETA: 0s - loss: 0.2233 - accuracy: 0.9034
# Epoch 10: val_loss improved from 0.22880 to 0.22788, saving model to AL_Model.h5
# 35/35 [==============================] - 1s 23ms/step - loss: 0.2239 - accuracy: 0.9028 - val_loss: 0.2279 - val_accuracy: 0.9006
# Iteration :
# 0
#
#
#
# 140/140 [==============================] - 0s 2ms/step
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.2165796309709549, 'accuracy': 0.9043267965316772}
# ----------------------------------------------------------------------------------------------------
# Starting to train with 15628 samples
# Epoch 1/10
# 49/49 [==============================] - ETA: 0s - loss: 0.2103 - accuracy: 0.9116
# Epoch 1: val_loss improved from inf to 0.10561, saving model to AL_Model.h5
# 49/49 [==============================] - 1s 25ms/step - loss: 0.2103 - accuracy: 0.9116 - val_loss: 0.1056 - val_accuracy: 0.9814
# Epoch 2/10
# 48/49 [============================>.] - ETA: 0s - loss: 0.2099 - accuracy: 0.9133
# Epoch 2: val_loss did not improve from 0.10561
# 49/49 [==============================] - 1s 21ms/step - loss: 0.2093 - accuracy: 0.9135 - val_loss: 0.1075 - val_accuracy: 0.9926
# Epoch 3/10
# 47/49 [===========================>..] - ETA: 0s - loss: 0.2080 - accuracy: 0.9130
# Epoch 3: val_loss did not improve from 0.10561
# 49/49 [==============================] - 1s 22ms/step - loss: 0.2073 - accuracy: 0.9134 - val_loss: 0.1066 - val_accuracy: 0.9914
# Epoch 4/10
# 47/49 [===========================>..] - ETA: 0s - loss: 0.2078 - accuracy: 0.9155
# Epoch 4: val_loss improved from 0.10561 to 0.10382, saving model to AL_Model.h5
# 49/49 [==============================] - 1s 21ms/step - loss: 0.2073 - accuracy: 0.9155 - val_loss: 0.1038 - val_accuracy: 0.9885
# Epoch 5/10
# 47/49 [===========================>..] - ETA: 0s - loss: 0.2070 - accuracy: 0.9133
# Epoch 5: val_loss did not improve from 0.10382
# 49/49 [==============================] - 1s 19ms/step - loss: 0.2071 - accuracy: 0.9130 - val_loss: 0.1068 - val_accuracy: 0.9869
# Epoch 6/10
# 46/49 [===========================>..] - ETA: 0s - loss: 0.2051 - accuracy: 0.9176
# Epoch 6: val_loss did not improve from 0.10382
# 49/49 [==============================] - 1s 20ms/step - loss: 0.2046 - accuracy: 0.9175 - val_loss: 0.1050 - val_accuracy: 0.9846
# Epoch 7/10
# 49/49 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9166
# Epoch 7: val_loss did not improve from 0.10382
# 49/49 [==============================] - 1s 20ms/step - loss: 0.2037 - accuracy: 0.9166 - val_loss: 0.1070 - val_accuracy: 0.9821
# Epoch 8/10
# 46/49 [===========================>..] - ETA: 0s - loss: 0.2021 - accuracy: 0.9164
# Epoch 8: val_loss did not improve from 0.10382
# 49/49 [==============================] - 1s 21ms/step - loss: 0.2042 - accuracy: 0.9156 - val_loss: 0.1283 - val_accuracy: 0.9594
# Epoch 9/10
# 47/49 [===========================>..] - ETA: 0s - loss: 0.2042 - accuracy: 0.9164
# Epoch 9: val_loss did not improve from 0.10382
# 49/49 [==============================] - 1s 20ms/step - loss: 0.2041 - accuracy: 0.9166 - val_loss: 0.1076 - val_accuracy: 0.9808
# Epoch 10/10
# 48/49 [============================>.] - ETA: 0s - loss: 0.2023 - accuracy: 0.9158
# Epoch 10: val_loss did not improve from 0.10382
# 49/49 [==============================] - 1s 19ms/step - loss: 0.2018 - accuracy: 0.9157 - val_loss: 0.1092 - val_accuracy: 0.9789
# Iteration :
# 1
#
#
#
# 140/140 [==============================] - 0s 3ms/step
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.2064594179391861, 'accuracy': 0.909522533416748}
# ----------------------------------------------------------------------------------------------------
# Starting to train with 20093 samples
# Epoch 1/10
# 61/63 [============================>.] - ETA: 0s - loss: 0.1798 - accuracy: 0.9302
# Epoch 1: val_loss improved from inf to 0.09207, saving model to AL_Model.h5
# 63/63 [==============================] - 2s 24ms/step - loss: 0.1798 - accuracy: 0.9304 - val_loss: 0.0921 - val_accuracy: 0.9950
# Epoch 2/10
# 63/63 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9312
# Epoch 2: val_loss did not improve from 0.09207
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1789 - accuracy: 0.9312 - val_loss: 0.1007 - val_accuracy: 0.9791
# Epoch 3/10
# 61/63 [============================>.] - ETA: 0s - loss: 0.1788 - accuracy: 0.9303
# Epoch 3: val_loss improved from 0.09207 to 0.08644, saving model to AL_Model.h5
# 63/63 [==============================] - 1s 22ms/step - loss: 0.1788 - accuracy: 0.9301 - val_loss: 0.0864 - val_accuracy: 0.9895
# Epoch 4/10
# 61/63 [============================>.] - ETA: 0s - loss: 0.1770 - accuracy: 0.9312
# Epoch 4: val_loss improved from 0.08644 to 0.08581, saving model to AL_Model.h5
# 63/63 [==============================] - 1s 22ms/step - loss: 0.1778 - accuracy: 0.9308 - val_loss: 0.0858 - val_accuracy: 0.9898
# Epoch 5/10
# 61/63 [============================>.] - ETA: 0s - loss: 0.1794 - accuracy: 0.9301
# Epoch 5: val_loss improved from 0.08581 to 0.08557, saving model to AL_Model.h5
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1792 - accuracy: 0.9300 - val_loss: 0.0856 - val_accuracy: 0.9821
# Epoch 6/10
# 62/63 [============================>.] - ETA: 0s - loss: 0.1793 - accuracy: 0.9307
# Epoch 6: val_loss did not improve from 0.08557
# 63/63 [==============================] - 1s 20ms/step - loss: 0.1790 - accuracy: 0.9309 - val_loss: 0.0871 - val_accuracy: 0.9950
# Epoch 7/10
# 60/63 [===========================>..] - ETA: 0s - loss: 0.1765 - accuracy: 0.9314
# Epoch 7: val_loss improved from 0.08557 to 0.08493, saving model to AL_Model.h5
# 63/63 [==============================] - 1s 22ms/step - loss: 0.1773 - accuracy: 0.9311 - val_loss: 0.0849 - val_accuracy: 0.9886
# Epoch 8/10
# 62/63 [============================>.] - ETA: 0s - loss: 0.1774 - accuracy: 0.9312
# Epoch 8: val_loss did not improve from 0.08493
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1773 - accuracy: 0.9312 - val_loss: 0.0949 - val_accuracy: 0.9861
# Epoch 9/10
# 61/63 [============================>.] - ETA: 0s - loss: 0.1785 - accuracy: 0.9313
# Epoch 9: val_loss did not improve from 0.08493
# 63/63 [==============================] - 1s 20ms/step - loss: 0.1778 - accuracy: 0.9313 - val_loss: 0.0947 - val_accuracy: 0.9866
# Epoch 10/10
# 62/63 [============================>.] - ETA: 0s - loss: 0.1777 - accuracy: 0.9301
# Epoch 10: val_loss did not improve from 0.08493
# 63/63 [==============================] - 1s 20ms/step - loss: 0.1772 - accuracy: 0.9303 - val_loss: 0.0903 - val_accuracy: 0.9923
# Iteration :
# 2
#
#
#
# 140/140 [==============================] - 0s 2ms/step
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.20372842252254486, 'accuracy': 0.9119412302970886}
# ----------------------------------------------------------------------------------------------------
# Starting to train with 24558 samples
# Epoch 1/10
# 77/77 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9407
# Epoch 1: val_loss improved from inf to 0.08129, saving model to AL_Model.h5
# 77/77 [==============================] - 2s 19ms/step - loss: 0.1612 - accuracy: 0.9407 - val_loss: 0.0813 - val_accuracy: 0.9776
# Epoch 2/10
# 76/77 [============================>.] - ETA: 0s - loss: 0.1602 - accuracy: 0.9408
# Epoch 2: val_loss did not improve from 0.08129
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1605 - accuracy: 0.9408 - val_loss: 0.0945 - val_accuracy: 0.9780
# Epoch 3/10
# 76/77 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9418
# Epoch 3: val_loss improved from 0.08129 to 0.07918, saving model to AL_Model.h5
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1593 - accuracy: 0.9417 - val_loss: 0.0792 - val_accuracy: 0.9904
# Epoch 4/10
# 77/77 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9413
# Epoch 4: val_loss did not improve from 0.07918
# 77/77 [==============================] - 1s 18ms/step - loss: 0.1600 - accuracy: 0.9413 - val_loss: 0.0802 - val_accuracy: 0.9737
# Epoch 5/10
# 75/77 [============================>.] - ETA: 0s - loss: 0.1600 - accuracy: 0.9416
# Epoch 5: val_loss improved from 0.07918 to 0.07908, saving model to AL_Model.h5
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1600 - accuracy: 0.9414 - val_loss: 0.0791 - val_accuracy: 0.9886
# Epoch 6/10
# 75/77 [============================>.] - ETA: 0s - loss: 0.1618 - accuracy: 0.9381
# Epoch 6: val_loss did not improve from 0.07908
# 77/77 [==============================] - 2s 20ms/step - loss: 0.1622 - accuracy: 0.9380 - val_loss: 0.0809 - val_accuracy: 0.9762
# Epoch 7/10
# 75/77 [============================>.] - ETA: 0s - loss: 0.1580 - accuracy: 0.9409
# Epoch 7: val_loss improved from 0.07908 to 0.07787, saving model to AL_Model.h5
# 77/77 [==============================] - 1s 18ms/step - loss: 0.1591 - accuracy: 0.9404 - val_loss: 0.0779 - val_accuracy: 0.9805
# Epoch 8/10
# 77/77 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9407
# Epoch 8: val_loss did not improve from 0.07787
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1589 - accuracy: 0.9407 - val_loss: 0.0785 - val_accuracy: 0.9937
# Epoch 9/10
# 74/77 [===========================>..] - ETA: 0s - loss: 0.1580 - accuracy: 0.9423
# Epoch 9: val_loss did not improve from 0.07787
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1582 - accuracy: 0.9422 - val_loss: 0.0786 - val_accuracy: 0.9910
# Epoch 10/10
# 76/77 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9414
# Epoch 10: val_loss improved from 0.07787 to 0.07738, saving model to AL_Model.h5
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1593 - accuracy: 0.9412 - val_loss: 0.0774 - val_accuracy: 0.9853
# Iteration :
# 3
#
#
#
# 140/140 [==============================] - 0s 2ms/step
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.20999811589717865, 'accuracy': 0.91032874584198}
# ----------------------------------------------------------------------------------------------------
# Starting to train with 29023 samples
# Epoch 1/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9480
# Epoch 1: val_loss improved from inf to 0.07036, saving model to AL_Model.h5
# 91/91 [==============================] - 2s 20ms/step - loss: 0.1474 - accuracy: 0.9480 - val_loss: 0.0704 - val_accuracy: 0.9935
# Epoch 2/10
# 90/91 [============================>.] - ETA: 0s - loss: 0.1468 - accuracy: 0.9479
# Epoch 2: val_loss did not improve from 0.07036
# 91/91 [==============================] - 2s 20ms/step - loss: 0.1468 - accuracy: 0.9480 - val_loss: 0.0797 - val_accuracy: 0.9833
# Epoch 3/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9475
# Epoch 3: val_loss did not improve from 0.07036
# 91/91 [==============================] - 2s 18ms/step - loss: 0.1484 - accuracy: 0.9475 - val_loss: 0.0721 - val_accuracy: 0.9935
# Epoch 4/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9496
# Epoch 4: val_loss did not improve from 0.07036
# 91/91 [==============================] - 2s 18ms/step - loss: 0.1469 - accuracy: 0.9496 - val_loss: 0.0763 - val_accuracy: 0.9867
# Epoch 5/10
# 90/91 [============================>.] - ETA: 0s - loss: 0.1471 - accuracy: 0.9462
# Epoch 5: val_loss did not improve from 0.07036
# 91/91 [==============================] - 2s 19ms/step - loss: 0.1468 - accuracy: 0.9462 - val_loss: 0.0910 - val_accuracy: 0.9681
# Epoch 6/10
# 89/91 [============================>.] - ETA: 0s - loss: 0.1470 - accuracy: 0.9473
# Epoch 6: val_loss improved from 0.07036 to 0.06870, saving model to AL_Model.h5
# 91/91 [==============================] - 2s 19ms/step - loss: 0.1476 - accuracy: 0.9469 - val_loss: 0.0687 - val_accuracy: 0.9914
# Epoch 7/10
# 89/91 [============================>.] - ETA: 0s - loss: 0.1457 - accuracy: 0.9491
# Epoch 7: val_loss did not improve from 0.06870
# 91/91 [==============================] - 2s 19ms/step - loss: 0.1452 - accuracy: 0.9492 - val_loss: 0.0707 - val_accuracy: 0.9933
# Epoch 8/10
# 90/91 [============================>.] - ETA: 0s - loss: 0.1464 - accuracy: 0.9482
# Epoch 8: val_loss did not improve from 0.06870
# 91/91 [==============================] - 2s 21ms/step - loss: 0.1463 - accuracy: 0.9483 - val_loss: 0.0778 - val_accuracy: 0.9850
# Epoch 9/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9470
# Epoch 9: val_loss did not improve from 0.06870
# 91/91 [==============================] - 2s 18ms/step - loss: 0.1468 - accuracy: 0.9470 - val_loss: 0.0747 - val_accuracy: 0.9902
# Epoch 10/10
# 89/91 [============================>.] - ETA: 0s - loss: 0.1455 - accuracy: 0.9492
# Epoch 10: val_loss did not improve from 0.06870
# 91/91 [==============================] - 2s 19ms/step - loss: 0.1452 - accuracy: 0.9492 - val_loss: 0.0741 - val_accuracy: 0.9895
# 13396/13396 [==============================] - 31s 2ms/step
# Starting to train with 457694 samples
# Epoch 1/10
# 1430/1431 [============================>.] - ETA: 0s - loss: 0.0449 - accuracy: 0.9892
# Epoch 1: val_loss improved from inf to 0.02301, saving model to AL_Model.h5
# 1431/1431 [==============================] - 38s 26ms/step - loss: 0.0449 - accuracy: 0.9892 - val_loss: 0.0230 - val_accuracy: 0.9972
# Epoch 2/10
# 1428/1431 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9909
# Epoch 2: val_loss did not improve from 0.02301
# 1431/1431 [==============================] - 29s 20ms/step - loss: 0.0397 - accuracy: 0.9909 - val_loss: 0.0269 - val_accuracy: 0.9874
# Epoch 3/10
# 1428/1431 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9906
# Epoch 3: val_loss improved from 0.02301 to 0.02015, saving model to AL_Model.h5
# 1431/1431 [==============================] - 29s 20ms/step - loss: 0.0399 - accuracy: 0.9906 - val_loss: 0.0201 - val_accuracy: 0.9977
# Epoch 4/10
# 1431/1431 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9911
# Epoch 4: val_loss did not improve from 0.02015
# 1431/1431 [==============================] - 30s 21ms/step - loss: 0.0395 - accuracy: 0.9911 - val_loss: 0.0221 - val_accuracy: 0.9923
# Epoch 5/10
# 1429/1431 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9914
# Epoch 5: val_loss did not improve from 0.02015
# 1431/1431 [==============================] - 30s 21ms/step - loss: 0.0392 - accuracy: 0.9915 - val_loss: 0.0231 - val_accuracy: 0.9930
# Epoch 6/10
# 1430/1431 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9910
# Epoch 6: val_loss improved from 0.02015 to 0.01970, saving model to AL_Model.h5
# 1431/1431 [==============================] - 33s 23ms/step - loss: 0.0392 - accuracy: 0.9910 - val_loss: 0.0197 - val_accuracy: 0.9978
# Epoch 7/10
# 1429/1431 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9912
# Epoch 7: val_loss did not improve from 0.01970
# 1431/1431 [==============================] - 30s 21ms/step - loss: 0.0392 - accuracy: 0.9912 - val_loss: 0.0237 - val_accuracy: 0.9918
# Epoch 8/10
# 1431/1431 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9916
# Epoch 8: val_loss did not improve from 0.01970
# 1431/1431 [==============================] - 31s 22ms/step - loss: 0.0390 - accuracy: 0.9916 - val_loss: 0.0209 - val_accuracy: 0.9952
# Epoch 9/10
# 1430/1431 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9919
# Epoch 9: val_loss did not improve from 0.01970
# 1431/1431 [==============================] - 32s 22ms/step - loss: 0.0387 - accuracy: 0.9919 - val_loss: 0.0324 - val_accuracy: 0.9842
# Epoch 10/10
# 1431/1431 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9916
# Epoch 10: val_loss improved from 0.01970 to 0.01904, saving model to AL_Model.h5
# 1431/1431 [==============================] - 31s 22ms/step - loss: 0.0388 - accuracy: 0.9916 - val_loss: 0.0190 - val_accuracy: 0.9967
