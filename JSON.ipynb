# %%
import glob
from glob import glob
import json

with open("E:/resp.json", 'r', encoding="utf8") as f:

  data = json.load(f)
data[7]
# Out:
# {'uuid': 'a844020f-384e-4f64-96f7-fcbffdfb377a',
#  'name': 'Python',
#  'topics': [{'uuid': 'c49bf5b2-a3a7-45a4-9e6f-08828377d437',
#    'name': 'Getting started with Python',
#    'lessons': [{'uuid': 'b992e1de-20d8-470e-8921-2f1d63c69625',
# ...

# %%
# Out:
# {'uuid': 'c352d14f-59c1-457b-b06e-207ef3ae215f',
#  'name': 'HTML',
#  'topics': [{'uuid': '9ea1fe84-08c6-4bbe-ba9b-df4bb020a815',
#    'name': 'Tags and attributes',
#    'lessons': [{'uuid': 'f22a9eda-5416-4772-9484-501702a4ec90',
# ...

# %%
data[7]
# Out:
# {'uuid': 'a844020f-384e-4f64-96f7-fcbffdfb377a',
#  'name': 'Python',
#  'topics': [{'uuid': 'c49bf5b2-a3a7-45a4-9e6f-08828377d437',
#    'name': 'Comenzando con Python',
#    'lessons': [{'uuid': 'b992e1de-20d8-470e-8921-2f1d63c69625',
# ...
