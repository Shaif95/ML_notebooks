# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json
import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns
import shutil
import keras
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16

# %%
from glob import glob
trn1='D:/Inv_Data_Imbalance/data/invasive-aquatic-species-data/invasive/*/'
trn2='D:/Inv_Data_Imbalance/data/invasive-aquatic-species-data/noninvasive/*/'
tr1= glob(trn1)
tr2= glob(trn2)

# %%
from glob import glob
import cv2
from PIL import Image, ImageStat
import math
trn1='D:/Inv_Data_Imbalance/newdata/To Baylor 2022-02-03/To Baylor 2022-02-03/Davis Dam Preserved Sample 2020-07-24/2022-01-29_6th_Vel_2c_No_NR/Veligers/*/'
trn2='D:/Inv_Data_Imbalance/newdata/To Baylor 2022-02-03/To Baylor 2022-02-03/Davis Dam Preserved Sample 2020-07-24/2022-01-29_6th_Vel_2c_No_NR/Non-Veligers/*/'
tr1= glob(trn1)
tr2= glob(trn2)

# %%
from glob import glob
import cv2
from PIL import Image, ImageStat
import math
trn1='D:/Inv_Data_Imbalance/newdata/To Baylor 2022-02-03/To Baylor 2022-02-03/Davis Dam Preserved Sample 2020-07-24/2022-01-29_6th_Vel_3b_No_NR/Veligers/*/'
trn2='D:/Inv_Data_Imbalance/newdata/To Baylor 2022-02-03/To Baylor 2022-02-03/Davis Dam Preserved Sample 2020-07-24/2022-01-29_6th_Vel_3b_No_NR/Non-Veligers/*/'
tr1= glob(trn1)
tr2= glob(trn2)

# %%
from glob import glob
import cv2
from PIL import Image, ImageStat
import math
trn1='D:/Inv_Data_Imbalance/newdata/To Baylor 2022-02-04/To Baylor 2022-02-04/Davis Dam Preserved Sample 2020-07-24/2022-01-29_6th_Vel_1f_No_NR/Veligers/*/'
trn2='D:/Inv_Data_Imbalance/newdata/To Baylor 2022-02-04/To Baylor 2022-02-04/Davis Dam Preserved Sample 2020-07-24/2022-01-29_6th_Vel_1f_No_NR/Non-Veligers/*/'
tr1= glob(trn1)
tr2= glob(trn2)

# %%
tr1= shuffle(tr1)
tr2= shuffle(tr2)

# %%
tran_index_inv = np.round( len(tr1)* .8  )
tran_index_noninv = np.round( len(tr2)* .8  )
tran_index_noninv
# Out:
# 92.0

# %%
from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Out:
# (25000,)

# %%
data = []
label = []
breath = []
total = 0

for j in tr1[:(int) (tran_index_inv)]:
    label.append(1)
    a = glob(j+'/*')
    breath.append(len(a))
    total = total + len(a)
    
for j in tr2[:(int) (tran_index_noninv)]:
    label.append(0)
    a = glob(j+'/*')
    breath.append(len(a)) 
    total = total + len(a)

for j in range(0,len(tr1[:(int) (tran_index_inv)])):
    a = glob(tr1[j]+'/*')
    for k in range(0,6):
        data.append(a[k])

for j in range(0,len(tr2[:(int) (tran_index_noninv)])):
    a = glob(tr2[j]+'/*')
    for k in range(0,6):
        data.append(a[k])        
        

imgdata=[]
for i in range(len(data)):
    a = Image.open(data[i])
    b = a.resize((15, 15))
    c = np.array(b)
    imgdata.append(c.reshape(15,15,3))
    
from tensorflow.keras.utils import to_categorical
idata = np.array(imgdata)
X_train = idata
X_train = X_train.astype('float32') / 255.
X_train = np.reshape(X_train, (len(X_train),15,15,3))

# %%
end= 0
train_df= []
breath = 6

i = 0
for i in range(0, len(label)):
    deff = []
    for k in range(0, (breath)):
        
        index = (i*6+k)
        
        deff.append(X_train[index])
        
    train_df.append(deff)

Y_train = to_categorical(label)
train_df = np.array(train_df)
train_df,Y_train = shuffle(train_df,Y_train)
np.shape(train_df)
# Out:
# (130, 6, 15, 15, 3)

# %%
data = []
label = []
breath = []
total = 0

for j in tr1[(int) (tran_index_inv) + 1 :]:
    label.append(1)
    a = glob(j+'/*')
    breath.append(len(a))
    total = total + len(a)
    
for j in tr2[ (int)(tran_index_noninv) + 1:]:
    label.append(0)
    a = glob(j+'/*')
    breath.append(len(a)) 
    total = total + len(a)

for j in range(0,len(tr1[(int) (tran_index_inv) + 1 :])):
    a = glob(tr1[j]+'/*')
    for k in range(0,6):
        data.append(a[k])

for j in range(0,len(tr2[ (int)(tran_index_noninv) + 1:])):
    a = glob(tr2[j]+'/*')
    for k in range(0,6):
        data.append(a[k])        
        

imgdata=[]
for i in range(len(data)):
    a = Image.open(data[i])
    b = a.resize((15, 15))
    c = np.array(b)
    imgdata.append(c.reshape(15,15,3))
    
from tensorflow.keras.utils import to_categorical
idata = np.array(imgdata)
X_test = idata
X_test = X_test.astype('float32') / 255.
X_test = np.reshape(X_test, (len(X_test),15,15,3))

# %%
end= 0
test_df= []
breath = 6

i = 0
for i in range(0, len(label)):
    deff = []
    for k in range(0, (breath)):
        
        index = (i*6+k)
        
        deff.append(X_test[index])
        
    test_df.append(deff)
    
Y_test = to_categorical(label)
test_df = np.array(test_df)
test_df,Y_test = shuffle(test_df,Y_test)
np.shape(test_df)
# Out:
# (31, 6, 15, 15, 3)

# %%
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    tn = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1-y_true) * (y_pred), 0, 1)))
    fn = K.sum(K.round(K.clip((y_true) * (1-y_pred), 0, 1)))
    

    f1_val = tp / ( tp + ( (1/2) * (fp+fn) ) + K.epsilon())
    return f1_val

# %%
model = load_model('models/RNN_model.h5')

# %%
#model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics='accuracy')
model.fit(train_df,Y_train,validation_split=0.15,batch_size=32,epochs=150)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 7s 692ms/step - loss: 1.8550 - accuracy: 0.6727 - val_loss: 0.7122 - val_accuracy: 0.7500
# Epoch 2/150
# 4/4 [==============================] - 0s 68ms/step - loss: 1.1242 - accuracy: 0.6545 - val_loss: 0.9547 - val_accuracy: 0.8000
# Epoch 3/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.8187 - accuracy: 0.6636 - val_loss: 0.8258 - val_accuracy: 0.8000
# Epoch 4/150
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6326 - accuracy: 0.7273 - val_loss: 0.4794 - val_accuracy: 0.8500
# Epoch 5/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.5965 - accuracy: 0.6909 - val_loss: 0.4583 - val_accuracy: 0.8500
# Epoch 6/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.5949 - accuracy: 0.6909 - val_loss: 0.5156 - val_accuracy: 0.9000
# Epoch 7/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.5693 - accuracy: 0.6818 - val_loss: 0.5395 - val_accuracy: 0.7000
# Epoch 8/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6085 - accuracy: 0.6818 - val_loss: 0.5337 - val_accuracy: 0.7000
# Epoch 9/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.5753 - accuracy: 0.7000 - val_loss: 0.5178 - val_accuracy: 0.8500
# Epoch 10/150
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5723 - accuracy: 0.7000 - val_loss: 0.5041 - val_accuracy: 0.9000
# Epoch 11/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.5591 - accuracy: 0.7091 - val_loss: 0.5303 - val_accuracy: 0.7500
# Epoch 12/150
# 4/4 [==============================] - 0s 69ms/step - loss: 0.5736 - accuracy: 0.7091 - val_loss: 0.4862 - val_accuracy: 0.9000
# Epoch 13/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.5593 - accuracy: 0.7182 - val_loss: 0.4688 - val_accuracy: 0.9000
# Epoch 14/150
# 4/4 [==============================] - 0s 70ms/step - loss: 0.5631 - accuracy: 0.7000 - val_loss: 0.4752 - val_accuracy: 0.9000
# Epoch 15/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.5580 - accuracy: 0.6909 - val_loss: 0.5349 - val_accuracy: 0.7000
# Epoch 16/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.5677 - accuracy: 0.6909 - val_loss: 0.5442 - val_accuracy: 0.7000
# Epoch 17/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.5582 - accuracy: 0.7273 - val_loss: 0.5014 - val_accuracy: 0.8000
# Epoch 18/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.5680 - accuracy: 0.6818 - val_loss: 0.4665 - val_accuracy: 0.9000
# Epoch 19/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.5616 - accuracy: 0.6818 - val_loss: 0.4436 - val_accuracy: 0.9000
# Epoch 20/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.5534 - accuracy: 0.7000 - val_loss: 0.4591 - val_accuracy: 0.9000
# Epoch 21/150
# 4/4 [==============================] - 0s 69ms/step - loss: 0.5880 - accuracy: 0.7182 - val_loss: 0.4902 - val_accuracy: 0.8500
# Epoch 22/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.5551 - accuracy: 0.6727 - val_loss: 0.5140 - val_accuracy: 0.7500
# Epoch 23/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.5517 - accuracy: 0.7182 - val_loss: 0.5263 - val_accuracy: 0.7500
# Epoch 24/150
# 4/4 [==============================] - 0s 75ms/step - loss: 0.5406 - accuracy: 0.7455 - val_loss: 0.5165 - val_accuracy: 0.7500
# Epoch 25/150
# 4/4 [==============================] - 0s 77ms/step - loss: 0.5453 - accuracy: 0.7000 - val_loss: 0.5075 - val_accuracy: 0.7500
# Epoch 26/150
# 4/4 [==============================] - 0s 72ms/step - loss: 0.5381 - accuracy: 0.7000 - val_loss: 0.5147 - val_accuracy: 0.7500
# Epoch 27/150
# 4/4 [==============================] - 0s 81ms/step - loss: 0.5441 - accuracy: 0.7000 - val_loss: 0.4783 - val_accuracy: 0.8500
# Epoch 28/150
# 4/4 [==============================] - 0s 72ms/step - loss: 0.5309 - accuracy: 0.7000 - val_loss: 0.5115 - val_accuracy: 0.8000
# Epoch 29/150
# 4/4 [==============================] - 0s 89ms/step - loss: 0.5253 - accuracy: 0.7091 - val_loss: 0.5322 - val_accuracy: 0.7000
# Epoch 30/150
# 4/4 [==============================] - 0s 74ms/step - loss: 0.5324 - accuracy: 0.7182 - val_loss: 0.5540 - val_accuracy: 0.7000
# Epoch 31/150
# 4/4 [==============================] - 0s 83ms/step - loss: 0.5417 - accuracy: 0.7000 - val_loss: 0.5041 - val_accuracy: 0.8000
# Epoch 32/150
# 4/4 [==============================] - 0s 88ms/step - loss: 0.5250 - accuracy: 0.7273 - val_loss: 0.4878 - val_accuracy: 0.8500
# Epoch 33/150
# 4/4 [==============================] - 0s 126ms/step - loss: 0.5087 - accuracy: 0.7364 - val_loss: 0.5346 - val_accuracy: 0.7000
# Epoch 34/150
# 4/4 [==============================] - 0s 84ms/step - loss: 0.5407 - accuracy: 0.7000 - val_loss: 0.5732 - val_accuracy: 0.7000
# Epoch 35/150
# 4/4 [==============================] - 0s 91ms/step - loss: 0.5288 - accuracy: 0.7182 - val_loss: 0.5170 - val_accuracy: 0.7500
# Epoch 36/150
# 4/4 [==============================] - 0s 93ms/step - loss: 0.5185 - accuracy: 0.7091 - val_loss: 0.5218 - val_accuracy: 0.7500
# Epoch 37/150
# 4/4 [==============================] - 0s 74ms/step - loss: 0.5173 - accuracy: 0.7273 - val_loss: 0.5256 - val_accuracy: 0.7500
# Epoch 38/150
# 4/4 [==============================] - 0s 74ms/step - loss: 0.5275 - accuracy: 0.7636 - val_loss: 0.5478 - val_accuracy: 0.7000
# Epoch 39/150
# 4/4 [==============================] - 0s 71ms/step - loss: 0.5302 - accuracy: 0.7455 - val_loss: 0.5537 - val_accuracy: 0.7000
# Epoch 40/150
# 4/4 [==============================] - 0s 69ms/step - loss: 0.5251 - accuracy: 0.7091 - val_loss: 0.5353 - val_accuracy: 0.7500
# Epoch 41/150
# 4/4 [==============================] - 0s 80ms/step - loss: 0.5079 - accuracy: 0.7364 - val_loss: 0.5358 - val_accuracy: 0.7500
# Epoch 42/150
# 4/4 [==============================] - 0s 75ms/step - loss: 0.5024 - accuracy: 0.7455 - val_loss: 0.5615 - val_accuracy: 0.7000
# Epoch 43/150
# 4/4 [==============================] - 0s 75ms/step - loss: 0.5339 - accuracy: 0.7091 - val_loss: 0.5273 - val_accuracy: 0.7500
# Epoch 44/150
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5032 - accuracy: 0.7455 - val_loss: 0.5420 - val_accuracy: 0.7000
# Epoch 45/150
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5318 - accuracy: 0.7091 - val_loss: 0.5137 - val_accuracy: 0.7500
# Epoch 46/150
# 4/4 [==============================] - 0s 83ms/step - loss: 0.5083 - accuracy: 0.7545 - val_loss: 0.4852 - val_accuracy: 0.8500
# Epoch 47/150
# 4/4 [==============================] - 0s 72ms/step - loss: 0.5065 - accuracy: 0.7545 - val_loss: 0.5005 - val_accuracy: 0.7500
# Epoch 48/150
# 4/4 [==============================] - 0s 73ms/step - loss: 0.5046 - accuracy: 0.7455 - val_loss: 0.5821 - val_accuracy: 0.6500
# Epoch 49/150
# 4/4 [==============================] - 0s 70ms/step - loss: 0.5282 - accuracy: 0.7545 - val_loss: 0.5213 - val_accuracy: 0.7000
# Epoch 50/150
# 4/4 [==============================] - 0s 71ms/step - loss: 0.4825 - accuracy: 0.7545 - val_loss: 0.5056 - val_accuracy: 0.7500
# Epoch 51/150
# 4/4 [==============================] - 0s 71ms/step - loss: 0.5171 - accuracy: 0.7182 - val_loss: 0.5434 - val_accuracy: 0.6500
# Epoch 52/150
# 4/4 [==============================] - 0s 68ms/step - loss: 0.4979 - accuracy: 0.7909 - val_loss: 0.5583 - val_accuracy: 0.6500
# Epoch 53/150
# 4/4 [==============================] - 0s 69ms/step - loss: 0.4964 - accuracy: 0.7545 - val_loss: 0.5351 - val_accuracy: 0.6500
# Epoch 54/150
# 4/4 [==============================] - 0s 70ms/step - loss: 0.4971 - accuracy: 0.7818 - val_loss: 0.5665 - val_accuracy: 0.6500
# Epoch 55/150
# 4/4 [==============================] - 0s 69ms/step - loss: 0.4849 - accuracy: 0.7364 - val_loss: 0.5370 - val_accuracy: 0.7500
# Epoch 56/150
# 4/4 [==============================] - 0s 71ms/step - loss: 0.5189 - accuracy: 0.7545 - val_loss: 0.6332 - val_accuracy: 0.6000
# Epoch 57/150
# 4/4 [==============================] - 0s 85ms/step - loss: 0.4937 - accuracy: 0.7455 - val_loss: 0.5185 - val_accuracy: 0.7000
# Epoch 58/150
# 4/4 [==============================] - 0s 82ms/step - loss: 0.4798 - accuracy: 0.7818 - val_loss: 0.5637 - val_accuracy: 0.6500
# Epoch 59/150
# 4/4 [==============================] - 0s 74ms/step - loss: 0.4953 - accuracy: 0.7273 - val_loss: 0.5163 - val_accuracy: 0.8000
# Epoch 60/150
# 4/4 [==============================] - 0s 75ms/step - loss: 0.4953 - accuracy: 0.7364 - val_loss: 0.5800 - val_accuracy: 0.6500
# Epoch 61/150
# 4/4 [==============================] - 0s 80ms/step - loss: 0.4760 - accuracy: 0.7636 - val_loss: 0.5879 - val_accuracy: 0.6500
# Epoch 62/150
# 4/4 [==============================] - 0s 79ms/step - loss: 0.4984 - accuracy: 0.7091 - val_loss: 0.4755 - val_accuracy: 0.8000
# Epoch 63/150
# 4/4 [==============================] - 0s 76ms/step - loss: 0.4700 - accuracy: 0.7636 - val_loss: 0.5149 - val_accuracy: 0.8000
# Epoch 64/150
# 4/4 [==============================] - 0s 75ms/step - loss: 0.4862 - accuracy: 0.7727 - val_loss: 0.6053 - val_accuracy: 0.6500
# Epoch 65/150
# 4/4 [==============================] - 0s 80ms/step - loss: 0.4767 - accuracy: 0.7818 - val_loss: 0.5784 - val_accuracy: 0.7000
# Epoch 66/150
# 4/4 [==============================] - 0s 70ms/step - loss: 0.4798 - accuracy: 0.7818 - val_loss: 0.4826 - val_accuracy: 0.8000
# Epoch 67/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.5055 - accuracy: 0.7545 - val_loss: 0.4855 - val_accuracy: 0.8000
# Epoch 68/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4976 - accuracy: 0.7455 - val_loss: 0.5053 - val_accuracy: 0.8000
# Epoch 69/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4595 - accuracy: 0.7909 - val_loss: 0.6122 - val_accuracy: 0.7000
# Epoch 70/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.4636 - accuracy: 0.7636 - val_loss: 0.6066 - val_accuracy: 0.7000
# Epoch 71/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.5070 - accuracy: 0.7455 - val_loss: 0.5190 - val_accuracy: 0.8000
# Epoch 72/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4633 - accuracy: 0.7636 - val_loss: 0.5185 - val_accuracy: 0.8000
# Epoch 73/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4990 - accuracy: 0.7364 - val_loss: 0.5727 - val_accuracy: 0.8000
# Epoch 74/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4877 - accuracy: 0.7727 - val_loss: 0.5350 - val_accuracy: 0.8000
# Epoch 75/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4504 - accuracy: 0.7909 - val_loss: 0.5426 - val_accuracy: 0.8000
# Epoch 76/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4594 - accuracy: 0.7909 - val_loss: 0.5932 - val_accuracy: 0.7000
# Epoch 77/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4445 - accuracy: 0.8091 - val_loss: 0.5413 - val_accuracy: 0.7500
# Epoch 78/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4672 - accuracy: 0.8000 - val_loss: 0.5485 - val_accuracy: 0.8000
# Epoch 79/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.4887 - accuracy: 0.7364 - val_loss: 0.4903 - val_accuracy: 0.8000
# Epoch 80/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4754 - accuracy: 0.7545 - val_loss: 0.4734 - val_accuracy: 0.8000
# Epoch 81/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4801 - accuracy: 0.7545 - val_loss: 0.5113 - val_accuracy: 0.8000
# Epoch 82/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4413 - accuracy: 0.7909 - val_loss: 0.5494 - val_accuracy: 0.7500
# Epoch 83/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4593 - accuracy: 0.8091 - val_loss: 0.5931 - val_accuracy: 0.7500
# Epoch 84/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.4632 - accuracy: 0.7818 - val_loss: 0.5054 - val_accuracy: 0.8000
# Epoch 85/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.4624 - accuracy: 0.7727 - val_loss: 0.4992 - val_accuracy: 0.8000
# Epoch 86/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.4506 - accuracy: 0.8273 - val_loss: 0.5630 - val_accuracy: 0.8000
# Epoch 87/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.4557 - accuracy: 0.7909 - val_loss: 0.5565 - val_accuracy: 0.7500
# Epoch 88/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4597 - accuracy: 0.7636 - val_loss: 0.5446 - val_accuracy: 0.7500
# Epoch 89/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4340 - accuracy: 0.8000 - val_loss: 0.5282 - val_accuracy: 0.7500
# Epoch 90/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4680 - accuracy: 0.7727 - val_loss: 0.5590 - val_accuracy: 0.7500
# Epoch 91/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4645 - accuracy: 0.7455 - val_loss: 0.6036 - val_accuracy: 0.7000
# Epoch 92/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4382 - accuracy: 0.7818 - val_loss: 0.6036 - val_accuracy: 0.7000
# Epoch 93/150
# 4/4 [==============================] - 0s 71ms/step - loss: 0.4209 - accuracy: 0.8182 - val_loss: 0.5779 - val_accuracy: 0.7500
# Epoch 94/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4143 - accuracy: 0.8182 - val_loss: 0.5418 - val_accuracy: 0.7500
# Epoch 95/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4203 - accuracy: 0.8000 - val_loss: 0.6048 - val_accuracy: 0.7500
# Epoch 96/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.4297 - accuracy: 0.8000 - val_loss: 0.6362 - val_accuracy: 0.7500
# Epoch 97/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.4359 - accuracy: 0.8000 - val_loss: 0.6203 - val_accuracy: 0.7500
# Epoch 98/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4058 - accuracy: 0.8364 - val_loss: 0.6211 - val_accuracy: 0.7500
# Epoch 99/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.4548 - accuracy: 0.7727 - val_loss: 0.5871 - val_accuracy: 0.7500
# Epoch 100/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.4469 - accuracy: 0.7909 - val_loss: 0.6205 - val_accuracy: 0.7500
# Epoch 101/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4196 - accuracy: 0.8364 - val_loss: 0.6882 - val_accuracy: 0.6500
# Epoch 102/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4580 - accuracy: 0.7727 - val_loss: 0.6038 - val_accuracy: 0.7000
# Epoch 103/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4077 - accuracy: 0.8091 - val_loss: 0.6113 - val_accuracy: 0.7000
# Epoch 104/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4408 - accuracy: 0.7818 - val_loss: 0.4986 - val_accuracy: 0.8000
# Epoch 105/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4461 - accuracy: 0.8000 - val_loss: 0.6542 - val_accuracy: 0.7000
# Epoch 106/150
# 4/4 [==============================] - 0s 68ms/step - loss: 0.4219 - accuracy: 0.8182 - val_loss: 0.6908 - val_accuracy: 0.7500
# Epoch 107/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.3926 - accuracy: 0.8455 - val_loss: 0.6050 - val_accuracy: 0.8000
# Epoch 108/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4029 - accuracy: 0.8000 - val_loss: 0.5978 - val_accuracy: 0.8000
# Epoch 109/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4050 - accuracy: 0.8000 - val_loss: 0.6475 - val_accuracy: 0.7500
# Epoch 110/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4189 - accuracy: 0.8273 - val_loss: 0.6900 - val_accuracy: 0.7500
# Epoch 111/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3896 - accuracy: 0.8364 - val_loss: 0.6465 - val_accuracy: 0.7500
# Epoch 112/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.3865 - accuracy: 0.8364 - val_loss: 0.6179 - val_accuracy: 0.7500
# Epoch 113/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3954 - accuracy: 0.8364 - val_loss: 0.6881 - val_accuracy: 0.7500
# Epoch 114/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4211 - accuracy: 0.8182 - val_loss: 0.6467 - val_accuracy: 0.7500
# Epoch 115/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4542 - accuracy: 0.7818 - val_loss: 0.6838 - val_accuracy: 0.7500
# Epoch 116/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3951 - accuracy: 0.8091 - val_loss: 0.6133 - val_accuracy: 0.7500
# Epoch 117/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.3847 - accuracy: 0.8182 - val_loss: 0.6607 - val_accuracy: 0.7500
# Epoch 118/150
# 4/4 [==============================] - 0s 72ms/step - loss: 0.4112 - accuracy: 0.8364 - val_loss: 0.7107 - val_accuracy: 0.7000
# Epoch 119/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3840 - accuracy: 0.8273 - val_loss: 0.6875 - val_accuracy: 0.7000
# Epoch 120/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.3780 - accuracy: 0.8545 - val_loss: 0.6897 - val_accuracy: 0.7000
# Epoch 121/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.3701 - accuracy: 0.8364 - val_loss: 0.7123 - val_accuracy: 0.7000
# Epoch 122/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4122 - accuracy: 0.7818 - val_loss: 0.6558 - val_accuracy: 0.8000
# Epoch 123/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4214 - accuracy: 0.8000 - val_loss: 0.6289 - val_accuracy: 0.7000
# Epoch 124/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4034 - accuracy: 0.8091 - val_loss: 0.6777 - val_accuracy: 0.7500
# Epoch 125/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3630 - accuracy: 0.8364 - val_loss: 0.8256 - val_accuracy: 0.7000
# Epoch 126/150
# 4/4 [==============================] - 0s 77ms/step - loss: 0.3864 - accuracy: 0.8455 - val_loss: 0.6125 - val_accuracy: 0.7500
# Epoch 127/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4230 - accuracy: 0.8273 - val_loss: 0.6207 - val_accuracy: 0.7500
# Epoch 128/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.4016 - accuracy: 0.7818 - val_loss: 0.6789 - val_accuracy: 0.7500
# Epoch 129/150
# 4/4 [==============================] - 0s 70ms/step - loss: 0.3901 - accuracy: 0.8000 - val_loss: 0.7997 - val_accuracy: 0.7000
# Epoch 130/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.4155 - accuracy: 0.8000 - val_loss: 0.8037 - val_accuracy: 0.7500
# Epoch 131/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.3667 - accuracy: 0.8545 - val_loss: 0.7142 - val_accuracy: 0.7500
# Epoch 132/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.3753 - accuracy: 0.8273 - val_loss: 0.6995 - val_accuracy: 0.8000
# Epoch 133/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3540 - accuracy: 0.8545 - val_loss: 0.7950 - val_accuracy: 0.7000
# Epoch 134/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.3853 - accuracy: 0.8364 - val_loss: 0.7755 - val_accuracy: 0.7500
# Epoch 135/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.3599 - accuracy: 0.8455 - val_loss: 0.7144 - val_accuracy: 0.7500
# Epoch 136/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.3605 - accuracy: 0.8273 - val_loss: 0.8158 - val_accuracy: 0.7000
# Epoch 137/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3941 - accuracy: 0.8091 - val_loss: 0.8673 - val_accuracy: 0.7000
# Epoch 138/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.3860 - accuracy: 0.8182 - val_loss: 0.7566 - val_accuracy: 0.7000
# Epoch 139/150
# 4/4 [==============================] - 0s 66ms/step - loss: 0.3748 - accuracy: 0.8455 - val_loss: 0.7893 - val_accuracy: 0.7500
# Epoch 140/150
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3857 - accuracy: 0.8364 - val_loss: 0.9107 - val_accuracy: 0.7500
# Epoch 141/150
# 4/4 [==============================] - 0s 68ms/step - loss: 0.3829 - accuracy: 0.8273 - val_loss: 1.0096 - val_accuracy: 0.6500
# Epoch 142/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.4175 - accuracy: 0.8091 - val_loss: 0.7902 - val_accuracy: 0.7500
# Epoch 143/150
# 4/4 [==============================] - 0s 60ms/step - loss: 0.3725 - accuracy: 0.8364 - val_loss: 0.7699 - val_accuracy: 0.7500
# Epoch 144/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.3761 - accuracy: 0.8182 - val_loss: 0.9006 - val_accuracy: 0.7500
# Epoch 145/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3685 - accuracy: 0.8455 - val_loss: 0.9585 - val_accuracy: 0.7000
# Epoch 146/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3573 - accuracy: 0.8273 - val_loss: 0.9064 - val_accuracy: 0.7500
# Epoch 147/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.3580 - accuracy: 0.8636 - val_loss: 0.8274 - val_accuracy: 0.7000
# Epoch 148/150
# 4/4 [==============================] - 0s 61ms/step - loss: 0.3759 - accuracy: 0.8182 - val_loss: 0.8894 - val_accuracy: 0.7500
# Epoch 149/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3402 - accuracy: 0.8818 - val_loss: 0.9532 - val_accuracy: 0.7000
# Epoch 150/150
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3564 - accuracy: 0.8273 - val_loss: 0.9010 - val_accuracy: 0.7000

# %%
Y_test = Y_test
pred = model.predict(test_df)
p = np.round(pred)
f1 = get_f1(Y_test, p)
f1

y_p = []
for i in range(len(p)):
    if ( p[i][0] == 0 ):
        y_p.append(1)
    else :
        y_p.append(0)
y_p = np.array(y_p)
y_t = []
for i in range(len(Y_test)):
    if ( Y_test[i][0] == 0 ):
        y_t.append(1)
    else :
        y_t.append(0)
y_t = np.array(y_t)

from sklearn.metrics import confusion_matrix
a=(confusion_matrix(y_t, y_p , labels=[0,1]))
a.T
# Out:
# array([[18,  5],
#        [ 4,  4]], dtype=int64)

# %%
f1
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.7096774>

# %%
from keras.models import load_model

model.save('models/RNN_model1.h5')

# %%
model = Sequential()
model.add(LSTM(5, input_shape = (10, 20), return_sequences = True))
model.add((Dense(1)))
print(model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 10, 5)             520
# _________________________________________________________________
# dense_11 (Dense)             (None, 10, 1)             6
# =================================================================
# Total params: 526
# Trainable params: 526
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model = Sequential()
model.add(LSTM(5, input_shape = (10, 20), return_sequences = True))
model.add(TimeDistributed(Dense(1)))
print(model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 10, 5)             520
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 10, 1)             6
# =================================================================
# Total params: 526
# Trainable params: 526
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.models import load_model

model.save('TimeDist30.h5')
