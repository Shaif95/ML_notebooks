# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [10, 40, 80]

# Define y-axis data (accuracy) for both lines
y1 = [ 32.5 , 37.41, 42.3]

y2 = [ 20.5 , 29.7, 34.5]

y3 = [ 18.3 , 27.8, 34.7]

y4 = [ 21.8, 27.3, 32.9]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)
ax.plot(x, y3, label="Entropy", color="black", linestyle="-.", linewidth=2, marker='o', markersize=8)
ax.plot(x, y4, label="CONF", color="red", linestyle=":", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title(" CIFAR100 results with variable AL annotation Budget : Accuracy vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [5, 10, 30, 40]

# Define y-axis data (accuracy) for both lines
y1 = [ 73.5 , 74.34, 78.7, 79.5]

y2 = [ 70.16 , 70.59, 73.2, 73.8]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title(" CIFAR10 results with variable initial labelled set : Accuracy vs. Base Set", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [20, 30, 60]

# Define y-axis data (accuracy) for both lines
y1 = [ 30.5, 32.15, 35.7]

y2 = [ 28.5 , 30.1, 32.9]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Tiny ImageNet results with variable AL annotation Budget : Accuracy vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [10, 40]

# Define y-axis data (accuracy) for both lines
y1 = [ 46.12 , 50.9]

y2 = [ 44.58 , 46.88]

y3 = [ 45.8 , 50.05]

y4 = [ 42.66 , 42.42]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)
ax.plot(x, y3, label="Entropy", color="black", linestyle="-.", linewidth=2, marker='o', markersize=8)
ax.plot(x, y4, label="CONF", color="red", linestyle=":", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title(" Caltech101 results with variable AL annotation Budget : Accuracy vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [5, 20, 40, 70, 90]

# Define y-axis data (accuracy) for both lines
y1 = [ 62.5 , 69.81, 71.1, 75.13, 79.1]

y2 = [ 59.14 , 65.4, 67.81, 71.03, 73.7]

y3 = [ 52.78 , 58.47, 65.34, 71.37, 73.2]

y4 = [ 39.8, 53.8 , 63.13, 71.57, 74.1]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)
ax.plot(x, y3, label="Entropy", color="black", linestyle="-.", linewidth=2, marker='o', markersize=8)
ax.plot(x, y4, label="CONF", color="red", linestyle=":", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title(" CIFAR10 results with variable AL annotation Budget : Accuracy vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [10, 20]

# Define y-axis data (accuracy) for both lines
y1 = [  87.3, 88.32]

y2 = [  87.1, 87.4]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Fashion-MNIST results with variable AL annotation Budget : Accuracy vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [10, 20]

# Define y-axis data (accuracy) for both lines
y1 = [  95.722  , 96.418]

y2 = [  97.443 , 97.570]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Results with different AL annotation Budget :  F1 vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [10, 20]

# Define y-axis data (accuracy) for both lines
y1 = [  90.558 , 92.148]

y2 = [  94.711 , 94.881]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
ax.plot(x, y1, label="Our Method", color="blue", linestyle="-", linewidth=2, marker='o', markersize=8)
ax.plot(x, y2, label="RAND", color="orange", linestyle="--", linewidth=2, marker='s', markersize=8)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Results with different AL annotation Budget : Invasive F1 vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
import json

import glob
import random
import collections
from glob import glob
import numpy as np
import pandas as pd

#import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import shutil
import keras
from PIL import Image
#import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
import json
import tensorflow as tf 
from keras.layers import Input
from keras import Sequential
from keras.layers import Dense, LSTM,Flatten, TimeDistributed, Conv2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

from keras.models import load_model
from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D,Reshape, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten, UpSampling2D
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import pandas as pd

from skimage.io import imread
from skimage.transform import resize
from keras import layers
from keras import models
import keras
from keras.layers import LeakyReLU
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dense, Dropout, Activation, Flatten
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from keras.callbacks import Callback,ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K

import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import Lambda, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras import Input
from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization
from keras import models
AUTO = tf.data.AUTOTUNE
from sklearn.metrics import confusion_matrix
import random

AUTO = tf.data.AUTOTUNE
BATCH_SIZE = 32
EPOCHS = 50
CROP_TO = 32
SEED = 26

PROJECT_DIM = 128
LATENT_DIM = 512
WEIGHT_DECAY = 0.0005
learning_rate = 0.0001
batch_size = 128
hidden_units = 512
projection_units = 256
num_epochs = 2
dropout_rate = 0.5

temperature = 0.05

import glob

# Invasive category
invasive_dirs = [ r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Umbonal',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Preserved Zebra D-Hinge 1 Baylor\Preserved Zebra D-Hinge 1 Baylor\Sorted Images\Zebra D-Hinge',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Umbonal'
]

# Non-Invasive category
non_invasive_dirs = [
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1 Image1\Baylor Preserved Zebra Umbo 1 Image1\Sorted Images\Not',
    r'D:\VeligerData\USGS Labled Zebra\USGS Labled Zebra\Baylor Preserved Zebra Umbo 1a Image1\Baylor Preserved Zebra Umbo 1a Image1\Sorted Images\Not'
]


# List to store subdirectories
invasive_subdirs = []
non_invasive_subdirs = []

# Collect subdirectories in the invasive category
for invasive_dir in invasive_dirs:
    invasive_subdirs.extend(glob.glob(invasive_dir))

# Collect subdirectories in the non-invasive category
for non_invasive_dir in non_invasive_dirs:
    non_invasive_subdirs.extend(glob.glob(non_invasive_dir))

# %%
import glob

# List of directories in x
x = non_invasive_subdirs

# List to store subdirectories
y1 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y1.extend(subdirectories)

import glob

# List of directories in x
x = invasive_subdirs

# List to store subdirectories
y2 = []

# Read subdirectories for each directory in x
for directory in x:
    subdirectories = glob.glob(directory + r'\*')
    y2.extend(subdirectories)

    
import os
import numpy as np
import tensorflow as tf
from PIL import Image

def preprocess_images(y1, label_num, target_size=(32, 32)):
    # List to store image files
    image_files = []
    # List to store labels
    labels = []

    # Retrieve image files and create labels for each directory in y1
    for directory in y1:
        for root, dirs, files in os.walk(directory):
            for file in files:
                # Check if the file has an image extension
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    # Add the file path to the image_files list
                    image_files.append(os.path.join(root, file))
                    # Add the label to the labels list
                    

    # List to store preprocessed images
    images = []

    # Preprocess each image
    for file in image_files:
        try:
            # Read the image using PIL
            image1 = Image.open(file)
            # Resize the image using tf.image.resize_with_crop_or_pad()
            image = image1.resize((32, 32), Image.ANTIALIAS)
            # Normalize the image pixels for ML training
            image = np.array(image) / 255.0
            # Add the preprocessed image to the images list
            images.append(image)
            labels.append(label_num)
        except Exception as e:
            print(f"Error processing image: {file}. Skipping...")
            continue

    # Convert the images and labels lists to numpy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels


X0,Y0 = preprocess_images(y1, label_num = 0)
X1,Y1 = preprocess_images(y2, label_num = 1)
# Out:
# C:\Users\shaif\AppData\Local\Temp\ipykernel_1856\1499657477.py:59: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   image = image1.resize((32, 32), Image.ANTIALIAS)

# %%
np.shape(X1)
# Out:
# (3640, 32, 32, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Replace X0 and X1 with your actual data
# Assuming X0 and X1 are numpy arrays containing images

# Generate random indices to select images
num_images_to_display = 10
random_indices_x0 = np.random.choice(range(len(X0)), num_images_to_display, replace=False)
random_indices_x1 = np.random.choice(range(len(X1)), num_images_to_display, replace=False)

# Create subplots
fig, axes = plt.subplots(2, num_images_to_display, figsize=(18, 6))

# Display images from X0
for i, idx in enumerate(random_indices_x0):
    axes[0, i].imshow(X0[idx])
    axes[0, i].axis('off')

# Display images from X1
for i, idx in enumerate(random_indices_x1):
    axes[1, i].imshow(X1[idx])
    axes[1, i].axis('off')

# Adjust layout
plt.tight_layout()

# Save or display the plot
plt.savefig('cvpr_images.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [5, 20, 40, 70, 90]

# Define y-axis data (accuracy) for all lines
y1_values = [62.5, 69.81, 71.1, 75.13, 79.1]
y1_errors = [0.48, 0.55, 0.51, 0.75, 1.48]

y2_values = [59.14, 65.4, 67.81, 71.03, 73.7]
y2_errors = [0.48, 0.65, 0.71, 0.95, 1.28]

y3_values = [52.78, 58.47, 65.34, 71.37, 73.2]
y3_errors = [0.35, 0.79, 0.87, 0.88, 0.9]

y4_values = [39.8, 53.8, 63.13, 71.57, 74.1]
y4_errors = [0.45, 0.72, 0.78, 1.08, 1.3]

y5_values = [62.8, 68.3, 68.9, 73.1, 75.5]
y5_errors = [0.52, 0.58, 0.62, 0.79, 1.21]

y6_values = [61.5, 67.81, 69.2, 72.13, 78.2]
y6_errors = [0.56, 0.61, 0.65, 0.82, 1.02]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
line1, = ax.plot(x, y1_values, label="Our Method", color="blue", linestyle="-", linewidth=1, marker='o', markersize=6)
line2, = ax.plot(x, y2_values, label="RAND", color="orange", linestyle="--", linewidth=1, marker='s', markersize=6)
line3, = ax.plot(x, y3_values, label="Entropy", color="black", linestyle="-.", linewidth=1, marker='o', markersize=6)
line4, = ax.plot(x, y4_values, label="CONF", color="red", linestyle=":", linewidth=1, marker='s', markersize=6)
line5, = ax.plot(x, y5_values, label="CORE-SET", color="green", linestyle="-", linewidth=1, marker='^', markersize=6)
line6, = ax.plot(x, y6_values, label="RND(CLR)", color="purple", linestyle="--", linewidth=1, marker='d', markersize=6)

# Fill between lines and error ranges
ax.fill_between(x, [y - e for y, e in zip(y1_values, y1_errors)], [y + e for y, e in zip(y1_values, y1_errors)], color='blue', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y2_values, y2_errors)], [y + e for y, e in zip(y2_values, y2_errors)], color='orange', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y3_values, y3_errors)], [y + e for y, e in zip(y3_values, y3_errors)], color='black', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y4_values, y4_errors)], [y + e for y, e in zip(y4_values, y4_errors)], color='red', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y5_values, y5_errors)], [y + e for y, e in zip(y5_values, y5_errors)], color='green', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y6_values, y6_errors)], [y + e for y, e in zip(y6_values, y6_errors)], color='purple', alpha=0.1)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(handles=[line1, line2, line3, line4, line5, line6], fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("CIFAR10 results with variable AL annotation Budget : Accuracy vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [10, 40, 80]

# Define y-axis data (accuracy) for all lines
y1_values = [ 32.5 , 37.41, 42.3]
y1_errors = [0.48, 0.75, 1.48]

y2_values = [ 20.5 , 29.7, 34.5]
y2_errors = [0.48, 0.65, 0.95]

y3_values = [ 18.3 , 27.8, 34.7]
y3_errors = [0.35, 0.88, 0.9]

y4_values = [ 21.8, 27.3, 32.9]
y4_errors = [0.45, 1.08, 1.3]

y5_values = [62.8, 68.3, 68.9, 73.1, 75.5]
y5_errors = [0.52, 0.58, 0.62, 0.79, 1.21]

y6_values = [61.5, 67.81, 69.2, 72.13, 78.2]
y6_errors = [0.56, 0.61, 0.65, 0.82, 1.02]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
line1, = ax.plot(x, y1_values, label="Our Method", color="blue", linestyle="-", linewidth=1, marker='o', markersize=6)
line2, = ax.plot(x, y2_values, label="RAND", color="orange", linestyle="--", linewidth=1, marker='s', markersize=6)
line3, = ax.plot(x, y3_values, label="Entropy", color="black", linestyle="-.", linewidth=1, marker='o', markersize=6)
line4, = ax.plot(x, y4_values, label="CONF", color="red", linestyle=":", linewidth=1, marker='s', markersize=6)
#line5, = ax.plot(x, y5_values, label="CORE-SET", color="green", linestyle="-", linewidth=1, marker='^', markersize=6)
#line6, = ax.plot(x, y6_values, label="RND(CLR)", color="purple", linestyle="--", linewidth=1, marker='d', markersize=6)

# Fill between lines and error ranges
ax.fill_between(x, [y - e for y, e in zip(y1_values, y1_errors)], [y + e for y, e in zip(y1_values, y1_errors)], color='blue', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y2_values, y2_errors)], [y + e for y, e in zip(y2_values, y2_errors)], color='orange', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y3_values, y3_errors)], [y + e for y, e in zip(y3_values, y3_errors)], color='black', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y4_values, y4_errors)], [y + e for y, e in zip(y4_values, y4_errors)], color='red', alpha=0.1)
#ax.fill_between(x, [y - e for y, e in zip(y5_values, y5_errors)], [y + e for y, e in zip(y5_values, y5_errors)], color='green', alpha=0.1)
#ax.fill_between(x, [y - e for y, e in zip(y6_values, y6_errors)], [y + e for y, e in zip(y6_values, y6_errors)], color='purple', alpha=0.1)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Annotation Budget as a Percent of Dataset Size", fontsize=12)
ax.set_ylabel("Accuracy", fontsize=12)
ax.legend(handles=[line1, line2, line3, line4], fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("CIFAR100 results with variable AL annotation Budget : Accuracy vs. Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [1500, 3500, 7000]

# Define y-axis data (accuracy) for all lines
y1_values =  [88.278, 90.641, 92.227]
y1_errors =  [0.48, 0.85, 1.20]

y2_values = [61.127, 86.691, 88.475]
y2_errors = [0.68, 0.85, 1.31]

y3_values =  [73.492, 81.743, 82.02]
y3_errors =  [0.58, 0.95, 1.71] 

y4_values = [73.892, 83.6624, 85.866]
y4_errors = [0.65, 1.11, 1.37]

y5_values = [73.769, 87.7878, 90.085]
y5_errors = [0.32, 0.88, 1.62]

y6_values = [89.035, 88.846, 90.827]
y6_errors = [0.56, 1.11, 0.95]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
line1, = ax.plot(x, y1_values, label="Our Method", color="blue", linestyle="-", linewidth=1, marker='o', markersize=6)
line2, = ax.plot(x, y2_values, label="RAND", color="orange", linestyle="--", linewidth=1, marker='s', markersize=6)
line3, = ax.plot(x, y3_values, label="Entropy", color="black", linestyle="-.", linewidth=1, marker='o', markersize=6)
line4, = ax.plot(x, y4_values, label="CONF", color="red", linestyle=":", linewidth=1, marker='s', markersize=6)
line5, = ax.plot(x, y5_values, label="CORE-SET", color="green", linestyle="-", linewidth=1, marker='^', markersize=6)
line6, = ax.plot(x, y6_values, label="RND(CLR)", color="purple", linestyle="--", linewidth=1, marker='d', markersize=6)

# Fill between lines and error ranges
ax.fill_between(x, [y - e for y, e in zip(y1_values, y1_errors)], [y + e for y, e in zip(y1_values, y1_errors)], color='blue', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y2_values, y2_errors)], [y + e for y, e in zip(y2_values, y2_errors)], color='orange', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y3_values, y3_errors)], [y + e for y, e in zip(y3_values, y3_errors)], color='black', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y4_values, y4_errors)], [y + e for y, e in zip(y4_values, y4_errors)], color='red', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y5_values, y5_errors)], [y + e for y, e in zip(y5_values, y5_errors)], color='green', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y6_values, y6_errors)], [y + e for y, e in zip(y6_values, y6_errors)], color='purple', alpha=0.1)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Size of Initial Base-set", fontsize=12)
ax.set_ylabel("Invasive F1 Score", fontsize=12)
ax.legend(handles=[line1, line2, line3, line4, line5, line6], fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Aquatic Invasive Species results with variable initial labeled set : Inv_F1 vs Initial Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [200, 500, 2000]

# Define y-axis data (accuracy) for all lines
y1_values =  [88.278, 90.641, 92.227]
y1_errors =  [0.48, 0.85, 1.20]

y2_values = [61.127, 86.691, 88.475]
y2_errors = [0.68, 0.85, 1.31]

y3_values =  [73.492, 81.743, 82.02]
y3_errors =  [0.58, 0.95, 1.71] 

y4_values = [73.892, 83.6624, 85.866]
y4_errors = [0.65, 1.11, 1.37]

y5_values = [73.769, 87.7878, 90.085]
y5_errors = [0.32, 0.88, 1.62]

y6_values = [89.035, 88.846, 90.827]
y6_errors = [0.56, 1.11, 0.95]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
line1, = ax.plot(x, y1_values, label="Our Method", color="blue", linestyle="-", linewidth=1, marker='o', markersize=6)
line2, = ax.plot(x, y2_values, label="RAND", color="orange", linestyle="--", linewidth=1, marker='s', markersize=6)
line3, = ax.plot(x, y3_values, label="Entropy", color="black", linestyle="-.", linewidth=1, marker='o', markersize=6)
line4, = ax.plot(x, y4_values, label="CONF", color="red", linestyle=":", linewidth=1, marker='s', markersize=6)
line5, = ax.plot(x, y5_values, label="CORE-SET", color="green", linestyle="-", linewidth=1, marker='^', markersize=6)
line6, = ax.plot(x, y6_values, label="RND(CLR)", color="purple", linestyle="--", linewidth=1, marker='d', markersize=6)

# Fill between lines and error ranges
ax.fill_between(x, [y - e for y, e in zip(y1_values, y1_errors)], [y + e for y, e in zip(y1_values, y1_errors)], color='blue', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y2_values, y2_errors)], [y + e for y, e in zip(y2_values, y2_errors)], color='orange', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y3_values, y3_errors)], [y + e for y, e in zip(y3_values, y3_errors)], color='black', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y4_values, y4_errors)], [y + e for y, e in zip(y4_values, y4_errors)], color='red', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y5_values, y5_errors)], [y + e for y, e in zip(y5_values, y5_errors)], color='green', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y6_values, y6_errors)], [y + e for y, e in zip(y6_values, y6_errors)], color='purple', alpha=0.1)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Size of Initial Base-set", fontsize=12)
ax.set_ylabel("Invasive F1 Score", fontsize=12)
ax.legend(handles=[line1, line2, line3, line4, line5, line6], fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Aquatic Invasive Species results with variable initial labeled set : Inv_F1 vs Initial Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [100, 200, 500, 2000]

# Define y-axis data (accuracy) for all lines
y1_values =  [78.58, 82.76, 84.59, 89.29]
y1_errors =  [2.05, 2.10, 1.85, 1.94]

y2_values = [51.12, 73.88, 79.1, 83.62]
y2_errors = [2.02, 2.13, 2.45, 2.45]

y3_values = [47.54, 60.4, 63.84, 67.89]
y3_errors = [2.75, 2.07, 0.90, 2.25]

y4_values = [46.09, 56.71, 69.78, 80.17]
y4_errors = [2.82, 2.92, 1.87, 2.37]

y5_values = [56.21, 59.73, 62.3, 69.42]
y5_errors = [1.95, 2.65, 1.97, 2.41]

y6_values = [65, 72.47, 81.46, 90.21]
y6_errors = [2.85, 3.04, 2.83, 2.56]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
line1, = ax.plot(x, y1_values, label="Our Method", color="blue", linestyle="-", linewidth=1, marker='o', markersize=6)
line2, = ax.plot(x, y2_values, label="RAND", color="orange", linestyle="--", linewidth=1, marker='s', markersize=6)
line3, = ax.plot(x, y3_values, label="Entropy", color="black", linestyle="-.", linewidth=1, marker='o', markersize=6)
line4, = ax.plot(x, y4_values, label="CONF", color="red", linestyle=":", linewidth=1, marker='s', markersize=6)
line5, = ax.plot(x, y5_values, label="CORE-SET", color="green", linestyle="-", linewidth=1, marker='^', markersize=6)
line6, = ax.plot(x, y6_values, label="RND(CLR)", color="purple", linestyle="--", linewidth=1, marker='d', markersize=6)

# Fill between lines and error ranges
ax.fill_between(x, [y - e for y, e in zip(y1_values, y1_errors)], [y + e for y, e in zip(y1_values, y1_errors)], color='blue', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y2_values, y2_errors)], [y + e for y, e in zip(y2_values, y2_errors)], color='orange', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y3_values, y3_errors)], [y + e for y, e in zip(y3_values, y3_errors)], color='black', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y4_values, y4_errors)], [y + e for y, e in zip(y4_values, y4_errors)], color='red', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y5_values, y5_errors)], [y + e for y, e in zip(y5_values, y5_errors)], color='green', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y6_values, y6_errors)], [y + e for y, e in zip(y6_values, y6_errors)], color='purple', alpha=0.1)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Size of AL BUdget", fontsize=12)
ax.set_ylabel("BAC Score", fontsize=12)
ax.legend(handles=[line1, line2, line3, line4, line5, line6], fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Aquatic Invasive Species results with variable initial labeled set : BAC vs Initial Budget", fontsize=14)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis data (annotation budget)
x = [100, 200, 500, 2000]

# Define y-axis data (accuracy) for all lines
y1_values =  [67.39,68.71,77.67,85.22]
y1_errors =  [2.45, 1.85, 0.90, 2.42]

y2_values = [27.19,59.15,60,66.82]
y2_errors = [2.3, 2.47, 1.75, 0.98]

y3_values = [10.2,41.9,43.84,57.89]
y3_errors = [3.5, 2.65, 1.85, 3.10]

y4_values = [7.23,29.72,50.78,64.69]
y4_errors = [3.05, 3.35, 1.75, 2.45]

y5_values = [14.52,31.25,34.87,50.27]
y5_errors = [2.05, 2.45, 1.75, 1.95]

y6_values = [60.53, 62.86,74.67,85.87]
y6_errors = [1.75, 2.85, 3.05, 2.20]

# Create the plot
fig, ax = plt.subplots()

# Plot the lines with different colors and line styles
line1, = ax.plot(x, y1_values, label="Our Method", color="blue", linestyle="-", linewidth=1, marker='o', markersize=6)
line2, = ax.plot(x, y2_values, label="RAND", color="orange", linestyle="--", linewidth=1, marker='s', markersize=6)
line3, = ax.plot(x, y3_values, label="Entropy", color="black", linestyle="-.", linewidth=1, marker='o', markersize=6)
line4, = ax.plot(x, y4_values, label="CONF", color="red", linestyle=":", linewidth=1, marker='s', markersize=6)
line5, = ax.plot(x, y5_values, label="CORE-SET", color="green", linestyle="-", linewidth=1, marker='^', markersize=6)
line6, = ax.plot(x, y6_values, label="RND(CLR)", color="purple", linestyle="--", linewidth=1, marker='d', markersize=6)

# Fill between lines and error ranges
ax.fill_between(x, [y - e for y, e in zip(y1_values, y1_errors)], [y + e for y, e in zip(y1_values, y1_errors)], color='blue', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y2_values, y2_errors)], [y + e for y, e in zip(y2_values, y2_errors)], color='orange', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y3_values, y3_errors)], [y + e for y, e in zip(y3_values, y3_errors)], color='black', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y4_values, y4_errors)], [y + e for y, e in zip(y4_values, y4_errors)], color='red', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y5_values, y5_errors)], [y + e for y, e in zip(y5_values, y5_errors)], color='green', alpha=0.1)
ax.fill_between(x, [y - e for y, e in zip(y6_values, y6_errors)], [y + e for y, e in zip(y6_values, y6_errors)], color='purple', alpha=0.1)

# Set labels for x-axis, y-axis, and legend
ax.set_xlabel("Size of AL BUdget", fontsize=12)
ax.set_ylabel("Invasive F1 Score", fontsize=12)
ax.legend(handles=[line1, line2, line3, line4, line5, line6], fontsize=10)

# Set grid and background color
ax.grid(True)
ax.set_facecolor('whitesmoke')

# Set title
ax.set_title("Aquatic Invasive Species results with variable annotation budget : F1-INV vs Initial Budget", fontsize=14)

# Display the plot
plt.show()
